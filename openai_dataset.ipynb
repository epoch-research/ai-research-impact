# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bs4 import BeautifulSoup
import datetime
import os
import pickle
import pyalex
from pyalex import Authors, Works
import requests

from research_impact.processors import OpenAlexProcessor
from research_impact.pyalex_utils import merge_pages

# %%
# The polite pool has much faster and more consistent response times. To get into the polite pool, you set your email:
pyalex.config.email = "ben@epochai.org"

# %%
data_file_location = "data/"
os.makedirs(data_file_location, exist_ok=True)

# %% [markdown]
# # Extract additional OpenAI works based on the Research webpage

# %%
def extract_urls(html_folder, html_filename, page_number):
    with open(html_folder + html_filename + str(page_number) + ".html", 'r') as f:
        text = f.read()
    
    soup = BeautifulSoup(text, 'html.parser')

    # Find the specific unordered list
    ul = soup.find('ul', {'aria-labelledby': 'feedHeading'})

    urls = []

    # If the unordered list was found, find all 'a' tags within it
    if ul:
        for link in ul.find_all('a'):
            href = link.get('href')
            if href.startswith('http'):
                urls.append(href)
                # print(href)

    return urls

# %%
def extract_title(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Try to get title from the <title> tag
    title_tag = soup.find('title')
    if title_tag:
        return title_tag.text

    # If no <title> tag, try <h1> through <h6>
    for i in range(1, 7):
        header_tag = soup.find(f'h{i}')
        if header_tag:
            return header_tag.text

    # If no title or header tags found, return None
    return None

# %%
extract_urls("data/openai/", "openai_research_index_page_", 7)
# Out:
# ['https://arxiv.org/abs/1706.01905',
#  'https://arxiv.org/abs/1707.06347',
#  'https://arxiv.org/abs/1707.07397',
#  'https://arxiv.org/abs/1707.01495',
#  'https://arxiv.org/abs/1707.00183',
#  'https://arxiv.org/abs/1706.03741',
#  'https://arxiv.org/abs/1706.02275',
#  'https://arxiv.org/abs/1706.01502',
#  'https://arxiv.org/abs/1704.06440',
#  'https://arxiv.org/abs/1704.03012',
#  'https://arxiv.org/abs/1704.01444',
#  'https://arxiv.org/abs/1703.03864',
#  'https://arxiv.org/abs/1703.07326']

# %%
html_folder = "data/openai/"
html_filename = "openai_research_index_page_"

# %%
openai_research_urls = []
for page in range(1, 9 + 1):
    page_urls = extract_urls(html_folder, html_filename, page)
    print(len(page_urls))
    openai_research_urls.extend(page_urls)
len(openai_research_urls)
# Out:
# 17
# 15
# 18
# 16
# 15
# 14
# 13
# 14
# 3
# 125

# %%
openai_research_urls
# Out:
# ['https://arxiv.org/abs/2307.03718',
#  'https://arxiv.org/abs/2305.20050',
#  'https://openaipublic.blob.core.windows.net/neuron-explainer/paper/index.html',
#  'https://arxiv.org/abs/2303.10130',
#  'https://arxiv.org/abs/2303.08774',
#  'https://arxiv.org/abs/2301.04246',
#  'https://arxiv.org/abs/2212.08751',
#  'https://arxiv.org/abs/2210.10760',
#  'https://cdn.openai.com/papers/whisper.pdf',
#  'https://arxiv.org/abs/2207.14255',
#  'https://arxiv.org/abs/2207.14157',
#  'https://arxiv.org/abs/2206.11795',
#  'https://arxiv.org/abs/2206.08896',
#  'https://arxiv.org/abs/2206.05802',
#  'https://arxiv.org/abs/2205.14334',
#  'https://arxiv.org/abs/2204.06125',
#  'https://cdn.openai.com/papers/Economic_Impacts_Research_Agenda.pdf',
#  'https://arxiv.org/abs/2202.01344',
#  'https://arxiv.org/abs/2203.02155',
#  'https://arxiv.org/abs/2201.10005',
#  'https://arxiv.org/abs/2112.09332',
#  'http://arxiv.org/abs/2110.14168',
#  'https://arxiv.org/abs/2109.07958',
#  'https://arxiv.org/abs/2107.03374',
#  'https://cdn.openai.com/palms.pdf',
#  'https://distill.pub/2021/multimodal-neurons/',
#  'https://arxiv.org/abs/2102.02503',
#  'https://arxiv.org/abs/2103.00020',
#  'https://arxiv.org/abs/2009.03393',
#  'https://arxiv.org/abs/2009.01325',
#  'https://cdn.openai.com/papers/Generative_Pretraining_from_Pixels_V2.pdf',
#  'https://arxiv.org/abs/2005.14165',
#  'https://arxiv.org/abs/2005.04305',
#  'https://arxiv.org/abs/2005.00341',
#  'https://arxiv.org/abs/2004.07213',
#  'https://arxiv.org/abs/2001.08361',
#  'https://arxiv.org/abs/1912.06680',
#  'https://arxiv.org/abs/1912.02292',
#  'https://arxiv.org/abs/1912.01588',
#  'https://cdn.openai.com/safexp-short.pdf',
#  'https://cdn.openai.com/safexp-short.pdf',
#  'https://arxiv.org/abs/1908.09203',
#  'https://arxiv.org/abs/1910.07113',
#  'https://arxiv.org/abs/1909.08593',
#  'https://arxiv.org/abs/1909.07528',
#  'http://arxiv.org/abs/1908.08016',
#  'https://arxiv.org/abs/1908.09203',
#  'http://arxiv.org/abs/1907.04534',
#  'https://arxiv.org/abs/1905.01034',
#  'https://arxiv.org/abs/1904.10509',
#  'http://arxiv.org/abs/1903.08689',
#  'https://distill.pub/2019/activation-atlas/',
#  'http://arxiv.org/abs/1903.00784',
#  'https://distill.pub/2019/safety-needs-social-scientists',
#  'https://cdn.openai.com/better-language-models/language_models_are_unsupervised_multitask_learners.pdf',
#  'https://arxiv.org/abs/1902.01086',
#  'https://arxiv.org/pdf/1812.06162.pdf',
#  'https://arxiv.org/abs/1812.02341',
#  'https://arxiv.org/abs/1811.02486',
#  'https://arxiv.org/abs/1811.01848',
#  'https://arxiv.org/abs/1810.12894',
#  'https://arxiv.org/abs/1810.08575',
#  'https://arxiv.org/abs/1810.01367',
#  'https://arxiv.org/abs/1808.04355',
#  'https://arxiv.org/abs/1808.00177',
#  'https://arxiv.org/abs/1807.10299',
#  'https://arxiv.org/abs/1807.03039',
#  'https://arxiv.org/abs/1806.06464',
#  'https://cdn.openai.com/research-covers/language-unsupervised/language_understanding_paper.pdf',
#  'https://arxiv.org/abs/1806.00608',
#  'https://arxiv.org/abs/1805.00899',
#  'https://arxiv.org/abs/1802.04821',
#  'https://arxiv.org/abs/1804.03720',
#  'https://arxiv.org/abs/1804.03720',
#  'https://arxiv.org/abs/1803.07246',
#  'https://arxiv.org/abs/1803.05573',
#  'https://arxiv.org/abs/1803.02999',
#  'https://arxiv.org/abs/1803.02999',
#  'https://arxiv.org/abs/1803.01118',
#  'https://arxiv.org/abs/1802.09464',
#  'https://arxiv.org/abs/1802.09464',
#  'https://arxiv.org/abs/1802.07228',
#  'https://arxiv.org/abs/1711.00694',
#  'https://arxiv.org/abs/1802.01021',
#  'https://cdn.openai.com/blocksparse/blocksparsepaper.pdf',
#  'https://arxiv.org/abs/1712.01312',
#  'https://arxiv.org/abs/1711.00694',
#  'https://arxiv.org/abs/1710.09767',
#  'https://arxiv.org/abs/1710.06537',
#  'https://arxiv.org/abs/1710.06425',
#  'https://arxiv.org/abs/1710.03641',
#  'https://arxiv.org/abs/1710.03748',
#  'https://arxiv.org/abs/1709.04326',
#  'https://arxiv.org/abs/1709.04326',
#  'https://arxiv.org/abs/1708.05144',
#  'https://arxiv.org/abs/1706.01905',
#  'https://arxiv.org/abs/1707.06347',
#  'https://arxiv.org/abs/1707.07397',
#  'https://arxiv.org/abs/1707.01495',
#  'https://arxiv.org/abs/1707.00183',
#  'https://arxiv.org/abs/1706.03741',
#  'https://arxiv.org/abs/1706.02275',
#  'https://arxiv.org/abs/1706.01502',
#  'https://arxiv.org/abs/1704.06440',
#  'https://arxiv.org/abs/1704.03012',
#  'https://arxiv.org/abs/1704.01444',
#  'https://arxiv.org/abs/1703.03864',
#  'https://arxiv.org/abs/1703.07326',
#  'https://arxiv.org/abs/1703.04908',
#  'https://arxiv.org/abs/1703.04070',
#  'https://arxiv.org/abs/1703.01703',
#  'https://arxiv.org/abs/1702.02284',
#  'https://arxiv.org/abs/1701.05517',
#  'https://arxiv.org/abs/1611.04717',
#  'https://arxiv.org/abs/1611.04273',
#  'https://arxiv.org/abs/1611.03852',
#  'https://arxiv.org/abs/1611.02779',
#  'https://arxiv.org/abs/1611.02731',
#  'https://arxiv.org/abs/1611.00736',
#  'https://arxiv.org/abs/1610.05755',
#  'https://arxiv.org/abs/1610.03518',
#  'https://arxiv.org/abs/1606.06565',
#  'https://arxiv.org/abs/1605.07725',
#  'https://arxiv.org/abs/1606.01540',
#  'https://arxiv.org/abs/1602.07868']

# %%
# Additional URLs from manual browsing
additional_urls = [
    "https://arxiv.org/abs/2109.10862",
    "https://arxiv.org/abs/1710.06537",
    "https://arxiv.org/abs/1710.06542",
    "https://arxiv.org/abs/1703.06907",
    "https://arxiv.org/abs/1703.07326",
]
openai_research_urls.extend(additional_urls)
# Remove duplicates. Example: multiple GPT-2 announcements.
openai_research_urls = list(set(openai_research_urls))
len(openai_research_urls)
# Out:
# 121

# %%
openai_research_titles = []
for url in openai_research_urls:
    title = extract_title(url)
    # Remove the square bracket part of the title, if present
    if title is not None:
        if '] ' in title:
            title = title.split('] ')[1]
        title = title.strip()
        openai_research_titles.append(title)
    print(title)
len(openai_research_titles)
# Out:
# Recursively Summarizing Books with Human Feedback
# One-Shot Imitation Learning
# Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online Videos
# Parameter Space Noise for Exploration
# Efficient Training of Language Models to Fill in the Middle
# Some Considerations on Learning to Explore via Meta-Reinforcement Learning
# Solving Rubik's Cube with a Robot Hand
# None
# Learning to Generate Reviews and Discovering Sentiment
# Prediction and Control with Temporal Segment Models
# Teaching Models to Express Their Uncertainty in Words
# Variational Option Discovery Algorithms
# Semi-supervised Knowledge Transfer for Deep Learning from Private Training Data
# Implicit Generation and Generalization in Energy-Based Models
# Large-Scale Study of Curiosity-Driven Learning
# None
# AI safety via debate
# OpenAI Gym
# Sim-to-Real Transfer of Robotic Control with Dynamics Randomization
# None
# Supervising strong learners by amplifying weak experts
# On First-Order Meta-Learning Algorithms
# None
# Understanding the Capabilities, Limitations, and Societal Impact of Large Language Models
# A Connection between Generative Adversarial Networks, Inverse Reinforcement Learning, and Energy-Based Models
# Self-critiquing models for assisting human evaluators
# Stochastic Neural Networks for Hierarchical Reinforcement Learning
# Gotta Learn Fast: A New Benchmark for Generalization in RL
# Equivalence Between Policy Gradients and Soft Q-Learning
# Third-Person Imitation Learning
# RL$^2$: Fast Reinforcement Learning via Slow Reinforcement Learning
# Formal Mathematics Statement Curriculum Learning
# Language Models are Few-Shot Learners
# Toward Trustworthy AI Development: Mechanisms for Supporting Verifiable Claims
# GPTs are GPTs: An Early Look at the Labor Market Impact Potential of Large Language Models
# TruthfulQA: Measuring How Models Mimic Human Falsehoods
# None
# Fine-Tuning Language Models from Human Preferences
# #Exploration: A Study of Count-Based Exploration for Deep Reinforcement Learning
# Learning with Opponent-Learning Awareness
# A Hazard Analysis Framework for Code Synthesis Large Language Models
# Multimodal Neurons in Artificial Neural Networks
# Emergent Complexity via Multi-Agent Competition
# GamePad: A Learning Environment for Theorem Proving
# Proximal Policy Optimization Algorithms
# Learning Policy Representations in Multiagent Systems
# None
# None
# Learning Dexterous In-Hand Manipulation
# Testing Robustness Against Unforeseen Adversaries
# Scaling Laws for Neural Language Models
# WebGPT: Browser-assisted question-answering with human feedback
# Quantifying Generalization in Reinforcement Learning
# Scalable trust-region method for deep reinforcement learning using Kronecker-factored approximation
# Transfer of Adversarial Robustness Between Perturbation Types
# Multi-Agent Actor-Critic for Mixed Cooperative-Competitive Environments
# Asymmetric Actor Critic for Image-Based Robot Learning
# Synthesizing Robust Adversarial Examples
# Concrete Problems in AI Safety
# Deep reinforcement learning from human preferences
# Release Strategies and the Social Impacts of Language Models
# Plan Online, Learn Offline: Efficient Learning and Exploration via Model-Based Control
# Evaluating Large Language Models Trained on Code
# Generating Long Sequences with Sparse Transformers
# Measuring the Algorithmic Efficiency of Neural Networks
# FFJORD: Free-form Continuous Dynamics for Scalable Reversible Generative Models
# None
# Let's Verify Step by Step
# Learning to summarize from human feedback
# Variance Reduction for Policy Gradient with Action-Dependent Factorized Baselines
# Variational Lossy Autoencoder
# Domain Randomization for Transferring Deep Neural Networks from Simulation to the Real World
# Adversarial Attacks on Neural Network Policies
# Activation Atlas
# Training Verifiers to Solve Math Word Problems
# Evolution Strategies as a Scalable Alternative to Reinforcement Learning
# Language models can explain neurons in language models
# Interpretable and Pedagogical Examples
# Computational Limitations in Robust Classification and Win-Win Results
# Jukebox: A Generative Model for Music
# Neural MMO: A Massively Multiagent Game Environment for Training and Evaluating Intelligent Agents
# Adversarial Training Methods for Semi-Supervised Text Classification
# UCB Exploration via Q-Ensembles
# Continuous Adaptation via Meta-Learning in Nonstationary and Competitive Environments
# Generative Language Models and Automated Influence Operations: Emerging Threats and Potential Mitigations
# DeepType: Multilingual Entity Linking by Neural Type System Evolution
# Frontier AI Regulation: Managing Emerging Risks to Public Safety
# Deep Double Descent: Where Bigger Models and More Data Hurt
# Text and Code Embeddings by Contrastive Pre-Training
# Generative Language Modeling for Automated Theorem Proving
# Weight Normalization: A Simple Reparameterization to Accelerate Training of Deep Neural Networks
# AI Safety Needs Social Scientists
# Scaling Laws for Reward Model Overoptimization
# Transfer from Simulation to Real World through Learning Deep Inverse Dynamics Model
# The Malicious Use of Artificial Intelligence: Forecasting, Prevention, and Mitigation
# Point-E: A System for Generating 3D Point Clouds from Complex Prompts
# Evolved Policy Gradients
# Evolution through Large Models
# Learning Sparse Neural Networks through $L_0$ Regularization
# Emergence of Grounded Compositional Language in Multi-Agent Populations
# Hierarchical Text-Conditional Image Generation with CLIP Latents
# The Role of Cooperation in Responsible AI Development
# Exploration by Random Network Distillation
# Learning Transferable Visual Models From Natural Language Supervision
# Meta Learning Shared Hierarchies
# Emergent Tool Use From Multi-Agent Autocurricula
# Hindsight Experience Replay
# Concept Learning with Energy-Based Models
# Glow: Generative Flow with Invertible 1x1 Convolutions
# GPT-4 Technical Report
# None
# PixelCNN++: Improving the PixelCNN with Discretized Logistic Mixture Likelihood and Other Modifications
# Dota 2 with Large Scale Deep Reinforcement Learning
# Domain Randomization and Generative Models for Robotic Grasping
# Teacher-Student Curriculum Learning
# Training language models to follow instructions with human feedback
# Extensions and Limitations of the Neural GPU
# Leveraging Procedural Generation to Benchmark Reinforcement Learning
# Improving GANs Using Optimal Transport
# On the Quantitative Analysis of Decoder-Based Generative Models
# Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research
# 112

# %%
for title in openai_research_titles:
    print("Original title: ", title)
    openalex_results = Works().search(title).get()
    if len(openalex_results) > 0:
        top_result = openalex_results[0]
        print("Search result: ", top_result['display_name'])
        print(top_result['id'])
        if len(openalex_results) > 1:
            print("Relevance score: ", top_result['relevance_score'])
            print("Match score: ", top_result['relevance_score'] / top_result['cited_by_count']**0.5)
    print()
# Out:
# Original title:  Recursively Summarizing Books with Human Feedback
# Search result:  Recursively Summarizing Books with Human Feedback
# https://openalex.org/W3200980294
# Relevance score:  486.11057
# Match score:  217.39525582023398
#
# Original title:  One-Shot Imitation Learning
# Search result:  One-Shot Imitation Learning
# https://openalex.org/W2963094133
# Relevance score:  2516.118
# Match score:  184.4907228766487
#
# Original title:  Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online Videos
# Search result:  Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online
#   Videos
# https://openalex.org/W4283460722
#
# Original title:  Parameter Space Noise for Exploration
# Search result:  Parameter Space Noise for Exploration
# https://openalex.org/W2623491082
# Relevance score:  1871.2231
# Match score:  152.27797625659912
#
# Original title:  Efficient Training of Language Models to Fill in the Middle
# Search result:  Efficient Training of Language Models to Fill in the Middle
# https://openalex.org/W4288804596
# Relevance score:  306.09576
# Match score:  176.72446943380308
#
# Original title:  Some Considerations on Learning to Explore via Meta-Reinforcement Learning
# Search result:  Some Considerations on Learning to Explore via Meta-Reinforcement Learning
# https://openalex.org/W2785397462
# Relevance score:  1564.1417
# Match score:  230.62011195144626
#
# Original title:  Solving Rubik's Cube with a Robot Hand
# Search result:  Solving Rubik's Cube with a Robot Hand
# https://openalex.org/W2981030070
# Relevance score:  3839.5698
# Match score:  243.322849384142
#
# Original title:  Learning to Generate Reviews and Discovering Sentiment
# Search result:  Learning To Generate Reviews and Discovering Sentiment
# https://openalex.org/W2606347107
# Relevance score:  2641.4417
# Match score:  182.71234293489925
#
# Original title:  Prediction and Control with Temporal Segment Models
# Search result:  Prediction and Control with Temporal Segment Models
# https://openalex.org/W2595180411
# Relevance score:  690.25323
# Match score:  154.34531439687973
#
# Original title:  Teaching Models to Express Their Uncertainty in Words
# Search result:  Teaching Models to Express Their Uncertainty in Words
# https://openalex.org/W4281748205
# Relevance score:  242.47575
# Match score:  171.456247098294
#
# Original title:  Variational Option Discovery Algorithms
# Search result:  Variational Option Discovery Algorithms.
# https://openalex.org/W2883433335
# Relevance score:  1189.4647
# Match score:  156.18436676956003
#
# Original title:  Semi-supervised Knowledge Transfer for Deep Learning from Private Training Data
# Search result:  Semi-supervised Knowledge Transfer for Deep Learning from Private Training Data
# https://openalex.org/W2950602864
# Relevance score:  3278.2717
# Match score:  264.1706618174522
#
# Original title:  Implicit Generation and Generalization in Energy-Based Models
# Search result:  Implicit Generation and Generalization in Energy-Based Models.
# https://openalex.org/W2922772346
# Relevance score:  1866.625
# Match score:  181.30264728226283
#
# Original title:  Large-Scale Study of Curiosity-Driven Learning
# Search result:  Large-Scale Study of Curiosity-Driven Learning
# https://openalex.org/W2885550588
# Relevance score:  2406.8845
# Match score:  193.32561528358266
#
# Original title:  AI safety via debate
# Search result:  AI safety via debate.
# https://openalex.org/W2798877128
# Relevance score:  775.9249
# Match score:  155.18498
#
# Original title:  OpenAI Gym
# Search result:  OpenAI Gym
# https://openalex.org/W3037207827
# Relevance score:  3719.8027
# Match score:  197.98512067398553
#
# Original title:  Sim-to-Real Transfer of Robotic Control with Dynamics Randomization
# Search result:  Sim-to-Real Transfer of Robotic Control with Dynamics Randomization
# https://openalex.org/W3101442004
# Relevance score:  5304.781
# Match score:  213.56244160308248
#
# Original title:  Supervising strong learners by amplifying weak experts
# Search result:  Supervising strong learners by amplifying weak experts.
# https://openalex.org/W2896930824
# Relevance score:  1076.0493
# Match score:  234.81320803591643
#
# Original title:  On First-Order Meta-Learning Algorithms
# Search result:  On First-Order Meta-Learning Algorithms.
# https://openalex.org/W2795900505
# Relevance score:  3493.256
# Match score:  169.2488062213778
#
# Original title:  Understanding the Capabilities, Limitations, and Societal Impact of Large Language Models
# Search result:  Understanding the Capabilities, Limitations, and Societal Impact of Large Language Models.
# https://openalex.org/W3128912454
# Relevance score:  672.08606
# Match score:  237.6183052834744
#
# Original title:  A Connection between Generative Adversarial Networks, Inverse Reinforcement Learning, and Energy-Based Models
# Search result:  A Connection between Generative Adversarial Networks, Inverse Reinforcement Learning, and Energy-Based Models
# https://openalex.org/W2566467060
# Relevance score:  3792.173
# Match score:  322.8112032016996
#
# Original title:  Self-critiquing models for assisting human evaluators
# Search result:  The Role of Debriefing in Simulation-Based Learning
# https://openalex.org/W2153694812
# Relevance score:  68.33836
# Match score:  2.0047558445153406
#
# Original title:  Stochastic Neural Networks for Hierarchical Reinforcement Learning
# Search result:  Stochastic Neural Networks for Hierarchical Reinforcement Learning
# https://openalex.org/W2606433045
# Relevance score:  2181.5398
# Match score:  206.13613521391372
#
# Original title:  Gotta Learn Fast: A New Benchmark for Generalization in RL
# Search result:  Gotta Learn Fast: A New Benchmark for Generalization in RL
# https://openalex.org/W2796979132
# Relevance score:  2733.1482
# Match score:  298.2109169531501
#
# Original title:  Equivalence Between Policy Gradients and Soft Q-Learning
# Search result:  Equivalence Between Policy Gradients and Soft Q-Learning
# https://openalex.org/W2609650878
# Relevance score:  2857.4954
# Match score:  242.36959648914404
#
# Original title:  Third-Person Imitation Learning
# Search result:  Third-Person Imitation Learning
# https://openalex.org/W2591957724
# Relevance score:  1493.1578
# Match score:  188.12020033220568
#
# Original title:  RL$^2$: Fast Reinforcement Learning via Slow Reinforcement Learning
# Search result:  RL$^2$: Fast Reinforcement Learning via Slow Reinforcement Learning
# https://openalex.org/W2578206533
# Relevance score:  4575.5557
# Match score:  303.6902981614128
#
# Original title:  Formal Mathematics Statement Curriculum Learning
# Search result:  Learning Styles and Learning Spaces: Enhancing Experiential Learning in Higher Education
# https://openalex.org/W2147454772
# Relevance score:  63.539074
# Match score:  1.1344454612502601
#
# Original title:  Language Models are Few-Shot Learners
# Search result:  Language Models are Few-Shot Learners
# https://openalex.org/W3030163527
# Relevance score:  6791.046
# Match score:  181.62811952235663
#
# Original title:  Toward Trustworthy AI Development: Mechanisms for Supporting Verifiable Claims
# Search result:  Toward Trustworthy AI Development: Mechanisms for Supporting Verifiable Claims
# https://openalex.org/W3017343191
# Relevance score:  1469.6913
# Match score:  272.914822969371
#
# Original title:  GPTs are GPTs: An Early Look at the Labor Market Impact Potential of Large Language Models
# Search result:  GPTs are GPTs: An Early Look at the Labor Market Impact Potential of
#   Large Language Models
# https://openalex.org/W4330336443
# Relevance score:  657.8817
# Match score:  294.2136404706247
#
# Original title:  TruthfulQA: Measuring How Models Mimic Human Falsehoods
# Search result:  TruthfulQA: Measuring How Models Mimic Human Falsehoods
# https://openalex.org/W3201174429
# Relevance score:  1090.8737
# Match score:  272.718425
#
# Original title:  Fine-Tuning Language Models from Human Preferences
# Search result:  Fine-Tuning Language Models from Human Preferences.
# https://openalex.org/W2973379954
# Relevance score:  1708.5774
# Match score:  194.7104654299094
#
# Original title:  #Exploration: A Study of Count-Based Exploration for Deep Reinforcement Learning
# Search result:  #Exploration: a study of count-based exploration for deep reinforcement learning
# https://openalex.org/W2561776174
# Relevance score:  3579.4543
# Match score:  233.0026286113136
#
# Original title:  Learning with Opponent-Learning Awareness
# Search result:  Learning with Opponent-Learning Awareness
# https://openalex.org/W2963627051
# Relevance score:  1989.1747
# Match score:  173.7950004797503
#
# Original title:  A Hazard Analysis Framework for Code Synthesis Large Language Models
# Search result:  A Hazard Analysis Framework for Code Synthesis Large Language Models
# https://openalex.org/W4288805334
# Relevance score:  197.5372
# Match score:  197.5372
#
# Original title:  Multimodal Neurons in Artificial Neural Networks
# Search result:  Multimodal Neurons in Artificial Neural Networks
# https://openalex.org/W3134095442
# Relevance score:  1323.198
# Match score:  165.39975
#
# Original title:  Emergent Complexity via Multi-Agent Competition
# Search result:  Emergent Complexity via Multi-Agent Competition.
# https://openalex.org/W2762117857
# Relevance score:  1927.5183
# Match score:  211.57261981608593
#
# Original title:  GamePad: A Learning Environment for Theorem Proving
# Search result:  GamePad: A Learning Environment for Theorem Proving
# https://openalex.org/W2807324060
# Relevance score:  1061.7709
# Match score:  226.3703164855412
#
# Original title:  Proximal Policy Optimization Algorithms
# Search result:  Proximal Policy Optimization Algorithms
# https://openalex.org/W2736601468
# Relevance score:  7691.4062
# Match score:  142.311491238939
#
# Original title:  Learning Policy Representations in Multiagent Systems
# Search result:  Learning Policy Representations in Multiagent Systems
# https://openalex.org/W2963231791
# Relevance score:  896.27313
# Match score:  182.95098655559786
#
# Original title:  Learning Dexterous In-Hand Manipulation
# Search result:  Learning dexterous in-hand manipulation
# https://openalex.org/W2990747716
# Relevance score:  5296.957
# Match score:  190.51830123269315
#
# Original title:  Testing Robustness Against Unforeseen Adversaries
# Search result:  Testing Robustness Against Unforeseen Adversaries
# https://openalex.org/W2969454448
# Relevance score:  1615.6958
# Match score:  224.05669432506963
#
# Original title:  Scaling Laws for Neural Language Models
# Search result:  Scaling Laws for Neural Language Models
# https://openalex.org/W3001279689
# Relevance score:  2386.3958
# Match score:  141.85650583692032
#
# Original title:  WebGPT: Browser-assisted question-answering with human feedback
# Search result:  WebGPT: Browser-assisted question-answering with human feedback
# https://openalex.org/W4309088836
# Relevance score:  493.16235
# Match score:  284.72741552668845
#
# Original title:  Quantifying Generalization in Reinforcement Learning
# Search result:  Quantifying Generalization in Reinforcement Learning
# https://openalex.org/W2903181768
# Relevance score:  1731.1418
# Match score:  158.69350862027125
#
# Original title:  Scalable trust-region method for deep reinforcement learning using Kronecker-factored approximation
# Search result:  Scalable trust-region method for deep reinforcement learning using Kronecker-factored approximation
# https://openalex.org/W2749928749
# Relevance score:  4510.666
# Match score:  310.52705359133165
#
# Original title:  Transfer of Adversarial Robustness Between Perturbation Types
# Search result:  Transfer of Adversarial Robustness Between Perturbation Types.
# https://openalex.org/W2943657790
# Relevance score:  811.8954
# Match score:  209.63049087082726
#
# Original title:  Multi-Agent Actor-Critic for Mixed Cooperative-Competitive Environments
# Search result:  Multi-Agent Actor-Critic for Mixed Cooperative-Competitive Environments
# https://openalex.org/W2963407617
# Relevance score:  5694.5127
# Match score:  270.8603474236742
#
# Original title:  Asymmetric Actor Critic for Image-Based Robot Learning
# Search result:  Asymmetric Actor Critic for Image-Based Robot Learning
# https://openalex.org/W2964198579
# Relevance score:  2031.995
# Match score:  219.11565598552082
#
# Original title:  Synthesizing Robust Adversarial Examples
# Search result:  Synthesizing Robust Adversarial Examples
# https://openalex.org/W2963557656
# Relevance score:  3198.1863
# Match score:  179.62803847575927
#
# Original title:  Concrete Problems in AI Safety
# Search result:  Concrete Problems in AI Safety
# https://openalex.org/W2462906003
# Relevance score:  3771.0046
# Match score:  156.8531132085685
#
# Original title:  Deep reinforcement learning from human preferences
# Search result:  Deep Reinforcement Learning from Human Preferences
# https://openalex.org/W2964263543
# Relevance score:  2217.4612
# Match score:  180.4544332332846
#
# Original title:  Release Strategies and the Social Impacts of Language Models
# Search result:  Release Strategies and the Social Impacts of Language Models.
# https://openalex.org/W2969958763
# Relevance score:  1290.283
# Match score:  158.82285825528635
#
# Original title:  Plan Online, Learn Offline: Efficient Learning and Exploration via Model-Based Control
# Search result:  Plan Online, Learn Offline: Efficient Learning and Exploration via Model-Based Control
# https://openalex.org/W2898917980
# Relevance score:  1819.8086
# Match score:  262.666746270899
#
# Original title:  Evaluating Large Language Models Trained on Code
# Search result:  Evaluating Large Language Models Trained on Code
# https://openalex.org/W3177813494
# Relevance score:  1237.7767
# Match score:  170.02170555454725
#
# Original title:  Generating Long Sequences with Sparse Transformers
# Search result:  Generating Long Sequences with Sparse Transformers.
# https://openalex.org/W2940744433
# Relevance score:  4128.4497
# Match score:  199.32342978939332
#
# Original title:  Measuring the Algorithmic Efficiency of Neural Networks
# Search result:  Measuring the Algorithmic Efficiency of Neural Networks.
# https://openalex.org/W3021954012
# Relevance score:  642.6989
# Match score:  147.44523980130276
#
# Original title:  FFJORD: Free-form Continuous Dynamics for Scalable Reversible Generative Models
# Search result:  FFJORD: Free-form Continuous Dynamics for Scalable Reversible Generative Models
# https://openalex.org/W2963641970
# Relevance score:  3819.3757
# Match score:  292.9327441154417
#
# Original title:  Let's Verify Step by Step
# Search result:  The Essential Guide to Semiconductors
# https://openalex.org/W612923280
# Relevance score:  27.300112
# Match score:  4.903244861124782
#
# Original title:  Learning to summarize from human feedback
# Search result:  Learning to summarize from human feedback
# https://openalex.org/W3082115681
# Relevance score:  956.73816
# Match score:  161.71826531702644
#
# Original title:  Variance Reduction for Policy Gradient with Action-Dependent Factorized Baselines
# Search result:  Variance Reduction for Policy Gradient with Action-Dependent Factorized Baselines
# https://openalex.org/W2786303200
# Relevance score:  1640.4972
# Match score:  269.6960783572742
#
# Original title:  Variational Lossy Autoencoder
# Search result:  Variational Lossy Autoencoder
# https://openalex.org/W2560512785
# Relevance score:  2578.3176
# Match score:  173.04534695048906
#
# Original title:  Domain Randomization for Transferring Deep Neural Networks from Simulation to the Real World
# Search result:  Domain randomization for transferring deep neural networks from simulation to the real world
# https://openalex.org/W2605102758
# Relevance score:  9646.931
# Match score:  247.03258923358644
#
# Original title:  Adversarial Attacks on Neural Network Policies
# Search result:  Adversarial Attacks on Neural Network Policies
# https://openalex.org/W2949103145
# Relevance score:  2758.559
# Match score:  190.35865593138854
#
# Original title:  Activation Atlas
# Search result:  MAP kinase in situ activation atlas during <i>Drosophila</i> embryogenesis
# https://openalex.org/W2148649613
# Relevance score:  1003.26373
# Match score:  58.313519824908326
#
# Original title:  Training Verifiers to Solve Math Word Problems
# Search result:  Training Verifiers to Solve Math Word Problems
# https://openalex.org/W4286892945
# Relevance score:  357.98676
# Match score:  206.68375225232197
#
# Original title:  Evolution Strategies as a Scalable Alternative to Reinforcement Learning
# Search result:  Evolution Strategies as a Scalable Alternative to Reinforcement Learning.
# https://openalex.org/W2596367596
# Relevance score:  4056.3833
# Match score:  190.37550117091445
#
# Original title:  Language models can explain neurons in language models
# Search result:  RECEPTIVE FIELDS AND FUNCTIONAL ARCHITECTURE IN TWO NONSTRIATE VISUAL AREAS (18 AND 19) OF THE CAT
# https://openalex.org/W1594551768
# Relevance score:  185.01836
# Match score:  3.7901186506632722
#
# Original title:  Interpretable and Pedagogical Examples
# Search result:  Interpretable and Pedagogical Examples
# https://openalex.org/W2766774033
# Relevance score:  407.46512
# Match score:  144.06067472449516
#
# Original title:  Computational Limitations in Robust Classification and Win-Win Results
# Search result:  Computational Limitations in Robust Classification and Win-Win Results.
# https://openalex.org/W2965341833
# Relevance score:  1053.3262
# Match score:  263.33155
#
# Original title:  Jukebox: A Generative Model for Music
# Search result:  Jukebox: A Generative Model for Music
# https://openalex.org/W3021164770
# Relevance score:  1743.3287
# Match score:  184.79247261542437
#
# Original title:  Neural MMO: A Massively Multiagent Game Environment for Training and Evaluating Intelligent Agents
# Search result:  Neural MMO: A Massively Multiagent Game Environment for Training and Evaluating Intelligent Agents.
# https://openalex.org/W2918965305
#
# Original title:  Adversarial Training Methods for Semi-Supervised Text Classification
# Search result:  Adversarial Training Methods for Semi-Supervised Text Classification.
# https://openalex.org/W3093419064
# Relevance score:  2819.4883
# Match score:  234.95735833333333
#
# Original title:  UCB Exploration via Q-Ensembles
# Search result:  UCB Exploration via Q-Ensembles
# https://openalex.org/W2767313115
# Relevance score:  1296.45
# Match score:  219.14004670855707
#
# Original title:  Continuous Adaptation via Meta-Learning in Nonstationary and Competitive Environments
# Search result:  Continuous Adaptation via Meta-Learning in Nonstationary and Competitive Environments
# https://openalex.org/W2762872434
# Relevance score:  2380.48
# Match score:  255.21424469306737
#
# Original title:  Generative Language Models and Automated Influence Operations: Emerging Threats and Potential Mitigations
# Search result:  Generative Language Models and Automated Influence Operations: Emerging
#   Threats and Potential Mitigations
# https://openalex.org/W4315881236
# Relevance score:  259.45657
# Match score:  259.45657
#
# Original title:  DeepType: Multilingual Entity Linking by Neural Type System Evolution
# Search result:  DeepType: Multilingual Entity Linking by Neural Type System Evolution
# https://openalex.org/W2964075320
# Relevance score:  2331.528
# Match score:  278.67089690642
#
# Original title:  Frontier AI Regulation: Managing Emerging Risks to Public Safety
# Search result:  Bounded Rationality and Organizational Learning
# https://openalex.org/W4362210174
# Relevance score:  123.15503
# Match score:  3.5463247289508395
#
# Original title:  Deep Double Descent: Where Bigger Models and More Data Hurt
# Search result:  Deep Double Descent: Where Bigger Models and More Data Hurt
# https://openalex.org/W2996603747
# Relevance score:  3133.2964
# Match score:  272.71844636321333
#
# Original title:  Text and Code Embeddings by Contrastive Pre-Training
# Search result:  Text and Code Embeddings by Contrastive Pre-Training
# https://openalex.org/W4225576545
# Relevance score:  290.3248
# Match score:  205.29063482662815
#
# Original title:  Generative Language Modeling for Automated Theorem Proving
# Search result:  Generative Language Modeling for Automated Theorem Proving.
# https://openalex.org/W3083835029
# Relevance score:  1381.0819
# Match score:  213.10556374201082
#
# Original title:  Weight Normalization: A Simple Reparameterization to Accelerate Training of Deep Neural Networks
# Search result:  Weight normalization: a simple reparameterization to accelerate training of deep neural networks
# https://openalex.org/W2963685250
# Relevance score:  7102.704
# Match score:  309.9874163701488
#
# Original title:  AI Safety Needs Social Scientists
# Search result:  AI Safety Needs Social Scientists
# https://openalex.org/W2917705988
# Relevance score:  881.2474
# Match score:  183.75278525032058
#
# Original title:  Scaling Laws for Reward Model Overoptimization
# Search result:  From initial idea to unique advantage: The entrepreneurial challenge of constructing a resource base
# https://openalex.org/W2179823604
# Relevance score:  17.644703
# Match score:  0.689962486191823
#
# Original title:  Transfer from Simulation to Real World through Learning Deep Inverse Dynamics Model
# Search result:  Transfer from Simulation to Real World through Learning Deep Inverse Dynamics Model
# https://openalex.org/W2530944449
# Relevance score:  2344.0632
# Match score:  260.45146666666665
#
# Original title:  The Malicious Use of Artificial Intelligence: Forecasting, Prevention, and Mitigation
# Search result:  The Malicious Use of Artificial Intelligence: Forecasting, Prevention, and Mitigation
# https://openalex.org/W2787887017
# Relevance score:  2209.1223
# Match score:  232.8619365956596
#
# Original title:  Point-E: A System for Generating 3D Point Clouds from Complex Prompts
# Search result:  Point-E: A System for Generating 3D Point Clouds from Complex Prompts
# https://openalex.org/W4312045746
# Relevance score:  250.61372
# Match score:  250.61372
#
# Original title:  Evolved Policy Gradients
# Search result:  Evolved Policy Gradients
# https://openalex.org/W2964227899
# Relevance score:  1048.81
# Match score:  140.1531315650849
#
# Original title:  Evolution through Large Models
# Search result:  Dynamic topic models
# https://openalex.org/W2072644219
# Relevance score:  220.71548
# Match score:  5.165143682567985
#
# Original title:  Learning Sparse Neural Networks through $L_0$ Regularization
# Search result:  Learning Sparse Neural Networks through L_0 Regularization
# https://openalex.org/W2963828549
# Relevance score:  4474.9854
# Match score:  244.1304682062171
#
# Original title:  Emergence of Grounded Compositional Language in Multi-Agent Populations
# Search result:  Emergence of Grounded Compositional Language in Multi-Agent Populations
# https://openalex.org/W2963881016
# Relevance score:  3057.88
# Match score:  227.2904303926285
#
# Original title:  Hierarchical Text-Conditional Image Generation with CLIP Latents
# Search result:  Hierarchical Text-Conditional Image Generation with CLIP Latents
# https://openalex.org/W4224035735
# Relevance score:  1211.0077
# Match score:  237.49814974658148
#
# Original title:  The Role of Cooperation in Responsible AI Development
# Search result:  The Role of Cooperation in Responsible AI Development
# https://openalex.org/W2962528222
# Relevance score:  565.8888
# Match score:  178.94975103794917
#
# Original title:  Exploration by Random Network Distillation
# Search result:  Exploration by Random Network Distillation.
# https://openalex.org/W2899205164
# Relevance score:  2350.5903
# Match score:  158.4767656967431
#
# Original title:  Learning Transferable Visual Models From Natural Language Supervision
# Search result:  Learning Transferable Visual Models From Natural Language Supervision
# https://openalex.org/W3135367836
# Relevance score:  3611.6416
# Match score:  203.17071333205533
#
# Original title:  Meta Learning Shared Hierarchies
# Search result:  Meta Learning Shared Hierarchies
# https://openalex.org/W2765602917
# Relevance score:  1277.4324
# Match score:  143.7223737490893
#
# Original title:  Emergent Tool Use From Multi-Agent Autocurricula
# Search result:  Emergent Tool Use From Multi-Agent Autocurricula.
# https://openalex.org/W2973525135
# Relevance score:  2329.0334
# Match score:  231.74748502412177
#
# Original title:  Hindsight Experience Replay
# Search result:  Hindsight Experience Replay
# https://openalex.org/W2964001908
# Relevance score:  4332.697
# Match score:  195.33306605573398
#
# Original title:  Concept Learning with Energy-Based Models
# Search result:  Concept Learning with Energy-Based Models
# https://openalex.org/W2963533931
# Relevance score:  248.94768
# Match score:  124.47384
#
# Original title:  Glow: Generative Flow with Invertible 1x1 Convolutions
# Search result:  Glow: Generative Flow with Invertible 1x1 Convolutions
# https://openalex.org/W2963139417
# Relevance score:  7831.4526
# Match score:  288.67117271958875
#
# Original title:  GPT-4 Technical Report
# Search result:  GPT-4 Technical Report
# https://openalex.org/W4327810158
# Relevance score:  770.0426
# Match score:  151.0177786037586
#
# Original title:  PixelCNN++: Improving the PixelCNN with Discretized Logistic Mixture Likelihood and Other Modifications
# Search result:  PixelCNN++: Improving the PixelCNN with Discretized Logistic Mixture Likelihood and Other Modifications
# https://openalex.org/W2964122153
# Relevance score:  6960.2837
# Match score:  376.9204945237658
#
# Original title:  Dota 2 with Large Scale Deep Reinforcement Learning
# Search result:  Dota 2 with Large Scale Deep Reinforcement Learning
# https://openalex.org/W2996037775
# Relevance score:  3953.8293
# Match score:  216.66851096608323
#
# Original title:  Domain Randomization and Generative Models for Robotic Grasping
# Search result:  Domain Randomization and Generative Models for Robotic Grasping
# https://openalex.org/W2964214518
# Relevance score:  2046.725
# Match score:  215.7437581336042
#
# Original title:  Teacher-Student Curriculum Learning
# Search result:  Teacher–Student Curriculum Learning
# https://openalex.org/W2972758308
# Relevance score:  1676.0002
# Match score:  143.7158314992809
#
# Original title:  Training language models to follow instructions with human feedback
# Search result:  Training language models to follow instructions with human feedback
# https://openalex.org/W4226278401
# Relevance score:  952.1189
# Match score:  198.5305145461666
#
# Original title:  Extensions and Limitations of the Neural GPU
# Search result:  Extensions and Limitations of the Neural GPU
# https://openalex.org/W2548137223
# Relevance score:  395.41043
# Match score:  176.83292009848444
#
# Original title:  Leveraging Procedural Generation to Benchmark Reinforcement Learning
# Search result:  Leveraging Procedural Generation to Benchmark Reinforcement Learning
# https://openalex.org/W2994073215
# Relevance score:  1759.466
# Match score:  219.93325
#
# Original title:  Improving GANs Using Optimal Transport
# Search result:  Improving GANs Using Optimal Transport
# https://openalex.org/W2963989027
# Relevance score:  1320.4009
# Match score:  154.5412360948033
#
# Original title:  On the Quantitative Analysis of Decoder-Based Generative Models
# Search result:  On the Quantitative Analysis of Decoder-Based Generative Models
# https://openalex.org/W2953116488
# Relevance score:  1835.1339
# Match score:  190.29452076622547
#
# Original title:  Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research
# Search result:  Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research
# https://openalex.org/W2789008106
# Relevance score:  3176.3042
# Match score:  263.77770645044967

# %%
Works().search("Extensions and Limitations of the Neural GPU").get()[0]
# Out:
# {'id': 'https://openalex.org/W2548137223',
#  'doi': None,
#  'title': 'Extensions and Limitations of the Neural GPU',
#  'display_name': 'Extensions and Limitations of the Neural GPU',
#  'relevance_score': 395.41043,
#  'publication_year': 2016,
#  'publication_date': '2016-11-04',
#  'ids': {'openalex': 'https://openalex.org/W2548137223', 'mag': '2548137223'},
#  'language': 'en',
#  'primary_location': {'is_oa': False,
#   'landing_page_url': 'https://openreview.net/pdf?id=ryjp1c9xg',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S4306400194',
#    'display_name': 'arXiv (Cornell University)',
#    'issn_l': None,
#    'issn': None,
#    'is_oa': True,
#    'is_in_doaj': False,
#    'host_organization': 'https://openalex.org/I205783295',
#    'host_organization_name': 'Cornell University',
#    'host_organization_lineage': ['https://openalex.org/I205783295'],
#    'host_organization_lineage_names': ['Cornell University'],
#    'type': 'repository'},
#   'license': None,
#   'version': 'submittedVersion',
#   'is_accepted': False,
#   'is_published': False},
#  'type': 'article',
#  'type_crossref': 'posted-content',
#  'open_access': {'is_oa': False,
#   'oa_status': 'closed',
#   'oa_url': None,
#   'any_repository_has_fulltext': False},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A5083990461',
#     'display_name': 'Eric Price',
#     'orcid': 'https://orcid.org/0000-0002-3480-8054'},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Eric Price',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5076651586',
#     'display_name': 'Wojciech Zaremba',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Wojciech Zaremba',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'last',
#    'author': {'id': 'https://openalex.org/A5006446297',
#     'display_name': 'Ilya Sutskever',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Ilya Sutskever',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []}],
#  'institutions_distinct_count': 0,
#  'corresponding_author_ids': [],
#  'corresponding_institution_ids': [],
#  'apc_list': None,
#  'apc_paid': None,
#  'cited_by_count': 5,
#  'biblio': {'volume': None,
#   'issue': None,
#   'first_page': None,
#   'last_page': None},
#  'is_retracted': False,
#  'is_paratext': False,
#  'concepts': [{'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 0.7362197},
#   {'id': 'https://openalex.org/C2780595030',
#    'wikidata': 'https://www.wikidata.org/wiki/Q3860309',
#    'display_name': 'Multiplication (music)',
#    'level': 2,
#    'score': 0.7172852},
#   {'id': 'https://openalex.org/C55526617',
#    'wikidata': 'https://www.wikidata.org/wiki/Q719375',
#    'display_name': 'Operand',
#    'level': 2,
#    'score': 0.68042856},
#   {'id': 'https://openalex.org/C177148314',
#    'wikidata': 'https://www.wikidata.org/wiki/Q170084',
#    'display_name': 'Generalization',
#    'level': 2,
#    'score': 0.5737948},
#   {'id': 'https://openalex.org/C48372109',
#    'wikidata': 'https://www.wikidata.org/wiki/Q3913',
#    'display_name': 'Binary number',
#    'level': 2,
#    'score': 0.55900514},
#   {'id': 'https://openalex.org/C50644808',
#    'wikidata': 'https://www.wikidata.org/wiki/Q192776',
#    'display_name': 'Artificial neural network',
#    'level': 2,
#    'score': 0.5444731},
#   {'id': 'https://openalex.org/C94375191',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11205',
#    'display_name': 'Arithmetic',
#    'level': 1,
#    'score': 0.5264424},
#   {'id': 'https://openalex.org/C177264268',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1514741',
#    'display_name': 'Set (abstract data type)',
#    'level': 2,
#    'score': 0.51185626},
#   {'id': 'https://openalex.org/C2776359362',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2145286',
#    'display_name': 'Representation (politics)',
#    'level': 3,
#    'score': 0.49315113},
#   {'id': 'https://openalex.org/C185798385',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1161707',
#    'display_name': 'Benchmark (surveying)',
#    'level': 2,
#    'score': 0.47091457},
#   {'id': 'https://openalex.org/C173608175',
#    'wikidata': 'https://www.wikidata.org/wiki/Q232661',
#    'display_name': 'Parallel computing',
#    'level': 1,
#    'score': 0.45361826},
#   {'id': 'https://openalex.org/C65045869',
#    'wikidata': 'https://www.wikidata.org/wiki/Q81365',
#    'display_name': 'Decimal',
#    'level': 2,
#    'score': 0.44052097},
#   {'id': 'https://openalex.org/C68339613',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1549489',
#    'display_name': 'Speedup',
#    'level': 2,
#    'score': 0.4173246},
#   {'id': 'https://openalex.org/C11413529',
#    'wikidata': 'https://www.wikidata.org/wiki/Q8366',
#    'display_name': 'Algorithm',
#    'level': 1,
#    'score': 0.40011102},
#   {'id': 'https://openalex.org/C154945302',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#    'display_name': 'Artificial intelligence',
#    'level': 1,
#    'score': 0.23288947},
#   {'id': 'https://openalex.org/C33923547',
#    'wikidata': 'https://www.wikidata.org/wiki/Q395',
#    'display_name': 'Mathematics',
#    'level': 0,
#    'score': 0.1564585},
#   {'id': 'https://openalex.org/C199360897',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#    'display_name': 'Programming language',
#    'level': 1,
#    'score': 0.07578629},
#   {'id': 'https://openalex.org/C134306372',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7754',
#    'display_name': 'Mathematical analysis',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C13280743',
#    'wikidata': 'https://www.wikidata.org/wiki/Q131089',
#    'display_name': 'Geodesy',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C114614502',
#    'wikidata': 'https://www.wikidata.org/wiki/Q76592',
#    'display_name': 'Combinatorics',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C94625758',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7163',
#    'display_name': 'Politics',
#    'level': 2,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C17744445',
#    'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#    'display_name': 'Political science',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C199539241',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#    'display_name': 'Law',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C205649164',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#    'display_name': 'Geography',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C111919701',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#    'display_name': 'Operating system',
#    'level': 1,
#    'score': 0.0}],
#  'mesh': [],
#  'locations_count': 1,
#  'locations': [{'is_oa': False,
#    'landing_page_url': 'https://openreview.net/pdf?id=ryjp1c9xg',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False}],
#  'best_oa_location': None,
#  'sustainable_development_goals': [],
#  'grants': [],
#  'referenced_works_count': 25,
#  'referenced_works': ['https://openalex.org/W71081281',
#   'https://openalex.org/W1581407678',
#   'https://openalex.org/W1639032689',
#   'https://openalex.org/W1659842140',
#   'https://openalex.org/W1771459135',
#   'https://openalex.org/W1969021871',
#   'https://openalex.org/W2095705004',
#   'https://openalex.org/W2135625884',
#   'https://openalex.org/W2148067905',
#   'https://openalex.org/W2161002933',
#   'https://openalex.org/W2173051530',
#   'https://openalex.org/W2175344611',
#   'https://openalex.org/W2204302769',
#   'https://openalex.org/W2264259902',
#   'https://openalex.org/W2296073425',
#   'https://openalex.org/W2325237720',
#   'https://openalex.org/W2423581336',
#   'https://openalex.org/W2612506596',
#   'https://openalex.org/W2949626814',
#   'https://openalex.org/W2950527759',
#   'https://openalex.org/W2950898700',
#   'https://openalex.org/W2951008357',
#   'https://openalex.org/W2951777936',
#   'https://openalex.org/W2963542991',
#   'https://openalex.org/W2964308564'],
#  'related_works': ['https://openalex.org/W1509471215',
#   'https://openalex.org/W2024908082',
#   'https://openalex.org/W2026378474',
#   'https://openalex.org/W2070966792',
#   'https://openalex.org/W2189100082',
#   'https://openalex.org/W2328959101',
#   'https://openalex.org/W2388772822',
#   'https://openalex.org/W2753015639',
#   'https://openalex.org/W2760098133',
#   'https://openalex.org/W2802840548',
#   'https://openalex.org/W2902948025',
#   'https://openalex.org/W2963095905',
#   'https://openalex.org/W2979365412',
#   'https://openalex.org/W3101434632',
#   'https://openalex.org/W3102736503',
#   'https://openalex.org/W3151612890',
#   'https://openalex.org/W3169486038',
#   'https://openalex.org/W3176486103',
#   'https://openalex.org/W3196029931',
#   'https://openalex.org/W3201295431'],
#  'ngrams_url': 'https://api.openalex.org/works/W2548137223/ngrams',
#  'abstract_inverted_index': {'The': [0, 55],
#   'Neural': [1, 43, 68, 90, 134, 174, 184, 207],
#   'GPU': [2, 69, 135, 175, 208],
#   'is': [3, 70],
#   'a': [4, 20, 48, 58, 63, 206],
#   'recent': [5],
#   'model': [6, 53],
#   'that': [7, 22, 31, 75, 84, 144, 183, 186, 209],
#   'can': [8, 85, 222],
#   'learn': [9, 97],
#   'algorithms': [10],
#   'such': [11],
#   'as': [12, 62],
#   'multi-digit': [13],
#   'binary': [14, 17, 160],
#   'addition': [15],
#   'and': [16, 50, 162],
#   'multiplication': [18, 215],
#   'in': [19, 115, 158],
#   'way': [21],
#   'generalizes': [23],
#   'to': [24, 96, 98, 106, 131, 136, 189, 195, 218],
#   'inputs': [25],
#   'of': [26, 37, 41, 66, 81, 150, 216, 239],
#   'arbitrary': [27],
#   'length.': [28],
#   'We': [29, 73, 126, 181],
#   'show': [30],
#   'there': [32],
#   'are': [33, 113, 237],
#   'two': [34],
#   'simple': [35],
#   'ways': [36],
#   'improving': [38],
#   'the': [39, 42, 67, 79, 89, 101, 111, 116, 133, 147, 151, 173, 197],
#   'performance': [40],
#   'GPU:': [44, 91],
#   'by': [45, 51, 88, 176],
#   'carefully': [46],
#   'designing': [47],
#   'curriculum,': [49],
#   'increasing': [52],
#   'size.': [54],
#   'latter': [56],
#   'requires': [57],
#   'memory': [59, 71],
#   'efficient': [60],
#   'implementation,': [61],
#   'naive': [64],
#   'implementation': [65],
#   'intensive.': [72],
#   'find': [74, 182],
#   'these': [76, 154],
#   'techniques': [77],
#   'increase': [78],
#   'set': [80],
#   'algorithmic': [82],
#   'problems': [83],
#   'be': [86],
#   'solved': [87],
#   'we': [92, 169],
#   'have': [93, 127, 155],
#   'been': [94, 123, 129],
#   'able': [95, 130],
#   'perform': [99],
#   'all': [100],
#   'arithmetic': [102, 139],
#   'operations': [103],
#   '(and': [104],
#   'generalize': [105, 188],
#   'arbitrarily': [107, 190],
#   'long': [108, 138, 191, 220],
#   'numbers)': [109],
#   'when': [110],
#   'arguments': [112],
#   'given': [114],
#   'decimal': [117, 214],
#   'representation': [118],
#   '(which,': [119],
#   'surprisingly,': [120],
#   'has': [121],
#   'not': [122, 163],
#   'possible': [124],
#   'before).': [125],
#   'also': [128],
#   'train': [132],
#   'evaluate': [137],
#   'expressions': [140],
#   'with': [141, 164],
#   'multiple': [142],
#   'operands': [143],
#   'require': [145],
#   'respecting': [146],
#   'precedence': [148],
#   'order': [149],
#   'operands,': [152],
#   'although': [153],
#   'succeeded': [156],
#   'only': [157],
#   'their': [159],
#   'representation,': [161],
#   'perfect': [165],
#   'accuracy.': [166],
#   '\r\nIn': [167],
#   'addition,': [168],
#   'gain': [170],
#   'insight': [171],
#   'into': [172],
#   'investigating': [177],
#   'its': [178],
#   'failure': [179, 235],
#   'modes.': [180],
#   'GPUs': [185],
#   'correctly': [187],
#   'numbers': [192, 221],
#   'still': [193],
#   'fail': [194, 223],
#   'compute': [196],
#   'correct': [198],
#   'answer': [199],
#   'on': [200, 213, 224],
#   'highly-symmetric,': [201],
#   'atypical': [202],
#   'inputs:': [203],
#   'for': [204],
#   'example,': [205],
#   'achieves': [210],
#   'near-perfect': [211],
#   'generalization': [212],
#   'up': [217],
#   '100-digit': [219],
#   '$000000\\dots002': [225],
#   '\\times': [226, 232],
#   '000000\\dots002$': [227],
#   'while': [228],
#   'succeeding': [229],
#   'at': [230],
#   '$2': [231],
#   '2$.': [233],
#   'These': [234],
#   'modes': [236],
#   'reminiscent': [238],
#   'adversarial': [240],
#   'examples.': [241]},
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2548137223',
#  'counts_by_year': [{'year': 2021, 'cited_by_count': 1},
#   {'year': 2019, 'cited_by_count': 1},
#   {'year': 2018, 'cited_by_count': 1},
#   {'year': 2017, 'cited_by_count': 1},
#   {'year': 2016, 'cited_by_count': 1}],
#  'updated_date': '2023-08-25T13:18:42.434064',
#  'created_date': '2016-11-11'}

# %% [markdown]
# Filter OpenAlex works that sufficiently match by title.

# %%
openai_research_works = []
for title in openai_research_titles:
    print("Original title: ", title)
    openalex_results = Works().search(title).get()
    if len(openalex_results) > 0:
        top_result = openalex_results[0]
        print("Search result: ", top_result['display_name'])
        print(top_result['id'])
        if len(openalex_results) > 1:
            print("Relevance score: ", top_result['relevance_score'])
            match_score = top_result['relevance_score'] / top_result['cited_by_count']**0.5
            print("Match score: ", match_score)
            if match_score >= 100:
                openai_research_works.append(top_result)
        else:
            openai_research_works.append(top_result)
    print()
len(openai_research_works)
# Out:
# Original title:  Recursively Summarizing Books with Human Feedback
# Search result:  Recursively Summarizing Books with Human Feedback
# https://openalex.org/W3200980294
# Relevance score:  486.11057
# Match score:  217.39525582023398
#
# Original title:  One-Shot Imitation Learning
# Search result:  One-Shot Imitation Learning
# https://openalex.org/W2963094133
# Relevance score:  2516.118
# Match score:  184.4907228766487
#
# Original title:  Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online Videos
# Search result:  Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online
#   Videos
# https://openalex.org/W4283460722
#
# Original title:  Parameter Space Noise for Exploration
# Search result:  Parameter Space Noise for Exploration
# https://openalex.org/W2623491082
# Relevance score:  1871.2231
# Match score:  152.27797625659912
#
# Original title:  Efficient Training of Language Models to Fill in the Middle
# Search result:  Efficient Training of Language Models to Fill in the Middle
# https://openalex.org/W4288804596
# Relevance score:  306.09576
# Match score:  176.72446943380308
#
# Original title:  Some Considerations on Learning to Explore via Meta-Reinforcement Learning
# Search result:  Some Considerations on Learning to Explore via Meta-Reinforcement Learning
# https://openalex.org/W2785397462
# Relevance score:  1564.362
# Match score:  230.6525934143872
#
# Original title:  Solving Rubik's Cube with a Robot Hand
# Search result:  Solving Rubik's Cube with a Robot Hand
# https://openalex.org/W2981030070
# Relevance score:  3839.5698
# Match score:  243.322849384142
#
# Original title:  Learning to Generate Reviews and Discovering Sentiment
# Search result:  Learning To Generate Reviews and Discovering Sentiment
# https://openalex.org/W2606347107
# Relevance score:  2641.4417
# Match score:  182.71234293489925
#
# Original title:  Prediction and Control with Temporal Segment Models
# Search result:  Prediction and Control with Temporal Segment Models
# https://openalex.org/W2595180411
# Relevance score:  690.25323
# Match score:  154.34531439687973
#
# Original title:  Teaching Models to Express Their Uncertainty in Words
# Search result:  Teaching Models to Express Their Uncertainty in Words
# https://openalex.org/W4281748205
# Relevance score:  242.47575
# Match score:  171.456247098294
#
# Original title:  Variational Option Discovery Algorithms
# Search result:  Variational Option Discovery Algorithms.
# https://openalex.org/W2883433335
# Relevance score:  1189.4647
# Match score:  156.18436676956003
#
# Original title:  Semi-supervised Knowledge Transfer for Deep Learning from Private Training Data
# Search result:  Semi-supervised Knowledge Transfer for Deep Learning from Private Training Data
# https://openalex.org/W2950602864
# Relevance score:  3278.2717
# Match score:  264.1706618174522
#
# Original title:  Implicit Generation and Generalization in Energy-Based Models
# Search result:  Implicit Generation and Generalization in Energy-Based Models.
# https://openalex.org/W2922772346
# Relevance score:  1866.625
# Match score:  181.30264728226283
#
# Original title:  Large-Scale Study of Curiosity-Driven Learning
# Search result:  Large-Scale Study of Curiosity-Driven Learning
# https://openalex.org/W2885550588
# Relevance score:  2406.8845
# Match score:  193.32561528358266
#
# Original title:  AI safety via debate
# Search result:  AI safety via debate.
# https://openalex.org/W2798877128
# Relevance score:  775.9249
# Match score:  155.18498
#
# Original title:  OpenAI Gym
# Search result:  OpenAI Gym
# https://openalex.org/W3037207827
# Relevance score:  3719.8027
# Match score:  197.98512067398553
#
# Original title:  Sim-to-Real Transfer of Robotic Control with Dynamics Randomization
# Search result:  Sim-to-Real Transfer of Robotic Control with Dynamics Randomization
# https://openalex.org/W3101442004
# Relevance score:  5304.781
# Match score:  213.56244160308248
#
# Original title:  Supervising strong learners by amplifying weak experts
# Search result:  Supervising strong learners by amplifying weak experts.
# https://openalex.org/W2896930824
# Relevance score:  1076.0493
# Match score:  234.81320803591643
#
# Original title:  On First-Order Meta-Learning Algorithms
# Search result:  On First-Order Meta-Learning Algorithms.
# https://openalex.org/W2795900505
# Relevance score:  3493.256
# Match score:  169.2488062213778
#
# Original title:  Understanding the Capabilities, Limitations, and Societal Impact of Large Language Models
# Search result:  Understanding the Capabilities, Limitations, and Societal Impact of Large Language Models.
# https://openalex.org/W3128912454
# Relevance score:  672.08606
# Match score:  237.6183052834744
#
# Original title:  A Connection between Generative Adversarial Networks, Inverse Reinforcement Learning, and Energy-Based Models
# Search result:  A Connection between Generative Adversarial Networks, Inverse Reinforcement Learning, and Energy-Based Models
# https://openalex.org/W2566467060
# Relevance score:  3792.173
# Match score:  322.8112032016996
#
# Original title:  Self-critiquing models for assisting human evaluators
# Search result:  The Role of Debriefing in Simulation-Based Learning
# https://openalex.org/W2153694812
# Relevance score:  68.33836
# Match score:  2.0047558445153406
#
# Original title:  Stochastic Neural Networks for Hierarchical Reinforcement Learning
# Search result:  Stochastic Neural Networks for Hierarchical Reinforcement Learning
# https://openalex.org/W2606433045
# Relevance score:  2181.5398
# Match score:  206.13613521391372
#
# Original title:  Gotta Learn Fast: A New Benchmark for Generalization in RL
# Search result:  Gotta Learn Fast: A New Benchmark for Generalization in RL
# https://openalex.org/W2796979132
# Relevance score:  2733.1482
# Match score:  298.2109169531501
#
# Original title:  Equivalence Between Policy Gradients and Soft Q-Learning
# Search result:  Equivalence Between Policy Gradients and Soft Q-Learning
# https://openalex.org/W2609650878
# Relevance score:  2857.4954
# Match score:  242.36959648914404
#
# Original title:  Third-Person Imitation Learning
# Search result:  Third-Person Imitation Learning
# https://openalex.org/W2591957724
# Relevance score:  1493.1578
# Match score:  188.12020033220568
#
# Original title:  RL$^2$: Fast Reinforcement Learning via Slow Reinforcement Learning
# Search result:  RL$^2$: Fast Reinforcement Learning via Slow Reinforcement Learning
# https://openalex.org/W2578206533
# Relevance score:  4575.5557
# Match score:  303.6902981614128
#
# Original title:  Formal Mathematics Statement Curriculum Learning
# Search result:  Learning Styles and Learning Spaces: Enhancing Experiential Learning in Higher Education
# https://openalex.org/W2147454772
# Relevance score:  63.539074
# Match score:  1.1344454612502601
#
# Original title:  Language Models are Few-Shot Learners
# Search result:  Language Models are Few-Shot Learners
# https://openalex.org/W3030163527
# Relevance score:  6791.046
# Match score:  181.62811952235663
#
# Original title:  Toward Trustworthy AI Development: Mechanisms for Supporting Verifiable Claims
# Search result:  Toward Trustworthy AI Development: Mechanisms for Supporting Verifiable Claims
# https://openalex.org/W3017343191
# Relevance score:  1469.6913
# Match score:  272.914822969371
#
# Original title:  GPTs are GPTs: An Early Look at the Labor Market Impact Potential of Large Language Models
# Search result:  GPTs are GPTs: An Early Look at the Labor Market Impact Potential of
#   Large Language Models
# https://openalex.org/W4330336443
# Relevance score:  657.8817
# Match score:  294.2136404706247
#
# Original title:  TruthfulQA: Measuring How Models Mimic Human Falsehoods
# Search result:  TruthfulQA: Measuring How Models Mimic Human Falsehoods
# https://openalex.org/W3201174429
# Relevance score:  1090.8737
# Match score:  272.718425
#
# Original title:  Fine-Tuning Language Models from Human Preferences
# Search result:  Fine-Tuning Language Models from Human Preferences.
# https://openalex.org/W2973379954
# Relevance score:  1708.5774
# Match score:  194.7104654299094
#
# Original title:  #Exploration: A Study of Count-Based Exploration for Deep Reinforcement Learning
# Search result:  #Exploration: a study of count-based exploration for deep reinforcement learning
# https://openalex.org/W2561776174
# Relevance score:  3579.4543
# Match score:  233.0026286113136
#
# Original title:  Learning with Opponent-Learning Awareness
# Search result:  Learning with Opponent-Learning Awareness
# https://openalex.org/W2963627051
# Relevance score:  1989.1747
# Match score:  173.7950004797503
#
# Original title:  A Hazard Analysis Framework for Code Synthesis Large Language Models
# Search result:  A Hazard Analysis Framework for Code Synthesis Large Language Models
# https://openalex.org/W4288805334
# Relevance score:  197.5372
# Match score:  197.5372
#
# Original title:  Multimodal Neurons in Artificial Neural Networks
# Search result:  Multimodal Neurons in Artificial Neural Networks
# https://openalex.org/W3134095442
# Relevance score:  1323.198
# Match score:  165.39975
#
# Original title:  Emergent Complexity via Multi-Agent Competition
# Search result:  Emergent Complexity via Multi-Agent Competition.
# https://openalex.org/W2762117857
# Relevance score:  1927.5183
# Match score:  211.57261981608593
#
# Original title:  GamePad: A Learning Environment for Theorem Proving
# Search result:  GamePad: A Learning Environment for Theorem Proving
# https://openalex.org/W2807324060
# Relevance score:  1061.7709
# Match score:  226.3703164855412
#
# Original title:  Proximal Policy Optimization Algorithms
# Search result:  Proximal Policy Optimization Algorithms
# https://openalex.org/W2736601468
# Relevance score:  7691.4062
# Match score:  142.311491238939
#
# Original title:  Learning Policy Representations in Multiagent Systems
# Search result:  Learning Policy Representations in Multiagent Systems
# https://openalex.org/W2963231791
# Relevance score:  896.27313
# Match score:  182.95098655559786
#
# Original title:  Learning Dexterous In-Hand Manipulation
# Search result:  Learning dexterous in-hand manipulation
# https://openalex.org/W2990747716
# Relevance score:  5296.957
# Match score:  190.51830123269315
#
# Original title:  Testing Robustness Against Unforeseen Adversaries
# Search result:  Testing Robustness Against Unforeseen Adversaries
# https://openalex.org/W2969454448
# Relevance score:  1615.6958
# Match score:  224.05669432506963
#
# Original title:  Scaling Laws for Neural Language Models
# Search result:  Scaling Laws for Neural Language Models
# https://openalex.org/W3001279689
# Relevance score:  2386.3958
# Match score:  141.85650583692032
#
# Original title:  WebGPT: Browser-assisted question-answering with human feedback
# Search result:  WebGPT: Browser-assisted question-answering with human feedback
# https://openalex.org/W4309088836
# Relevance score:  493.16235
# Match score:  284.72741552668845
#
# Original title:  Quantifying Generalization in Reinforcement Learning
# Search result:  Quantifying Generalization in Reinforcement Learning
# https://openalex.org/W2903181768
# Relevance score:  1731.1418
# Match score:  158.69350862027125
#
# Original title:  Scalable trust-region method for deep reinforcement learning using Kronecker-factored approximation
# Search result:  Scalable trust-region method for deep reinforcement learning using Kronecker-factored approximation
# https://openalex.org/W2749928749
# Relevance score:  4510.666
# Match score:  310.52705359133165
#
# Original title:  Transfer of Adversarial Robustness Between Perturbation Types
# Search result:  Transfer of Adversarial Robustness Between Perturbation Types.
# https://openalex.org/W2943657790
# Relevance score:  811.8954
# Match score:  209.63049087082726
#
# Original title:  Multi-Agent Actor-Critic for Mixed Cooperative-Competitive Environments
# Search result:  Multi-Agent Actor-Critic for Mixed Cooperative-Competitive Environments
# https://openalex.org/W2963407617
# Relevance score:  5694.5127
# Match score:  270.8603474236742
#
# Original title:  Asymmetric Actor Critic for Image-Based Robot Learning
# Search result:  Asymmetric Actor Critic for Image-Based Robot Learning
# https://openalex.org/W2964198579
# Relevance score:  2031.995
# Match score:  219.11565598552082
#
# Original title:  Synthesizing Robust Adversarial Examples
# Search result:  Synthesizing Robust Adversarial Examples
# https://openalex.org/W2963557656
# Relevance score:  3198.1863
# Match score:  179.62803847575927
#
# Original title:  Concrete Problems in AI Safety
# Search result:  Concrete Problems in AI Safety
# https://openalex.org/W2462906003
# Relevance score:  3771.0046
# Match score:  156.8531132085685
#
# Original title:  Deep reinforcement learning from human preferences
# Search result:  Deep Reinforcement Learning from Human Preferences
# https://openalex.org/W2964263543
# Relevance score:  2217.4612
# Match score:  180.4544332332846
#
# Original title:  Release Strategies and the Social Impacts of Language Models
# Search result:  Release Strategies and the Social Impacts of Language Models.
# https://openalex.org/W2969958763
# Relevance score:  1290.283
# Match score:  158.82285825528635
#
# Original title:  Plan Online, Learn Offline: Efficient Learning and Exploration via Model-Based Control
# Search result:  Plan Online, Learn Offline: Efficient Learning and Exploration via Model-Based Control
# https://openalex.org/W2898917980
# Relevance score:  1819.8086
# Match score:  262.666746270899
#
# Original title:  Evaluating Large Language Models Trained on Code
# Search result:  Evaluating Large Language Models Trained on Code
# https://openalex.org/W3177813494
# Relevance score:  1237.7767
# Match score:  170.02170555454725
#
# Original title:  Generating Long Sequences with Sparse Transformers
# Search result:  Generating Long Sequences with Sparse Transformers.
# https://openalex.org/W2940744433
# Relevance score:  4128.4497
# Match score:  199.32342978939332
#
# Original title:  Measuring the Algorithmic Efficiency of Neural Networks
# Search result:  Measuring the Algorithmic Efficiency of Neural Networks.
# https://openalex.org/W3021954012
# Relevance score:  642.6989
# Match score:  147.44523980130276
#
# Original title:  FFJORD: Free-form Continuous Dynamics for Scalable Reversible Generative Models
# Search result:  FFJORD: Free-form Continuous Dynamics for Scalable Reversible Generative Models
# https://openalex.org/W2963641970
# Relevance score:  3819.3757
# Match score:  292.9327441154417
#
# Original title:  Let's Verify Step by Step
# Search result:  The Essential Guide to Semiconductors
# https://openalex.org/W612923280
# Relevance score:  27.300112
# Match score:  4.903244861124782
#
# Original title:  Learning to summarize from human feedback
# Search result:  Learning to summarize from human feedback
# https://openalex.org/W3082115681
# Relevance score:  956.73816
# Match score:  161.71826531702644
#
# Original title:  Variance Reduction for Policy Gradient with Action-Dependent Factorized Baselines
# Search result:  Variance Reduction for Policy Gradient with Action-Dependent Factorized Baselines
# https://openalex.org/W2786303200
# Relevance score:  1640.4972
# Match score:  269.6960783572742
#
# Original title:  Variational Lossy Autoencoder
# Search result:  Variational Lossy Autoencoder
# https://openalex.org/W2560512785
# Relevance score:  2578.3176
# Match score:  173.04534695048906
#
# Original title:  Domain Randomization for Transferring Deep Neural Networks from Simulation to the Real World
# Search result:  Domain randomization for transferring deep neural networks from simulation to the real world
# https://openalex.org/W2605102758
# Relevance score:  9646.931
# Match score:  247.03258923358644
#
# Original title:  Adversarial Attacks on Neural Network Policies
# Search result:  Adversarial Attacks on Neural Network Policies
# https://openalex.org/W2949103145
# Relevance score:  2758.559
# Match score:  190.35865593138854
#
# Original title:  Activation Atlas
# Search result:  MAP kinase in situ activation atlas during <i>Drosophila</i> embryogenesis
# https://openalex.org/W2148649613
# Relevance score:  1003.26373
# Match score:  58.313519824908326
#
# Original title:  Training Verifiers to Solve Math Word Problems
# Search result:  Training Verifiers to Solve Math Word Problems
# https://openalex.org/W4286892945
# Relevance score:  357.98676
# Match score:  206.68375225232197
#
# Original title:  Evolution Strategies as a Scalable Alternative to Reinforcement Learning
# Search result:  Evolution Strategies as a Scalable Alternative to Reinforcement Learning.
# https://openalex.org/W2596367596
# Relevance score:  4056.3833
# Match score:  190.37550117091445
#
# Original title:  Language models can explain neurons in language models
# Search result:  RECEPTIVE FIELDS AND FUNCTIONAL ARCHITECTURE IN TWO NONSTRIATE VISUAL AREAS (18 AND 19) OF THE CAT
# https://openalex.org/W1594551768
# Relevance score:  185.01836
# Match score:  3.7901186506632722
#
# Original title:  Interpretable and Pedagogical Examples
# Search result:  Interpretable and Pedagogical Examples
# https://openalex.org/W2766774033
# Relevance score:  407.46512
# Match score:  144.06067472449516
#
# Original title:  Computational Limitations in Robust Classification and Win-Win Results
# Search result:  Computational Limitations in Robust Classification and Win-Win Results.
# https://openalex.org/W2965341833
# Relevance score:  1053.3262
# Match score:  263.33155
#
# Original title:  Jukebox: A Generative Model for Music
# Search result:  Jukebox: A Generative Model for Music
# https://openalex.org/W3021164770
# Relevance score:  1743.3287
# Match score:  184.79247261542437
#
# Original title:  Neural MMO: A Massively Multiagent Game Environment for Training and Evaluating Intelligent Agents
# Search result:  Neural MMO: A Massively Multiagent Game Environment for Training and Evaluating Intelligent Agents.
# https://openalex.org/W2918965305
#
# Original title:  Adversarial Training Methods for Semi-Supervised Text Classification
# Search result:  Adversarial Training Methods for Semi-Supervised Text Classification.
# https://openalex.org/W3093419064
# Relevance score:  2819.4883
# Match score:  234.95735833333333
#
# Original title:  UCB Exploration via Q-Ensembles
# Search result:  UCB Exploration via Q-Ensembles
# https://openalex.org/W2767313115
# Relevance score:  1296.45
# Match score:  219.14004670855707
#
# Original title:  Continuous Adaptation via Meta-Learning in Nonstationary and Competitive Environments
# Search result:  Continuous Adaptation via Meta-Learning in Nonstationary and Competitive Environments
# https://openalex.org/W2762872434
# Relevance score:  2380.48
# Match score:  255.21424469306737
#
# Original title:  Generative Language Models and Automated Influence Operations: Emerging Threats and Potential Mitigations
# Search result:  Generative Language Models and Automated Influence Operations: Emerging
#   Threats and Potential Mitigations
# https://openalex.org/W4315881236
# Relevance score:  259.45657
# Match score:  259.45657
#
# Original title:  DeepType: Multilingual Entity Linking by Neural Type System Evolution
# Search result:  DeepType: Multilingual Entity Linking by Neural Type System Evolution
# https://openalex.org/W2964075320
# Relevance score:  2331.528
# Match score:  278.67089690642
#
# Original title:  Frontier AI Regulation: Managing Emerging Risks to Public Safety
# Search result:  Bounded Rationality and Organizational Learning
# https://openalex.org/W4362210174
# Relevance score:  123.15503
# Match score:  3.5463247289508395
#
# Original title:  Deep Double Descent: Where Bigger Models and More Data Hurt
# Search result:  Deep Double Descent: Where Bigger Models and More Data Hurt
# https://openalex.org/W2996603747
# Relevance score:  3133.2964
# Match score:  272.71844636321333
#
# Original title:  Text and Code Embeddings by Contrastive Pre-Training
# Search result:  Text and Code Embeddings by Contrastive Pre-Training
# https://openalex.org/W4225576545
# Relevance score:  290.3248
# Match score:  205.29063482662815
#
# Original title:  Generative Language Modeling for Automated Theorem Proving
# Search result:  Generative Language Modeling for Automated Theorem Proving.
# https://openalex.org/W3083835029
# Relevance score:  1381.0819
# Match score:  213.10556374201082
#
# Original title:  Weight Normalization: A Simple Reparameterization to Accelerate Training of Deep Neural Networks
# Search result:  Weight normalization: a simple reparameterization to accelerate training of deep neural networks
# https://openalex.org/W2963685250
# Relevance score:  7102.704
# Match score:  309.9874163701488
#
# Original title:  AI Safety Needs Social Scientists
# Search result:  AI Safety Needs Social Scientists
# https://openalex.org/W2917705988
# Relevance score:  881.2474
# Match score:  183.75278525032058
#
# Original title:  Scaling Laws for Reward Model Overoptimization
# Search result:  From initial idea to unique advantage: The entrepreneurial challenge of constructing a resource base
# https://openalex.org/W2179823604
# Relevance score:  17.644703
# Match score:  0.689962486191823
#
# Original title:  Transfer from Simulation to Real World through Learning Deep Inverse Dynamics Model
# Search result:  Transfer from Simulation to Real World through Learning Deep Inverse Dynamics Model
# https://openalex.org/W2530944449
# Relevance score:  2344.0632
# Match score:  260.45146666666665
#
# Original title:  The Malicious Use of Artificial Intelligence: Forecasting, Prevention, and Mitigation
# Search result:  The Malicious Use of Artificial Intelligence: Forecasting, Prevention, and Mitigation
# https://openalex.org/W2787887017
# Relevance score:  2209.1223
# Match score:  232.8619365956596
#
# Original title:  Point-E: A System for Generating 3D Point Clouds from Complex Prompts
# Search result:  Point-E: A System for Generating 3D Point Clouds from Complex Prompts
# https://openalex.org/W4312045746
# Relevance score:  250.61372
# Match score:  250.61372
#
# Original title:  Evolved Policy Gradients
# Search result:  Evolved Policy Gradients
# https://openalex.org/W2964227899
# Relevance score:  1048.81
# Match score:  140.1531315650849
#
# Original title:  Evolution through Large Models
# Search result:  Dynamic topic models
# https://openalex.org/W2072644219
# Relevance score:  220.71548
# Match score:  5.165143682567985
#
# Original title:  Learning Sparse Neural Networks through $L_0$ Regularization
# Search result:  Learning Sparse Neural Networks through L_0 Regularization
# https://openalex.org/W2963828549
# Relevance score:  4474.9854
# Match score:  244.1304682062171
#
# Original title:  Emergence of Grounded Compositional Language in Multi-Agent Populations
# Search result:  Emergence of Grounded Compositional Language in Multi-Agent Populations
# https://openalex.org/W2963881016
# Relevance score:  3057.88
# Match score:  227.2904303926285
#
# Original title:  Hierarchical Text-Conditional Image Generation with CLIP Latents
# Search result:  Hierarchical Text-Conditional Image Generation with CLIP Latents
# https://openalex.org/W4224035735
# Relevance score:  1211.0077
# Match score:  237.49814974658148
#
# Original title:  The Role of Cooperation in Responsible AI Development
# Search result:  The Role of Cooperation in Responsible AI Development
# https://openalex.org/W2962528222
# Relevance score:  565.8888
# Match score:  178.94975103794917
#
# Original title:  Exploration by Random Network Distillation
# Search result:  Exploration by Random Network Distillation.
# https://openalex.org/W2899205164
# Relevance score:  2350.5903
# Match score:  158.4767656967431
#
# Original title:  Learning Transferable Visual Models From Natural Language Supervision
# Search result:  Learning Transferable Visual Models From Natural Language Supervision
# https://openalex.org/W3135367836
# Relevance score:  3611.6416
# Match score:  203.17071333205533
#
# Original title:  Meta Learning Shared Hierarchies
# Search result:  Meta Learning Shared Hierarchies
# https://openalex.org/W2765602917
# Relevance score:  1277.4324
# Match score:  143.7223737490893
#
# Original title:  Emergent Tool Use From Multi-Agent Autocurricula
# Search result:  Emergent Tool Use From Multi-Agent Autocurricula.
# https://openalex.org/W2973525135
# Relevance score:  2329.0334
# Match score:  231.74748502412177
#
# Original title:  Hindsight Experience Replay
# Search result:  Hindsight Experience Replay
# https://openalex.org/W2964001908
# Relevance score:  4332.697
# Match score:  195.33306605573398
#
# Original title:  Concept Learning with Energy-Based Models
# Search result:  Concept Learning with Energy-Based Models
# https://openalex.org/W2963533931
# Relevance score:  248.94768
# Match score:  124.47384
#
# Original title:  Glow: Generative Flow with Invertible 1x1 Convolutions
# Search result:  Glow: Generative Flow with Invertible 1x1 Convolutions
# https://openalex.org/W2963139417
# Relevance score:  7831.4526
# Match score:  288.67117271958875
#
# Original title:  GPT-4 Technical Report
# Search result:  GPT-4 Technical Report
# https://openalex.org/W4327810158
# Relevance score:  770.0426
# Match score:  151.0177786037586
#
# Original title:  PixelCNN++: Improving the PixelCNN with Discretized Logistic Mixture Likelihood and Other Modifications
# Search result:  PixelCNN++: Improving the PixelCNN with Discretized Logistic Mixture Likelihood and Other Modifications
# https://openalex.org/W2964122153
# Relevance score:  6960.2837
# Match score:  376.9204945237658
#
# Original title:  Dota 2 with Large Scale Deep Reinforcement Learning
# Search result:  Dota 2 with Large Scale Deep Reinforcement Learning
# https://openalex.org/W2996037775
# Relevance score:  3953.8293
# Match score:  216.66851096608323
#
# Original title:  Domain Randomization and Generative Models for Robotic Grasping
# Search result:  Domain Randomization and Generative Models for Robotic Grasping
# https://openalex.org/W2964214518
# Relevance score:  2046.725
# Match score:  215.7437581336042
#
# Original title:  Teacher-Student Curriculum Learning
# Search result:  Teacher–Student Curriculum Learning
# https://openalex.org/W2972758308
# Relevance score:  1676.0002
# Match score:  143.7158314992809
#
# Original title:  Training language models to follow instructions with human feedback
# Search result:  Training language models to follow instructions with human feedback
# https://openalex.org/W4226278401
# Relevance score:  952.1189
# Match score:  198.5305145461666
#
# Original title:  Extensions and Limitations of the Neural GPU
# Search result:  Extensions and Limitations of the Neural GPU
# https://openalex.org/W2548137223
# Relevance score:  395.41043
# Match score:  176.83292009848444
#
# Original title:  Leveraging Procedural Generation to Benchmark Reinforcement Learning
# Search result:  Leveraging Procedural Generation to Benchmark Reinforcement Learning
# https://openalex.org/W2994073215
# Relevance score:  1759.466
# Match score:  219.93325
#
# Original title:  Improving GANs Using Optimal Transport
# Search result:  Improving GANs Using Optimal Transport
# https://openalex.org/W2963989027
# Relevance score:  1320.4009
# Match score:  154.5412360948033
#
# Original title:  On the Quantitative Analysis of Decoder-Based Generative Models
# Search result:  On the Quantitative Analysis of Decoder-Based Generative Models
# https://openalex.org/W2953116488
# Relevance score:  1835.1339
# Match score:  190.29452076622547
#
# Original title:  Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research
# Search result:  Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research
# https://openalex.org/W2789008106
# Relevance score:  3176.3042
# Match score:  263.77770645044967
# 104

# %%
openai_research_works
# Out:
# [{'id': 'https://openalex.org/W3200980294',
#   'doi': None,
#   'title': 'Recursively Summarizing Books with Human Feedback',
#   'display_name': 'Recursively Summarizing Books with Human Feedback',
#   'relevance_score': 486.11057,
#   'publication_year': 2021,
#   'publication_date': '2021-09-22',
#   'ids': {'openalex': 'https://openalex.org/W3200980294', 'mag': '3200980294'},
#   'language': 'en',
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'http://arxiv.org/pdf/2109.10862.pdf',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'posted-content',
#   'open_access': {'is_oa': False,
#    'oa_status': 'closed',
#    'oa_url': None,
#    'any_repository_has_fulltext': False},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5007570707',
#      'display_name': 'Jeff Wu',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Jeff Wu',
#     'raw_affiliation_string': '[OpenAI.]',
#     'raw_affiliation_strings': ['[OpenAI.]']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5068949174',
#      'display_name': 'Long Ouyang',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Long Ouyang',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5089747113',
#      'display_name': 'Daniel M. Ziegler',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Daniel M. Ziegler',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5019575601',
#      'display_name': 'Nisan Stiennon',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Nisan Stiennon',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5004295653',
#      'display_name': 'Ryan Lowe',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Ryan Lowe',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5090592321',
#      'display_name': 'Jan Leike',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Jan Leike',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5037736834',
#      'display_name': 'Paul F. Christiano',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Paul F. Christiano',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'institutions_distinct_count': 0,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 5,
#   'biblio': {'volume': None,
#    'issue': None,
#    'first_page': None,
#    'last_page': None},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C170858558',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1394144',
#     'display_name': 'Automatic summarization',
#     'level': 2,
#     'score': 0.93695277},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.86179805},
#    {'id': 'https://openalex.org/C185798385',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1161707',
#     'display_name': 'Benchmark (surveying)',
#     'level': 2,
#     'score': 0.7243924},
#    {'id': 'https://openalex.org/C2780451532',
#     'wikidata': 'https://www.wikidata.org/wiki/Q759676',
#     'display_name': 'Task (project management)',
#     'level': 2,
#     'score': 0.7044509},
#    {'id': 'https://openalex.org/C165064840',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1321061',
#     'display_name': 'Matching (statistics)',
#     'level': 2,
#     'score': 0.58795375},
#    {'id': 'https://openalex.org/C61423126',
#     'wikidata': 'https://www.wikidata.org/wiki/Q187432',
#     'display_name': 'Scripting language',
#     'level': 2,
#     'score': 0.5717827},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.5666259},
#    {'id': 'https://openalex.org/C119857082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#     'display_name': 'Machine learning',
#     'level': 1,
#     'score': 0.49615583},
#    {'id': 'https://openalex.org/C2776214188',
#     'wikidata': 'https://www.wikidata.org/wiki/Q408386',
#     'display_name': 'Inference',
#     'level': 2,
#     'score': 0.45501888},
#    {'id': 'https://openalex.org/C204321447',
#     'wikidata': 'https://www.wikidata.org/wiki/Q30642',
#     'display_name': 'Natural language processing',
#     'level': 1,
#     'score': 0.38447872},
#    {'id': 'https://openalex.org/C23123220',
#     'wikidata': 'https://www.wikidata.org/wiki/Q816826',
#     'display_name': 'Information retrieval',
#     'level': 1,
#     'score': 0.37147945},
#    {'id': 'https://openalex.org/C105795698',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12483',
#     'display_name': 'Statistics',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C187736073',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2920921',
#     'display_name': 'Management',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C13280743',
#     'wikidata': 'https://www.wikidata.org/wiki/Q131089',
#     'display_name': 'Geodesy',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C162324750',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#     'display_name': 'Economics',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': 0.0}],
#   'mesh': [],
#   'locations_count': 1,
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'http://arxiv.org/pdf/2109.10862.pdf',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': 'submittedVersion',
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': None,
#   'sustainable_development_goals': [],
#   'grants': [],
#   'referenced_works_count': 66,
#   'referenced_works': ['https://openalex.org/W1517524280',
#    'https://openalex.org/W1525595230',
#    'https://openalex.org/W1540841088',
#    'https://openalex.org/W1602831581',
#    'https://openalex.org/W2012036715',
#    'https://openalex.org/W2051840895',
#    'https://openalex.org/W2073512134',
#    'https://openalex.org/W2108325777',
#    'https://openalex.org/W2157979304',
#    'https://openalex.org/W2160371091',
#    'https://openalex.org/W2174803659',
#    'https://openalex.org/W2295759824',
#    'https://openalex.org/W2462906003',
#    'https://openalex.org/W2487501366',
#    'https://openalex.org/W2618097077',
#    'https://openalex.org/W2626796053',
#    'https://openalex.org/W2787214294',
#    'https://openalex.org/W2798047776',
#    'https://openalex.org/W2798240283',
#    'https://openalex.org/W2798299685',
#    'https://openalex.org/W2798664956',
#    'https://openalex.org/W2798877128',
#    'https://openalex.org/W2896930824',
#    'https://openalex.org/W2899485151',
#    'https://openalex.org/W2901707424',
#    'https://openalex.org/W2905137389',
#    'https://openalex.org/W2910458567',
#    'https://openalex.org/W2936695845',
#    'https://openalex.org/W2943766373',
#    'https://openalex.org/W2945918281',
#    'https://openalex.org/W2947881255',
#    'https://openalex.org/W2948036864',
#    'https://openalex.org/W2948138438',
#    'https://openalex.org/W2953981431',
#    'https://openalex.org/W2962943921',
#    'https://openalex.org/W2963325985',
#    'https://openalex.org/W2963403868',
#    'https://openalex.org/W2963963993',
#    'https://openalex.org/W2964263543',
#    'https://openalex.org/W2969740599',
#    'https://openalex.org/W2971996420',
#    'https://openalex.org/W2972005891',
#    'https://openalex.org/W2972114612',
#    'https://openalex.org/W2972838397',
#    'https://openalex.org/W2973379954',
#    'https://openalex.org/W2974904219',
#    'https://openalex.org/W2981852735',
#    'https://openalex.org/W2998546572',
#    'https://openalex.org/W3005958085',
#    'https://openalex.org/W3015517925',
#    'https://openalex.org/W3020908159',
#    'https://openalex.org/W3021557422',
#    'https://openalex.org/W3022800647',
#    'https://openalex.org/W3030163527',
#    'https://openalex.org/W3036831227',
#    'https://openalex.org/W3047189408',
#    'https://openalex.org/W3082115681',
#    'https://openalex.org/W3100436891',
#    'https://openalex.org/W3101144749',
#    'https://openalex.org/W3104442086',
#    'https://openalex.org/W3105952014',
#    'https://openalex.org/W3106110407',
#    'https://openalex.org/W3111425437',
#    'https://openalex.org/W3116972344',
#    'https://openalex.org/W3163073193',
#    'https://openalex.org/W3163837402'],
#   'related_works': ['https://openalex.org/W1879936196',
#    'https://openalex.org/W2231123512',
#    'https://openalex.org/W2280475815',
#    'https://openalex.org/W2510759893',
#    'https://openalex.org/W2803946715',
#    'https://openalex.org/W2883616768',
#    'https://openalex.org/W2947053256',
#    'https://openalex.org/W2963721761',
#    'https://openalex.org/W2973374199',
#    'https://openalex.org/W2985050317',
#    'https://openalex.org/W2994088922',
#    'https://openalex.org/W3020535887',
#    'https://openalex.org/W3020873268',
#    'https://openalex.org/W3023420335',
#    'https://openalex.org/W3035043191',
#    'https://openalex.org/W3106234277',
#    'https://openalex.org/W3136182385',
#    'https://openalex.org/W3144879261',
#    'https://openalex.org/W3153480004',
#    'https://openalex.org/W3212747844'],
#   'ngrams_url': 'https://api.openalex.org/works/W3200980294/ngrams',
#   'abstract_inverted_index': {'A': [0, 176],
#    'major': [1],
#    'challenge': [2],
#    'for': [3, 19, 173, 191],
#    'scaling': [4],
#    'machine': [5],
#    'learning': [6, 42],
#    'is': [7],
#    'training': [8],
#    'models': [9, 52, 131],
#    'to': [10, 21, 60, 91, 113, 126],
#    'perform': [11],
#    'tasks': [12],
#    'that': [13],
#    'are': [14, 124],
#    'very': [15],
#    'difficult': [16],
#    'or': [17],
#    'time-consuming': [18],
#    'humans': [20, 62],
#    'evaluate.': [22],
#    'We': [23, 70, 164, 199],
#    'present': [24],
#    'progress': [25],
#    'on': [26, 29, 54, 66, 168, 186],
#    'this': [27],
#    'problem': [28],
#    'the': [30, 58, 67, 98, 105, 118, 130, 137, 152, 169, 187],
#    'task': [31, 48, 59],
#    'of': [32, 35, 57, 75, 104, 117, 147, 154, 162, 202],
#    'abstractive': [33],
#    'summarization': [34, 93],
#    'entire': [36, 119, 138, 148],
#    'fiction': [37],
#    'novels.': [38],
#    'Our': [39, 121, 141],
#    'method': [40],
#    'combines': [41],
#    'from': [43, 79, 204],
#    'human': [44, 80, 122],
#    'feedback': [45, 65],
#    'with': [46],
#    'recursive': [47],
#    'decomposition:': [49],
#    'we': [50],
#    'use': [51],
#    'trained': [53],
#    'smaller': [55],
#    'parts': [56],
#    'assist': [61],
#    'in': [63, 157],
#    'giving': [64],
#    'broader': [68],
#    'task.': [69],
#    'collect': [71],
#    'a': [72, 115, 158],
#    'large': [73],
#    'volume': [74],
#    'demonstrations': [76],
#    'and': [77, 82, 88, 107, 128, 196],
#    'comparisons': [78],
#    'labelers,': [81],
#    'fine-tune': [83],
#    'GPT-3': [84],
#    'using': [85, 180],
#    'behavioral': [86],
#    'cloning': [87],
#    'reward': [89],
#    'modeling': [90],
#    'do': [92],
#    'recursively.': [94],
#    'At': [95],
#    'inference': [96],
#    'time,': [97],
#    'model': [99, 143, 179],
#    'first': [100],
#    'summarizes': [101, 110],
#    'small': [102],
#    'sections': [103],
#    'book': [106],
#    'then': [108],
#    'recursively': [109],
#    'these': [111, 181],
#    'summaries': [112, 146, 156, 182],
#    'produce': [114],
#    'summary': [116],
#    'book.': [120],
#    'labelers': [123],
#    'able': [125],
#    'supervise': [127],
#    'evaluate': [129],
#    'quickly,': [132],
#    'despite': [133],
#    'not': [134],
#    'having': [135],
#    'read': [136],
#    'books': [139, 195],
#    'themselves.': [140],
#    'resulting': [142],
#    'generates': [144],
#    'sensible': [145],
#    'books,': [149],
#    'even': [150],
#    'matching': [151],
#    'quality': [153],
#    'human-written': [155],
#    'few': [159],
#    'cases': [160],
#    '($\\sim5\\%$': [161],
#    'books).': [163],
#    'achieve': [165],
#    'state-of-the-art': [166, 184],
#    'results': [167, 185],
#    'recent': [170],
#    'BookSum': [171],
#    'dataset': [172],
#    'book-length': [174],
#    'summarization.': [175],
#    'zero-shot': [177],
#    'question-answering': [178],
#    'achieves': [183],
#    'challenging': [188],
#    'NarrativeQA': [189],
#    'benchmark': [190],
#    'answering': [192],
#    'questions': [193],
#    'about': [194],
#    'movie': [197],
#    'scripts.': [198],
#    'release': [200],
#    'datasets': [201],
#    'samples': [203],
#    'our': [205],
#    'model.': [206]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W3200980294',
#   'counts_by_year': [{'year': 2022, 'cited_by_count': 1},
#    {'year': 2021, 'cited_by_count': 4}],
#   'updated_date': '2023-08-23T23:50:39.870035',
#   'created_date': '2021-09-27'},
#  {'id': 'https://openalex.org/W2963094133',
#   'doi': None,
#   'title': 'One-Shot Imitation Learning',
#   'display_name': 'One-Shot Imitation Learning',
#   'relevance_score': 2516.118,
#   'publication_year': 2017,
#   'publication_date': '2017-03-21',
#   'ids': {'openalex': 'https://openalex.org/W2963094133', 'mag': '2963094133'},
#   'language': 'en',
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'http://papers.nips.cc/paper/6709-one-shot-imitation-learning.pdf',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306420609',
#     'display_name': 'Neural Information Processing Systems',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': False,
#     'is_in_doaj': False,
#     'host_organization': None,
#     'host_organization_name': None,
#     'host_organization_lineage': [],
#     'host_organization_lineage_names': [],
#     'type': 'conference'},
#    'license': None,
#    'version': None,
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'proceedings-article',
#   'open_access': {'is_oa': False,
#    'oa_status': 'closed',
#    'oa_url': None,
#    'any_repository_has_fulltext': False},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5027941146',
#      'display_name': 'Yan Duan',
#      'orcid': 'https://orcid.org/0009-0007-2205-1182'},
#     'institutions': [{'id': 'https://openalex.org/I95457486',
#       'display_name': 'University of California, Berkeley',
#       'ror': 'https://ror.org/01an7q238',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_author_name': 'Yan Duan',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5091819924',
#      'display_name': 'Marcin Andrychowicz',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4654613',
#       'display_name': 'University of Warsaw',
#       'ror': 'https://ror.org/039bjqg32',
#       'country_code': 'PL',
#       'type': 'education'}],
#     'countries': ['PL'],
#     'is_corresponding': False,
#     'raw_author_name': 'Marcin Andrychowicz',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5004762590',
#      'display_name': 'Bradly C. Stadie',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I95457486',
#       'display_name': 'University of California, Berkeley',
#       'ror': 'https://ror.org/01an7q238',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_author_name': 'Bradly Stadie',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5067435818',
#      'display_name': 'OpenAI Jonathan Ho',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'OpenAI Jonathan Ho',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5009926169',
#      'display_name': 'Jonas Schneider',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Jonas Schneider',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5006446297',
#      'display_name': 'Ilya Sutskever',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Ilya Sutskever',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5049349154',
#      'display_name': 'Pieter Abbeel',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I95457486',
#       'display_name': 'University of California, Berkeley',
#       'ror': 'https://ror.org/01an7q238',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_author_name': 'Pieter Abbeel',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5076651586',
#      'display_name': 'Wojciech Zaremba',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Wojciech Zaremba',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'institutions_distinct_count': 2,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 186,
#   'biblio': {'volume': '30',
#    'issue': None,
#    'first_page': '1087',
#    'last_page': '1098'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.77718294},
#    {'id': 'https://openalex.org/C2780451532',
#     'wikidata': 'https://www.wikidata.org/wiki/Q759676',
#     'display_name': 'Task (project management)',
#     'level': 2,
#     'score': 0.6721312},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.59236103},
#    {'id': 'https://openalex.org/C177264268',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1514741',
#     'display_name': 'Set (abstract data type)',
#     'level': 2,
#     'score': 0.5482342},
#    {'id': 'https://openalex.org/C45235069',
#     'wikidata': 'https://www.wikidata.org/wiki/Q278425',
#     'display_name': 'Table (database)',
#     'level': 2,
#     'score': 0.5258285},
#    {'id': 'https://openalex.org/C2778112365',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3511065',
#     'display_name': 'Sequence (biology)',
#     'level': 2,
#     'score': 0.5184274},
#    {'id': 'https://openalex.org/C50644808',
#     'wikidata': 'https://www.wikidata.org/wiki/Q192776',
#     'display_name': 'Artificial neural network',
#     'level': 2,
#     'score': 0.47698456},
#    {'id': 'https://openalex.org/C2776401178',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12050496',
#     'display_name': 'Feature (linguistics)',
#     'level': 2,
#     'score': 0.4652679},
#    {'id': 'https://openalex.org/C2777210771',
#     'wikidata': 'https://www.wikidata.org/wiki/Q4927124',
#     'display_name': 'Block (permutation group theory)',
#     'level': 2,
#     'score': 0.4396219},
#    {'id': 'https://openalex.org/C28006648',
#     'wikidata': 'https://www.wikidata.org/wiki/Q6934509',
#     'display_name': 'Multi-task learning',
#     'level': 3,
#     'score': 0.4287194},
#    {'id': 'https://openalex.org/C90509273',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11012',
#     'display_name': 'Robot',
#     'level': 2,
#     'score': 0.41340223},
#    {'id': 'https://openalex.org/C119857082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#     'display_name': 'Machine learning',
#     'level': 1,
#     'score': 0.39017582},
#    {'id': 'https://openalex.org/C124101348',
#     'wikidata': 'https://www.wikidata.org/wiki/Q172491',
#     'display_name': 'Data mining',
#     'level': 1,
#     'score': 0.11267784},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 0.10158989},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 0.08426723},
#    {'id': 'https://openalex.org/C41895202',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8162',
#     'display_name': 'Linguistics',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C2524010',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8087',
#     'display_name': 'Geometry',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C201995342',
#     'wikidata': 'https://www.wikidata.org/wiki/Q682496',
#     'display_name': 'Systems engineering',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': 0.0}],
#   'mesh': [],
#   'locations_count': 1,
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'http://papers.nips.cc/paper/6709-one-shot-imitation-learning.pdf',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S4306420609',
#      'display_name': 'Neural Information Processing Systems',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': False,
#      'is_in_doaj': False,
#      'host_organization': None,
#      'host_organization_name': None,
#      'host_organization_lineage': [],
#      'host_organization_lineage_names': [],
#      'type': 'conference'},
#     'license': None,
#     'version': None,
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': None,
#   'sustainable_development_goals': [],
#   'grants': [],
#   'referenced_works_count': 0,
#   'referenced_works': [],
#   'related_works': ['https://openalex.org/W1771410628',
#    'https://openalex.org/W1986014385',
#    'https://openalex.org/W1999874108',
#    'https://openalex.org/W2061562262',
#    'https://openalex.org/W2064675550',
#    'https://openalex.org/W2099471712',
#    'https://openalex.org/W2121863487',
#    'https://openalex.org/W2145339207',
#    'https://openalex.org/W2158782408',
#    'https://openalex.org/W2167224731',
#    'https://openalex.org/W2194775991',
#    'https://openalex.org/W2257979135',
#    'https://openalex.org/W2604763608',
#    'https://openalex.org/W2736601468',
#    'https://openalex.org/W2962732055',
#    'https://openalex.org/W2962957031',
#    'https://openalex.org/W2963099939',
#    'https://openalex.org/W2963277051',
#    'https://openalex.org/W2964121744',
#    'https://openalex.org/W2964161785'],
#   'ngrams_url': 'https://api.openalex.org/works/W2963094133/ngrams',
#   'abstract_inverted_index': {'Imitation': [0],
#    'learning': [1],
#    'has': [2, 98],
#    'been': [3],
#    'commonly': [4],
#    'applied': [5],
#    'to': [6, 37, 50, 107, 122, 242, 264, 266],
#    'solve': [7],
#    'different': [8, 136, 144, 149],
#    'tasks': [9, 269, 288],
#    'in': [10, 271],
#    'isolation.': [11],
#    'This': [12, 25],
#    'usually': [13],
#    'requires': [14],
#    'either': [15],
#    'careful': [16],
#    'feature': [17],
#    'engineering,': [18],
#    'or': [19],
#    'a': [20, 66, 87, 103, 112, 115, 127, 164, 224, 227, 231, 283, 294],
#    'significant': [21],
#    'number': [22],
#    'of': [23,
#     43,
#     53,
#     93,
#     138,
#     143,
#     146,
#     161,
#     166,
#     190,
#     194,
#     208,
#     226,
#     230,
#     248,
#     258,
#     287,
#     311],
#    'samples.': [24],
#    'is': [26, 86, 157, 172, 186, 234, 240],
#    'far': [27],
#    'from': [28, 39],
#    'what': [29],
#    'we': [30, 64, 74, 80, 291],
#    'desire:': [31],
#    'ideally,': [32],
#    'robots': [33],
#    'should': [34],
#    'be': [35, 106, 121],
#    'able': [36],
#    'learn': [38],
#    'very': [40, 88],
#    'few': [41],
#    'demonstrations': [42, 162, 301],
#    'any': [44, 300],
#    'given': [45],
#    'task,': [46, 56],
#    'and': [47, 95, 180, 197, 210, 236, 268, 289],
#    'instantly': [48],
#    'generalize': [49, 265],
#    'new': [51, 232, 246, 250],
#    'situations': [52],
#    'the': [54, 82, 139, 181, 187, 191, 195, 202, 205, 218, 237, 256, 262, 272],
#    'same': [55],
#    'without': [57],
#    'requiring': [58],
#    'task-specific': [59],
#    'engineering.': [60],
#    'In': [61, 133],
#    'this': [62, 249, 280],
#    'paper,': [63],
#    'propose': [65],
#    'meta-learning': [67],
#    'framework': [68],
#    'for': [69, 163],
#    'achieving': [70],
#    'such': [71],
#    'capability,': [72],
#    'which': [73],
#    'call': [75],
#    'one-shot': [76],
#    'imitation': [77],
#    'learning.': [78],
#    'Specifically,': [79],
#    'consider': [81],
#    'setting': [83],
#    'where': [84],
#    'there': [85],
#    'large': [89],
#    '(maybe': [90],
#    'infinite)': [91],
#    'set': [92],
#    'tasks,': [94],
#    'each': [96, 134],
#    'task': [97, 104, 119, 140, 233],
#    'many': [99],
#    'instantiations.': [100],
#    'For': [101],
#    'example,': [102],
#    'could': [105, 120],
#    'stack': [108],
#    'all': [109, 124, 167],
#    'blocks': [110, 125, 147],
#    'on': [111, 126, 245, 282],
#    'table': [113, 128],
#    'into': [114, 129, 302],
#    'single': [116, 228],
#    'tower,': [117],
#    'another': [118],
#    'place': [123],
#    'two-block': [130],
#    'towers,': [131],
#    'etc.': [132],
#    'case,': [135],
#    'instances': [137, 247],
#    'would': [141],
#    'consist': [142],
#    'sets': [145],
#    'with': [148, 159, 201, 217],
#    'initial': [150, 188],
#    'states.': [151],
#    'At': [152, 221],
#    'training': [153, 273, 279],
#    'time,': [154, 223],
#    'our': [155],
#    'algorithm': [156],
#    'presented': [158],
#    'pairs': [160],
#    'subset': [165],
#    'tasks.': [168, 312],
#    'A': [169],
#    'neural': [170, 238],
#    'net': [171, 239],
#    'trained': [173],
#    'that': [174, 204, 255, 277, 297, 305],
#    'takes': [175],
#    'as': [176, 213, 215],
#    'input': [177],
#    'one': [178],
#    'demonstration': [179, 193, 225],
#    'current': [182],
#    'state': [183, 189],
#    '(which': [184],
#    'initially': [185],
#    'other': [192],
#    'pair),': [196],
#    'outputs': [198],
#    'an': [199, 308],
#    'action': [200],
#    'goal': [203],
#    'resulting': [206],
#    'sequence': [207],
#    'states': [209],
#    'actions': [211],
#    'matches': [212],
#    'closely': [214],
#    'possible': [216],
#    'second': [219],
#    'demonstration.': [220],
#    'test': [222],
#    'instance': [229],
#    'presented,': [235],
#    'expected': [241],
#    'perform': [243],
#    'well': [244],
#    'task.': [251],
#    'Our': [252],
#    'experiments': [253],
#    'show': [254],
#    'use': [257],
#    'soft': [259],
#    'attention': [260],
#    'allows': [261],
#    'model': [263, 281],
#    'conditions': [267],
#    'unseen': [270],
#    'data.': [274],
#    'We': [275],
#    'anticipate': [276],
#    'by': [278],
#    'much': [284],
#    'greater': [285],
#    'variety': [286, 310],
#    'settings,': [290],
#    'will': [292],
#    'obtain': [293],
#    'general': [295],
#    'system': [296],
#    'can': [298, 306],
#    'turn': [299],
#    'robust': [303],
#    'policies': [304],
#    'accomplish': [307],
#    'overwhelming': [309]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2963094133',
#   'counts_by_year': [{'year': 2022, 'cited_by_count': 1},
#    {'year': 2021, 'cited_by_count': 30},
#    {'year': 2020, 'cited_by_count': 53},
#    {'year': 2019, 'cited_by_count': 55},
#    {'year': 2018, 'cited_by_count': 38},
#    {'year': 2017, 'cited_by_count': 9}],
#   'updated_date': '2023-08-22T01:58:58.960142',
#   'created_date': '2019-07-30'},
#  {'id': 'https://openalex.org/W4283460722',
#   'doi': 'https://doi.org/10.48550/arxiv.2206.11795',
#   'title': 'Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online\n  Videos',
#   'display_name': 'Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online\n  Videos',
#   'publication_year': 2022,
#   'publication_date': '2022-06-23',
#   'ids': {'openalex': 'https://openalex.org/W4283460722',
#    'doi': 'https://doi.org/10.48550/arxiv.2206.11795'},
#   'language': 'en',
#   'primary_location': {'is_oa': True,
#    'landing_page_url': 'http://arxiv.org/abs/2206.11795',
#    'pdf_url': 'http://arxiv.org/pdf/2206.11795',
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'posted-content',
#   'open_access': {'is_oa': True,
#    'oa_status': 'green',
#    'oa_url': 'http://arxiv.org/pdf/2206.11795',
#    'any_repository_has_fulltext': True},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5048522044',
#      'display_name': 'Bowen Baker',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5046491870',
#      'display_name': 'Ilge Akkaya',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5018957231',
#      'display_name': 'P. A. Zhokhov',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5018598100',
#      'display_name': 'Joost Huizinga',
#      'orcid': 'https://orcid.org/0000-0003-0877-3051'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5034676524',
#      'display_name': 'Jie Tang',
#      'orcid': 'https://orcid.org/0000-0002-4969-9620'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5033112877',
#      'display_name': 'Adrien Ecoffet',
#      'orcid': 'https://orcid.org/0000-0001-9985-365X'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5091596210',
#      'display_name': 'Brandon Houghton',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5078100000',
#      'display_name': 'Raul Sampedro',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5006797018',
#      'display_name': 'Jeff Clune',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'institutions_distinct_count': 0,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 0,
#   'biblio': {'volume': None,
#    'issue': None,
#    'first_page': None,
#    'last_page': None},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.74374604},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.57366675},
#    {'id': 'https://openalex.org/C97541855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q830687',
#     'display_name': 'Reinforcement learning',
#     'level': 2,
#     'score': 0.53712696},
#    {'id': 'https://openalex.org/C110875604',
#     'wikidata': 'https://www.wikidata.org/wiki/Q75',
#     'display_name': 'The Internet',
#     'level': 2,
#     'score': 0.48209718},
#    {'id': 'https://openalex.org/C107457646',
#     'wikidata': 'https://www.wikidata.org/wiki/Q207434',
#     'display_name': 'Human–computer interaction',
#     'level': 1,
#     'score': 0.45431563},
#    {'id': 'https://openalex.org/C119857082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#     'display_name': 'Machine learning',
#     'level': 1,
#     'score': 0.40115023},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': 0.14347813}],
#   'mesh': [],
#   'locations_count': 1,
#   'locations': [{'is_oa': True,
#     'landing_page_url': 'http://arxiv.org/abs/2206.11795',
#     'pdf_url': 'http://arxiv.org/pdf/2206.11795',
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': 'submittedVersion',
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': {'is_oa': True,
#    'landing_page_url': 'http://arxiv.org/abs/2206.11795',
#    'pdf_url': 'http://arxiv.org/pdf/2206.11795',
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False},
#   'sustainable_development_goals': [{'id': 'https://metadata.un.org/sdg/4',
#     'display_name': 'Quality Education',
#     'score': 0.93}],
#   'grants': [],
#   'referenced_works_count': 0,
#   'referenced_works': [],
#   'related_works': ['https://openalex.org/W1562959674',
#    'https://openalex.org/W2923653485',
#    'https://openalex.org/W2952472710',
#    'https://openalex.org/W2961085424',
#    'https://openalex.org/W3005560120',
#    'https://openalex.org/W3022038857',
#    'https://openalex.org/W4206669594',
#    'https://openalex.org/W4210912933',
#    'https://openalex.org/W4224287422',
#    'https://openalex.org/W4255994452'],
#   'ngrams_url': 'https://api.openalex.org/works/W4283460722/ngrams',
#   'abstract_inverted_index': {'Pretraining': [0],
#    'on': [1],
#    'noisy,': [2],
#    'internet-scale': [3, 59],
#    'datasets': [4],
#    'has': [5, 145],
#    'been': [6],
#    'heavily': [7],
#    'studied': [8],
#    'as': [9, 32],
#    'a': [10, 85, 102, 124],
#    'technique': [11],
#    'for': [12, 19, 26],
#    'training': [13],
#    'models': [14, 179],
#    'with': [15, 84, 155],
#    'broad,': [16],
#    'general': [17, 125],
#    'capabilities': [18, 148],
#    'text,': [20],
#    'images,': [21],
#    'and': [22, 36, 135, 149, 159, 183],
#    'other': [23],
#    'modalities.': [24],
#    'However,': [25],
#    'many': [27, 176],
#    'sequential': [28, 63],
#    'decision': [29, 64],
#    'domains': [30, 65],
#    'such': [31],
#    'robotics,': [33],
#    'video': [34],
#    'games,': [35],
#    'computer': [37, 190],
#    'use,': [38],
#    'publicly': [39],
#    'available': [40],
#    'data': [41, 90, 108],
#    'does': [42],
#    'not': [43],
#    'contain': [44],
#    'the': [45, 53, 58, 130, 186],
#    'labels': [46],
#    'required': [47],
#    'to': [48, 62, 73, 100, 162, 168, 188, 211],
#    'train': [49, 93, 123],
#    'behavioral': [50, 126, 143],
#    'priors': [51],
#    'in': [52],
#    'same': [54],
#    'way.': [55],
#    'We': [56],
#    'extend': [57],
#    'pretraining': [60],
#    'paradigm': [61],
#    'through': [66],
#    'semi-supervised': [67],
#    'imitation': [68, 157],
#    'learning': [69, 158],
#    'wherein': [70],
#    'agents': [71, 191],
#    'learn': [72, 169],
#    'act': [74],
#    'by': [75],
#    'watching': [76],
#    'online': [77, 107, 111],
#    'unlabeled': [78, 104],
#    'videos.': [79],
#    'Specifically,': [80],
#    'we': [81, 91, 120, 139, 184],
#    'show': [82, 140],
#    'that': [83, 141, 150, 165, 192],
#    'small': [86],
#    'amount': [87],
#    'of': [88, 106, 113, 203, 209],
#    'labeled': [89],
#    'can': [92, 121, 152, 193, 198],
#    'an': [94],
#    'inverse': [95],
#    'dynamics': [96],
#    'model': [97],
#    'accurate': [98],
#    'enough': [99],
#    'label': [101],
#    'huge': [103],
#    'source': [105],
#    '--': [109, 117],
#    'here,': [110],
#    'videos': [112],
#    'people': [114],
#    'playing': [115],
#    'Minecraft': [116],
#    'from': [118, 170],
#    'which': [119, 197],
#    'then': [122],
#    'prior.': [127],
#    'Despite': [128],
#    'using': [129],
#    'native': [131],
#    'human': [132],
#    'interface': [133],
#    '(mouse': [134],
#    'keyboard': [136],
#    'at': [137],
#    '20Hz),': [138],
#    'this': [142],
#    'prior': [144],
#    'nontrivial': [146],
#    'zero-shot': [147],
#    'it': [151],
#    'be': [153],
#    'fine-tuned,': [154],
#    'both': [156],
#    'reinforcement': [160, 173],
#    'learning,': [161],
#    'hard-exploration': [163],
#    'tasks': [164, 177],
#    'are': [166, 185],
#    'impossible': [167],
#    'scratch': [171],
#    'via': [172],
#    'learning.': [174],
#    'For': [175],
#    'our': [178],
#    'exhibit': [180],
#    'human-level': [181],
#    'performance,': [182],
#    'first': [187],
#    'report': [189],
#    'craft': [194],
#    'diamond': [195],
#    'tools,': [196],
#    'take': [199],
#    'proficient': [200],
#    'humans': [201],
#    'upwards': [202],
#    '20': [204],
#    'minutes': [205],
#    '(24,000': [206],
#    'environment': [207],
#    'actions)': [208],
#    'gameplay': [210],
#    'accomplish.': [212]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4283460722',
#   'counts_by_year': [],
#   'updated_date': '2023-08-20T19:35:56.491944',
#   'created_date': '2022-06-26'},
#  {'id': 'https://openalex.org/W2623491082',
#   'doi': None,
#   'title': 'Parameter Space Noise for Exploration',
#   'display_name': 'Parameter Space Noise for Exploration',
#   'relevance_score': 1871.2231,
#   'publication_year': 2017,
#   'publication_date': '2017-06-06',
#   'ids': {'openalex': 'https://openalex.org/W2623491082', 'mag': '2623491082'},
#   'language': 'en',
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'https://arxiv.org/pdf/1706.01905.pdf',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'posted-content',
#   'open_access': {'is_oa': False,
#    'oa_status': 'closed',
#    'oa_url': None,
#    'any_repository_has_fulltext': False},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5037117755',
#      'display_name': 'Matthias Plappert',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I102335020',
#       'display_name': 'Karlsruhe Institute of Technology',
#       'ror': 'https://ror.org/04t3en479',
#       'country_code': 'DE',
#       'type': 'education'}],
#     'countries': ['DE'],
#     'is_corresponding': False,
#     'raw_author_name': 'Matthias Plappert',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5003630193',
#      'display_name': 'Rein Houthooft',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I32597200',
#       'display_name': 'Ghent University',
#       'ror': 'https://ror.org/00cv9y106',
#       'country_code': 'BE',
#       'type': 'education'}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'Rein Houthooft',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5076418776',
#      'display_name': 'Prafulla Dhariwal',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Prafulla Dhariwal',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5051574174',
#      'display_name': 'Szymon Sidor',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Szymon Sidor',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5005243537',
#      'display_name': 'Richard Y. Chen',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Richard Y. Chen',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5008171524',
#      'display_name': 'Xi Chen',
#      'orcid': 'https://orcid.org/0000-0002-8523-3967'},
#     'institutions': [{'id': 'https://openalex.org/I95457486',
#       'display_name': 'University of California, Berkeley',
#       'ror': 'https://ror.org/01an7q238',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_author_name': 'Xi Chen',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5012730104',
#      'display_name': 'Tamim Asfour',
#      'orcid': 'https://orcid.org/0000-0003-4879-7680'},
#     'institutions': [{'id': 'https://openalex.org/I102335020',
#       'display_name': 'Karlsruhe Institute of Technology',
#       'ror': 'https://ror.org/04t3en479',
#       'country_code': 'DE',
#       'type': 'education'}],
#     'countries': ['DE'],
#     'is_corresponding': False,
#     'raw_author_name': 'Tamim Asfour',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5049349154',
#      'display_name': 'Pieter Abbeel',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I95457486',
#       'display_name': 'University of California, Berkeley',
#       'ror': 'https://ror.org/01an7q238',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_author_name': 'Pieter Abbeel',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5091819924',
#      'display_name': 'Marcin Andrychowicz',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Marcin Andrychowicz',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'institutions_distinct_count': 3,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 151,
#   'biblio': {'volume': None,
#    'issue': None,
#    'first_page': None,
#    'last_page': None},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C97541855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q830687',
#     'display_name': 'Reinforcement learning',
#     'level': 2,
#     'score': 0.832054},
#    {'id': 'https://openalex.org/C99498987',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2210247',
#     'display_name': 'Noise (video)',
#     'level': 3,
#     'score': 0.7712461},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.67878354},
#    {'id': 'https://openalex.org/C2780791683',
#     'wikidata': 'https://www.wikidata.org/wiki/Q846785',
#     'display_name': 'Action (physics)',
#     'level': 2,
#     'score': 0.6546056},
#    {'id': 'https://openalex.org/C73586568',
# ...
#    'https://openalex.org/W2561050497',
#    'https://openalex.org/W2605135824',
#    'https://openalex.org/W2949117887',
#    'https://openalex.org/W2953318193',
#    'https://openalex.org/W2963275229',
#    'https://openalex.org/W2963981733',
#    'https://openalex.org/W3118608800'],
#   'ngrams_url': 'https://api.openalex.org/works/W2953116488/ngrams',
#   'abstract_inverted_index': {'The': [0, 100],
#    'past': [1],
#    'several': [2],
#    'years': [3],
#    'have': [4],
#    'seen': [5],
#    'remarkable': [6],
#    'progress': [7],
#    'in': [8],
#    'generative': [9, 26, 40, 46, 50],
#    'models': [10, 27, 65, 91, 135],
#    'which': [11, 133],
#    'produce': [12],
#    'convincing': [13],
#    'samples': [14, 75],
#    'of': [15, 23, 63, 67, 70, 116, 121, 127, 139],
#    'images': [16],
#    'and': [17, 49, 73, 92, 129],
#    'other': [18],
#    'modalities.': [19],
#    'A': [20],
#    'shared': [21],
#    'component': [22],
#    'many': [24],
#    'powerful': [25],
#    'is': [28, 103],
#    'a': [29, 32, 39],
#    'decoder': [30],
#    'network,': [31],
#    'parametric': [33],
#    'deep': [34],
#    'neural': [35],
#    'net': [36],
#    'that': [37],
#    'defines': [38],
#    'distribution.': [41, 142],
#    'Examples': [42],
#    'include': [43],
#    'variational': [44],
#    'autoencoders,': [45],
#    'adversarial': [47],
#    'networks,': [48],
#    'moment': [51],
#    'matching': [52],
#    'networks.': [53],
#    'Unfortunately,': [54],
#    'it': [55],
#    'can': [56, 76],
#    'be': [57, 77],
#    'difficult': [58],
#    'to': [59, 81, 132],
#    'quantify': [60],
#    'the': [61, 68, 114, 119, 125, 130, 140],
#    'performance': [62, 115],
#    'these': [64, 134],
#    'because': [66],
#    'intractability': [69],
#    'log-likelihood': [71, 123],
#    'estimation,': [72],
#    'inspecting': [74],
#    'misleading.': [78],
#    'We': [79],
#    'propose': [80],
#    'use': [82],
#    'Annealed': [83],
#    'Importance': [84],
#    'Sampling': [85],
#    'for': [86, 89],
#    'evaluating': [87],
#    'log-likelihoods': [88],
#    'decoder-based': [90, 117],
#    'validate': [93],
#    'its': [94],
#    'accuracy': [95],
#    'using': [96],
#    'bidirectional': [97],
#    'Monte': [98],
#    'Carlo.': [99],
#    'evaluation': [101],
#    'code': [102],
#    'provided': [104],
#    'at': [105],
#    'this': [106, 110],
#    'https': [107],
#    'URL.': [108],
#    'Using': [109],
#    'technique,': [111],
#    'we': [112],
#    'analyze': [113],
#    'models,': [118],
#    'effectiveness': [120],
#    'existing': [122],
#    'estimators,': [124],
#    'degree': [126, 131],
#    'overfitting,': [128],
#    'miss': [136],
#    'important': [137],
#    'modes': [138],
#    'data': [141]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2953116488',
#   'counts_by_year': [{'year': 2021, 'cited_by_count': 9},
#    {'year': 2020, 'cited_by_count': 16},
#    {'year': 2019, 'cited_by_count': 13},
#    {'year': 2018, 'cited_by_count': 23},
#    {'year': 2017, 'cited_by_count': 28},
#    {'year': 2016, 'cited_by_count': 4}],
#   'updated_date': '2023-08-25T13:13:53.992578',
#   'created_date': '2019-06-27'},
#  {'id': 'https://openalex.org/W2789008106',
#   'doi': None,
#   'title': 'Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research',
#   'display_name': 'Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research',
#   'relevance_score': 3176.3042,
#   'publication_year': 2018,
#   'publication_date': '2018-02-26',
#   'ids': {'openalex': 'https://openalex.org/W2789008106', 'mag': '2789008106'},
#   'language': 'en',
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'http://export.arxiv.org/pdf/1802.09464',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'posted-content',
#   'open_access': {'is_oa': False,
#    'oa_status': 'closed',
#    'oa_url': None,
#    'any_repository_has_fulltext': False},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5037117755',
#      'display_name': 'Matthias Plappert',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Matthias Plappert',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5091819924',
#      'display_name': 'Marcin Andrychowicz',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Marcin Andrychowicz',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5031013142',
#      'display_name': 'Alex Ray',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Alex Ray',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5026829243',
#      'display_name': 'Bob McGrew',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Bob McGrew',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5048522044',
#      'display_name': 'Bowen Baker',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Bowen Baker',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5010167098',
#      'display_name': 'Glenn Powell',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Glenn Powell',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5009926169',
#      'display_name': 'Jonas Schneider',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Jonas Schneider',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5073825955',
#      'display_name': 'Josh Tobin',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Josh Tobin',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5016448989',
#      'display_name': 'Maciek Chociej',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Maciek Chociej',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5010674841',
#      'display_name': 'Peter Welinder',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Peter Welinder',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5027007388',
#      'display_name': 'Vikash Kumar',
#      'orcid': 'https://orcid.org/0000-0002-3168-7955'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Vikash Kumar',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5076651586',
#      'display_name': 'Wojciech Zaremba',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Wojciech Zaremba',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'institutions_distinct_count': 0,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 145,
#   'biblio': {'volume': None,
#    'issue': None,
#    'first_page': None,
#    'last_page': None},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C97541855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q830687',
#     'display_name': 'Reinforcement learning',
#     'level': 2,
#     'score': 0.8076452},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.68057907},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.6656912},
#    {'id': 'https://openalex.org/C34413123',
#     'wikidata': 'https://www.wikidata.org/wiki/Q170978',
#     'display_name': 'Robotics',
#     'level': 3,
#     'score': 0.66250265},
#    {'id': 'https://openalex.org/C10347200',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1960297',
#     'display_name': 'Hindsight bias',
#     'level': 2,
#     'score': 0.643398},
#    {'id': 'https://openalex.org/C79581498',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1367530',
#     'display_name': 'Suite',
#     'level': 2,
#     'score': 0.6220715},
#    {'id': 'https://openalex.org/C177264268',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1514741',
#     'display_name': 'Set (abstract data type)',
#     'level': 2,
#     'score': 0.526882},
#    {'id': 'https://openalex.org/C107457646',
#     'wikidata': 'https://www.wikidata.org/wiki/Q207434',
#     'display_name': 'Human–computer interaction',
#     'level': 1,
#     'score': 0.4394215},
#    {'id': 'https://openalex.org/C90509273',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11012',
#     'display_name': 'Robot',
#     'level': 2,
#     'score': 0.40855372},
#    {'id': 'https://openalex.org/C119857082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#     'display_name': 'Machine learning',
#     'level': 1,
#     'score': 0.369274},
#    {'id': 'https://openalex.org/C15744967',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#     'display_name': 'Psychology',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C166957645',
#     'wikidata': 'https://www.wikidata.org/wiki/Q23498',
#     'display_name': 'Archaeology',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C180747234',
#     'wikidata': 'https://www.wikidata.org/wiki/Q23373',
#     'display_name': 'Cognitive psychology',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C95457728',
#     'wikidata': 'https://www.wikidata.org/wiki/Q309',
#     'display_name': 'History',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': 0.0}],
#   'mesh': [],
#   'locations_count': 1,
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'http://export.arxiv.org/pdf/1802.09464',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': 'submittedVersion',
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': None,
#   'sustainable_development_goals': [],
#   'grants': [],
#   'referenced_works_count': 17,
#   'referenced_works': ['https://openalex.org/W567721252',
#    'https://openalex.org/W2145339207',
#    'https://openalex.org/W2158782408',
#    'https://openalex.org/W2173248099',
#    'https://openalex.org/W2553109721',
#    'https://openalex.org/W2609650878',
#    'https://openalex.org/W2620671107',
#    'https://openalex.org/W2623491082',
#    'https://openalex.org/W2736601468',
#    'https://openalex.org/W2737215407',
#    'https://openalex.org/W2949604932',
#    'https://openalex.org/W2963003097',
#    'https://openalex.org/W2963423916',
#    'https://openalex.org/W2963477884',
#    'https://openalex.org/W2964001908',
#    'https://openalex.org/W2964036701',
#    'https://openalex.org/W2964121744'],
#   'related_works': ['https://openalex.org/W567721252',
#    'https://openalex.org/W1757796397',
#    'https://openalex.org/W1771410628',
#    'https://openalex.org/W2109910161',
#    'https://openalex.org/W2121863487',
#    'https://openalex.org/W2145339207',
#    'https://openalex.org/W2158782408',
#    'https://openalex.org/W2173248099',
#    'https://openalex.org/W2257979135',
#    'https://openalex.org/W2575705757',
#    'https://openalex.org/W2736601468',
#    'https://openalex.org/W2781726626',
#    'https://openalex.org/W2963099939',
#    'https://openalex.org/W2963411833',
#    'https://openalex.org/W2963477884',
#    'https://openalex.org/W2964001908',
#    'https://openalex.org/W2964043796',
#    'https://openalex.org/W2964121744',
#    'https://openalex.org/W2964161785',
#    'https://openalex.org/W2990747716'],
#   'ngrams_url': 'https://api.openalex.org/works/W2789008106/ngrams',
#   'abstract_inverted_index': {'The': [0, 30],
#    'purpose': [1],
#    'of': [2, 9, 15, 85, 91, 100],
#    'this': [3],
#    'technical': [4],
#    'report': [5],
#    'is': [6, 73],
#    'two-fold.': [7],
#    'First': [8],
#    'all,': [10],
#    'it': [11],
#    'introduces': [12],
#    'a': [13, 40, 51, 63, 89],
#    'suite': [14],
#    'challenging': [16],
#    'continuous': [17],
#    'control': [18],
#    'tasks': [19, 31, 56],
#    '(integrated': [20],
#    'with': [21, 39, 50],
#    'OpenAI': [22],
#    'Gym)': [23],
#    'based': [24],
#    'on': [25],
#    'currently': [26],
#    'existing': [27],
#    'robotics': [28],
#    'hardware.': [29],
#    'include': [32],
#    'pushing,': [33],
#    'sliding': [34],
#    'and': [35, 61, 107],
#    'pick': [36],
#    '&': [37],
#    'place': [38],
#    'Fetch': [41],
#    'robotic': [42],
#    'arm': [43],
#    'as': [44, 46],
#    'well': [45],
#    'in-hand': [47],
#    'object': [48],
#    'manipulation': [49],
#    'Shadow': [52],
#    'Dexterous': [53],
#    'Hand.': [54],
#    'All': [55],
#    'have': [57],
#    'sparse': [58],
#    'binary': [59],
#    'rewards': [60],
#    'follow': [62],
#    'Multi-Goal': [64, 105],
#    'Reinforcement': [65],
#    'Learning': [66],
#    '(RL)': [67],
#    'framework': [68],
#    'in': [69],
#    'which': [70, 101],
#    'an': [71, 79],
#    'agent': [72],
#    'told': [74],
#    'what': [75],
#    'to': [76, 104],
#    'do': [77],
#    'using': [78],
#    'additional': [80],
#    'input.': [81],
#    '\r\nThe': [82],
#    'second': [83],
#    'part': [84],
#    'the': [86],
#    'paper': [87],
#    'presents': [88],
#    'set': [90],
#    'concrete': [92],
#    'research': [93],
#    'ideas': [94],
#    'for': [95],
#    'improving': [96],
#    'RL': [97, 106],
#    'algorithms,': [98],
#    'most': [99],
#    'are': [102],
#    'related': [103],
#    'Hindsight': [108],
#    'Experience': [109],
#    'Replay.': [110]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2789008106',
#   'counts_by_year': [{'year': 2022, 'cited_by_count': 1},
#    {'year': 2021, 'cited_by_count': 46},
#    {'year': 2020, 'cited_by_count': 37},
#    {'year': 2019, 'cited_by_count': 45},
#    {'year': 2018, 'cited_by_count': 16}],
#   'updated_date': '2023-08-25T12:59:24.022477',
#   'created_date': '2018-03-06'}]

# %%
with open("data/openai/openai_research_works", "wb") as f:
    pickle.dump(openai_research_works, f)

# %% [markdown]
# # Compare with OpenAlex works that have an OpenAI affiliation recorded

# %%
with open("data/openai/openai_research_works", "rb") as f:
    openai_research_works = pickle.load(f)

# %%
len(openai_research_works)
# Out:
# 104

# %%
with open(data_file_location + "selected_institution_works_openalex_deduplicated_2023-08-29_12-22-34", "rb") as f:
    works_obj = pickle.load(f)
    all_works = works_obj["works"]

# %%
len(all_works)
# Out:
# 66093

# %%
selected_institution_ids = [
    "https://openalex.org/I4210161460",  # OpenAI (United States)
]

# %%
institution_aliases = {selected_institution_ids[0]: 'OpenAI'}

# %%
processor = OpenAlexProcessor(all_works, selected_institution_ids, institution_aliases, citation_year_bound=3)
processor.process_works()

# %%
institution_authors_by_work = processor.get_authors_by_work()
institution_authors_by_work
# Out:
# defaultdict(<function research_impact.processors.OpenAlexProcessor.process_works.<locals>.<lambda>()>,
#             {'OpenAI': defaultdict(list,
#                          {'https://openalex.org/W2618530766': ['https://openalex.org/A5024209719'],
#                           'https://openalex.org/W2473418344': ['https://openalex.org/A5004271128'],
#                           'https://openalex.org/W2951777958': ['https://openalex.org/A5067370075'],
#                           'https://openalex.org/W2965130685': ['https://openalex.org/A5041662257',
#                            'https://openalex.org/A5068388812'],
#                           'https://openalex.org/W3198675127': ['https://openalex.org/A5061984381'],
#                           'https://openalex.org/W2976896402': ['https://openalex.org/A5039751155'],
#                           'https://openalex.org/W3129659662': ['https://openalex.org/A5031789995'],
#                           'https://openalex.org/W4308995511': ['https://openalex.org/A5073086818'],
#                           'https://openalex.org/W4376455648': ['https://openalex.org/A5070645440'],
#                           'https://openalex.org/W4207074987': ['https://openalex.org/A5000711679'],
#                           'https://openalex.org/W2983335573': ['https://openalex.org/A5014407395',
#                            'https://openalex.org/A5084821923'],
#                           'https://openalex.org/W2963773578': ['https://openalex.org/A5076651586'],
#                           'https://openalex.org/W3012934742': ['https://openalex.org/A5008951080'],
#                           'https://openalex.org/W3093414036': ['https://openalex.org/A5006797018'],
#                           'https://openalex.org/W4283166089': ['https://openalex.org/A5014959740'],
#                           'https://openalex.org/W3040707741': ['https://openalex.org/A5009970175'],
#                           'https://openalex.org/W2962785568': ['https://openalex.org/A5017456911'],
#                           'https://openalex.org/W2603766943': ['https://openalex.org/A5004271128'],
#                           'https://openalex.org/W2605102758': ['https://openalex.org/A5073825955',
#                            'https://openalex.org/A5052434214',
#                            'https://openalex.org/A5031013142',
#                            'https://openalex.org/A5009926169',
#                            'https://openalex.org/A5076651586',
#                            'https://openalex.org/A5049349154'],
#                           'https://openalex.org/W2990747716': ['https://openalex.org/A5086668201',
#                            'https://openalex.org/A5048522044',
#                            'https://openalex.org/A5016448989',
#                            'https://openalex.org/A5067370075',
#                            'https://openalex.org/A5026829243',
#                            'https://openalex.org/A5011053473',
#                            'https://openalex.org/A5040970183',
#                            'https://openalex.org/A5037117755',
#                            'https://openalex.org/A5010167098',
#                            'https://openalex.org/A5031013142',
#                            'https://openalex.org/A5009926169',
#                            'https://openalex.org/A5051574174',
#                            'https://openalex.org/A5073825955',
#                            'https://openalex.org/A5010674841',
#                            'https://openalex.org/A5009970175',
#                            'https://openalex.org/A5076651586'],
#                           'https://openalex.org/W3101442004': ['https://openalex.org/A5070606710',
#                            'https://openalex.org/A5091819924',
#                            'https://openalex.org/A5076651586',
#                            'https://openalex.org/A5049349154'],
#                           'https://openalex.org/W2963099939': ['https://openalex.org/A5026829243',
#                            'https://openalex.org/A5091819924',
#                            'https://openalex.org/A5076651586'],
#                           'https://openalex.org/W2963641140': ['https://openalex.org/A5009037058'],
#                           'https://openalex.org/W3135367836': ['https://openalex.org/A5051250767',
#                            'https://openalex.org/A5061984381',
#                            'https://openalex.org/A5007406730',
#                            'https://openalex.org/A5043641795',
#                            'https://openalex.org/A5041662257',
#                            'https://openalex.org/A5057289323',
#                            'https://openalex.org/A5059260582',
#                            'https://openalex.org/A5030305998',
#                            'https://openalex.org/A5028772381',
#                            'https://openalex.org/A5031107879',
#                            'https://openalex.org/A5064685592',
#                            'https://openalex.org/A5006446297'],
#                           'https://openalex.org/W3001279689': ['https://openalex.org/A5054887773',
#                            'https://openalex.org/A5049786610',
#                            'https://openalex.org/A5079465685',
#                            'https://openalex.org/A5057742306',
#                            'https://openalex.org/A5084512458',
#                            'https://openalex.org/A5026541761',
#                            'https://openalex.org/A5051250767',
#                            'https://openalex.org/A5081413425',
#                            'https://openalex.org/A5066197394'],
#                           'https://openalex.org/W2561776174': ['https://openalex.org/A5003630193',
#                            'https://openalex.org/A5009037058'],
#                           'https://openalex.org/W2602275733': ['https://openalex.org/A5014193325'],
#                           'https://openalex.org/W2963303956': ['https://openalex.org/A5019471288'],
#                           'https://openalex.org/W2894737833': ['https://openalex.org/A5019471288'],
#                           'https://openalex.org/W2972758308': ['https://openalex.org/A5072920795',
#                            'https://openalex.org/A5009037058'],
#                           'https://openalex.org/W2963403593': ['https://openalex.org/A5049349154'],
#                           'https://openalex.org/W4312083290': ['https://openalex.org/A5008551527'],
#                           'https://openalex.org/W3129322645': ['https://openalex.org/A5033112877',
#                            'https://openalex.org/A5018598100',
#                            'https://openalex.org/A5053798319',
#                            'https://openalex.org/A5029264794',
#                            'https://openalex.org/A5006797018'],
#                           'https://openalex.org/W2964214518': ['https://openalex.org/A5073825955',
#                            'https://openalex.org/A5091819924',
#                            'https://openalex.org/A5026829243',
#                            'https://openalex.org/A5031013142',
#                            'https://openalex.org/A5009926169',
#                            'https://openalex.org/A5010674841',
#                            'https://openalex.org/A5076651586'],
#                           'https://openalex.org/W3021208093': ['https://openalex.org/A5049349154'],
#                           'https://openalex.org/W2964070888': ['https://openalex.org/A5049349154'],
#                           'https://openalex.org/W2739245956': ['https://openalex.org/A5017456911'],
#                           'https://openalex.org/W4206410067': ['https://openalex.org/A5006446297'],
#                           'https://openalex.org/W3134095442': ['https://openalex.org/A5041662257',
#                            'https://openalex.org/A5005680249',
#                            'https://openalex.org/A5051743369',
#                            'https://openalex.org/A5000965900',
#                            'https://openalex.org/A5051250767'],
#                           'https://openalex.org/W2962743868': ['https://openalex.org/A5049349154'],
#                           'https://openalex.org/W2963165111': ['https://openalex.org/A5049349154'],
#                           'https://openalex.org/W3101747404': ['https://openalex.org/A5006797018'],
#                           'https://openalex.org/W2962937807': ['https://openalex.org/A5049349154'],
#                           'https://openalex.org/W3121596465': ['https://openalex.org/A5066559387'],
#                           'https://openalex.org/W3087570018': ['https://openalex.org/A5006797018'],
#                           'https://openalex.org/W2774742309': ['https://openalex.org/A5049349154'],
#                           'https://openalex.org/W3029249725': ['https://openalex.org/A5044764535'],
#                           'https://openalex.org/W3034828529': ['https://openalex.org/A5038969014'],
#                           'https://openalex.org/W4220747123': ['https://openalex.org/A5009970175'],
#                           'https://openalex.org/W3152331843': ['https://openalex.org/A5010674841'],
#                           'https://openalex.org/W4318618627': ['https://openalex.org/A5008551527'],
#                           'https://openalex.org/W3010756906': ['https://openalex.org/A5006797018'],
#                           'https://openalex.org/W3085735333': ['https://openalex.org/A5022214962'],
#                           'https://openalex.org/W2964665249': ['https://openalex.org/A5068388812'],
#                           'https://openalex.org/W4312129726': ['https://openalex.org/A5019073826'],
#                           'https://openalex.org/W2895135219': ['https://openalex.org/A5037864229'],
#                           'https://openalex.org/W3175270462': ['https://openalex.org/A5037117755'],
#                           'https://openalex.org/W3032890203': ['https://openalex.org/A5011053473'],
#                           'https://openalex.org/W3100003809': ['https://openalex.org/A5007861777',
#                            'https://openalex.org/A5005680249',
#                            'https://openalex.org/A5041662257',
#                            'https://openalex.org/A5039751155'],
#                           'https://openalex.org/W3112541430': ['https://openalex.org/A5039751155',
#                            'https://openalex.org/A5005680249',
#                            'https://openalex.org/A5051743369',
#                            'https://openalex.org/A5041662257'],
#                           'https://openalex.org/W3120327542': ['https://openalex.org/A5048350993',
#                            'https://openalex.org/A5037117755',
#                            'https://openalex.org/A5078100000',
#                            'https://openalex.org/A5035394666',
#                            'https://openalex.org/A5046491870',
#                            'https://openalex.org/A5010674841',
#                            'https://openalex.org/A5068437964',
#                            'https://openalex.org/A5040970183',
#                            'https://openalex.org/A5028891032',
#                            'https://openalex.org/A5080211309',
#                            'https://openalex.org/A5009970175',
#                            'https://openalex.org/A5002281342'],
#                           'https://openalex.org/W3119161812': ['https://openalex.org/A5023045278'],
#                           'https://openalex.org/W3168053944': ['https://openalex.org/A5066308512',
#                            'https://openalex.org/A5076418776'],
#                           'https://openalex.org/W2966411109': ['https://openalex.org/A5041662257'],
#                           'https://openalex.org/W4320473078': ['https://openalex.org/A5019073826'],
#                           'https://openalex.org/W2966795390': ['https://openalex.org/A5041662257'],
#                           'https://openalex.org/W3216533345': ['https://openalex.org/A5018598100',
#                            'https://openalex.org/A5006797018'],
#                           'https://openalex.org/W4224068385': ['https://openalex.org/A5044764535'],
#                           'https://openalex.org/W3034296948': ['https://openalex.org/A5032275803'],
#                           'https://openalex.org/W3197040007': ['https://openalex.org/A5025285284',
#                            'https://openalex.org/A5078756156'],
#                           'https://openalex.org/W4312433637': ['https://openalex.org/A5019073826'],
#                           'https://openalex.org/W4313224236': ['https://openalex.org/A5073325012'],
#                           'https://openalex.org/W4319723206': ['https://openalex.org/A5047304570'],
#                           'https://openalex.org/W4327911463': ['https://openalex.org/A5063326523'],
#                           'https://openalex.org/W4376133361': ['https://openalex.org/A5000711679'],
#                           'https://openalex.org/W4379145164': ['https://openalex.org/A5051772019'],
#                           'https://openalex.org/W4386075632': ['https://openalex.org/A5030637764']})})

# %%
openai_authors_by_work = institution_authors_by_work["OpenAI"]
openai_authors_by_work
# Out:
# defaultdict(list,
#             {'https://openalex.org/W2618530766': ['https://openalex.org/A5024209719'],
#              'https://openalex.org/W2473418344': ['https://openalex.org/A5004271128'],
#              'https://openalex.org/W2951777958': ['https://openalex.org/A5067370075'],
#              'https://openalex.org/W2965130685': ['https://openalex.org/A5041662257',
#               'https://openalex.org/A5068388812'],
#              'https://openalex.org/W3198675127': ['https://openalex.org/A5061984381'],
#              'https://openalex.org/W2976896402': ['https://openalex.org/A5039751155'],
#              'https://openalex.org/W3129659662': ['https://openalex.org/A5031789995'],
#              'https://openalex.org/W4308995511': ['https://openalex.org/A5073086818'],
#              'https://openalex.org/W4376455648': ['https://openalex.org/A5070645440'],
#              'https://openalex.org/W4207074987': ['https://openalex.org/A5000711679'],
#              'https://openalex.org/W2983335573': ['https://openalex.org/A5014407395',
#               'https://openalex.org/A5084821923'],
#              'https://openalex.org/W2963773578': ['https://openalex.org/A5076651586'],
#              'https://openalex.org/W3012934742': ['https://openalex.org/A5008951080'],
#              'https://openalex.org/W3093414036': ['https://openalex.org/A5006797018'],
#              'https://openalex.org/W4283166089': ['https://openalex.org/A5014959740'],
#              'https://openalex.org/W3040707741': ['https://openalex.org/A5009970175'],
#              'https://openalex.org/W2962785568': ['https://openalex.org/A5017456911'],
#              'https://openalex.org/W2603766943': ['https://openalex.org/A5004271128'],
#              'https://openalex.org/W2605102758': ['https://openalex.org/A5073825955',
#               'https://openalex.org/A5052434214',
#               'https://openalex.org/A5031013142',
#               'https://openalex.org/A5009926169',
#               'https://openalex.org/A5076651586',
#               'https://openalex.org/A5049349154'],
#              'https://openalex.org/W2990747716': ['https://openalex.org/A5086668201',
#               'https://openalex.org/A5048522044',
#               'https://openalex.org/A5016448989',
#               'https://openalex.org/A5067370075',
#               'https://openalex.org/A5026829243',
#               'https://openalex.org/A5011053473',
#               'https://openalex.org/A5040970183',
#               'https://openalex.org/A5037117755',
#               'https://openalex.org/A5010167098',
#               'https://openalex.org/A5031013142',
#               'https://openalex.org/A5009926169',
#               'https://openalex.org/A5051574174',
#               'https://openalex.org/A5073825955',
#               'https://openalex.org/A5010674841',
#               'https://openalex.org/A5009970175',
#               'https://openalex.org/A5076651586'],
#              'https://openalex.org/W3101442004': ['https://openalex.org/A5070606710',
#               'https://openalex.org/A5091819924',
#               'https://openalex.org/A5076651586',
#               'https://openalex.org/A5049349154'],
#              'https://openalex.org/W2963099939': ['https://openalex.org/A5026829243',
#               'https://openalex.org/A5091819924',
#               'https://openalex.org/A5076651586'],
#              'https://openalex.org/W2963641140': ['https://openalex.org/A5009037058'],
#              'https://openalex.org/W3135367836': ['https://openalex.org/A5051250767',
#               'https://openalex.org/A5061984381',
#               'https://openalex.org/A5007406730',
#               'https://openalex.org/A5043641795',
#               'https://openalex.org/A5041662257',
#               'https://openalex.org/A5057289323',
#               'https://openalex.org/A5059260582',
#               'https://openalex.org/A5030305998',
#               'https://openalex.org/A5028772381',
#               'https://openalex.org/A5031107879',
#               'https://openalex.org/A5064685592',
#               'https://openalex.org/A5006446297'],
#              'https://openalex.org/W3001279689': ['https://openalex.org/A5054887773',
#               'https://openalex.org/A5049786610',
#               'https://openalex.org/A5079465685',
#               'https://openalex.org/A5057742306',
#               'https://openalex.org/A5084512458',
#               'https://openalex.org/A5026541761',
#               'https://openalex.org/A5051250767',
#               'https://openalex.org/A5081413425',
#               'https://openalex.org/A5066197394'],
#              'https://openalex.org/W2561776174': ['https://openalex.org/A5003630193',
#               'https://openalex.org/A5009037058'],
#              'https://openalex.org/W2602275733': ['https://openalex.org/A5014193325'],
#              'https://openalex.org/W2963303956': ['https://openalex.org/A5019471288'],
#              'https://openalex.org/W2894737833': ['https://openalex.org/A5019471288'],
#              'https://openalex.org/W2972758308': ['https://openalex.org/A5072920795',
#               'https://openalex.org/A5009037058'],
#              'https://openalex.org/W2963403593': ['https://openalex.org/A5049349154'],
#              'https://openalex.org/W4312083290': ['https://openalex.org/A5008551527'],
#              'https://openalex.org/W3129322645': ['https://openalex.org/A5033112877',
#               'https://openalex.org/A5018598100',
#               'https://openalex.org/A5053798319',
#               'https://openalex.org/A5029264794',
#               'https://openalex.org/A5006797018'],
#              'https://openalex.org/W2964214518': ['https://openalex.org/A5073825955',
#               'https://openalex.org/A5091819924',
#               'https://openalex.org/A5026829243',
#               'https://openalex.org/A5031013142',
#               'https://openalex.org/A5009926169',
#               'https://openalex.org/A5010674841',
#               'https://openalex.org/A5076651586'],
#              'https://openalex.org/W3021208093': ['https://openalex.org/A5049349154'],
#              'https://openalex.org/W2964070888': ['https://openalex.org/A5049349154'],
#              'https://openalex.org/W2739245956': ['https://openalex.org/A5017456911'],
#              'https://openalex.org/W4206410067': ['https://openalex.org/A5006446297'],
#              'https://openalex.org/W3134095442': ['https://openalex.org/A5041662257',
#               'https://openalex.org/A5005680249',
#               'https://openalex.org/A5051743369',
#               'https://openalex.org/A5000965900',
#               'https://openalex.org/A5051250767'],
#              'https://openalex.org/W2962743868': ['https://openalex.org/A5049349154'],
#              'https://openalex.org/W2963165111': ['https://openalex.org/A5049349154'],
#              'https://openalex.org/W3101747404': ['https://openalex.org/A5006797018'],
#              'https://openalex.org/W2962937807': ['https://openalex.org/A5049349154'],
#              'https://openalex.org/W3121596465': ['https://openalex.org/A5066559387'],
#              'https://openalex.org/W3087570018': ['https://openalex.org/A5006797018'],
#              'https://openalex.org/W2774742309': ['https://openalex.org/A5049349154'],
#              'https://openalex.org/W3029249725': ['https://openalex.org/A5044764535'],
#              'https://openalex.org/W3034828529': ['https://openalex.org/A5038969014'],
#              'https://openalex.org/W4220747123': ['https://openalex.org/A5009970175'],
#              'https://openalex.org/W3152331843': ['https://openalex.org/A5010674841'],
#              'https://openalex.org/W4318618627': ['https://openalex.org/A5008551527'],
#              'https://openalex.org/W3010756906': ['https://openalex.org/A5006797018'],
#              'https://openalex.org/W3085735333': ['https://openalex.org/A5022214962'],
#              'https://openalex.org/W2964665249': ['https://openalex.org/A5068388812'],
#              'https://openalex.org/W4312129726': ['https://openalex.org/A5019073826'],
#              'https://openalex.org/W2895135219': ['https://openalex.org/A5037864229'],
#              'https://openalex.org/W3175270462': ['https://openalex.org/A5037117755'],
#              'https://openalex.org/W3032890203': ['https://openalex.org/A5011053473'],
#              'https://openalex.org/W3100003809': ['https://openalex.org/A5007861777',
#               'https://openalex.org/A5005680249',
#               'https://openalex.org/A5041662257',
#               'https://openalex.org/A5039751155'],
#              'https://openalex.org/W3112541430': ['https://openalex.org/A5039751155',
#               'https://openalex.org/A5005680249',
#               'https://openalex.org/A5051743369',
#               'https://openalex.org/A5041662257'],
#              'https://openalex.org/W3120327542': ['https://openalex.org/A5048350993',
#               'https://openalex.org/A5037117755',
#               'https://openalex.org/A5078100000',
#               'https://openalex.org/A5035394666',
#               'https://openalex.org/A5046491870',
#               'https://openalex.org/A5010674841',
#               'https://openalex.org/A5068437964',
#               'https://openalex.org/A5040970183',
#               'https://openalex.org/A5028891032',
#               'https://openalex.org/A5080211309',
#               'https://openalex.org/A5009970175',
#               'https://openalex.org/A5002281342'],
#              'https://openalex.org/W3119161812': ['https://openalex.org/A5023045278'],
#              'https://openalex.org/W3168053944': ['https://openalex.org/A5066308512',
#               'https://openalex.org/A5076418776'],
#              'https://openalex.org/W2966411109': ['https://openalex.org/A5041662257'],
#              'https://openalex.org/W4320473078': ['https://openalex.org/A5019073826'],
#              'https://openalex.org/W2966795390': ['https://openalex.org/A5041662257'],
#              'https://openalex.org/W3216533345': ['https://openalex.org/A5018598100',
#               'https://openalex.org/A5006797018'],
#              'https://openalex.org/W4224068385': ['https://openalex.org/A5044764535'],
#              'https://openalex.org/W3034296948': ['https://openalex.org/A5032275803'],
#              'https://openalex.org/W3197040007': ['https://openalex.org/A5025285284',
#               'https://openalex.org/A5078756156'],
#              'https://openalex.org/W4312433637': ['https://openalex.org/A5019073826'],
#              'https://openalex.org/W4313224236': ['https://openalex.org/A5073325012'],
#              'https://openalex.org/W4319723206': ['https://openalex.org/A5047304570'],
#              'https://openalex.org/W4327911463': ['https://openalex.org/A5063326523'],
#              'https://openalex.org/W4376133361': ['https://openalex.org/A5000711679'],
#              'https://openalex.org/W4379145164': ['https://openalex.org/A5051772019'],
#              'https://openalex.org/W4386075632': ['https://openalex.org/A5030637764']})

# %%
openai_openalex_work_ids = list(openai_authors_by_work.keys())
len(openai_openalex_work_ids)
# Out:
# 77

# %%
openai_research_work_ids = [work["id"] for work in openai_research_works]
len(openai_research_work_ids)
# Out:
# 104

# %%
len(openai_research_work_ids) - len(set(openai_research_work_ids))
# Out:
# 0

# %%
len(openai_openalex_work_ids) - len(set(openai_openalex_work_ids))
# Out:
# 0

# %%
for work_id in set(openai_research_work_ids).intersection(set(openai_openalex_work_ids)):
    print(Works()[work_id]['title'])
# Out:
# Scaling Laws for Neural Language Models
# Domain randomization for transferring deep neural networks from simulation to the real world
# Teacher–Student Curriculum Learning
# Learning Transferable Visual Models From Natural Language Supervision
# #Exploration: a study of count-based exploration for deep reinforcement learning
# Multimodal Neurons in Artificial Neural Networks
# Sim-to-Real Transfer of Robotic Control with Dynamics Randomization
# Domain Randomization and Generative Models for Robotic Grasping
# Learning dexterous in-hand manipulation

# %%
new_openai_research_works = [work for work in openai_research_works if work["id"] not in set(openai_openalex_work_ids)]
len(new_openai_research_works)
# Out:
# 95

# %%
all_time_unique_authors = {}
for work in new_openai_research_works:
    print("Title: ", work["title"])
    for authorship in work["authorships"]:
        print("Author: ", authorship["author"]["display_name"])
        print("Institutions: ", authorship["institutions"])
        print("Raw affiliation strings: ", authorship["raw_affiliation_strings"])
        print()
        all_time_unique_authors[authorship["author"]["id"]] = authorship["author"]["display_name"]
    print()
# Out:
# Title:  Recursively Summarizing Books with Human Feedback
# Author:  Jeff Wu
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Long Ouyang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Daniel M. Ziegler
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Nisan Stiennon
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ryan Lowe
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jan Leike
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Paul F. Christiano
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  One-Shot Imitation Learning
# Author:  Yan Duan
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Marcin Andrychowicz
# Institutions:  [{'id': 'https://openalex.org/I4654613', 'display_name': 'University of Warsaw', 'ror': 'https://ror.org/039bjqg32', 'country_code': 'PL', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Bradly C. Stadie
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  OpenAI Jonathan Ho
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonas Schneider
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Wojciech Zaremba
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Video PreTraining (VPT): Learning to Act by Watching Unlabeled Online
#   Videos
# Author:  Bowen Baker
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilge Akkaya
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  P. A. Zhokhov
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Joost Huizinga
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jie Tang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Adrien Ecoffet
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Brandon Houghton
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Raul Sampedro
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jeff Clune
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Parameter Space Noise for Exploration
# Author:  Matthias Plappert
# Institutions:  [{'id': 'https://openalex.org/I102335020', 'display_name': 'Karlsruhe Institute of Technology', 'ror': 'https://ror.org/04t3en479', 'country_code': 'DE', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Rein Houthooft
# Institutions:  [{'id': 'https://openalex.org/I32597200', 'display_name': 'Ghent University', 'ror': 'https://ror.org/00cv9y106', 'country_code': 'BE', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Prafulla Dhariwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Szymon Sidor
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Richard Y. Chen
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Xi Chen
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Tamim Asfour
# Institutions:  [{'id': 'https://openalex.org/I102335020', 'display_name': 'Karlsruhe Institute of Technology', 'ror': 'https://ror.org/04t3en479', 'country_code': 'DE', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Marcin Andrychowicz
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Efficient Training of Language Models to Fill in the Middle
# Author:  Mohammad Bavarian
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Heewoo Jun
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Nikolas Tezak
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sabu John
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christine McLeavey
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jerry Tworek
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Mark Chen
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Some Considerations on Learning to Explore via Meta-Reinforcement Learning
# Author:  Bradly C. Stadie
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ge Yang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Rein Houthooft
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Xi Chen
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Yan Duan
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Yuhuai Wu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Solving Rubik's Cube with a Robot Hand
# Author:  OpenAI
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilge Akkaya
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Marcin Andrychowicz
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Maciek Chociej
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Mateusz Litwin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Bob McGrew
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Arthur Petron
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alex Paino
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Matthias Plappert
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Glenn Powell
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Raphael Ribas
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonas Schneider
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Nikolas Tezak
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jerry Tworek
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Peter Welinder
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Li Weng
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Qiming Yuan
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Wojciech Zaremba
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Lei Zhang
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Learning To Generate Reviews and Discovering Sentiment
# Author:  Alec Radford
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Rafal Jozefowicz
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Prediction and Control with Temporal Segment Models
# Author:  Nishikant Mishra
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of California–Berkeley.']
#
# Author:  Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  ['University of California, Berkeley and OpenAI#TAB#']
#
# Author:  Igor Mordatch
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  Teaching Models to Express Their Uncertainty in Words
# Author:  Stephanie Lin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Hilton
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Owain Evans
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Variational Option Discovery Algorithms.
# Author:  Joshua Achiam
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Harrison Edwards
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dario Amodei
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Semi-supervised Knowledge Transfer for Deep Learning from Private Training Data
# Author:  Nicolas Papernot
# Institutions:  [{'id': 'https://openalex.org/I130769515', 'display_name': 'Pennsylvania State University', 'ror': 'https://ror.org/04p491231', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Martín Abadi
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Úlfar Erlingsson
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Ian Goodfellow
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Kunal Talwar
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
#
# Title:  Implicit Generation and Generalization in Energy-Based Models.
# Author:  Yilun Du
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['Massachusetts Institute Of Technology#TAB#']
#
# Author:  Igor Mordatch
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Large-Scale Study of Curiosity-Driven Learning
# Author:  Yuri Burda
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Harri Edwards
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Deepak Pathak
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of California–Berkeley.']
#
# Author:  Amos Storkey
# Institutions:  []
# Raw affiliation strings:  ['Institute for Adaptive and Neural Computation']
#
# Author:  Trevor Darrell
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of California–Berkeley.']
#
# Author:  Alexei A. Efros
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of California–Berkeley.']
#
#
# Title:  AI safety via debate.
# Author:  Geoffrey Irving
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Paul F. Christiano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dario Amodei
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  OpenAI Gym
# Author:  Greg Brockman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Vicki Cheung
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ludwig Pettersson
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonas Schneider
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jie Tang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Wojciech Zaremba
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Supervising strong learners by amplifying weak experts.
# Author:  Paul F. Christiano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Shlegeris, Buck
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dario Amodei
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  On First-Order Meta-Learning Algorithms.
# Author:  Alex Nichol
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Joshua Achiam
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Understanding the Capabilities, Limitations, and Societal Impact of Large Language Models.
# Author:  Alex Tamkin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Miles Brundage
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jack Clark
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ganguli, Deep
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  A Connection between Generative Adversarial Networks, Inverse Reinforcement Learning, and Energy-Based Models
# Author:  Chelsea Finn
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Paul F. Christiano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sergey Levine
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Stochastic Neural Networks for Hierarchical Reinforcement Learning
# Author:  Carlos Florensa
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Yan Duan
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
#
# Title:  Gotta Learn Fast: A New Benchmark for Generalization in RL
# Author:  Alex Nichol
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pfau, Vicki
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christopher Hesse
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Oleg Klimov
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Equivalence Between Policy Gradients and Soft Q-Learning
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Xi Chen
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Third-Person Imitation Learning
# Author:  Bradly C. Stadie
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  RL$^2$: Fast Reinforcement Learning via Slow Reinforcement Learning
# Author:  Yan Duan
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Xi Chen
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Peter L. Bartlett
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Language Models are Few-Shot Learners
# Author:  T. B. Brown
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Benjamin Mann
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Nick Ryder
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Melanie Subbiah
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jared Kaplan
# Institutions:  [{'id': 'https://openalex.org/I145311948', 'display_name': 'Johns Hopkins University', 'ror': 'https://ror.org/00za53h95', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Prafulla Dhariwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Arvind Neelakantan
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Pranav Shyam
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Girish Sastry
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Askell, Amanda
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sandhini Agarwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ariel Herbert-Voss
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Gretchen Krueger
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Henighan, Tom
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Rewon Child
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  A. Ramesh
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Daniel M. Ziegler
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Jeffrey Wu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Clemens Winter
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christopher Hesse
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Mark Chen
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Eric J. Sigler
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Mateusz Litwin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Scott Gray
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Chess, Benjamin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jack Clark
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christopher Berner
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  McCandlish, Sam
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alec Radford
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dario Amodei
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Toward Trustworthy AI Development: Mechanisms for Supporting Verifiable Claims
# Author:  Miles Brundage
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Shahar Avin
# Institutions:  [{'id': 'https://openalex.org/I2802641067', 'display_name': 'Leverhulme Trust', 'ror': 'https://ror.org/012mzw131', 'country_code': 'GB', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Leverhulme Centre for the Future of Intelligence']
#
# Author:  Jasmine Wang
# Institutions:  []
# Raw affiliation strings:  ['Montreal Institute for Learning Algorithms  [Montréal]']
#
# Author:  Haydn Belfield
# Institutions:  [{'id': 'https://openalex.org/I2802641067', 'display_name': 'Leverhulme Trust', 'ror': 'https://ror.org/012mzw131', 'country_code': 'GB', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Leverhulme Centre for the Future of Intelligence']
#
# Author:  Gretchen Krueger
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Gillian K. Hadfield
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Heidy Khlaaf
# Institutions:  [{'id': 'https://openalex.org/I4210163610', 'display_name': 'Adelard', 'ror': 'https://ror.org/05nns5525', 'country_code': 'GB', 'type': 'company'}]
# Raw affiliation strings:  ['Adelard']
#
# Author:  Jingying Yang
# Institutions:  [{'id': 'https://openalex.org/I129364015', 'display_name': 'Partners In Health', 'ror': 'https://ror.org/05tsvnv68', 'country_code': 'US', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Partnership on AI']
#
# Author:  Helen Toner
# Institutions:  [{'id': 'https://openalex.org/I4210145449', 'display_name': 'Center for Security and Emerging Technology', 'ror': 'https://ror.org/045qf3j54', 'country_code': 'US', 'type': 'other'}]
# Raw affiliation strings:  ['Center for Security and Emerging Technology']
#
# Author:  Ruth Fong
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Tegan Maharaj
# Institutions:  [{'id': 'https://openalex.org/I45683168', 'display_name': 'Polytechnique Montréal', 'ror': 'https://ror.org/05f8d4e86', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  ['École Polytechnique de Montréal']
#
# Author:  Pang Wei Koh
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Sara Hooker
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Jade Leung
# Institutions:  []
# Raw affiliation strings:  ['Future of Humanity Institute']
#
# Author:  Andrew Trask
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Emma Bluemke
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Jonathan Lebensbold
# Institutions:  [{'id': 'https://openalex.org/I5023651', 'display_name': 'McGill University', 'ror': 'https://ror.org/01pxwe438', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Cullen O'Keefe
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Mark Koren
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Théo Ryffel
# Institutions:  [{'id': 'https://openalex.org/I4210161954', 'display_name': "Département d'Informatique", 'ror': 'https://ror.org/05y6rqs46', 'country_code': 'FR', 'type': 'facility'}, {'id': 'https://openalex.org/I29607241', 'display_name': 'École Normale Supérieure - PSL', 'ror': 'https://ror.org/05a0dhs15', 'country_code': 'FR', 'type': 'other'}, {'id': 'https://openalex.org/I4210100258', 'display_name': 'National Confidential Enquiry into Patient Outcome and Death', 'ror': 'https://ror.org/016knsn07', 'country_code': 'GB', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Construction and Analysis of Systems for Confidentiality and Authenticity of Data and Entities', "Département d'informatique - ENS Paris"]
#
# Author:  Jasmin Rubinovitz
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Tamay Besiroglu
# Institutions:  [{'id': 'https://openalex.org/I241749', 'display_name': 'University of Cambridge', 'ror': 'https://ror.org/013meh722', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Federica Carugati
# Institutions:  []
# Raw affiliation strings:  ['Center for Advanced Study in the Behavioral Sciences']
#
# Author:  Jack Clark
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Peter Eckersley
# Institutions:  [{'id': 'https://openalex.org/I129364015', 'display_name': 'Partners In Health', 'ror': 'https://ror.org/05tsvnv68', 'country_code': 'US', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Partnership on AI']
#
# Author:  Sarah Haas
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Maritza Johnson
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Ben Laurie
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Alex Ingerman
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Igor Krawczuk
# Institutions:  [{'id': 'https://openalex.org/I5124864', 'display_name': 'École Polytechnique Fédérale de Lausanne', 'ror': 'https://ror.org/02s376052', 'country_code': 'CH', 'type': 'facility'}]
# Raw affiliation strings:  []
#
# Author:  Askell, Amanda
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Rosario Cammarota
# Institutions:  [{'id': 'https://openalex.org/I1343180700', 'display_name': 'Intel (United States)', 'ror': 'https://ror.org/01ek73717', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Andrew J. Lohn
# Institutions:  [{'id': 'https://openalex.org/I1309849503', 'display_name': 'RAND Corporation', 'ror': 'https://ror.org/00f2z7n96', 'country_code': 'US', 'type': 'nonprofit'}]
# Raw affiliation strings:  []
#
# Author:  David W. Krueger
# Institutions:  [{'id': 'https://openalex.org/I159129438', 'display_name': 'University of Quebec at Montreal', 'ror': 'https://ror.org/002rjbv21', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  ['Université du Québec à Montréal = University of Québec in Montréal']
#
# Author:  Charlotte Stix
# Institutions:  [{'id': 'https://openalex.org/I83019370', 'display_name': 'Eindhoven University of Technology', 'ror': 'https://ror.org/02c2kyt77', 'country_code': 'NL', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Peter Henderson
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Logan Graham
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Carina Prunkl
# Institutions:  []
# Raw affiliation strings:  ['Future of Humanity Institute']
#
# Author:  Bianca Martin
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Elizabeth Seger
# Institutions:  [{'id': 'https://openalex.org/I241749', 'display_name': 'University of Cambridge', 'ror': 'https://ror.org/013meh722', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Noa Zilberman
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Seán Ó hÉigeartaigh
# Institutions:  [{'id': 'https://openalex.org/I2802641067', 'display_name': 'Leverhulme Trust', 'ror': 'https://ror.org/012mzw131', 'country_code': 'GB', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Leverhulme Centre for the Future of Intelligence']
#
# Author:  Frens Kroeger
# Institutions:  [{'id': 'https://openalex.org/I73417466', 'display_name': 'Coventry University', 'ror': 'https://ror.org/01tgmhj36', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  ['Coventry University']
#
# Author:  Girish Sastry
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Rebecca Kagan
# Institutions:  [{'id': 'https://openalex.org/I4210145449', 'display_name': 'Center for Security and Emerging Technology', 'ror': 'https://ror.org/045qf3j54', 'country_code': 'US', 'type': 'other'}]
# Raw affiliation strings:  ['Center for Security and Emerging Technology']
#
# Author:  Adrian Weller
# Institutions:  [{'id': 'https://openalex.org/I241749', 'display_name': 'University of Cambridge', 'ror': 'https://ror.org/013meh722', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Brian Tse
# Institutions:  [{'id': 'https://openalex.org/I129364015', 'display_name': 'Partners In Health', 'ror': 'https://ror.org/05tsvnv68', 'country_code': 'US', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Future of Humanity Institute', 'Partnership on AI']
#
# Author:  Elizabeth A. Barnes
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Allan Dafoe
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Paul Scharre
# Institutions:  [{'id': 'https://openalex.org/I2800860796', 'display_name': 'Center for a New American Security', 'ror': 'https://ror.org/0168qf015', 'country_code': 'US', 'type': 'nonprofit'}]
# Raw affiliation strings:  []
#
# Author:  Ariel Herbert-Voss
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Martijn Rasser
# Institutions:  [{'id': 'https://openalex.org/I2800860796', 'display_name': 'Center for a New American Security', 'ror': 'https://ror.org/0168qf015', 'country_code': 'US', 'type': 'nonprofit'}]
# Raw affiliation strings:  []
#
# Author:  Shagun Sodhani
# Institutions:  [{'id': 'https://openalex.org/I159129438', 'display_name': 'University of Quebec at Montreal', 'ror': 'https://ror.org/002rjbv21', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  ['Université du Québec à Montréal = University of Québec in Montréal']
#
# Author:  Carrick Flynn
# Institutions:  [{'id': 'https://openalex.org/I4210145449', 'display_name': 'Center for Security and Emerging Technology', 'ror': 'https://ror.org/045qf3j54', 'country_code': 'US', 'type': 'other'}]
# Raw affiliation strings:  ['Center for Security and Emerging Technology']
#
# Author:  Thomas Gilbert
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of California [Berkeley]']
#
# Author:  Lisa M. Dyer
# Institutions:  [{'id': 'https://openalex.org/I129364015', 'display_name': 'Partners In Health', 'ror': 'https://ror.org/05tsvnv68', 'country_code': 'US', 'type': 'nonprofit'}]
# Raw affiliation strings:  ['Partnership on AI']
#
# Author:  Saif M. Khan
# Institutions:  [{'id': 'https://openalex.org/I4210145449', 'display_name': 'Center for Security and Emerging Technology', 'ror': 'https://ror.org/045qf3j54', 'country_code': 'US', 'type': 'other'}]
# Raw affiliation strings:  ['Center for Security and Emerging Technology']
#
# Author:  Yoshua Bengio
# Institutions:  [{'id': 'https://openalex.org/I159129438', 'display_name': 'University of Quebec at Montreal', 'ror': 'https://ror.org/002rjbv21', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  ['Université du Québec à Montréal = University of Québec in Montréal']
#
# Author:  Markus Anderljung
# Institutions:  []
# Raw affiliation strings:  ['Future of Humanity Institute']
#
#
# Title:  GPTs are GPTs: An Early Look at the Labor Market Impact Potential of
#   Large Language Models
# Author:  Tyna Eloundou
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sam Manning
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pamela Mishkin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Daniel L. Rock
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  TruthfulQA: Measuring How Models Mimic Human Falsehoods
# Author:  Stephanie Lin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Hilton
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Owain Evans
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Fine-Tuning Language Models from Human Preferences.
# Author:  Daniel M. Ziegler
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Nisan Stiennon
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jeffrey Wu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  T. B. Brown
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alec Radford
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dario Amodei
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Paul F. Christiano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Geoffrey Irving
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Learning with Opponent-Learning Awareness
# Author:  Jakob Foerster
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  ['University of Oxford, Oxford , United Kingdom#TAB#']
#
# Author:  Richard Y. Chen
# Institutions:  []
# Raw affiliation strings:  ['OpenAI San Francisco CA USA']
#
# Author:  Maruan Al-Shedivat
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  [' Carnegie Mellon University Pittsburgh PA USA']
#
# Author:  Shimon Whiteson
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  ['University of Oxford, Oxford , United Kingdom#TAB#']
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of California Berkeley, Berkeley, CA, USA']
#
# Author:  Igor Mordatch
# Institutions:  []
# Raw affiliation strings:  ['OpenAI San Francisco CA USA']
#
#
# Title:  A Hazard Analysis Framework for Code Synthesis Large Language Models
# Author:  Heidy Khlaaf
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pamela Mishkin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Joshua Achiam
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Gretchen Krueger
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Miles Brundage
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Emergent Complexity via Multi-Agent Competition.
# Author:  Trapit Bansal
# Institutions:  [{'id': 'https://openalex.org/I24603500', 'display_name': 'University of Massachusetts Amherst', 'ror': 'https://ror.org/0072zz521', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Jakub Pachocki
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Szymon Sidor
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Igor Mordatch
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  GamePad: A Learning Environment for Theorem Proving
# Author:  Danhong Huang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Prafulla Dhariwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dezhen Song
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Proximal Policy Optimization Algorithms
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Filip Wolski
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Prafulla Dhariwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alec Radford
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Oleg Klimov
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Learning Policy Representations in Multiagent Systems
# Author:  Aditya Grover
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Maruan Al-Shedivat
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Jyoti Gupta
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Yura Burda
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Harrison Edwards
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Testing Robustness Against Unforeseen Adversaries
# Author:  Daniel Kang
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['Stanford University ()']
#
# Author:  Yi Sun
# Institutions:  [{'id': 'https://openalex.org/I40347166', 'display_name': 'University of Chicago', 'ror': 'https://ror.org/024mw5h28', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of Chicago (  )']
#
# Author:  Dan Hendrycks
# Institutions:  [{'id': 'https://openalex.org/I134446601', 'display_name': 'Berkeley College', 'ror': 'https://ror.org/02xewxa75', 'country_code': 'US', 'type': 'education'}, {'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['UC Berkeley#TAB#']
#
# Author:  T. B. Brown
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Steinhardt
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['University of California–Berkeley.']
#
#
# Title:  WebGPT: Browser-assisted question-answering with human feedback
# Author:  Reiichiro Nakano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Hilton
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Suchir Balaji
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jeff Wu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Long Ouyang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christina Kim
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christopher Hesse
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sandeep Jain
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Vineet Kosaraju
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  William H. Saunders
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Xu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Karl Cobbe
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Tyna Eloundou
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Gretchen Krueger
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Kevin Button
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Matthew M. Knight
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Chess, Benjamin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sabu John
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Quantifying Generalization in Reinforcement Learning
# Author:  Karl Cobbe
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Oleg Klimov
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Chris Hesse
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Tae-Hoon Kim
# Institutions:  [{'id': 'https://openalex.org/I48566637', 'display_name': 'Ulsan National Institute of Science and Technology', 'ror': 'https://ror.org/017cjz748', 'country_code': 'KR', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Scalable trust-region method for deep reinforcement learning using Kronecker-factored approximation
# Author:  Yuhuai Wu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Elman Mansimov
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  S. Matthew Liao
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Roger Grosse
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jimmy Ba
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Transfer of Adversarial Robustness Between Perturbation Types.
# Author:  Daniel Kang
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['Stanford University ()']
#
# Author:  Yi Sun
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  T. B. Brown
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dan Hendrycks
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Steinhardt
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Multi-Agent Actor-Critic for Mixed Cooperative-Competitive Environments
# Author:  Ryan Lowe
# Institutions:  [{'id': 'https://openalex.org/I5023651', 'display_name': 'McGill University', 'ror': 'https://ror.org/01pxwe438', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Yi Wu
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Aviv Tamar
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Jean Harb
# Institutions:  [{'id': 'https://openalex.org/I5023651', 'display_name': 'McGill University', 'ror': 'https://ror.org/01pxwe438', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  OpenAI Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Igor Mordatch
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Asymmetric Actor Critic for Image-Based Robot Learning
# Author:  Lerrel Pinto
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Marcin Andrychowicz
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Peter Welinder
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Wojciech Zaremba
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
#
# Title:  Synthesizing Robust Adversarial Examples
# Author:  Anish Athalye
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Logan Engstrom
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Andrew Ilyas
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Kwan S. Kwok
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Concrete Problems in AI Safety
# Author:  Dario Amodei
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Chris Olah
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Steinhardt
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Paul F. Christiano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dan Mané
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Deep Reinforcement Learning from Human Preferences
# Author:  Paul F. Christiano
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Jan Leike
# Institutions:  [{'id': 'https://openalex.org/I40120149', 'display_name': 'University of Oxford', 'ror': 'https://ror.org/052gg0110', 'country_code': 'GB', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  T. B. Brown
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Miljan Martic
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Shane Legg
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dario Amodei
# Institutions:  [{'id': 'https://openalex.org/I98301712', 'display_name': 'Baidu (China)', 'ror': 'https://ror.org/03vs3wt56', 'country_code': 'CN', 'type': 'company'}]
# Raw affiliation strings:  []
#
#
# Title:  Release Strategies and the Social Impacts of Language Models.
# Author:  Irene Solaiman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Miles Brundage
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jack Clark
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Askell, Amanda
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ariel Herbert-Voss
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jeff Wu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alec Radford
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jasmine Wang
# Institutions:  []
# Raw affiliation strings:  []
#
#
# ...
#
# Author:  Paul Scharre
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Thomas Zeitzoff
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Bobby Filar
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Hyrum S. Anderson
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Heather M. Roff
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Gregory C. Allen
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Steinhardt
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Carrick Flynn
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Seán Ó hÉigeartaigh
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Simon Beard
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Haydn Belfield
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sebastian Farquhar
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Clare Lyle
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Rebecca Crootof
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Owain Evans
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Michael Le Page
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Joanna J. Bryson
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Roman V. Yampolskiy
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dario Amodei
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Point-E: A System for Generating 3D Point Clouds from Complex Prompts
# Author:  Alex Nichol
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Heewoo Jun
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Prafulla Dhariwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pamela Mishkin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Mark Chen
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Evolved Policy Gradients
# Author:  Rein Houthooft
# Institutions:  [{'id': 'https://openalex.org/I32597200', 'display_name': 'Ghent University', 'ror': 'https://ror.org/00cv9y106', 'country_code': 'BE', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Richard Y. Chen
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Phillip Isola
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Bradly C. Stadie
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Filip Wolski
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonathan Ho
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
#
# Title:  Learning Sparse Neural Networks through L_0 Regularization
# Author:  Christos Louizos
# Institutions:  [{'id': 'https://openalex.org/I887064364', 'display_name': 'University of Amsterdam', 'ror': 'https://ror.org/04dkp9463', 'country_code': 'NL', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Max Welling
# Institutions:  [{'id': 'https://openalex.org/I109736498', 'display_name': 'Canadian Institute for Advanced Research', 'ror': 'https://ror.org/01sdtdd95', 'country_code': 'CA', 'type': 'facility'}]
# Raw affiliation strings:  []
#
# Author:  Diederik P. Kingma
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Emergence of Grounded Compositional Language in Multi-Agent Populations
# Author:  Igor Mordatch
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  ['UC Berkeley#TAB#']
#
#
# Title:  Hierarchical Text-Conditional Image Generation with CLIP Latents
# Author:  A. Ramesh
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Prafulla Dhariwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alex Nichol
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Casey Chu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Mark Chen
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  The Role of Cooperation in Responsible AI Development
# Author:  Askell, Amanda
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Miles Brundage
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Gillian K. Hadfield
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  Exploration by Random Network Distillation.
# Author:  Yuri Burda
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Harrison Edwards
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Amos Storkey
# Institutions:  []
# Raw affiliation strings:  ['Institute for Adaptive and Neural Computation']
#
# Author:  Oleg Klimov
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  Meta Learning Shared Hierarchies
# Author:  Kevin Frans
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Jonathan Ho
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Xi Chen
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Pieter Abbeel
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Emergent Tool Use From Multi-Agent Autocurricula.
# Author:  Bowen Baker
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Ingmar Kanitscheider
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Todor Markov
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Yi Wu
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Glenn Powell
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Bob McGrew
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Igor Mordatch
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  ['Google,,,,,']
#
#
# Title:  Hindsight Experience Replay
# Author:  Marcin Andrychowicz
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Filip Wolski
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alex Ray
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonas Schneider
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Rachel Fong
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Peter Welinder
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Bob McGrew
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Josh Tobin
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  OpenAI Pieter Abbeel
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Wojciech Zaremba
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Concept Learning with Energy-Based Models
# Author:  Igor Mordatch
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Glow: Generative Flow with Invertible 1x1 Convolutions
# Author:  Diederik P. Kingma
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Prafulla Dhariwal
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  GPT-4 Technical Report
# Author:  OpenAI
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  PixelCNN++: Improving the PixelCNN with Discretized Logistic Mixture Likelihood and Other Modifications
# Author:  Tim Salimans
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Andrej Karpathy
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Xi Chen
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Diederik P. Kingma
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Dota 2 with Large Scale Deep Reinforcement Learning
# Author:  Christopher Berner
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Greg Brockman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Brooke Chan
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Vicki Cheung
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Przemyslaw Debiak
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christy Dennison
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  David Farhi
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Quirin Fischer
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Shariq Hashme
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Christopher Hesse
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Rafal Jozefowicz
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Scott Gray
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Catherine Olsson
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jakub Pachocki
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  M. N. Petrov
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Henrique Ponde de Oliveira Pinto
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonathan Raiman
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Tim Salimans
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jeremy Schlatter
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonas Schneider
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Szymon Sidor
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jie Tang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Filip Wolski
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Susan Zhang
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Training language models to follow instructions with human feedback
# Author:  Long Ouyang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jeff Wu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Xu
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  D.P. Almeida
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Carroll L. Wainwright
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Pamela Mishkin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Chong Zhang
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sandhini Agarwal
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Katarina Slama
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alex Ray
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Sabu John
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jacob Hilton
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Fraser Kelton
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Luke Miller
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Maddie Simens
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Askell, Amanda
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Peter Welinder
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Paul Christiano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jan Leike
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ryan J. Lowe
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Extensions and Limitations of the Neural GPU
# Author:  Eric Price
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Wojciech Zaremba
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Ilya Sutskever
# Institutions:  []
# Raw affiliation strings:  []
#
#
# Title:  Leveraging Procedural Generation to Benchmark Reinforcement Learning
# Author:  Karl Cobbe
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Christopher Hesse
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Jacob Hilton
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  John Schulman
# Institutions:  []
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  Improving GANs Using Optimal Transport
# Author:  Tim Salimans
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Han Zhang
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company'}]
# Raw affiliation strings:  []
#
# Author:  Alec Radford
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Dimitris N. Metaxas
# Institutions:  [{'id': 'https://openalex.org/I102322142', 'display_name': 'Rutgers, The State University of New Jersey', 'ror': 'https://ror.org/05vt9qd57', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
#
# Title:  On the Quantitative Analysis of Decoder-Based Generative Models
# Author:  Yuhuai Wu
# Institutions:  [{'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Yuri Burda
# Institutions:  [{'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Ruslan Salakhutdinov
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education'}]
# Raw affiliation strings:  []
#
# Author:  Roger Grosse
# Institutions:  [{'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education'}]
# Raw affiliation strings:  []
#
#
# Title:  Multi-Goal Reinforcement Learning: Challenging Robotics Environments and Request for Research
# Author:  Matthias Plappert
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Marcin Andrychowicz
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Alex Ray
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Bob McGrew
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Bowen Baker
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Glenn Powell
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Jonas Schneider
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Josh Tobin
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Maciek Chociej
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Peter Welinder
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Vikash Kumar
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Wojciech Zaremba
# Institutions:  []
# Raw affiliation strings:  []

# %%
print("Total unique authors: ", len(all_time_unique_authors))
all_time_unique_authors
# Out:
# Total unique authors:  343
# {'https://openalex.org/A5007570707': 'Jeff Wu',
#  'https://openalex.org/A5068949174': 'Long Ouyang',
#  'https://openalex.org/A5089747113': 'Daniel M. Ziegler',
#  'https://openalex.org/A5019575601': 'Nisan Stiennon',
#  'https://openalex.org/A5004295653': 'Ryan Lowe',
#  'https://openalex.org/A5090592321': 'Jan Leike',
#  'https://openalex.org/A5037736834': 'Paul F. Christiano',
#  'https://openalex.org/A5027941146': 'Yan Duan',
#  'https://openalex.org/A5091819924': 'Marcin Andrychowicz',
#  'https://openalex.org/A5004762590': 'Bradly C. Stadie',
#  'https://openalex.org/A5067435818': 'OpenAI Jonathan Ho',
#  'https://openalex.org/A5009926169': 'Jonas Schneider',
#  'https://openalex.org/A5006446297': 'Ilya Sutskever',
#  'https://openalex.org/A5049349154': 'Pieter Abbeel',
#  'https://openalex.org/A5076651586': 'Wojciech Zaremba',
#  'https://openalex.org/A5048522044': 'Bowen Baker',
#  'https://openalex.org/A5046491870': 'Ilge Akkaya',
#  'https://openalex.org/A5018957231': 'P. A. Zhokhov',
#  'https://openalex.org/A5018598100': 'Joost Huizinga',
#  'https://openalex.org/A5034676524': 'Jie Tang',
#  'https://openalex.org/A5033112877': 'Adrien Ecoffet',
#  'https://openalex.org/A5091596210': 'Brandon Houghton',
#  'https://openalex.org/A5078100000': 'Raul Sampedro',
#  'https://openalex.org/A5006797018': 'Jeff Clune',
#  'https://openalex.org/A5037117755': 'Matthias Plappert',
#  'https://openalex.org/A5003630193': 'Rein Houthooft',
#  'https://openalex.org/A5076418776': 'Prafulla Dhariwal',
#  'https://openalex.org/A5051574174': 'Szymon Sidor',
#  'https://openalex.org/A5005243537': 'Richard Y. Chen',
#  'https://openalex.org/A5008171524': 'Xi Chen',
#  'https://openalex.org/A5012730104': 'Tamim Asfour',
#  'https://openalex.org/A5043772703': 'Mohammad Bavarian',
#  'https://openalex.org/A5065707162': 'Heewoo Jun',
#  'https://openalex.org/A5013248082': 'Nikolas Tezak',
#  'https://openalex.org/A5058738098': 'Sabu John',
#  'https://openalex.org/A5042623426': 'Christine McLeavey',
#  'https://openalex.org/A5044086066': 'Jerry Tworek',
#  'https://openalex.org/A5030935953': 'Mark Chen',
#  'https://openalex.org/A5002389298': 'Ge Yang',
#  'https://openalex.org/A5024901763': 'Yuhuai Wu',
#  'https://openalex.org/A5054034251': 'OpenAI',
#  'https://openalex.org/A5016448989': 'Maciek Chociej',
#  'https://openalex.org/A5049998033': 'Mateusz Litwin',
#  'https://openalex.org/A5026829243': 'Bob McGrew',
#  'https://openalex.org/A5040970183': 'Arthur Petron',
#  'https://openalex.org/A5080211309': 'Alex Paino',
#  'https://openalex.org/A5010167098': 'Glenn Powell',
#  'https://openalex.org/A5071277203': 'Raphael Ribas',
#  'https://openalex.org/A5010674841': 'Peter Welinder',
#  'https://openalex.org/A5009970175': 'Li Weng',
#  'https://openalex.org/A5002281342': 'Qiming Yuan',
#  'https://openalex.org/A5082164874': 'Lei Zhang',
#  'https://openalex.org/A5051250767': 'Alec Radford',
#  'https://openalex.org/A5067370075': 'Rafal Jozefowicz',
#  'https://openalex.org/A5055522778': 'Nishikant Mishra',
#  'https://openalex.org/A5014193325': 'Igor Mordatch',
#  'https://openalex.org/A5007914769': 'Stephanie Lin',
#  'https://openalex.org/A5007861777': 'Jacob Hilton',
#  'https://openalex.org/A5089789418': 'Owain Evans',
#  'https://openalex.org/A5032275803': 'Joshua Achiam',
#  'https://openalex.org/A5019471288': 'Harrison Edwards',
#  'https://openalex.org/A5066197394': 'Dario Amodei',
#  'https://openalex.org/A5018809423': 'Nicolas Papernot',
#  'https://openalex.org/A5061767913': 'Martín Abadi',
#  'https://openalex.org/A5024723282': 'Úlfar Erlingsson',
#  'https://openalex.org/A5004271128': 'Ian Goodfellow',
#  'https://openalex.org/A5080065269': 'Kunal Talwar',
#  'https://openalex.org/A5041777043': 'Yilun Du',
#  'https://openalex.org/A5055399590': 'Yuri Burda',
#  'https://openalex.org/A5090678609': 'Harri Edwards',
#  'https://openalex.org/A5066151318': 'Deepak Pathak',
#  'https://openalex.org/A5007901825': 'Amos Storkey',
#  'https://openalex.org/A5029105520': 'Trevor Darrell',
#  'https://openalex.org/A5077436220': 'Alexei A. Efros',
#  'https://openalex.org/A5029611587': 'Geoffrey Irving',
#  'https://openalex.org/A5040311065': 'Greg Brockman',
#  'https://openalex.org/A5046603680': 'Vicki Cheung',
#  'https://openalex.org/A5046841068': 'Ludwig Pettersson',
#  'https://openalex.org/A5009037058': 'John Schulman',
#  'https://openalex.org/A5002056567': 'Jie Tang',
#  'https://openalex.org/A5083629800': 'Shlegeris, Buck',
#  'https://openalex.org/A5058076181': 'Alex Nichol',
#  'https://openalex.org/A5081558429': 'Alex Tamkin',
#  'https://openalex.org/A5066559387': 'Miles Brundage',
#  'https://openalex.org/A5031107879': 'Jack Clark',
#  'https://openalex.org/A5006294201': 'Ganguli, Deep',
#  'https://openalex.org/A5005431772': 'Chelsea Finn',
#  'https://openalex.org/A5026322200': 'Sergey Levine',
#  'https://openalex.org/A5001534200': 'Carlos Florensa',
#  'https://openalex.org/A5015072918': 'Pfau, Vicki',
#  'https://openalex.org/A5002922045': 'Christopher Hesse',
#  'https://openalex.org/A5067512589': 'Oleg Klimov',
#  'https://openalex.org/A5030261391': 'Peter L. Bartlett',
#  'https://openalex.org/A5079465685': 'T. B. Brown',
#  'https://openalex.org/A5084254760': 'Benjamin Mann',
#  'https://openalex.org/A5080941449': 'Nick Ryder',
#  'https://openalex.org/A5031060893': 'Melanie Subbiah',
#  'https://openalex.org/A5053213601': 'Jared Kaplan',
#  'https://openalex.org/A5043840749': 'Arvind Neelakantan',
#  'https://openalex.org/A5083109184': 'Pranav Shyam',
#  'https://openalex.org/A5059260582': 'Girish Sastry',
#  'https://openalex.org/A5030305998': 'Askell, Amanda',
#  'https://openalex.org/A5057289323': 'Sandhini Agarwal',
#  'https://openalex.org/A5070026510': 'Ariel Herbert-Voss',
#  'https://openalex.org/A5064685592': 'Gretchen Krueger',
#  'https://openalex.org/A5049786610': 'Henighan, Tom',
#  'https://openalex.org/A5084512458': 'Rewon Child',
#  'https://openalex.org/A5043641795': 'A. Ramesh',
#  'https://openalex.org/A5081413425': 'Jeffrey Wu',
#  'https://openalex.org/A5089232745': 'Clemens Winter',
#  'https://openalex.org/A5016619179': 'Eric J. Sigler',
#  'https://openalex.org/A5026541761': 'Scott Gray',
#  'https://openalex.org/A5057742306': 'Chess, Benjamin',
#  'https://openalex.org/A5022674572': 'Christopher Berner',
#  'https://openalex.org/A5054887773': 'McCandlish, Sam',
#  'https://openalex.org/A5059363123': 'Shahar Avin',
#  'https://openalex.org/A5041434797': 'Jasmine Wang',
#  'https://openalex.org/A5040767120': 'Haydn Belfield',
#  'https://openalex.org/A5000711679': 'Gillian K. Hadfield',
#  'https://openalex.org/A5057529586': 'Heidy Khlaaf',
#  'https://openalex.org/A5044272417': 'Jingying Yang',
#  'https://openalex.org/A5011967325': 'Helen Toner',
#  'https://openalex.org/A5030205315': 'Ruth Fong',
#  'https://openalex.org/A5061026145': 'Tegan Maharaj',
#  'https://openalex.org/A5079904764': 'Pang Wei Koh',
#  'https://openalex.org/A5078850040': 'Sara Hooker',
#  'https://openalex.org/A5041819739': 'Jade Leung',
#  'https://openalex.org/A5051375994': 'Andrew Trask',
#  'https://openalex.org/A5071500568': 'Emma Bluemke',
#  'https://openalex.org/A5035459842': 'Jonathan Lebensbold',
#  'https://openalex.org/A5075689333': "Cullen O'Keefe",
#  'https://openalex.org/A5059386117': 'Mark Koren',
#  'https://openalex.org/A5080234773': 'Théo Ryffel',
#  'https://openalex.org/A5070383871': 'Jasmin Rubinovitz',
#  'https://openalex.org/A5009016780': 'Tamay Besiroglu',
#  'https://openalex.org/A5076220181': 'Federica Carugati',
#  'https://openalex.org/A5028409556': 'Peter Eckersley',
#  'https://openalex.org/A5030803415': 'Sarah Haas',
#  'https://openalex.org/A5085824259': 'Maritza Johnson',
#  'https://openalex.org/A5069096861': 'Ben Laurie',
#  'https://openalex.org/A5053479641': 'Alex Ingerman',
#  'https://openalex.org/A5063651637': 'Igor Krawczuk',
#  'https://openalex.org/A5085883266': 'Rosario Cammarota',
#  'https://openalex.org/A5052029742': 'Andrew J. Lohn',
#  'https://openalex.org/A5029025914': 'David W. Krueger',
#  'https://openalex.org/A5089079497': 'Charlotte Stix',
#  'https://openalex.org/A5027489992': 'Peter Henderson',
#  'https://openalex.org/A5041121552': 'Logan Graham',
#  'https://openalex.org/A5090934878': 'Carina Prunkl',
#  'https://openalex.org/A5072277201': 'Bianca Martin',
#  'https://openalex.org/A5004799433': 'Elizabeth Seger',
#  'https://openalex.org/A5034926658': 'Noa Zilberman',
#  'https://openalex.org/A5033871638': 'Seán Ó hÉigeartaigh',
#  'https://openalex.org/A5008254188': 'Frens Kroeger',
#  'https://openalex.org/A5014260570': 'Rebecca Kagan',
#  'https://openalex.org/A5042278493': 'Adrian Weller',
#  'https://openalex.org/A5087031022': 'Brian Tse',
#  'https://openalex.org/A5038101556': 'Elizabeth A. Barnes',
#  'https://openalex.org/A5054425888': 'Allan Dafoe',
#  'https://openalex.org/A5053289503': 'Paul Scharre',
#  'https://openalex.org/A5029764811': 'Martijn Rasser',
#  'https://openalex.org/A5052862844': 'Shagun Sodhani',
#  'https://openalex.org/A5066054511': 'Carrick Flynn',
#  'https://openalex.org/A5069143323': 'Thomas Gilbert',
#  'https://openalex.org/A5088226403': 'Lisa M. Dyer',
#  'https://openalex.org/A5061242820': 'Saif M. Khan',
#  'https://openalex.org/A5028826050': 'Yoshua Bengio',
#  'https://openalex.org/A5005250335': 'Markus Anderljung',
#  'https://openalex.org/A5065917408': 'Tyna Eloundou',
#  'https://openalex.org/A5040276644': 'Sam Manning',
#  'https://openalex.org/A5028772381': 'Pamela Mishkin',
#  'https://openalex.org/A5018502975': 'Daniel L. Rock',
#  'https://openalex.org/A5059094093': 'Jakob Foerster',
#  'https://openalex.org/A5008835202': 'Maruan Al-Shedivat',
#  'https://openalex.org/A5056879203': 'Shimon Whiteson',
#  'https://openalex.org/A5084271903': 'Trapit Bansal',
#  'https://openalex.org/A5011053473': 'Jakub Pachocki',
#  'https://openalex.org/A5083564856': 'Danhong Huang',
#  'https://openalex.org/A5054819263': 'Dezhen Song',
#  'https://openalex.org/A5064092435': 'Filip Wolski',
#  'https://openalex.org/A5014409944': 'Aditya Grover',
#  'https://openalex.org/A5002351623': 'Jyoti Gupta',
#  'https://openalex.org/A5031242492': 'Yura Burda',
#  'https://openalex.org/A5072348548': 'Daniel Kang',
#  'https://openalex.org/A5026251625': 'Yi Sun',
#  'https://openalex.org/A5020400986': 'Dan Hendrycks',
#  'https://openalex.org/A5060196069': 'Jacob Steinhardt',
#  'https://openalex.org/A5014003952': 'Reiichiro Nakano',
#  'https://openalex.org/A5082224513': 'Suchir Balaji',
#  'https://openalex.org/A5075972279': 'Christina Kim',
#  'https://openalex.org/A5032024231': 'Sandeep Jain',
#  'https://openalex.org/A5065338363': 'Vineet Kosaraju',
#  'https://openalex.org/A5046282300': 'William H. Saunders',
#  'https://openalex.org/A5048689504': 'Xu',
#  'https://openalex.org/A5040657467': 'Karl Cobbe',
#  'https://openalex.org/A5011602093': 'Kevin Button',
#  'https://openalex.org/A5061161174': 'Matthew M. Knight',
#  'https://openalex.org/A5058633252': 'Chris Hesse',
#  'https://openalex.org/A5037864229': 'Tae-Hoon Kim',
#  'https://openalex.org/A5045225880': 'Elman Mansimov',
#  'https://openalex.org/A5052326736': 'S. Matthew Liao',
#  'https://openalex.org/A5067036768': 'Roger Grosse',
#  'https://openalex.org/A5012276327': 'Jimmy Ba',
#  'https://openalex.org/A5078326384': 'Yi Sun',
#  'https://openalex.org/A5008951080': 'Yi Wu',
#  'https://openalex.org/A5020699288': 'Aviv Tamar',
#  'https://openalex.org/A5025745431': 'Jean Harb',
#  'https://openalex.org/A5015405491': 'OpenAI Pieter Abbeel',
#  'https://openalex.org/A5056646668': 'Lerrel Pinto',
#  'https://openalex.org/A5091720485': 'Anish Athalye',
#  'https://openalex.org/A5061993024': 'Logan Engstrom',
#  'https://openalex.org/A5067427666': 'Andrew Ilyas',
#  'https://openalex.org/A5000123142': 'Kwan S. Kwok',
#  'https://openalex.org/A5039751155': 'Chris Olah',
#  'https://openalex.org/A5045113162': 'Dan Mané',
#  'https://openalex.org/A5025651820': 'Miljan Martic',
#  'https://openalex.org/A5008987732': 'Shane Legg',
#  'https://openalex.org/A5041785132': 'Irene Solaiman',
#  'https://openalex.org/A5059445103': 'Kendall Lowrey',
#  'https://openalex.org/A5040732794': 'Aravind Rajeswaran',
#  'https://openalex.org/A5018792915': 'Sham M. Kakade',
#  'https://openalex.org/A5069122170': 'Emanuel Todorov',
#  'https://openalex.org/A5028891032': 'Henrique Ponde de Oliveira Pinto',
#  'https://openalex.org/A5063374092': 'Nicholas Joseph',
#  'https://openalex.org/A5031013142': 'Alex Ray',
#  'https://openalex.org/A5041667198': 'Raul Puri',
#  'https://openalex.org/A5000965900': 'M. N. Petrov',
#  'https://openalex.org/A5087045209': 'Brooke Chan',
#  'https://openalex.org/A5070966194': 'Mikhail Pavlov',
#  'https://openalex.org/A5091250983': 'Alethea Power',
#  'https://openalex.org/A5031789995': 'Lukasz Kaiser',
#  'https://openalex.org/A5089646974': 'Philippe Tillet',
#  'https://openalex.org/A5065686484': 'Felipe Petroski Such',
#  'https://openalex.org/A5001482492': 'Dave Cummings',
#  'https://openalex.org/A5031279787': 'Fotios Chantzis',
#  'https://openalex.org/A5077125863': 'Elizabeth Barnes',
#  'https://openalex.org/A5065253486': 'William H. Guss',
#  'https://openalex.org/A5044791875': 'Jie Tang',
#  'https://openalex.org/A5085244021': 'I. Babuschkin',
#  'https://openalex.org/A5062927867': 'Shantanu Jain',
#  'https://openalex.org/A5057686891': 'William S. Saunders',
#  'https://openalex.org/A5081028846': 'Andrew N. Carr',
#  'https://openalex.org/A5034729427': 'Vedant Misra',
#  'https://openalex.org/A5017223053': 'Evan Morikawa',
#  'https://openalex.org/A5011569714': 'Mira Murati',
#  'https://openalex.org/A5042208401': 'Katie Mayer',
#  'https://openalex.org/A5011653106': 'Danny Hernandez',
#  'https://openalex.org/A5040853420': 'Will Grathwohl',
#  'https://openalex.org/A5029262768': 'Ricky T. Q. Chen',
#  'https://openalex.org/A5027925889': 'Jesse Bettencourt',
#  'https://openalex.org/A5030409494': 'David Duvenaud',
#  'https://openalex.org/A5051743369': 'Chelsea Voss',
#  'https://openalex.org/A5036207701': 'Cathy Wu',
#  'https://openalex.org/A5027007388': 'Vikash Kumar',
#  'https://openalex.org/A5021116704': 'Alexandre M. Bayen',
#  'https://openalex.org/A5027194515': 'Xi Chen',
#  'https://openalex.org/A5024065815': 'Diederik P. Kingma',
#  'https://openalex.org/A5082512329': 'Tim Salimans',
#  'https://openalex.org/A5082738872': 'Sandy H. Huang',
#  'https://openalex.org/A5053018827': 'Jonathan Ho',
#  'https://openalex.org/A5019383629': 'Xi Chen',
#  'https://openalex.org/A5070509173': 'Smitha Milli',
#  'https://openalex.org/A5076416853': 'Akshay Degwekar',
#  'https://openalex.org/A5068388812': 'Venkatesan Guruswami',
#  'https://openalex.org/A5000240220': 'Vinod Vaikuntanathan',
#  'https://openalex.org/A5056489227': 'Christine K. Payne',
#  'https://openalex.org/A5061984381': 'Jong Wook Kim',
#  'https://openalex.org/A5078012334': 'Joseph Suarez',
#  'https://openalex.org/A5017456911': 'Phillip Isola',
#  'https://openalex.org/A5090469776': 'Takeru Miyato',
#  'https://openalex.org/A5029197877': 'Andrew M. Dai',
#  'https://openalex.org/A5087223073': 'Josh A. Goldstein',
#  'https://openalex.org/A5001439307': 'Micah Musser',
#  'https://openalex.org/A5067816317': 'Renee DiResta',
#  'https://openalex.org/A5028350037': 'Matthew Gentzel',
#  'https://openalex.org/A5048611641': 'Katerina Sedova',
#  'https://openalex.org/A5058844317': 'Jonathan Raiman',
#  'https://openalex.org/A5086846020': 'Olivier Raiman',
#  'https://openalex.org/A5018206582': 'Gal Kaplun',
#  'https://openalex.org/A5085627713': 'Yamini Bansal',
#  'https://openalex.org/A5067973451': 'Tristan Yang',
#  'https://openalex.org/A5000871493': 'Boaz Barak',
#  'https://openalex.org/A5042906130': 'Tao Xu',
#  'https://openalex.org/A5025285284': 'Jesse Michael Han',
#  'https://openalex.org/A5045136980': 'Quan Yuan',
#  'https://openalex.org/A5007406730': 'Chris Hallacy',
#  'https://openalex.org/A5062062874': 'Johannes Heidecke',
#  'https://openalex.org/A5091659614': 'Boris Power',
#  'https://openalex.org/A5088970351': 'Tyna Eloundou Nekoul',
#  'https://openalex.org/A5026449815': 'David P. Schnurr',
#  'https://openalex.org/A5073195867': 'Kenny Hsu',
#  'https://openalex.org/A5045084827': 'Madeleine Thompson',
#  'https://openalex.org/A5060583646': 'Tabarak Khan',
#  'https://openalex.org/A5029781628': 'Toki Sherbakov',
#  'https://openalex.org/A5003577867': 'Joanne Jang',
#  'https://openalex.org/A5078756156': 'Stanislas Polu',
#  'https://openalex.org/A5060454700': 'Zain Shah',
#  'https://openalex.org/A5081604363': 'Trevor Blackwell',
#  'https://openalex.org/A5012812463': 'Joshua Tobin',
#  'https://openalex.org/A5079846844': 'Ben Garfinkel',
#  'https://openalex.org/A5085701018': 'Thomas Zeitzoff',
#  'https://openalex.org/A5069030737': 'Bobby Filar',
#  'https://openalex.org/A5005817824': 'Hyrum S. Anderson',
#  'https://openalex.org/A5084938905': 'Heather M. Roff',
#  'https://openalex.org/A5048158022': 'Gregory C. Allen',
#  'https://openalex.org/A5066400110': 'Simon Beard',
#  'https://openalex.org/A5051690066': 'Sebastian Farquhar',
#  'https://openalex.org/A5089486474': 'Clare Lyle',
#  'https://openalex.org/A5018878332': 'Rebecca Crootof',
#  'https://openalex.org/A5032868662': 'Michael Le Page',
#  'https://openalex.org/A5009631016': 'Joanna J. Bryson',
#  'https://openalex.org/A5060472193': 'Roman V. Yampolskiy',
#  'https://openalex.org/A5005095861': 'Christos Louizos',
#  'https://openalex.org/A5087368991': 'Max Welling',
#  'https://openalex.org/A5028386506': 'Casey Chu',
#  'https://openalex.org/A5053366330': 'Kevin Frans',
#  'https://openalex.org/A5044764535': 'Ingmar Kanitscheider',
#  'https://openalex.org/A5081692949': 'Todor Markov',
#  'https://openalex.org/A5052434214': 'Rachel Fong',
#  'https://openalex.org/A5073825955': 'Josh Tobin',
#  'https://openalex.org/A5009290031': 'Andrej Karpathy',
#  'https://openalex.org/A5011030024': 'Przemyslaw Debiak',
#  'https://openalex.org/A5026089146': 'Christy Dennison',
#  'https://openalex.org/A5059240947': 'David Farhi',
#  'https://openalex.org/A5054167605': 'Quirin Fischer',
#  'https://openalex.org/A5033509151': 'Shariq Hashme',
#  'https://openalex.org/A5064850171': 'Catherine Olsson',
#  'https://openalex.org/A5067477920': 'Jeremy Schlatter',
#  'https://openalex.org/A5051860831': 'Susan Zhang',
#  'https://openalex.org/A5028206366': 'D.P. Almeida',
#  'https://openalex.org/A5022076965': 'Carroll L. Wainwright',
#  'https://openalex.org/A5047835985': 'Chong Zhang',
#  'https://openalex.org/A5022205442': 'Katarina Slama',
#  'https://openalex.org/A5065002167': 'Alex Ray',
#  'https://openalex.org/A5011207305': 'Fraser Kelton',
#  'https://openalex.org/A5037192369': 'Luke Miller',
#  'https://openalex.org/A5011719782': 'Maddie Simens',
#  'https://openalex.org/A5043847536': 'Paul Christiano',
#  'https://openalex.org/A5038882588': 'Ryan J. Lowe',
#  'https://openalex.org/A5083990461': 'Eric Price',
#  'https://openalex.org/A5050852420': 'Han Zhang',
#  'https://openalex.org/A5064437234': 'Dimitris N. Metaxas',
#  'https://openalex.org/A5071983998': 'Ruslan Salakhutdinov'}

# %%
num_authors_confirmed_openai = 0
for author_id, author_name in all_time_unique_authors.items():
    last_known_affiliation = Authors()[author_id]["last_known_institution"]
    if last_known_affiliation is not None: 
        if last_known_affiliation["id"] == selected_institution_ids[0]:
            num_authors_confirmed_openai += 1
        print(f"{author_name}: {last_known_affiliation['display_name']}")
num_authors_confirmed_openai
# Out:
# Jeff Wu: Visual Sciences (United States)
# Long Ouyang: Plastic Surgery Hospital
# Daniel M. Ziegler: Massachusetts Institute of Technology
# Ryan Lowe: Facebook (Israel)
# Jan Leike: DeepMind (United Kingdom)
# Paul F. Christiano: University of California, Berkeley
# Yan Duan: Qingdao Agricultural University
# Marcin Andrychowicz: Google (United States)
# Bradly C. Stadie: University of California, Berkeley
# Jonas Schneider: University of Basel
# Ilya Sutskever: OpenAI (United States)
# Pieter Abbeel: University of California, Berkeley
# Wojciech Zaremba: New York University
# Bowen Baker: International Commission on Missing Persons
# Ilge Akkaya: OpenAI (United States)
# P. A. Zhokhov: Texas A&M University
# Joost Huizinga: OpenAI (United States)
# Jie Tang: University of Chinese Academy of Sciences
# Adrien Ecoffet: International Commission on Missing Persons
# Brandon Houghton: International Commission on Missing Persons
# Raul Sampedro: OpenAI (United States)
# Jeff Clune: OpenAI (United States)
# Matthias Plappert: OpenAI (United States)
# Rein Houthooft: Ghent University
# Prafulla Dhariwal: International Commission on Missing Persons
# Szymon Sidor: International Commission on Missing Persons
# Richard Y. Chen: Center for Grain and Animal Health Research
# Xi Chen: Harbin Institute of Technology
# Tamim Asfour: Robotics Research (United States)
# Mohammad Bavarian: Massachusetts Institute of Technology
# Heewoo Jun: International Commission on Missing Persons
# Nikolas Tezak: Rigetti Computing (United States)
# Sabu John: Kings County Hospital Center
# Christine McLeavey: D. E. Shaw Research
# Mark Chen: Tan Tock Seng Hospital
# Ge Yang: Peking University
# Yuhuai Wu: Google (United States)
# Maciek Chociej: OpenAI (United States)
# Bob McGrew: International Commission on Missing Persons
# Arthur Petron: OpenAI (United States)
# Alex Paino: OpenAI (United States)
# Glenn Powell: International Commission on Missing Persons
# Peter Welinder: OpenAI (United States)
# Li Weng: Guangdong Medical College
# Qiming Yuan: Chinese Institute for Brain Research
# Lei Zhang: Zhejiang University
# Alec Radford: International Commission on Missing Persons
# Rafal Jozefowicz: OpenAI (United States)
# Nishikant Mishra: University of Hull
# Igor Mordatch: Brain (Germany)
# Stephanie Lin: Creative Commons
# Jacob Hilton: National Institute of Neurological Disorders and Stroke
# Owain Evans: University of Oxford
# Joshua Achiam: University of California, Berkeley
# Harrison Edwards: University of Toronto
# Dario Amodei: AnthroTronix (United States)
# Nicolas Papernot: Google (United States)
# Martín Abadi: International Islamic University Malaysia
# Úlfar Erlingsson: Apple (Israel)
# Ian Goodfellow: Google (United States)
# Kunal Talwar: Apple (United Kingdom)
# Yilun Du: Protein Express (United States)
# Yuri Burda: International Commission on Missing Persons
# Harri Edwards: International Commission on Missing Persons
# Deepak Pathak: Carnegie Mellon University
# Amos Storkey: Leonardo (United Kingdom)
# Trevor Darrell: DeepMind (United Kingdom)
# Alexei A. Efros: University of California, Berkeley
# Geoffrey Irving: DeepMind (United Kingdom)
# Greg Brockman: University of North Dakota
# John Schulman: International Commission on Missing Persons
# Jie Tang: Southwest Jiaotong University
# Alex Nichol: International Commission on Missing Persons
# Alex Tamkin: Stanford University
# Miles Brundage: OpenAI (United States)
# Jack Clark: AnthroTronix (United States)
# Ganguli, Deep: AnthroTronix (United States)
# Chelsea Finn: Stanford University
# Sergey Levine: Berkeley College
# Carlos Florensa: University of California, Berkeley
# Christopher Hesse: International Commission on Missing Persons
# Oleg Klimov: International Commission on Missing Persons
# Peter L. Bartlett: University of California, Berkeley
# T. B. Brown: International Commission on Missing Persons
# Nick Ryder: University of California, Berkeley
# Melanie Subbiah: Dartmouth Psychiatric Research Center
# Jared Kaplan: AnthroTronix (United States)
# Arvind Neelakantan: Google (United States)
# Pranav Shyam: SRM Institute of Science and Technology
# Girish Sastry: OpenAI (United States)
# Askell, Amanda: AnthroTronix (United States)
# Sandhini Agarwal: OpenAI (United States)
# Ariel Herbert-Voss: OpenAI (United States)
# Gretchen Krueger: OpenAI (United States)
# Henighan, Tom: AnthroTronix (United States)
# Rewon Child: International Commission on Missing Persons
# A. Ramesh: Indian Institute of Technology Madras
# Jeffrey Wu: International Commission on Missing Persons
# Clemens Winter: Page Public Library
# Eric J. Sigler: Ophthalmic Consultants of Long Island
# Scott Gray: Battery Park
# Chess, Benjamin: International Commission on Missing Persons
# Christopher Berner: Facebook (Israel)
# McCandlish, Sam: AnthroTronix (United States)
# Shahar Avin: University of Cambridge
# Jasmine Wang: Hunter College
# Haydn Belfield: Leverhulme Trust
# Gillian K. Hadfield: OpenAI (United States)
# Heidy Khlaaf: Adelard
# Jingying Yang: Tianjin University of Science and Technology
# Helen Toner: Center for Security and Emerging Technology
# Ruth Fong: Princeton University
# Tegan Maharaj: University of Toronto
# Pang Wei Koh: Stanford University
# Sara Hooker: Google (United States)
# Jade Leung: University of Oxford
# Andrew Trask: University of Oxford
# Emma Bluemke: University of Oxford
# Jonathan Lebensbold: McGill University
# Cullen O'Keefe: OpenAI (United States)
# Mark Koren: Stanford University
# Théo Ryffel: Département d'Informatique
# Jasmin Rubinovitz: Massachusetts Institute of Technology
# Tamay Besiroglu: Massachusetts Institute of Technology
# Federica Carugati: King's College London
# Peter Eckersley: Nottingham Trent University
# Sarah Haas: Virtual Vehicle (Austria)
# Maritza Johnson: University of San Diego
# Ben Laurie: Google (United Kingdom)
# Alex Ingerman: Google (United States)
# Igor Krawczuk: École Polytechnique Fédérale de Lausanne
# Rosario Cammarota: Intel (United States)
# Andrew J. Lohn: RAND Corporation
# David W. Krueger: Mila - Quebec Artificial Intelligence Institute
# Charlotte Stix: Eindhoven University of Technology
# Peter Henderson: Stanford University
# Logan Graham: University of Oxford
# Carina Prunkl: University of Oxford
# Bianca Martin: University of Freiburg
# Elizabeth Seger: Leverhulme Trust
# Noa Zilberman: University of Oxford
# Seán Ó hÉigeartaigh: Leverhulme Trust
# Frens Kroeger: Coventry University
# Rebecca Kagan: United States Fish and Wildlife Service
# Adrian Weller: The Alan Turing Institute
# Brian Tse: Partners In Health
# Elizabeth A. Barnes: University of Toronto
# Allan Dafoe: DeepMind (United Kingdom)
# Paul Scharre: Center for a New American Security
# Martijn Rasser: Center for a New American Security
# Shagun Sodhani: Facebook (Israel)
# Carrick Flynn: Center for Security and Emerging Technology
# Thomas Gilbert: Cornell University
# Lisa M. Dyer: Cincinnati Children's Hospital Medical Center
# Saif M. Khan: Center for Security and Emerging Technology
# Yoshua Bengio: University of Montreal
# Markus Anderljung: Institute on Governance
# Sam Manning: Oxford Brookes University
# Pamela Mishkin: OpenAI (United States)
# Daniel L. Rock: William P. Wharton Trust
# Jakob Foerster: Facebook (Israel)
# Maruan Al-Shedivat: Carnegie Mellon University
# Shimon Whiteson: Nomor Research (Germany)
# Trapit Bansal: University of Massachusetts Amherst
# Jakub Pachocki: International Commission on Missing Persons
# Danhong Huang: University of California, Berkeley
# Dezhen Song: Texas A&M University
# Filip Wolski: International Commission on Missing Persons
# Aditya Grover: University of California, Los Angeles
# Jyoti Gupta: University of Maryland, Baltimore
# Yura Burda: International Commission on Missing Persons
# Daniel Kang: Stanford University
# Yi Sun: Dalian University of Technology
# Dan Hendrycks: Berkeley College
# Jacob Steinhardt: Berkeley College
# Reiichiro Nakano: De La Salle University
# Christina Kim: University of Manitoba
# Sandeep Jain: University of Pittsburgh Medical Center
# Vineet Kosaraju: Stanford University
# William H. Saunders: National Weather Service
# Xu: Chongqing University
# Karl Cobbe: International Commission on Missing Persons
# Matthew M. Knight: Liverpool John Moores University
# Chris Hesse: International Commission on Missing Persons
# Tae-Hoon Kim: Korea Institute of Machinery and Materials
# Elman Mansimov: Amazon (United States)
# S. Matthew Liao: New York University
# Roger Grosse: University of Toronto
# Jimmy Ba: University of Toronto
# Yi Sun: CCTEG Shenyang Research Institute
# Yi Wu: Xi’an University of Posts and Telecommunications
# Aviv Tamar: Technion – Israel Institute of Technology
# Jean Harb: McGill University
# Lerrel Pinto: New York University
# Anish Athalye: Massachusetts Institute of Technology
# Logan Engstrom: Massachusetts Institute of Technology
# Andrew Ilyas: Massachusetts Institute of Technology
# Kwan S. Kwok: Sandia National Laboratories
# Chris Olah: OpenAI (United States)
# Miljan Martic: Sapienza University of Rome
# Shane Legg: DeepMind (United Kingdom)
# Irene Solaiman: International Commission on Missing Persons
# Kendall Lowrey: University of Washington
# Aravind Rajeswaran: University of Washington
# Sham M. Kakade: Harvard University Press
# Emanuel Todorov: University of Washington
# Henrique Ponde de Oliveira Pinto: OpenAI (United States)
# Nicholas Joseph: AnthroTronix (United States)
# Alex Ray: OpenAI (United States)
# Raul Puri: University of California, Berkeley
# M. N. Petrov: Max Planck Computing and Data Facility
# Mikhail Pavlov: International Commission on Missing Persons
# Lukasz Kaiser: OpenAI (United States)
# Philippe Tillet: Harvard University Press
# Felipe Petroski Such: Uber AI (United States)
# Elizabeth Barnes: University of Virginia
# William H. Guss: Carnegie Mellon University
# Jie Tang: Tsinghua University
# I. Babuschkin: DeepMind (United Kingdom)
# Shantanu Jain: Indraprastha Institute of Information Technology Delhi
# William S. Saunders: University of Pittsburgh
# Andrew N. Carr: Brigham Young University
# Danny Hernandez: International Commission on Missing Persons
# Will Grathwohl: DeepMind (United Kingdom)
# Ricky T. Q. Chen: Vector Institute
# Jesse Bettencourt: University of Toronto
# David Duvenaud: University of Toronto
# Chelsea Voss: International Commission on Missing Persons
# Cathy Wu: Southeast University
# Vikash Kumar: Jadavpur University
# Alexandre M. Bayen: University of California, Berkeley
# Xi Chen: Hunan Institute of Science and Technology
# Diederik P. Kingma: Brain (Germany)
# Tim Salimans: Brain (Germany)
# Sandy H. Huang: University of Queensland
# Jonathan Ho: Stanford University
# Xi Chen: Wenzhou University
# Smitha Milli: University of California, Berkeley
# Akshay Degwekar: Two Sigma Investments (United States)
# Venkatesan Guruswami: University of California, Berkeley
# Vinod Vaikuntanathan: Massachusetts Institute of Technology
# Christine K. Payne: Duke University
# Jong Wook Kim: Inje University Ilsan Paik Hospital
# Joseph Suarez: Massachusetts Institute of Technology
# Phillip Isola: Moscow Institute of Thermal Technology
# Takeru Miyato: Preferred Networks (Japan)
# Andrew M. Dai: Google (United States)
# Josh A. Goldstein: Stanford University
# Micah Musser: Georgetown University
# Renee DiResta: Stanford University
# Jonathan Raiman: Nvidia (United States)
# Olivier Raiman: Palo Alto Research Center
# Gal Kaplun: Harvard University Press
# Yamini Bansal: Harvard University
# Tristan Yang: Harvard University Press
# Boaz Barak: Tel Aviv University
# Tao Xu: Changchun University of Science and Technology
# Jesse Michael Han: OpenAI (United States)
# Quan Yuan: Sichuan University
# Chris Hallacy: OpenAI (United States)
# David P. Schnurr: California Department of Public Health
# Madeleine Thompson: Georgia College & State University
# Joanne Jang: Beth Israel Deaconess Medical Center
# Stanislas Polu: OpenAI (United States)
# Zain Shah: University of Toronto
# Trevor Blackwell: Harvard University
# Ben Garfinkel: Institute on Governance
# Thomas Zeitzoff: American University
# Hyrum S. Anderson: Robust Chip (United States)
# Heather M. Roff: Arizona State University
# Gregory C. Allen: Children's Hospital Colorado
# Simon Beard: Centre for Advanced Study
# Sebastian Farquhar: DeepMind (United Kingdom)
# Clare Lyle: University of Oxford
# Rebecca Crootof: Richmond School and Sixth Form College
# Michael Le Page: Fundação Getulio Vargas
# Joanna J. Bryson: Hertie School
# Roman V. Yampolskiy: University of Louisville
# Christos Louizos: Qualcomm (United Kingdom)
# Max Welling: Amsterdam University of the Arts
# Casey Chu: Yale University
# Kevin Frans: Cross Compass (Japan)
# Ingmar Kanitscheider: OpenAI (United States)
# Todor Markov: OpenAI (United States)
# Rachel Fong: OpenAI (United States)
# Josh Tobin: OpenAI (United States)
# Andrej Karpathy: Stanford University
# Christy Dennison: International Commission on Missing Persons
# Catherine Olsson: Murdoch Children's Research Institute
# Susan Zhang: University School
# D.P. Almeida: KU Leuven
# Carroll L. Wainwright: University of California, Santa Cruz
# Chong Zhang: University of Utah
# Alex Ray: Albert Einstein College of Medicine
# Luke Miller: Radboud University Nijmegen
# Paul Christiano: Carnegie Mellon University
# Ryan J. Lowe: University of Western Australia
# Eric Price: University of Stuttgart
# Han Zhang: Hubei Normal University
# Dimitris N. Metaxas: Rutgers, The State University of New Jersey
# Ruslan Salakhutdinov: Carnegie Mellon University
# 30

# %%
openai_openalex_works = [Works()[work_id] for work_id in openai_openalex_work_ids]

# %%
len(openai_openalex_works)
# Out:
# 77

# %%
all_time_unique_authors_openalex = {}
for work in openai_openalex_works:
    print("Title: ", work["title"])
    for authorship in work["authorships"]:
        print("Author: ", authorship["author"]["display_name"])
        print("Institutions: ", authorship["institutions"])
        print("Raw affiliation strings: ", authorship["raw_affiliation_strings"])
        print()
        for institution in authorship["institutions"]:
            if institution["id"] == selected_institution_ids[0]:
                all_time_unique_authors_openalex[authorship["author"]["id"]] = authorship["author"]["display_name"]
                break
    print()
# Out:
# Title:  ImageNet classification with deep convolutional neural networks
# Author:  Alex Krizhevsky
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['GOOGLE INC.']
#
# Author:  Ilya Sutskever
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['GOOGLE INC.']
#
# Author:  Geoffrey E. Hinton
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  Deep Learning with Differential Privacy
# Author:  Martín Abadi
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Mountain View CA USA']
#
# Author:  Andy Chu
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Mountain View CA USA']
#
# Author:  Ian Goodfellow
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['Open AI, San Francisco, CA, USA']
#
# Author:  H. Brendan McMahan
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Mountain View CA USA']
#
# Author:  Ilya Mironov
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Mountain View CA USA']
#
# Author:  Kunal Talwar
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Mountain View CA USA']
#
# Author:  Li Zhang
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Mountain View CA USA']
#
#
# Title:  Inferring single-trial neural population dynamics using sequential auto-encoders
# Author:  Chethan Pandarinath
# Institutions:  [{'id': 'https://openalex.org/I2802612298', 'display_name': 'The Wallace H. Coulter Department of Biomedical Engineering', 'ror': 'https://ror.org/02j15s898', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I130701444', 'https://openalex.org/I150468666', 'https://openalex.org/I2802612298']}, {'id': 'https://openalex.org/I130701444', 'display_name': 'Georgia Institute of Technology', 'ror': 'https://ror.org/01zkghx44', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I1289702989', 'https://openalex.org/I130701444']}]
# Raw affiliation strings:  ['Wallace H Coulter Department of Biomedical Engineering, Emory University and Georgia Institute of Technology, Atlanta, GA, USA.']
#
# Author:  Daniel J. O’Shea
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}]
# Raw affiliation strings:  ['Department of Electrical Engineering, Stanford University, Stanford, CA, USA#TAB#']
#
# Author:  Jasmine Collins
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google AI, Google Inc., Mountain View, CA, USA.']
#
# Author:  Rafal Jozefowicz
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}, {'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['Google AI, Google Inc., Mountain View, USA', 'OpenAI, San Francisco, USA']
#
# Author:  Sergey D. Stavisky
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}]
# Raw affiliation strings:  ['[Department of Neurosurgery, Stanford University, Stanford, CA, USA]']
#
# Author:  Jennifer L. Kao
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}, {'id': 'https://openalex.org/I161318765', 'display_name': 'University of California, Los Angeles', 'ror': 'https://ror.org/046rm7j60', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I161318765', 'https://openalex.org/I2803209242']}]
# Raw affiliation strings:  ['Department of Electrical Engineering, Stanford University, Stanford, USA', 'Department of Electrical Engineering, University of California, Los Angeles, Los Angeles, USA']
#
# Author:  Eric M. Trautmann
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}]
# Raw affiliation strings:  ['Neurosciences Graduate Program, Stanford University, Stanford, CA, USA.']
#
# Author:  Matthew T. Kaufman
# Institutions:  [{'id': 'https://openalex.org/I2750212522', 'display_name': 'Cold Spring Harbor Laboratory', 'ror': 'https://ror.org/02qz8b764', 'country_code': 'US', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I2750212522']}, {'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}]
# Raw affiliation strings:  ['Cold Spring Harbor Laboratory, Cold Spring Harbor, USA', 'Neurosciences Graduate Program, Stanford University, Stanford, USA']
#
# Author:  Stephen I. Ryu
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}, {'id': 'https://openalex.org/I4210124598', 'display_name': 'Palo Alto Institute', 'ror': 'https://ror.org/02xf01n45', 'country_code': 'US', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I4210124598']}]
# Raw affiliation strings:  ['Department of Electrical Engineering, Stanford University, Stanford, USA', 'Department of Neurosurgery, Palo Alto Medical Foundation, Palo Alto, USA']
#
# Author:  Leigh R. Hochberg
# Institutions:  []
# Raw affiliation strings:  ['VA RR&D Center for Neurorestoration and Neurotechnology, Veterans Affairs Medical Center, Providence, RI, USA.']
#
# Author:  Jaimie M. Henderson
# Institutions:  [{'id': 'https://openalex.org/I186667990', 'display_name': 'Neurosciences Institute', 'ror': 'https://ror.org/0460vf117', 'country_code': 'US', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I186667990']}, {'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}]
# Raw affiliation strings:  ['Stanford Neurosciences Institute, Stanford University, Stanford, USA']
#
# Author:  Krishna V. Shenoy
# Institutions:  [{'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}]
# Raw affiliation strings:  ['Department of Electrical Engineering, Stanford University, Stanford, USA']
#
# Author:  L. F. Abbott
# Institutions:  [{'id': 'https://openalex.org/I78577930', 'display_name': 'Columbia University', 'ror': 'https://ror.org/00hj8s172', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I78577930']}]
# Raw affiliation strings:  ['Zuckerman Mind Brain Behavior Institute, Columbia University, New York, NY, USA.']
#
# Author:  David Sussillo
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}, {'id': 'https://openalex.org/I186667990', 'display_name': 'Neurosciences Institute', 'ror': 'https://ror.org/0460vf117', 'country_code': 'US', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I186667990']}, {'id': 'https://openalex.org/I97018004', 'display_name': 'Stanford University', 'ror': 'https://ror.org/00f54p054', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I97018004']}]
# Raw affiliation strings:  ['Google AI, Google Inc., Mountain View, USA', 'Stanford Neurosciences Institute, Stanford University, Stanford, USA']
#
#
# Title:  A Discussion of 'Adversarial Examples Are Not Bugs, They Are Features'
# Author:  Logan Engstrom
# Institutions:  [{'id': 'https://openalex.org/I4210109586', 'display_name': 'Moscow Institute of Thermal Technology', 'ror': 'https://ror.org/021es5e59', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I4210109586']}]
# Raw affiliation strings:  ['-MIT']
#
# Author:  Justin Gilmer
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Brain Team']
#
# Author:  Gabriel Goh
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Dan Hendrycks
# Institutions:  [{'id': 'https://openalex.org/I134446601', 'display_name': 'Berkeley College', 'ror': 'https://ror.org/02xewxa75', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I134446601']}, {'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}]
# Raw affiliation strings:  ['UC Berkeley#TAB#']
#
# Author:  Andrew Ilyas
# Institutions:  [{'id': 'https://openalex.org/I4210109586', 'display_name': 'Moscow Institute of Thermal Technology', 'ror': 'https://ror.org/021es5e59', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I4210109586']}]
# Raw affiliation strings:  ['-MIT']
#
# Author:  Aleksander Madry
# Institutions:  [{'id': 'https://openalex.org/I4210109586', 'display_name': 'Moscow Institute of Thermal Technology', 'ror': 'https://ror.org/021es5e59', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I4210109586']}]
# Raw affiliation strings:  ['-MIT']
#
# Author:  Reiichiro Nakano
# Institutions:  []
# Raw affiliation strings:  []
#
# Author:  Venkatesan Guruswami
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI & Harvard']
#
# Author:  Shibani Santurkar
# Institutions:  [{'id': 'https://openalex.org/I4210109586', 'display_name': 'Moscow Institute of Thermal Technology', 'ror': 'https://ror.org/021es5e59', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I4210109586']}]
# Raw affiliation strings:  ['-MIT']
#
# Author:  Brandon Tran
# Institutions:  [{'id': 'https://openalex.org/I4210109586', 'display_name': 'Moscow Institute of Thermal Technology', 'ror': 'https://ror.org/021es5e59', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I4210109586']}]
# Raw affiliation strings:  ['-MIT']
#
# Author:  Dimitris Tsipras
# Institutions:  [{'id': 'https://openalex.org/I4210109586', 'display_name': 'Moscow Institute of Thermal Technology', 'ror': 'https://ror.org/021es5e59', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I4210109586']}]
# Raw affiliation strings:  ['-MIT']
#
# Author:  Eric Wallace
# Institutions:  [{'id': 'https://openalex.org/I4210140341', 'display_name': 'Allen Institute', 'ror': 'https://ror.org/03cpe7c52', 'country_code': 'US', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I4210140341']}]
# Raw affiliation strings:  ['[Allen Institute for AI.]']
#
#
# Title:  Robust fine-tuning of zero-shot models
# Author:  Wortsman, Mitchell
# Institutions:  [{'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}]
# Raw affiliation strings:  ['University of Washington']
#
# Author:  Gabriel Ilharco
# Institutions:  [{'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}]
# Raw affiliation strings:  ['University of Washington']
#
# Author:  Jong Wook Kim
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Mike Li
# Institutions:  [{'id': 'https://openalex.org/I78577930', 'display_name': 'Columbia University', 'ror': 'https://ror.org/00hj8s172', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I78577930']}]
# Raw affiliation strings:  ['Columbia University']
#
# Author:  Simon Kornblith
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}, {'id': 'https://openalex.org/I4210113520', 'display_name': 'Brain (Germany)', 'ror': 'https://ror.org/01gamcy45', 'country_code': 'DE', 'type': 'company', 'lineage': ['https://openalex.org/I4210113520']}]
# Raw affiliation strings:  ['Google Research, Brain Team']
#
# Author:  Rebecca Roelofs
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}, {'id': 'https://openalex.org/I4210113520', 'display_name': 'Brain (Germany)', 'ror': 'https://ror.org/01gamcy45', 'country_code': 'DE', 'type': 'company', 'lineage': ['https://openalex.org/I4210113520']}]
# Raw affiliation strings:  ['Google Research, Brain Team']
#
# Author:  Raphael Gontijo Lopes
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}, {'id': 'https://openalex.org/I4210113520', 'display_name': 'Brain (Germany)', 'ror': 'https://ror.org/01gamcy45', 'country_code': 'DE', 'type': 'company', 'lineage': ['https://openalex.org/I4210113520']}]
# Raw affiliation strings:  ['Google Research, Brain Team']
#
# Author:  Hannaneh Hajishirzi
# Institutions:  [{'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}]
# Raw affiliation strings:  ['University of Washington']
#
# Author:  Ali Farhadi
# Institutions:  [{'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}]
# Raw affiliation strings:  ['University of Washington']
#
# Author:  Hongseok Namkoong
# Institutions:  [{'id': 'https://openalex.org/I78577930', 'display_name': 'Columbia University', 'ror': 'https://ror.org/00hj8s172', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I78577930']}]
# Raw affiliation strings:  ['Columbia University']
#
# Author:  Ludwig Schmidt
# Institutions:  [{'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}]
# Raw affiliation strings:  ['University of Washington']
#
#
# Title:  The Paths Perspective on Value Learning
# Author:  Sam Greydanus
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['[Google Brain]']
#
# Author:  Chris Olah
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  Q-Value Weighted Regression: Reinforcement Learning with Limited Data
# Author:  Piotr Kozakowski
# Institutions:  [{'id': 'https://openalex.org/I4654613', 'display_name': 'University of Warsaw', 'ror': 'https://ror.org/039bjqg32', 'country_code': 'PL', 'type': 'education', 'lineage': ['https://openalex.org/I4654613']}]
# Raw affiliation strings:  ['University of Warsaw']
#
# Author:  Lukasz Kaiser
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI, San Francisco, United States']
#
# Author:  Henryk Michalewski
# Institutions:  []
# Raw affiliation strings:  ['Google, Warsaw, Poland']
#
# Author:  Afroz Mohiuddin
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google,,,,,']
#
# Author:  Katarzyna Kańska
# Institutions:  []
# Raw affiliation strings:  ['Google, Warsaw, Poland']
#
#
# Title:  Enhancing the reliability and accuracy of AI-enabled diagnosis via complementarity-driven deferral to clinicians (CoDoC)
# Author:  Krishnamurthy Dvijotham
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Jim Winkens
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Melih Barsbey
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind']
#
# Author:  Sumedh Ghaisas
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind']
#
# Author:  Nick Pawlowski
# Institutions:  [{'id': 'https://openalex.org/I4210164937', 'display_name': 'Microsoft Research (United Kingdom)', 'ror': 'https://ror.org/05k87vq12', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253', 'https://openalex.org/I4210164937']}]
# Raw affiliation strings:  ['Microsoft']
#
# Author:  Robert Stanforth
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind']
#
# Author:  Patricia MacWilliams
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Zahra S. Ahmed
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind']
#
# Author:  Shekoofeh Azizi
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Yoram Bachrach
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind']
#
# Author:  Laura Culp
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Mayank Daswani
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Jan Freyberg
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Christopher Kelly
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Health']
#
# Author:  Atilla P. Kiraly
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google (United States)']
#
# Author:  Scott McKinney
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Basil Mustafa
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Vivek Natarajan
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
# Author:  Krzysztof J. Geras
# Institutions:  [{'id': 'https://openalex.org/I57206974', 'display_name': 'New York University', 'ror': 'https://ror.org/0190ak572', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I57206974']}]
# Raw affiliation strings:  ['NYU Grossman School of Medicine']
#
# Author:  Jan Witowski
# Institutions:  [{'id': 'https://openalex.org/I57206974', 'display_name': 'New York University', 'ror': 'https://ror.org/0190ak572', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I57206974']}]
# Raw affiliation strings:  ['NYU Grossman School of Medicine']
#
# Author:  Zhi Zhen Qin
# Institutions:  []
# Raw affiliation strings:  ['StopTB']
#
# Author:  Jacob Creswell
# Institutions:  []
# Raw affiliation strings:  ['StopTB']
#
# Author:  Shravya Shetty
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Health']
#
# Author:  Marcin Sieniek
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Inc.']
#
# Author:  Terry Spitz
# Institutions:  [{'id': 'https://openalex.org/I4210113297', 'display_name': 'Google (United Kingdom)', 'ror': 'https://ror.org/024bc3e07', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210113297']}]
# Raw affiliation strings:  ['Google Health, London']
#
# Author:  Greg S. Corrado
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google, Inc']
#
# Author:  Pushmeet Kohli
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind']
#
# Author:  Taylan Cemgil
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind']
#
# Author:  Alan Karthikesalingam
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google']
#
#
# Title:  End-to-End Differentiable Reactive Molecular Dynamics Simulations Using JAX
# Author:  Mehmet Cagri Kaymak
# Institutions:  [{'id': 'https://openalex.org/I87216513', 'display_name': 'Michigan State University', 'ror': 'https://ror.org/05hs6h993', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I87216513']}]
# Raw affiliation strings:  ['Department of Computer Science and Engineering, Michigan State University, East Lansing, USA']
#
# Author:  Samuel S. Schoenholz
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI, San Francisco, USA']
#
# Author:  Ekin D. Cubuk
# Institutions:  [{'id': 'https://openalex.org/I1291425158', 'display_name': 'Google (United States)', 'ror': 'https://ror.org/00njsd438', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1291425158', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['Google Research, Mountain View, USA']
#
# Author:  Kurt A. O'Hearn
# Institutions:  [{'id': 'https://openalex.org/I87216513', 'display_name': 'Michigan State University', 'ror': 'https://ror.org/05hs6h993', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I87216513']}]
# Raw affiliation strings:  ['Department of Computer Science and Engineering, Michigan State University, East Lansing, USA']
#
# Author:  Kenneth M. Merz
# Institutions:  [{'id': 'https://openalex.org/I87216513', 'display_name': 'Michigan State University', 'ror': 'https://ror.org/05hs6h993', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I87216513']}]
# Raw affiliation strings:  ['Department of Chemistry, Michigan State University, East Lansing, USA']
#
# Author:  Hasan Metin Aktulga
# Institutions:  [{'id': 'https://openalex.org/I87216513', 'display_name': 'Michigan State University', 'ror': 'https://ror.org/05hs6h993', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I87216513']}]
# Raw affiliation strings:  ['Department of Computer Science and Engineering, Michigan State University, East Lansing, USA']
#
#
# Title:  Spurious normativity enhances learning of compliance and enforcement behavior in artificial agents
# Author:  Raphael Koster
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind, London EC4A 3TW, United Kingdom']
#
# Author:  Dylan Hadfield-Menell
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I63966007']}, {'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}]
# Raw affiliation strings:  ['Center for Human-Compatible AI, University of California, Berkeley, CA 94720', 'Computer Science and Artificial Intelligence Laboratory, Department of Electrical Engineering and Computer Science, Massachusetts Institute of Technology, Cambridge, MA 02139']
#
# Author:  Richard Everett
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind, London EC4A 3TW, United Kingdom']
#
# Author:  Laura Weidinger
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind, London EC4A 3TW, United Kingdom']
#
# Author:  Gillian K. Hadfield
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}, {'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education', 'lineage': ['https://openalex.org/I185261750']}, {'id': 'https://openalex.org/I4210149858', 'display_name': 'Schwartz/Reisman Emergency Medicine Institute', 'ror': 'https://ror.org/03sc84089', 'country_code': 'CA', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I4210149858']}, {'id': 'https://openalex.org/I4210127509', 'display_name': 'Vector Institute', 'ror': 'https://ror.org/03kqdja62', 'country_code': 'CA', 'type': 'facility', 'lineage': ['https://openalex.org/I4210127509']}, {'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['Center for Human-Compatible AI, University of California, Berkeley, CA 94720', 'Faculty of Law, University of Toronto, Toronto, ON M5S 3E6, Canada', 'OpenAI, San Francisco, CA 94110', 'Schwartz Reisman Institute for Technology and Society, University of Toronto, Toronto, ON M5G 1L7, Canada', 'Vector Institute for Artificial Intelligence, Toronto, ON M5G 1M1, Canada']
#
# Author:  Joel Z. Leibo
# Institutions:  [{'id': 'https://openalex.org/I4210090411', 'display_name': 'DeepMind (United Kingdom)', 'ror': 'https://ror.org/00971b260', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210090411', 'https://openalex.org/I4210128969']}]
# Raw affiliation strings:  ['DeepMind, London EC4A 3TW, United Kingdom']
#
#
# Title:  Bayesian Relational Memory for Semantic Visual Navigation
# Author:  Yi Wu
# Institutions:  [{'id': 'https://openalex.org/I134446601', 'display_name': 'Berkeley College', 'ror': 'https://ror.org/02xewxa75', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I134446601']}, {'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}, {'id': 'https://openalex.org/I2252078561', 'display_name': 'Facebook (Israel)', 'ror': 'https://ror.org/02388em19', 'country_code': 'IL', 'type': 'company', 'lineage': ['https://openalex.org/I2252078561', 'https://openalex.org/I4210114444']}]
# Raw affiliation strings:  ['Facebook AI Research', 'UC Berkeley']
#
# Author:  Yuxin Wu
# Institutions:  [{'id': 'https://openalex.org/I134446601', 'display_name': 'Berkeley College', 'ror': 'https://ror.org/02xewxa75', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I134446601']}, {'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}]
# Raw affiliation strings:  ['UC Berkeley']
#
# Author:  Aviv Tamar
# Institutions:  [{'id': 'https://openalex.org/I174306211', 'display_name': 'Technion – Israel Institute of Technology', 'ror': 'https://ror.org/03qryx823', 'country_code': 'IL', 'type': 'education', 'lineage': ['https://openalex.org/I174306211']}]
# Raw affiliation strings:  ['Technion']
#
# Author:  Stuart Russell
# Institutions:  [{'id': 'https://openalex.org/I134446601', 'display_name': 'Berkeley College', 'ror': 'https://ror.org/02xewxa75', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I134446601']}, {'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}]
# Raw affiliation strings:  ['UC Berkeley#TAB#']
#
# Author:  Georgia Gkioxari
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Yuandong Tian
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI']
#
#
# Title:  Learning simple algorithms from examples
# Author:  Wojciech Zaremba
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI and New York University#TAB#']
#
# Author:  Tomas Mikolov
# Institutions:  [{'id': 'https://openalex.org/I2252078561', 'display_name': 'Facebook (Israel)', 'ror': 'https://ror.org/02388em19', 'country_code': 'IL', 'type': 'company', 'lineage': ['https://openalex.org/I2252078561', 'https://openalex.org/I4210114444']}]
# Raw affiliation strings:  ['Facebook AI Research#TAB#']
#
# Author:  Armand Joulin
# Institutions:  [{'id': 'https://openalex.org/I2252078561', 'display_name': 'Facebook (Israel)', 'ror': 'https://ror.org/02388em19', 'country_code': 'IL', 'type': 'company', 'lineage': ['https://openalex.org/I2252078561', 'https://openalex.org/I4210114444']}]
# Raw affiliation strings:  ['Facebook AI Research#TAB#']
#
# Author:  Rob Fergus
# Institutions:  [{'id': 'https://openalex.org/I2252078561', 'display_name': 'Facebook (Israel)', 'ror': 'https://ror.org/02388em19', 'country_code': 'IL', 'type': 'company', 'lineage': ['https://openalex.org/I2252078561', 'https://openalex.org/I4210114444']}]
# Raw affiliation strings:  ['Facebook AI Research#TAB#']
#
#
# Title:  Evolutionary Population Curriculum for Scaling Multi-Agent Reinforcement Learning
# Author:  Qian Long
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I74973139']}]
# Raw affiliation strings:  ['Carnegie Mellon University']
#
# Author:  Zihan Zhou
# Institutions:  [{'id': 'https://openalex.org/I183067930', 'display_name': 'Shanghai Jiao Tong University', 'ror': 'https://ror.org/0220qvk04', 'country_code': 'CN', 'type': 'education', 'lineage': ['https://openalex.org/I183067930']}]
# Raw affiliation strings:  ['Shanghai Jiao Tong University']
#
# Author:  Abhibav Gupta
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I74973139']}]
# Raw affiliation strings:  ['Carnegie Mellon University']
#
# Author:  Fei Fang
# Institutions:  [{'id': 'https://openalex.org/I74973139', 'display_name': 'Carnegie Mellon University', 'ror': 'https://ror.org/05x2bcf33', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I74973139']}]
# Raw affiliation strings:  ['Carnegie Mellon University']
#
# Author:  Yi Wu
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Xiaolong Wang
# Institutions:  [{'id': 'https://openalex.org/I36258959', 'display_name': 'University of California, San Diego', 'ror': 'https://ror.org/0168r3w48', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I36258959']}]
# Raw affiliation strings:  ['University of California—San Diego']
#
#
# Title:  A deep active learning system for species identification and counting in camera trap images
# Author:  Mohammad Sadegh Norouzzadeh
# Institutions:  [{'id': 'https://openalex.org/I12834331', 'display_name': 'University of Wyoming', 'ror': 'https://ror.org/01485tq96', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I12834331']}, {'id': 'https://openalex.org/I1290206253', 'display_name': 'Microsoft (United States)', 'ror': 'https://ror.org/00d0nc645', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253']}]
# Raw affiliation strings:  ['Computer Science Department University of Wyoming Laramie WY USA', 'Microsoft AI for Earth Redmond WA USA']
#
# Author:  Dan Morris
# Institutions:  [{'id': 'https://openalex.org/I1290206253', 'display_name': 'Microsoft (United States)', 'ror': 'https://ror.org/00d0nc645', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253']}]
# Raw affiliation strings:  ['Microsoft AI for Earth Redmond WA USA']
#
# Author:  Sara Beery
# Institutions:  [{'id': 'https://openalex.org/I122411786', 'display_name': 'California Institute of Technology', 'ror': 'https://ror.org/05dxps055', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I122411786']}, {'id': 'https://openalex.org/I1290206253', 'display_name': 'Microsoft (United States)', 'ror': 'https://ror.org/00d0nc645', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253']}]
# Raw affiliation strings:  ['Computer Science Department California Institute of Technology Pasadena CA USA', 'Microsoft AI for Earth Redmond WA USA']
#
# Author:  Neel Joshi
# Institutions:  [{'id': 'https://openalex.org/I1290206253', 'display_name': 'Microsoft (United States)', 'ror': 'https://ror.org/00d0nc645', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253']}]
# Raw affiliation strings:  ['Microsoft Research, redmond, WA, USA#TAB#']
#
# Author:  Nebojsa Jojic
# Institutions:  [{'id': 'https://openalex.org/I1290206253', 'display_name': 'Microsoft (United States)', 'ror': 'https://ror.org/00d0nc645', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253']}]
# Raw affiliation strings:  ['Microsoft Research, redmond, WA, USA#TAB#']
#
# Author:  Jeff Clune
# Institutions:  [{'id': 'https://openalex.org/I12834331', 'display_name': 'University of Wyoming', 'ror': 'https://ror.org/01485tq96', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I12834331']}, {'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['Computer Science Department University of Wyoming Laramie WY USA', 'OpenAI San Francisco CA USA']
#
#
# Title:  Disentangling the Components of Ethical Research in Machine Learning
# Author:  Carolyn Ashurst
# Institutions:  [{'id': 'https://openalex.org/I4210128584', 'display_name': 'The Alan Turing Institute', 'ror': 'https://ror.org/035dkdb55', 'country_code': 'GB', 'type': 'facility', 'lineage': ['https://openalex.org/I4210128584']}]
# Raw affiliation strings:  ['Alan Turing Institute, United Kingdom']
#
# Author:  Solon Barocas
# Institutions:  [{'id': 'https://openalex.org/I1290206253', 'display_name': 'Microsoft (United States)', 'ror': 'https://ror.org/00d0nc645', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253']}, {'id': 'https://openalex.org/I205783295', 'display_name': 'Cornell University', 'ror': 'https://ror.org/05bnh6r87', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I205783295']}]
# Raw affiliation strings:  ['Cornell / Microsoft Research, USA']
#
# Author:  Rosie Campbell
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI, USA']
#
# Author:  Deborah Raji
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}]
# Raw affiliation strings:  ['UC Berkeley / Mozilla, USA']
#
#
# Title:  Automatic Curriculum Learning For Deep RL: A Short Survey
# Author:  Rémy Portelas
# Institutions:  [{'id': 'https://openalex.org/I1326498283', 'display_name': 'French Institute for Research in Computer Science and Automation', 'ror': 'https://ror.org/02kvxyf05', 'country_code': 'FR', 'type': 'government', 'lineage': ['https://openalex.org/I1326498283']}]
# Raw affiliation strings:  ['Inria']
#
# Author:  Cédric Colas
# Institutions:  [{'id': 'https://openalex.org/I1326498283', 'display_name': 'French Institute for Research in Computer Science and Automation', 'ror': 'https://ror.org/02kvxyf05', 'country_code': 'FR', 'type': 'government', 'lineage': ['https://openalex.org/I1326498283']}]
# Raw affiliation strings:  ['Inria']
#
# Author:  Li Weng
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Katja Hofmann
# Institutions:  [{'id': 'https://openalex.org/I4210164937', 'display_name': 'Microsoft Research (United Kingdom)', 'ror': 'https://ror.org/05k87vq12', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I1290206253', 'https://openalex.org/I4210164937']}]
# Raw affiliation strings:  ['Microsoft Research Cambridge,#TAB#']
#
# Author:  Pierre-Yves Oudeyer
# ...
# Institutions:  [{'id': 'https://openalex.org/I95457486', 'display_name': 'University of California, Berkeley', 'ror': 'https://ror.org/01an7q238', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I2803209242', 'https://openalex.org/I95457486']}]
# Raw affiliation strings:  ['UC Berkeley & Covariant']
#
#
# Title:  MiniF2F: a cross-system benchmark for formal Olympiad-level mathematics
# Author:  Zheng, Kunhao
# Institutions:  [{'id': 'https://openalex.org/I142476485', 'display_name': 'École Polytechnique', 'ror': 'https://ror.org/05hy3tk52', 'country_code': 'FR', 'type': 'education', 'lineage': ['https://openalex.org/I142476485', 'https://openalex.org/I4210145102']}]
# Raw affiliation strings:  [' Ecole Polytechnique']
#
# Author:  Jesse Michael Han
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['[OpenAI.]']
#
# Author:  Stanislas Polu
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['[OpenAI.]']
#
#
# Title:  Correction: A smile is all you need: predicting limiting activity coefficients from SMILES with natural language processing
# Author:  Benedikt Winter
# Institutions:  [{'id': 'https://openalex.org/I35440088', 'display_name': 'ETH Zurich', 'ror': 'https://ror.org/05a28rw58', 'country_code': 'CH', 'type': 'education', 'lineage': ['https://openalex.org/I2799323385', 'https://openalex.org/I35440088']}]
# Raw affiliation strings:  ['Energy and Process System Engineering, ETH Zürich, Tannenstrasse 3, 8092, Zürich, Switzerland']
#
# Author:  Clemens Winter
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI, 3180 18TH St, San Francisco, CA 94110, USA']
#
# Author:  Johannes Schilling
# Institutions:  [{'id': 'https://openalex.org/I35440088', 'display_name': 'ETH Zurich', 'ror': 'https://ror.org/05a28rw58', 'country_code': 'CH', 'type': 'education', 'lineage': ['https://openalex.org/I2799323385', 'https://openalex.org/I35440088']}]
# Raw affiliation strings:  ['Energy and Process System Engineering, ETH Zürich, Tannenstrasse 3, 8092, Zürich, Switzerland']
#
# Author:  André Bardow
# Institutions:  [{'id': 'https://openalex.org/I35440088', 'display_name': 'ETH Zurich', 'ror': 'https://ror.org/05a28rw58', 'country_code': 'CH', 'type': 'education', 'lineage': ['https://openalex.org/I2799323385', 'https://openalex.org/I35440088']}]
# Raw affiliation strings:  ['Energy and Process System Engineering, ETH Zürich, Tannenstrasse 3, 8092, Zürich, Switzerland']
#
#
# Title:  Does GPT-3 qualify as a co-author of a scientific paper publishable in peer-review journals according to the ICMJE criteria? - A Case Study.
# Author:  Almira Osmanovic Thunström
# Institutions:  [{'id': 'https://openalex.org/I881427289', 'display_name': 'University of Gothenburg', 'ror': 'https://ror.org/01tm6cn81', 'country_code': 'SE', 'type': 'education', 'lineage': ['https://openalex.org/I881427289']}]
# Raw affiliation strings:  ['University of Gothenburg']
#
# Author:  Generative Pretrained Transformer
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI (United States)']
#
# Author:  Steinn Steingrimsson
# Institutions:  [{'id': 'https://openalex.org/I881427289', 'display_name': 'University of Gothenburg', 'ror': 'https://ror.org/01tm6cn81', 'country_code': 'SE', 'type': 'education', 'lineage': ['https://openalex.org/I881427289']}]
# Raw affiliation strings:  ['University of Gothenburg']
#
#
# Title:  Transfer Learning: A New Promising Techniques
# Author:  Ahmed Hussein Ali
# Institutions:  [{'id': 'https://openalex.org/I3131779051', 'display_name': 'Iraqi University', 'ror': 'https://ror.org/01wfhkb67', 'country_code': 'IQ', 'type': 'education', 'lineage': ['https://openalex.org/I3131779051']}]
# Raw affiliation strings:  ['Department of Computer, College of Education, AL-Iraqia University, Baghdad, Iraq.']
#
# Author:  Mohanad G. Yaseen
# Institutions:  [{'id': 'https://openalex.org/I3131779051', 'display_name': 'Iraqi University', 'ror': 'https://ror.org/01wfhkb67', 'country_code': 'IQ', 'type': 'education', 'lineage': ['https://openalex.org/I3131779051']}]
# Raw affiliation strings:  ['Department of Computer, College of Education, AL-Iraqia University, Baghdad, Iraq.']
#
# Author:  Mohammad Aljanabi
# Institutions:  [{'id': 'https://openalex.org/I3131779051', 'display_name': 'Iraqi University', 'ror': 'https://ror.org/01wfhkb67', 'country_code': 'IQ', 'type': 'education', 'lineage': ['https://openalex.org/I3131779051']}]
# Raw affiliation strings:  ['Department of Computer, College of Education, AL-Iraqia University, Iraq']
#
# Author:  Saad Abbas Abed
# Institutions:  [{'id': 'https://openalex.org/I3131779051', 'display_name': 'Iraqi University', 'ror': 'https://ror.org/01wfhkb67', 'country_code': 'IQ', 'type': 'education', 'lineage': ['https://openalex.org/I3131779051']}]
# Raw affiliation strings:  ['Department of Computer, College of Education, AL-Iraqia University, Iraq']
#
# Author:  Chat GPT
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['Open AI L.L.C., 3180 18th Street, San Francisco, CA 94110, United States.']
#
#
# Title:  DrGPUM: Guiding Memory Optimization for GPU-Accelerated Applications
# Author:  Lin Mao
# Institutions:  [{'id': 'https://openalex.org/I156087764', 'display_name': 'University of California, Merced', 'ror': 'https://ror.org/00d9ah105', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I156087764', 'https://openalex.org/I2803209242']}]
# Raw affiliation strings:  ['University of California at Merced, Merced, USA']
#
# Author:  Keren Zhou
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI, USA']
#
# Author:  Pengfei Su
# Institutions:  [{'id': 'https://openalex.org/I156087764', 'display_name': 'University of California, Merced', 'ror': 'https://ror.org/00d9ah105', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I156087764', 'https://openalex.org/I2803209242']}]
# Raw affiliation strings:  ['University of California at Merced, Merced, USA']
#
#
# Title:  Judging facts, judging norms: Training machine learning models to judge humans requires a modified approach to labeling data
# Author:  Aparna Balagopalan
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I63966007']}]
# Raw affiliation strings:  ['Massachusetts Institute of Technology, Cambridge, MA, USA.']
#
# Author:  David Madras
# Institutions:  [{'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education', 'lineage': ['https://openalex.org/I185261750']}, {'id': 'https://openalex.org/I4210127509', 'display_name': 'Vector Institute', 'ror': 'https://ror.org/03kqdja62', 'country_code': 'CA', 'type': 'facility', 'lineage': ['https://openalex.org/I4210127509']}]
# Raw affiliation strings:  ['University of Toronto, Toronto, Ontario, Canada.', 'Vector Institute, Toronto, Ontario, Canada.']
#
# Author:  David Yang
# Institutions:  [{'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education', 'lineage': ['https://openalex.org/I185261750']}]
# Raw affiliation strings:  ['ML Estimation, Toronto, Ontario, Canada.', 'University of Toronto, Toronto, Ontario, Canada.']
#
# Author:  Dylan Hadfield-Menell
# Institutions:  [{'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I63966007']}]
# Raw affiliation strings:  ['Massachusetts Institute of Technology, Cambridge, MA, USA.']
#
# Author:  Gillian K. Hadfield
# Institutions:  [{'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education', 'lineage': ['https://openalex.org/I185261750']}, {'id': 'https://openalex.org/I4210127509', 'display_name': 'Vector Institute', 'ror': 'https://ror.org/03kqdja62', 'country_code': 'CA', 'type': 'facility', 'lineage': ['https://openalex.org/I4210127509']}, {'id': 'https://openalex.org/I4210149858', 'display_name': 'Schwartz/Reisman Emergency Medicine Institute', 'ror': 'https://ror.org/03sc84089', 'country_code': 'CA', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I4210149858']}, {'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['Center for Human-Compatible AI, Berkeley, CA, USA.', 'OpenAI, San\xa0Francisco, CA, USA.', 'Schwartz Reisman Institute for Technology and Society, Toronto, Ontario, Canada.', 'University of Toronto, Toronto, Ontario, Canada.', 'Vector Institute, Toronto, Ontario, Canada.']
#
# Author:  Marzyeh Ghassemi
# Institutions:  [{'id': 'https://openalex.org/I185261750', 'display_name': 'University of Toronto', 'ror': 'https://ror.org/03dbr7087', 'country_code': 'CA', 'type': 'education', 'lineage': ['https://openalex.org/I185261750']}, {'id': 'https://openalex.org/I4210127509', 'display_name': 'Vector Institute', 'ror': 'https://ror.org/03kqdja62', 'country_code': 'CA', 'type': 'facility', 'lineage': ['https://openalex.org/I4210127509']}, {'id': 'https://openalex.org/I63966007', 'display_name': 'Massachusetts Institute of Technology', 'ror': 'https://ror.org/042nb2s44', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I63966007']}]
# Raw affiliation strings:  ['Massachusetts Institute of Technology, Cambridge, MA, USA.', 'University of Toronto, Toronto, Ontario, Canada.', 'Vector Institute, Toronto, Ontario, Canada.']
#
#
# Title:  A machine’s perspective
# Author:  Neil Hodgson
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['Openai.com', 'Searcher Geodata UK Ltd']
#
#
# Title:  Fusing Pre-Trained Language Models with Multimodal Prompts through Reinforcement Learning
# Author:  Yang Yu
# Institutions:  [{'id': 'https://openalex.org/I193775966', 'display_name': 'Yonsei University', 'ror': 'https://ror.org/01wjejq96', 'country_code': 'KR', 'type': 'education', 'lineage': ['https://openalex.org/I193775966']}]
# Raw affiliation strings:  ['Department of Artificial Intelligence, Yonsei University']
#
# Author:  Jae-Young Chung
# Institutions:  [{'id': 'https://openalex.org/I193775966', 'display_name': 'Yonsei University', 'ror': 'https://ror.org/01wjejq96', 'country_code': 'KR', 'type': 'education', 'lineage': ['https://openalex.org/I193775966']}]
# Raw affiliation strings:  ['Department of Artificial Intelligence, Yonsei University']
#
# Author:  Heeseung Yun
# Institutions:  [{'id': 'https://openalex.org/I139264467', 'display_name': 'Seoul National University', 'ror': 'https://ror.org/04h9pn542', 'country_code': 'KR', 'type': 'education', 'lineage': ['https://openalex.org/I139264467']}]
# Raw affiliation strings:  ['Department of Computer Science and Engineering, Seoul National University']
#
# Author:  Jack Hessel
# Institutions:  [{'id': 'https://openalex.org/I4210156221', 'display_name': 'Allen Institute for Artificial Intelligence', 'ror': 'https://ror.org/05w520734', 'country_code': 'US', 'type': 'facility', 'lineage': ['https://openalex.org/I4210156221']}]
# Raw affiliation strings:  ['Allen Institute for Artificial Intelligence']
#
# Author:  Jae Sung Park
# Institutions:  [{'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}, {'id': 'https://openalex.org/I4210156221', 'display_name': 'Allen Institute for Artificial Intelligence', 'ror': 'https://ror.org/05w520734', 'country_code': 'US', 'type': 'facility', 'lineage': ['https://openalex.org/I4210156221']}]
# Raw affiliation strings:  ['Allen Institute for Artificial Intelligence', 'Paul G. Allen School of Computer Science, University of Washington']
#
# Author:  Ximing Lu
# Institutions:  [{'id': 'https://openalex.org/I4210156221', 'display_name': 'Allen Institute for Artificial Intelligence', 'ror': 'https://ror.org/05w520734', 'country_code': 'US', 'type': 'facility', 'lineage': ['https://openalex.org/I4210156221']}, {'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}]
# Raw affiliation strings:  ['Allen Institute for Artificial Intelligence', 'Paul G. Allen School of Computer Science, University of Washington']
#
# Author:  Rowan Zellers
# Institutions:  [{'id': 'https://openalex.org/I4210161460', 'display_name': 'OpenAI (United States)', 'ror': 'https://ror.org/05wx9n238', 'country_code': 'US', 'type': None, 'lineage': ['https://openalex.org/I4210161460']}]
# Raw affiliation strings:  ['OpenAI']
#
# Author:  Prithviraj Ammanabrolu
# Institutions:  [{'id': 'https://openalex.org/I4210156221', 'display_name': 'Allen Institute for Artificial Intelligence', 'ror': 'https://ror.org/05w520734', 'country_code': 'US', 'type': 'facility', 'lineage': ['https://openalex.org/I4210156221']}]
# Raw affiliation strings:  ['Allen Institute for Artificial Intelligence']
#
# Author:  Ronan Le Bras
# Institutions:  [{'id': 'https://openalex.org/I4210156221', 'display_name': 'Allen Institute for Artificial Intelligence', 'ror': 'https://ror.org/05w520734', 'country_code': 'US', 'type': 'facility', 'lineage': ['https://openalex.org/I4210156221']}]
# Raw affiliation strings:  ['Allen Institute for Artificial Intelligence']
#
# Author:  Gun-Hee Kim
# Institutions:  [{'id': 'https://openalex.org/I139264467', 'display_name': 'Seoul National University', 'ror': 'https://ror.org/04h9pn542', 'country_code': 'KR', 'type': 'education', 'lineage': ['https://openalex.org/I139264467']}]
# Raw affiliation strings:  ['Department of Computer Science and Engineering, Seoul National University']
#
# Author:  Yejin Choi
# Institutions:  [{'id': 'https://openalex.org/I4210156221', 'display_name': 'Allen Institute for Artificial Intelligence', 'ror': 'https://ror.org/05w520734', 'country_code': 'US', 'type': 'facility', 'lineage': ['https://openalex.org/I4210156221']}, {'id': 'https://openalex.org/I201448701', 'display_name': 'University of Washington', 'ror': 'https://ror.org/00cvxb145', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I201448701']}]
# Raw affiliation strings:  ['Allen Institute for Artificial Intelligence', 'Paul G. Allen School of Computer Science, University of Washington']

# %%
all_time_unique_authors_openalex
# Out:
# {'https://openalex.org/A5024209719': 'Geoffrey E. Hinton',
#  'https://openalex.org/A5004271128': 'Ian Goodfellow',
#  'https://openalex.org/A5067370075': 'Rafal Jozefowicz',
#  'https://openalex.org/A5041662257': 'Gabriel Goh',
#  'https://openalex.org/A5068388812': 'Venkatesan Guruswami',
#  'https://openalex.org/A5061984381': 'Jong Wook Kim',
#  'https://openalex.org/A5039751155': 'Chris Olah',
#  'https://openalex.org/A5031789995': 'Lukasz Kaiser',
#  'https://openalex.org/A5073086818': 'Scott McKinney',
#  'https://openalex.org/A5070645440': 'Samuel S. Schoenholz',
#  'https://openalex.org/A5000711679': 'Gillian K. Hadfield',
#  'https://openalex.org/A5014407395': 'Georgia Gkioxari',
#  'https://openalex.org/A5084821923': 'Yuandong Tian',
#  'https://openalex.org/A5076651586': 'Wojciech Zaremba',
#  'https://openalex.org/A5008951080': 'Yi Wu',
#  'https://openalex.org/A5006797018': 'Jeff Clune',
#  'https://openalex.org/A5014959740': 'Rosie Campbell',
#  'https://openalex.org/A5009970175': 'Li Weng',
#  'https://openalex.org/A5017456911': 'Phillip Isola',
#  'https://openalex.org/A5073825955': 'Josh Tobin',
#  'https://openalex.org/A5052434214': 'Rachel Fong',
#  'https://openalex.org/A5031013142': 'Alex Ray',
#  'https://openalex.org/A5009926169': 'Jonas Schneider',
#  'https://openalex.org/A5049349154': 'Pieter Abbeel',
#  'https://openalex.org/A5086668201': 'OpenAI: Marcin Andrychowicz',
#  'https://openalex.org/A5048522044': 'Bowen Baker',
#  'https://openalex.org/A5016448989': 'Maciek Chociej',
#  'https://openalex.org/A5026829243': 'Bob McGrew',
#  'https://openalex.org/A5011053473': 'Jakub Pachocki',
#  'https://openalex.org/A5040970183': 'Arthur Petron',
#  'https://openalex.org/A5037117755': 'Matthias Plappert',
#  'https://openalex.org/A5010167098': 'Glenn Powell',
#  'https://openalex.org/A5051574174': 'Szymon Sidor',
#  'https://openalex.org/A5010674841': 'Peter Welinder',
#  'https://openalex.org/A5070606710': 'Xue Bin Peng',
#  'https://openalex.org/A5091819924': 'Marcin Andrychowicz',
#  'https://openalex.org/A5009037058': 'John Schulman',
#  'https://openalex.org/A5051250767': 'Alec Radford',
#  'https://openalex.org/A5007406730': 'Chris Hallacy',
#  'https://openalex.org/A5043641795': 'A. Ramesh',
#  'https://openalex.org/A5057289323': 'Sandhini Agarwal',
#  'https://openalex.org/A5059260582': 'Girish Sastry',
#  'https://openalex.org/A5030305998': 'Askell, Amanda',
#  'https://openalex.org/A5028772381': 'Pamela Mishkin',
#  'https://openalex.org/A5031107879': 'Jack Clark',
#  'https://openalex.org/A5064685592': 'Gretchen Krueger',
#  'https://openalex.org/A5006446297': 'Ilya Sutskever',
#  'https://openalex.org/A5054887773': 'McCandlish, Sam',
#  'https://openalex.org/A5049786610': 'Henighan, Tom',
#  'https://openalex.org/A5079465685': 'T. B. Brown',
#  'https://openalex.org/A5057742306': 'Benjamin Chess',
#  'https://openalex.org/A5084512458': 'Rewon Child',
#  'https://openalex.org/A5026541761': 'Scott Gray',
#  'https://openalex.org/A5081413425': 'Jeffrey Wu',
#  'https://openalex.org/A5066197394': 'Dario Amodei',
#  'https://openalex.org/A5003630193': 'Rein Houthooft',
#  'https://openalex.org/A5014193325': 'Igor Mordatch',
#  'https://openalex.org/A5019471288': 'Harrison Edwards',
#  'https://openalex.org/A5072920795': 'Avital Oliver',
#  'https://openalex.org/A5008551527': 'ChatGPT',
#  'https://openalex.org/A5033112877': 'Adrien Ecoffet',
#  'https://openalex.org/A5018598100': 'Joost Huizinga',
#  'https://openalex.org/A5053798319': 'Joel Lehman',
#  'https://openalex.org/A5029264794': 'Kenneth O. Stanley',
#  'https://openalex.org/A5005680249': 'Nick Cammarata',
#  'https://openalex.org/A5051743369': 'Chelsea Voss',
#  'https://openalex.org/A5000965900': 'M. N. Petrov',
#  'https://openalex.org/A5066559387': 'Miles Brundage',
#  'https://openalex.org/A5044764535': 'Ingmar Kanitscheider',
#  'https://openalex.org/A5038969014': 'Jeffrey Clune',
#  'https://openalex.org/A5022214962': 'Carles Gelada',
#  'https://openalex.org/A5019073826': 'Clemens Winter',
#  'https://openalex.org/A5037864229': 'Tae-Hoon Kim',
#  'https://openalex.org/A5007861777': 'Jacob Hilton',
#  'https://openalex.org/A5048350993': 'OpenAI OpenAI',
#  'https://openalex.org/A5078100000': 'Raul Sampedro',
#  'https://openalex.org/A5035394666': 'Tao Xu',
#  'https://openalex.org/A5046491870': 'Ilge Akkaya',
#  'https://openalex.org/A5068437964': "Ruben D'Sa",
#  'https://openalex.org/A5028891032': 'Henrique Ponde de Oliveira Pinto',
#  'https://openalex.org/A5080211309': 'Alex Paino',
#  'https://openalex.org/A5002281342': 'Qiming Yuan',
#  'https://openalex.org/A5023045278': 'V. M. Misra',
#  'https://openalex.org/A5066308512': 'Alexander Quinn Nichol',
#  'https://openalex.org/A5076418776': 'Prafulla Dhariwal',
#  'https://openalex.org/A5032275803': 'Joshua Achiam',
#  'https://openalex.org/A5025285284': 'Jesse Michael Han',
#  'https://openalex.org/A5078756156': 'Stanislas Polu',
#  'https://openalex.org/A5073325012': 'Generative Pretrained Transformer',
#  'https://openalex.org/A5047304570': 'Chat GPT',
#  'https://openalex.org/A5063326523': 'Keren Zhou',
#  'https://openalex.org/A5051772019': 'Neil Hodgson',
#  'https://openalex.org/A5030637764': 'Rowan Zellers'}

# %%
set(all_time_unique_authors_openalex.keys()).intersection(set(all_time_unique_authors.keys()))
# Out:
# {'https://openalex.org/A5000711679',
#  'https://openalex.org/A5000965900',
#  'https://openalex.org/A5002281342',
#  'https://openalex.org/A5003630193',
#  'https://openalex.org/A5004271128',
#  'https://openalex.org/A5006446297',
#  'https://openalex.org/A5006797018',
#  'https://openalex.org/A5007406730',
#  'https://openalex.org/A5007861777',
#  'https://openalex.org/A5008951080',
#  'https://openalex.org/A5009037058',
#  'https://openalex.org/A5009926169',
#  'https://openalex.org/A5009970175',
#  'https://openalex.org/A5010167098',
#  'https://openalex.org/A5010674841',
#  'https://openalex.org/A5011053473',
#  'https://openalex.org/A5014193325',
#  'https://openalex.org/A5016448989',
#  'https://openalex.org/A5017456911',
#  'https://openalex.org/A5018598100',
#  'https://openalex.org/A5019471288',
#  'https://openalex.org/A5025285284',
#  'https://openalex.org/A5026541761',
#  'https://openalex.org/A5026829243',
#  'https://openalex.org/A5028772381',
#  'https://openalex.org/A5028891032',
#  'https://openalex.org/A5030305998',
#  'https://openalex.org/A5031013142',
#  'https://openalex.org/A5031107879',
#  'https://openalex.org/A5031789995',
#  'https://openalex.org/A5032275803',
#  'https://openalex.org/A5033112877',
#  'https://openalex.org/A5037117755',
#  'https://openalex.org/A5037864229',
#  'https://openalex.org/A5039751155',
#  'https://openalex.org/A5040970183',
#  'https://openalex.org/A5043641795',
#  'https://openalex.org/A5044764535',
#  'https://openalex.org/A5046491870',
#  'https://openalex.org/A5048522044',
#  'https://openalex.org/A5049349154',
#  'https://openalex.org/A5049786610',
#  'https://openalex.org/A5051250767',
#  'https://openalex.org/A5051574174',
#  'https://openalex.org/A5051743369',
#  'https://openalex.org/A5052434214',
#  'https://openalex.org/A5054887773',
#  'https://openalex.org/A5057289323',
#  'https://openalex.org/A5057742306',
#  'https://openalex.org/A5059260582',
#  'https://openalex.org/A5061984381',
#  'https://openalex.org/A5064685592',
#  'https://openalex.org/A5066197394',
#  'https://openalex.org/A5066559387',
#  'https://openalex.org/A5067370075',
#  'https://openalex.org/A5068388812',
#  'https://openalex.org/A5073825955',
#  'https://openalex.org/A5076418776',
#  'https://openalex.org/A5076651586',
#  'https://openalex.org/A5078100000',
#  'https://openalex.org/A5078756156',
#  'https://openalex.org/A5079465685',
#  'https://openalex.org/A5080211309',
#  'https://openalex.org/A5081413425',
#  'https://openalex.org/A5084512458',
#  'https://openalex.org/A5091819924'}

# %%
overlapping_openai_author_ids = list(
    set(all_time_unique_authors_openalex.keys()).intersection(set(all_time_unique_authors.keys()))
)

# %%
for author_id in overlapping_openai_author_ids:
    print(all_time_unique_authors_openalex[author_id])
# Out:
# Ilya Sutskever
# Joshua Achiam
# Stanislas Polu
# Yi Wu
# Chris Hallacy
# Jeff Clune
# Prafulla Dhariwal
# Ingmar Kanitscheider
# Bob McGrew
# Jack Clark
# Phillip Isola
# Benjamin Chess
# Bowen Baker
# M. N. Petrov
# Jeffrey Wu
# Rein Houthooft
# Askell, Amanda
# Jong Wook Kim
# Dario Amodei
# Jakub Pachocki
# Adrien Ecoffet
# Miles Brundage
# Pamela Mishkin
# A. Ramesh
# Arthur Petron
# Josh Tobin
# Wojciech Zaremba
# Lukasz Kaiser
# Jonas Schneider
# Pieter Abbeel
# McCandlish, Sam
# Szymon Sidor
# Henighan, Tom
# Henrique Ponde de Oliveira Pinto
# Glenn Powell
# Ilge Akkaya
# Gillian K. Hadfield
# Rewon Child
# Chris Olah
# Maciek Chociej
# Jacob Hilton
# Li Weng
# Alex Paino
# Marcin Andrychowicz
# Jesse Michael Han
# Qiming Yuan
# Rafal Jozefowicz
# Rachel Fong
# Alex Ray
# Chelsea Voss
# Alec Radford
# Peter Welinder
# Gretchen Krueger
# T. B. Brown
# Ian Goodfellow
# Igor Mordatch
# Matthias Plappert
# Sandhini Agarwal
# Girish Sastry
# John Schulman
# Tae-Hoon Kim
# Harrison Edwards
# Venkatesan Guruswami
# Raul Sampedro
# Scott Gray
# Joost Huizinga

# %% [markdown]
# Modify the extra works so that the authorships which we know are affiliated with OpenAI have their affiliation recorded.

# %% [markdown]
# Test case: work that doesn't have an OpenAI affiliation

# %%
new_openai_research_works[0]["authorships"]
# Out:
# [{'author_position': 'first',
#   'author': {'id': 'https://openalex.org/A5007570707',
#    'display_name': 'Jeff Wu',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Jeff Wu',
#   'raw_affiliation_string': '[OpenAI.]',
#   'raw_affiliation_strings': ['[OpenAI.]']},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5068949174',
#    'display_name': 'Long Ouyang',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Long Ouyang',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5089747113',
#    'display_name': 'Daniel M. Ziegler',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Daniel M. Ziegler',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5019575601',
#    'display_name': 'Nisan Stiennon',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Nisan Stiennon',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5004295653',
#    'display_name': 'Ryan Lowe',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Ryan Lowe',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5090592321',
#    'display_name': 'Jan Leike',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Jan Leike',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'last',
#   'author': {'id': 'https://openalex.org/A5037736834',
#    'display_name': 'Paul F. Christiano',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Paul F. Christiano',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []}]

# %%
len(new_openai_research_works)
# Out:
# 95

# %%
openai_institution_data = {
    'id': 'https://openalex.org/I4210161460',
    'display_name': 'OpenAI (United States)',
    'ror': 'https://ror.org/05wx9n238',
    'country_code': 'US',
    'type': None
}
num_works_added = 0
for work in new_openai_research_works:
    work_added = False
    for authorship in work["authorships"]:
        if authorship["author"]["id"] in overlapping_openai_author_ids:
            authorship["institutions"].append(openai_institution_data)
            if not work_added:
                num_works_added += 1
                work_added = True
        elif any([text in authorship["raw_affiliation_string"].lower() for text in ("openai", "open ai")]):
            authorship["institutions"].append(openai_institution_data)
            if not work_added:
                num_works_added += 1
                work_added = True
num_works_added
# Out:
# 87

# %%
new_openai_research_works[0]["authorships"]
# Out:
# [{'author_position': 'first',
#   'author': {'id': 'https://openalex.org/A5007570707',
#    'display_name': 'Jeff Wu',
#    'orcid': None},
#   'institutions': [{'id': 'https://openalex.org/I4210161460',
#     'display_name': 'OpenAI (United States)',
#     'ror': 'https://ror.org/05wx9n238',
#     'country_code': 'US',
#     'type': None}],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Jeff Wu',
#   'raw_affiliation_string': '[OpenAI.]',
#   'raw_affiliation_strings': ['[OpenAI.]']},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5068949174',
#    'display_name': 'Long Ouyang',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Long Ouyang',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5089747113',
#    'display_name': 'Daniel M. Ziegler',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Daniel M. Ziegler',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5019575601',
#    'display_name': 'Nisan Stiennon',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Nisan Stiennon',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5004295653',
#    'display_name': 'Ryan Lowe',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Ryan Lowe',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'middle',
#   'author': {'id': 'https://openalex.org/A5090592321',
#    'display_name': 'Jan Leike',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Jan Leike',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []},
#  {'author_position': 'last',
#   'author': {'id': 'https://openalex.org/A5037736834',
#    'display_name': 'Paul F. Christiano',
#    'orcid': None},
#   'institutions': [],
#   'countries': [],
#   'is_corresponding': False,
#   'raw_author_name': 'Paul F. Christiano',
#   'raw_affiliation_string': '',
#   'raw_affiliation_strings': []}]

# %% [markdown]
# Save as new dataset

# %%
timestamp = datetime.datetime.now()
fname = f"openai_research_works_processed_{timestamp.strftime('%Y-%m-%d_%H-%M-%S')}"
with open(f"data/openai/{fname}", "wb") as f:
    pickle.dump(new_openai_research_works, f)
