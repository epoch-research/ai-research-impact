# %%
import datetime
import json
import os
import pickle
from pyalex import Works

# %%
data_file_location = 'data/'
os.makedirs(data_file_location, exist_ok=True)

# %% [markdown]
# # Load initial data

# %%
with open(data_file_location + "selected_institution_works_openalex_deduplicated_2023-08-29_12-22-34", "rb") as f:
    works_obj = pickle.load(f)
    works = works_obj["works"]
    selected_institution_ids = works_obj["selected_institution_ids"]
    institution_aliases = works_obj["institution_aliases"]

# %%
len(works)
# Out:
# 66093

# %%
works[0]
# Out:
# {'id': 'https://openalex.org/W2919115771',
#  'doi': 'https://doi.org/10.1038/nature14539',
#  'title': 'Deep learning',
#  'display_name': 'Deep learning',
#  'publication_year': 2015,
#  'publication_date': '2015-05-27',
#  'ids': {'openalex': 'https://openalex.org/W2919115771',
#   'doi': 'https://doi.org/10.1038/nature14539',
#   'mag': '2919115771',
#   'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26017442'},
#  'language': 'en',
#  'primary_location': {'is_oa': False,
#   'landing_page_url': 'https://doi.org/10.1038/nature14539',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S137773608',
#    'display_name': 'Nature',
#    'issn_l': '0028-0836',
#    'issn': ['1476-4687', '0028-0836'],
#    'is_oa': False,
#    'is_in_doaj': False,
#    'host_organization': 'https://openalex.org/P4310319908',
#    'host_organization_name': 'Nature Portfolio',
#    'host_organization_lineage': ['https://openalex.org/P4310319908',
#     'https://openalex.org/P4310319965'],
#    'host_organization_lineage_names': ['Nature Portfolio', 'Springer Nature'],
#    'type': 'journal'},
#   'license': None,
#   'version': None,
#   'is_accepted': False,
#   'is_published': False},
#  'type': 'article',
#  'type_crossref': 'journal-article',
#  'open_access': {'is_oa': False,
#   'oa_status': 'closed',
#   'oa_url': None,
#   'any_repository_has_fulltext': False},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A5001226970',
#     'display_name': 'Yann LeCun',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210114444',
#      'display_name': 'Meta (United States)',
#      'ror': 'https://ror.org/01zbnvs85',
#      'country_code': 'US',
#      'type': 'company'},
#     {'id': 'https://openalex.org/I57206974',
#      'display_name': 'New York University',
#      'ror': 'https://ror.org/0190ak572',
#      'country_code': 'US',
#      'type': 'education'}],
#    'countries': ['US'],
#    'is_corresponding': True,
#    'raw_author_name': 'Yann LeCun',
#    'raw_affiliation_string': 'Facebook AI Research, New York, USA; New York University, New York, USA',
#    'raw_affiliation_strings': ['Facebook AI Research, New York, USA',
#     'New York University, New York, USA']},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5086198262',
#     'display_name': 'Yoshua Bengio',
#     'orcid': 'https://orcid.org/0000-0002-9322-3515'},
#    'institutions': [{'id': 'https://openalex.org/I70931966',
#      'display_name': 'Université de Montréal',
#      'ror': 'https://ror.org/0161xgx34',
#      'country_code': 'CA',
#      'type': 'education'}],
#    'countries': ['CA'],
#    'is_corresponding': False,
#    'raw_author_name': 'Yoshua Bengio',
#    'raw_affiliation_string': 'Department of Computer Science and Operations Research Université de Montréal, Pavillon André-Aisenstadt, Montréal, Canada',
#    'raw_affiliation_strings': ['Department of Computer Science and Operations Research Université de Montréal, Pavillon André-Aisenstadt, Montréal, Canada']},
#   {'author_position': 'last',
#    'author': {'id': 'https://openalex.org/A5024209719',
#     'display_name': 'Geoffrey E. Hinton',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I1291425158',
#      'display_name': 'Google (United States)',
#      'ror': 'https://ror.org/00njsd438',
#      'country_code': 'US',
#      'type': 'company'},
#     {'id': 'https://openalex.org/I185261750',
#      'display_name': 'University of Toronto',
#      'ror': 'https://ror.org/03dbr7087',
#      'country_code': 'CA',
#      'type': 'education'}],
#    'countries': ['US', 'CA'],
#    'is_corresponding': False,
#    'raw_author_name': 'Geoffrey Hinton',
#    'raw_affiliation_string': 'Department of Computer Science, University of Toronto, Toronto, Canada; Google, Mountain View, USA',
#    'raw_affiliation_strings': ['Department of Computer Science, University of Toronto, Toronto, Canada',
#     'Google, Mountain View, USA']}],
#  'institutions_distinct_count': 5,
#  'corresponding_author_ids': ['https://openalex.org/A5001226970'],
#  'corresponding_institution_ids': ['https://openalex.org/I4210114444',
#   'https://openalex.org/I57206974'],
#  'apc_list': {'value': 9750,
#   'currency': 'EUR',
#   'value_usd': 11690,
#   'provenance': 'doaj'},
#  'apc_paid': {'value': 9750,
#   'currency': 'EUR',
#   'value_usd': 11690,
#   'provenance': 'doaj'},
#  'cited_by_count': 48856,
#  'biblio': {'volume': '521',
#   'issue': '7553',
#   'first_page': '436',
#   'last_page': '444'},
#  'is_retracted': False,
#  'is_paratext': False,
#  'concepts': [{'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 0.8015775},
#   {'id': 'https://openalex.org/C108583219',
#    'wikidata': 'https://www.wikidata.org/wiki/Q197536',
#    'display_name': 'Deep learning',
#    'level': 2,
#    'score': 0.7103696},
#   {'id': 'https://openalex.org/C154945302',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#    'display_name': 'Artificial intelligence',
#    'level': 1,
#    'score': 0.6422157},
#   {'id': 'https://openalex.org/C124304363',
#    'wikidata': 'https://www.wikidata.org/wiki/Q673661',
#    'display_name': 'Abstraction',
#    'level': 2,
#    'score': 0.6072902},
#   {'id': 'https://openalex.org/C2776359362',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2145286',
#    'display_name': 'Representation (politics)',
#    'level': 3,
#    'score': 0.5885506},
#   {'id': 'https://openalex.org/C2779227376',
#    'wikidata': 'https://www.wikidata.org/wiki/Q6505497',
#    'display_name': 'Layer (electronics)',
#    'level': 2,
#    'score': 0.47483593},
#   {'id': 'https://openalex.org/C2781238097',
#    'wikidata': 'https://www.wikidata.org/wiki/Q175026',
#    'display_name': 'Object (grammar)',
#    'level': 2,
#    'score': 0.45451212},
#   {'id': 'https://openalex.org/C155032097',
#    'wikidata': 'https://www.wikidata.org/wiki/Q798503',
#    'display_name': 'Backpropagation',
#    'level': 3,
#    'score': 0.44843948},
#   {'id': 'https://openalex.org/C81363708',
#    'wikidata': 'https://www.wikidata.org/wiki/Q17084460',
#    'display_name': 'Convolutional neural network',
#    'level': 2,
#    'score': 0.4377303},
#   {'id': 'https://openalex.org/C153180895',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7148389',
#    'display_name': 'Pattern recognition (psychology)',
#    'level': 2,
#    'score': 0.42470092},
#   {'id': 'https://openalex.org/C59404180',
#    'wikidata': 'https://www.wikidata.org/wiki/Q17013334',
#    'display_name': 'Feature learning',
#    'level': 2,
#    'score': 0.42264658},
#   {'id': 'https://openalex.org/C28490314',
#    'wikidata': 'https://www.wikidata.org/wiki/Q189436',
#    'display_name': 'Speech recognition',
#    'level': 1,
#    'score': 0.35645497},
#   {'id': 'https://openalex.org/C50644808',
#    'wikidata': 'https://www.wikidata.org/wiki/Q192776',
#    'display_name': 'Artificial neural network',
#    'level': 2,
#    'score': 0.24452063},
#   {'id': 'https://openalex.org/C138885662',
#    'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#    'display_name': 'Philosophy',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C185592680',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#    'display_name': 'Chemistry',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C178790620',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#    'display_name': 'Organic chemistry',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C111472728',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9471',
#    'display_name': 'Epistemology',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C94625758',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7163',
#    'display_name': 'Politics',
#    'level': 2,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C17744445',
#    'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#    'display_name': 'Political science',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C199539241',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#    'display_name': 'Law',
#    'level': 1,
#    'score': 0.0}],
#  'mesh': [{'descriptor_ui': 'D001185',
#    'descriptor_name': 'Artificial Intelligence',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': True},
#   {'descriptor_ui': 'D000465',
#    'descriptor_name': 'Algorithms',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D001185',
#    'descriptor_name': 'Artificial Intelligence',
#    'qualifier_ui': 'Q000639',
#    'qualifier_name': 'trends',
#    'is_major_topic': False},
#   {'descriptor_ui': 'D003201',
#    'descriptor_name': 'Computers',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D007802',
#    'descriptor_name': 'Language',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False},
#   {'descriptor_ui': 'D016571',
#    'descriptor_name': 'Neural Networks, Computer',
#    'qualifier_ui': '',
#    'qualifier_name': None,
#    'is_major_topic': False}],
#  'locations_count': 2,
#  'locations': [{'is_oa': False,
#    'landing_page_url': 'https://doi.org/10.1038/nature14539',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S137773608',
#     'display_name': 'Nature',
#     'issn_l': '0028-0836',
#     'issn': ['1476-4687', '0028-0836'],
#     'is_oa': False,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/P4310319908',
#     'host_organization_name': 'Nature Portfolio',
#     'host_organization_lineage': ['https://openalex.org/P4310319908',
#      'https://openalex.org/P4310319965'],
#     'host_organization_lineage_names': ['Nature Portfolio', 'Springer Nature'],
#     'type': 'journal'},
#    'license': None,
#    'version': None,
#    'is_accepted': False,
#    'is_published': False},
#   {'is_oa': False,
#    'landing_page_url': 'https://pubmed.ncbi.nlm.nih.gov/26017442',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306525036',
#     'display_name': 'PubMed',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': False,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I1299303238',
#     'host_organization_name': 'National Institutes of Health',
#     'host_organization_lineage': ['https://openalex.org/I1299303238'],
#     'host_organization_lineage_names': ['National Institutes of Health'],
#     'type': 'repository'},
#    'license': None,
#    'version': None,
#    'is_accepted': False,
#    'is_published': False}],
#  'best_oa_location': None,
#  'sustainable_development_goals': [],
#  'grants': [],
#  'referenced_works_count': 37,
#  'referenced_works': ['https://openalex.org/W1498436455',
#   'https://openalex.org/W1752712236',
#   'https://openalex.org/W1970689298',
#   'https://openalex.org/W1978592082',
#   'https://openalex.org/W1993845689',
#   'https://openalex.org/W1993882792',
#   'https://openalex.org/W1999497791',
#   'https://openalex.org/W1999798000',
#   'https://openalex.org/W2022508996',
#   'https://openalex.org/W2025768430',
#   'https://openalex.org/W2064675550',
#   'https://openalex.org/W2072128103',
#   'https://openalex.org/W2074551195',
#   'https://openalex.org/W2088338354',
#   'https://openalex.org/W2091987367',
#   'https://openalex.org/W2095739681',
#   'https://openalex.org/W2098580305',
#   'https://openalex.org/W2100495367',
#   'https://openalex.org/W2107878631',
#   'https://openalex.org/W2108069432',
#   'https://openalex.org/W2112796928',
#   'https://openalex.org/W2116360511',
#   'https://openalex.org/W2117671523',
#   'https://openalex.org/W2120284346',
#   'https://openalex.org/W2120432001',
#   'https://openalex.org/W2121289914',
#   'https://openalex.org/W2136922672',
#   'https://openalex.org/W2144015117',
#   'https://openalex.org/W2144354855',
#   'https://openalex.org/W2145339207',
#   'https://openalex.org/W2158778629',
#   'https://openalex.org/W2160815625',
#   'https://openalex.org/W2163922914',
#   'https://openalex.org/W2166206801',
#   'https://openalex.org/W2169805405',
#   'https://openalex.org/W4232280717',
#   'https://openalex.org/W4249882522'],
#  'related_works': ['https://openalex.org/W2731899572',
#   'https://openalex.org/W2999805992',
#   'https://openalex.org/W3011074480',
#   'https://openalex.org/W3116150086',
#   'https://openalex.org/W3133861977',
#   'https://openalex.org/W3156786002',
#   'https://openalex.org/W4200173597',
#   'https://openalex.org/W4291897433',
#   'https://openalex.org/W4312417841',
#   'https://openalex.org/W4321369474'],
#  'ngrams_url': 'https://api.openalex.org/works/W2919115771/ngrams',
#  'abstract_inverted_index': None,
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2919115771',
#  'counts_by_year': [{'year': 2023, 'cited_by_count': 4718},
#   {'year': 2022, 'cited_by_count': 8642},
#   {'year': 2021, 'cited_by_count': 9219},
#   {'year': 2020, 'cited_by_count': 8866},
#   {'year': 2019, 'cited_by_count': 7638},
#   {'year': 2018, 'cited_by_count': 5059},
#   {'year': 2017, 'cited_by_count': 2766},
#   {'year': 2016, 'cited_by_count': 1081},
#   {'year': 2015, 'cited_by_count': 147},
#   {'year': 2014, 'cited_by_count': 7},
#   {'year': 2012, 'cited_by_count': 4}],
#  'updated_date': '2023-08-22T12:57:53.290445',
#  'created_date': '2019-03-11'}

# %%
selected_institution_ids
# Out:
# ['https://openalex.org/I1291425158',
#  'https://openalex.org/I4210113297',
#  'https://openalex.org/I4210100430',
#  'https://openalex.org/I4210148186',
#  'https://openalex.org/I4210117425',
#  'https://openalex.org/I4210131802',
#  'https://openalex.org/I4210090411',
#  'https://openalex.org/I2252078561',
#  'https://openalex.org/I4210114444',
#  'https://openalex.org/I4210111288',
#  'https://openalex.org/I1290206253',
#  'https://openalex.org/I4210164937',
#  'https://openalex.org/I4210113369',
#  'https://openalex.org/I4210124949',
#  'https://openalex.org/I4210105678',
#  'https://openalex.org/I4210087053',
#  'https://openalex.org/I4210125051',
#  'https://openalex.org/I4210162141',
#  'https://openalex.org/I4210086099',
#  'https://openalex.org/I4210153468',
#  'https://openalex.org/I4210161634',
#  'https://openalex.org/I4210110431',
#  'https://openalex.org/I4210099966',
#  'https://openalex.org/I4210108625',
#  'https://openalex.org/I4210135422',
#  'https://openalex.org/I4210139986',
#  'https://openalex.org/I4210109507',
#  'https://openalex.org/I4210092974',
#  'https://openalex.org/I4210151458',
#  'https://openalex.org/I4210161460',
#  'https://openalex.org/I45928872',
#  'https://openalex.org/I4210095624',
#  'https://openalex.org/I4210086143',
#  'https://openalex.org/I1304085615',
#  'https://openalex.org/I4210127875',
#  'https://openalex.org/I98301712',
#  'https://openalex.org/I1311688040',
#  'https://openalex.org/I4210089985',
#  'https://openalex.org/I4210123934',
#  'https://openalex.org/I2250653659',
#  'https://openalex.org/I4210103558',
#  'https://openalex.org/I1341412227',
#  'https://openalex.org/I4210114115',
#  'https://openalex.org/I4210085935',
#  'https://openalex.org/I4210126328',
#  'https://openalex.org/I4210167297',
#  'https://openalex.org/I4210156936',
#  'https://openalex.org/I4210145865',
#  'https://openalex.org/I4210103279',
#  'https://openalex.org/I4210126794',
#  'https://openalex.org/I4210113654',
#  'https://openalex.org/I4210095996',
#  'https://openalex.org/I4210145784',
#  'https://openalex.org/I4210120068',
#  'https://openalex.org/I4210121844',
#  'https://openalex.org/I4210113516',
#  'https://openalex.org/I4210112067',
#  'https://openalex.org/I4210167072',
#  'https://openalex.org/I4210145636',
#  'https://openalex.org/I4210129961',
#  'https://openalex.org/I4210152544',
#  'https://openalex.org/I4210122524',
#  'https://openalex.org/I4210100977',
#  'https://openalex.org/I4210148065',
#  'https://openalex.org/I4210131585',
#  'https://openalex.org/I4210129932',
#  'https://openalex.org/I1343180700',
#  'https://openalex.org/I4210158342',
#  'https://openalex.org/I4210104622',
#  'https://openalex.org/I4210094487',
#  'https://openalex.org/I4210142644',
#  'https://openalex.org/I131781684',
#  'https://openalex.org/I4210146682',
#  'https://openalex.org/I4210133876',
#  'https://openalex.org/I4210140447',
#  'https://openalex.org/I4210155185',
#  'https://openalex.org/I4210135487',
#  'https://openalex.org/I2250955327',
#  'https://openalex.org/I4210123571',
#  'https://openalex.org/I4210146936',
#  'https://openalex.org/I4210159102',
#  'https://openalex.org/I4210115038',
#  'https://openalex.org/I4210129353',
#  'https://openalex.org/I4210160618',
#  'https://openalex.org/I4210166625',
#  'https://openalex.org/I113979032',
#  'https://openalex.org/I1306409833',
#  'https://openalex.org/I4210132870',
#  'https://openalex.org/I33976269',
#  'https://openalex.org/I4210159094',
#  'https://openalex.org/I4210138183',
#  'https://openalex.org/I4210155268',
#  'https://openalex.org/I60922564',
#  'https://openalex.org/I4210121859',
#  'https://openalex.org/I4210098317',
#  'https://openalex.org/I4210128910',
#  'https://openalex.org/I118347220',
#  'https://openalex.org/I4210107353',
#  'https://openalex.org/I4210164122',
#  'https://openalex.org/I4210149379',
#  'https://openalex.org/I4210161085',
#  'https://openalex.org/I4210087554',
#  'https://openalex.org/I4210156496',
#  'https://openalex.org/I2946016260',
#  'https://openalex.org/I58957048',
#  'https://openalex.org/I869089601']

# %%
institution_aliases
# Out:
# {'https://openalex.org/I1291425158': 'Google',
#  'https://openalex.org/I4210113297': 'Google',
#  'https://openalex.org/I4210100430': 'Google',
#  'https://openalex.org/I4210148186': 'Google',
#  'https://openalex.org/I4210117425': 'Google',
#  'https://openalex.org/I4210131802': 'Google',
#  'https://openalex.org/I4210090411': 'DeepMind',
#  'https://openalex.org/I2252078561': 'Meta',
#  'https://openalex.org/I4210114444': 'Meta',
#  'https://openalex.org/I4210111288': 'Meta',
#  'https://openalex.org/I1290206253': 'Microsoft',
#  'https://openalex.org/I4210164937': 'Microsoft',
#  'https://openalex.org/I4210113369': 'Microsoft',
#  'https://openalex.org/I4210124949': 'Microsoft',
#  'https://openalex.org/I4210105678': 'Microsoft',
#  'https://openalex.org/I4210087053': 'Microsoft',
#  'https://openalex.org/I4210125051': 'Microsoft',
#  'https://openalex.org/I4210162141': 'Microsoft',
#  'https://openalex.org/I4210086099': 'Microsoft',
#  'https://openalex.org/I4210153468': 'Microsoft',
#  'https://openalex.org/I4210161634': 'Microsoft',
#  'https://openalex.org/I4210110431': 'Microsoft',
#  'https://openalex.org/I4210099966': 'Microsoft',
#  'https://openalex.org/I4210108625': 'Microsoft',
#  'https://openalex.org/I4210135422': 'Microsoft',
#  'https://openalex.org/I4210139986': 'Microsoft',
#  'https://openalex.org/I4210109507': 'Microsoft',
#  'https://openalex.org/I4210092974': 'Microsoft',
#  'https://openalex.org/I4210151458': 'Microsoft',
#  'https://openalex.org/I4210161460': 'OpenAI',
#  'https://openalex.org/I45928872': 'Alibaba',
#  'https://openalex.org/I4210095624': 'Alibaba',
#  'https://openalex.org/I4210086143': 'Alibaba',
#  'https://openalex.org/I1304085615': 'Nvidia',
#  'https://openalex.org/I4210127875': 'Nvidia',
#  'https://openalex.org/I98301712': 'Baidu',
#  'https://openalex.org/I1311688040': 'Amazon',
#  'https://openalex.org/I4210089985': 'Amazon',
#  'https://openalex.org/I4210123934': 'Amazon',
#  'https://openalex.org/I2250653659': 'Tencent',
#  'https://openalex.org/I4210103558': 'Tencent',
#  'https://openalex.org/I1341412227': 'IBM',
#  'https://openalex.org/I4210114115': 'IBM',
#  'https://openalex.org/I4210085935': 'IBM',
#  'https://openalex.org/I4210126328': 'IBM',
#  'https://openalex.org/I4210167297': 'IBM',
#  'https://openalex.org/I4210156936': 'IBM',
#  'https://openalex.org/I4210145865': 'IBM',
#  'https://openalex.org/I4210103279': 'IBM',
#  'https://openalex.org/I4210126794': 'IBM',
#  'https://openalex.org/I4210113654': 'IBM',
#  'https://openalex.org/I4210095996': 'IBM',
#  'https://openalex.org/I4210145784': 'IBM',
#  'https://openalex.org/I4210120068': 'IBM',
#  'https://openalex.org/I4210121844': 'IBM',
#  'https://openalex.org/I4210113516': 'IBM',
#  'https://openalex.org/I4210112067': 'IBM',
#  'https://openalex.org/I4210167072': 'IBM',
#  'https://openalex.org/I4210145636': 'IBM',
#  'https://openalex.org/I4210129961': 'IBM',
#  'https://openalex.org/I4210152544': 'IBM',
#  'https://openalex.org/I4210122524': 'IBM',
#  'https://openalex.org/I4210100977': 'IBM',
#  'https://openalex.org/I4210148065': 'IBM',
#  'https://openalex.org/I4210131585': 'IBM',
#  'https://openalex.org/I4210129932': 'IBM',
#  'https://openalex.org/I1343180700': 'Intel',
#  'https://openalex.org/I4210158342': 'Intel',
#  'https://openalex.org/I4210104622': 'Intel',
#  'https://openalex.org/I4210094487': 'Intel',
#  'https://openalex.org/I4210142644': 'Intel',
#  'https://openalex.org/I131781684': 'Intel',
#  'https://openalex.org/I4210146682': 'Intel',
#  'https://openalex.org/I4210133876': 'Intel',
#  'https://openalex.org/I4210140447': 'Intel',
#  'https://openalex.org/I4210155185': 'Intel',
#  'https://openalex.org/I4210135487': 'Intel',
#  'https://openalex.org/I2250955327': 'Huawei',
#  'https://openalex.org/I4210123571': 'Huawei',
#  'https://openalex.org/I4210146936': 'Huawei',
#  'https://openalex.org/I4210159102': 'Huawei',
#  'https://openalex.org/I4210115038': 'Huawei',
#  'https://openalex.org/I4210129353': 'Huawei',
#  'https://openalex.org/I4210160618': 'Huawei',
#  'https://openalex.org/I4210166625': 'Huawei',
#  'https://openalex.org/I113979032': 'Twitter',
#  'https://openalex.org/I1306409833': 'Adobe',
#  'https://openalex.org/I4210132870': 'Xerox',
#  'https://openalex.org/I33976269': 'Xerox',
#  'https://openalex.org/I4210159094': 'Xerox',
#  'https://openalex.org/I4210138183': 'Xerox',
#  'https://openalex.org/I4210155268': 'Salesforce',
#  'https://openalex.org/I60922564': 'Naver',
#  'https://openalex.org/I4210121859': 'Enthought',
#  'https://openalex.org/I4210098317': 'Quansight',
#  'https://openalex.org/I4210128910': 'Group Sense',
#  'https://openalex.org/I118347220': 'NEC',
#  'https://openalex.org/I4210107353': 'NEC',
#  'https://openalex.org/I4210164122': 'NEC',
#  'https://openalex.org/I4210149379': 'NEC',
#  'https://openalex.org/I4210161085': 'NEC',
#  'https://openalex.org/I4210087554': 'NEC',
#  'https://openalex.org/I4210156496': 'Uber',
#  'https://openalex.org/I2946016260': 'Uber',
#  'https://openalex.org/I58957048': 'Yandex',
#  'https://openalex.org/I869089601': 'Netflix'}

# %%
# Correction. OpenAlex has systematically labelled affiliations with "SenseTime" or "Sense Time" as Group Sense.
# 97.5% of "Group Sense" papers are actually SenseTime.
# There is no institution called SenseTime in OpenAlex, so the best we can do is simply change the alias.
# See `publication_sense_checks.ipynb` for more details.
institution_aliases['https://openalex.org/I4210128910'] = 'SenseTime'

# %% [markdown]
# # Add extra OpenAI data and merge

# %%
with open("data/openai/openai_research_works_processed_2023-09-07_17-16-25", "rb") as f:
    openai_research_works = pickle.load(f)

# %%
len(openai_research_works)
# Out:
# 95

# %%
openai_research_works[0]
# Out:
# {'id': 'https://openalex.org/W3200980294',
#  'doi': None,
#  'title': 'Recursively Summarizing Books with Human Feedback',
#  'display_name': 'Recursively Summarizing Books with Human Feedback',
#  'relevance_score': 486.11057,
#  'publication_year': 2021,
#  'publication_date': '2021-09-22',
#  'ids': {'openalex': 'https://openalex.org/W3200980294', 'mag': '3200980294'},
#  'language': 'en',
#  'primary_location': {'is_oa': False,
#   'landing_page_url': 'http://arxiv.org/pdf/2109.10862.pdf',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S4306400194',
#    'display_name': 'arXiv (Cornell University)',
#    'issn_l': None,
#    'issn': None,
#    'is_oa': True,
#    'is_in_doaj': False,
#    'host_organization': 'https://openalex.org/I205783295',
#    'host_organization_name': 'Cornell University',
#    'host_organization_lineage': ['https://openalex.org/I205783295'],
#    'host_organization_lineage_names': ['Cornell University'],
#    'type': 'repository'},
#   'license': None,
#   'version': 'submittedVersion',
#   'is_accepted': False,
#   'is_published': False},
#  'type': 'article',
#  'type_crossref': 'posted-content',
#  'open_access': {'is_oa': False,
#   'oa_status': 'closed',
#   'oa_url': None,
#   'any_repository_has_fulltext': False},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A5007570707',
#     'display_name': 'Jeff Wu',
#     'orcid': None},
#    'institutions': [{'id': 'https://openalex.org/I4210161460',
#      'display_name': 'OpenAI (United States)',
#      'ror': 'https://ror.org/05wx9n238',
#      'country_code': 'US',
#      'type': None}],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Jeff Wu',
#    'raw_affiliation_string': '[OpenAI.]',
#    'raw_affiliation_strings': ['[OpenAI.]']},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5068949174',
#     'display_name': 'Long Ouyang',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Long Ouyang',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5089747113',
#     'display_name': 'Daniel M. Ziegler',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Daniel M. Ziegler',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5019575601',
#     'display_name': 'Nisan Stiennon',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Nisan Stiennon',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5004295653',
#     'display_name': 'Ryan Lowe',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Ryan Lowe',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5090592321',
#     'display_name': 'Jan Leike',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Jan Leike',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'last',
#    'author': {'id': 'https://openalex.org/A5037736834',
#     'display_name': 'Paul F. Christiano',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Paul F. Christiano',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []}],
#  'institutions_distinct_count': 0,
#  'corresponding_author_ids': [],
#  'corresponding_institution_ids': [],
#  'apc_list': None,
#  'apc_paid': None,
#  'cited_by_count': 5,
#  'biblio': {'volume': None,
#   'issue': None,
#   'first_page': None,
#   'last_page': None},
#  'is_retracted': False,
#  'is_paratext': False,
#  'concepts': [{'id': 'https://openalex.org/C170858558',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1394144',
#    'display_name': 'Automatic summarization',
#    'level': 2,
#    'score': 0.93695277},
#   {'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 0.86179805},
#   {'id': 'https://openalex.org/C185798385',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1161707',
#    'display_name': 'Benchmark (surveying)',
#    'level': 2,
#    'score': 0.7243924},
#   {'id': 'https://openalex.org/C2780451532',
#    'wikidata': 'https://www.wikidata.org/wiki/Q759676',
#    'display_name': 'Task (project management)',
#    'level': 2,
#    'score': 0.7044509},
#   {'id': 'https://openalex.org/C165064840',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1321061',
#    'display_name': 'Matching (statistics)',
#    'level': 2,
#    'score': 0.58795375},
#   {'id': 'https://openalex.org/C61423126',
#    'wikidata': 'https://www.wikidata.org/wiki/Q187432',
#    'display_name': 'Scripting language',
#    'level': 2,
#    'score': 0.5717827},
#   {'id': 'https://openalex.org/C154945302',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#    'display_name': 'Artificial intelligence',
#    'level': 1,
#    'score': 0.5666259},
#   {'id': 'https://openalex.org/C119857082',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#    'display_name': 'Machine learning',
#    'level': 1,
#    'score': 0.49615583},
#   {'id': 'https://openalex.org/C2776214188',
#    'wikidata': 'https://www.wikidata.org/wiki/Q408386',
#    'display_name': 'Inference',
#    'level': 2,
#    'score': 0.45501888},
#   {'id': 'https://openalex.org/C204321447',
#    'wikidata': 'https://www.wikidata.org/wiki/Q30642',
#    'display_name': 'Natural language processing',
#    'level': 1,
#    'score': 0.38447872},
#   {'id': 'https://openalex.org/C23123220',
#    'wikidata': 'https://www.wikidata.org/wiki/Q816826',
#    'display_name': 'Information retrieval',
#    'level': 1,
#    'score': 0.37147945},
#   {'id': 'https://openalex.org/C105795698',
#    'wikidata': 'https://www.wikidata.org/wiki/Q12483',
#    'display_name': 'Statistics',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C33923547',
#    'wikidata': 'https://www.wikidata.org/wiki/Q395',
#    'display_name': 'Mathematics',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C187736073',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2920921',
#    'display_name': 'Management',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C13280743',
#    'wikidata': 'https://www.wikidata.org/wiki/Q131089',
#    'display_name': 'Geodesy',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C162324750',
#    'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#    'display_name': 'Economics',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C205649164',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#    'display_name': 'Geography',
#    'level': 0,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C111919701',
#    'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#    'display_name': 'Operating system',
#    'level': 1,
#    'score': 0.0}],
#  'mesh': [],
#  'locations_count': 1,
#  'locations': [{'is_oa': False,
#    'landing_page_url': 'http://arxiv.org/pdf/2109.10862.pdf',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False}],
#  'best_oa_location': None,
#  'sustainable_development_goals': [],
#  'grants': [],
#  'referenced_works_count': 66,
#  'referenced_works': ['https://openalex.org/W1517524280',
#   'https://openalex.org/W1525595230',
#   'https://openalex.org/W1540841088',
#   'https://openalex.org/W1602831581',
#   'https://openalex.org/W2012036715',
#   'https://openalex.org/W2051840895',
#   'https://openalex.org/W2073512134',
#   'https://openalex.org/W2108325777',
#   'https://openalex.org/W2157979304',
#   'https://openalex.org/W2160371091',
#   'https://openalex.org/W2174803659',
#   'https://openalex.org/W2295759824',
#   'https://openalex.org/W2462906003',
#   'https://openalex.org/W2487501366',
#   'https://openalex.org/W2618097077',
#   'https://openalex.org/W2626796053',
#   'https://openalex.org/W2787214294',
#   'https://openalex.org/W2798047776',
#   'https://openalex.org/W2798240283',
#   'https://openalex.org/W2798299685',
#   'https://openalex.org/W2798664956',
#   'https://openalex.org/W2798877128',
#   'https://openalex.org/W2896930824',
#   'https://openalex.org/W2899485151',
#   'https://openalex.org/W2901707424',
#   'https://openalex.org/W2905137389',
#   'https://openalex.org/W2910458567',
#   'https://openalex.org/W2936695845',
#   'https://openalex.org/W2943766373',
#   'https://openalex.org/W2945918281',
#   'https://openalex.org/W2947881255',
#   'https://openalex.org/W2948036864',
#   'https://openalex.org/W2948138438',
#   'https://openalex.org/W2953981431',
#   'https://openalex.org/W2962943921',
#   'https://openalex.org/W2963325985',
#   'https://openalex.org/W2963403868',
#   'https://openalex.org/W2963963993',
#   'https://openalex.org/W2964263543',
#   'https://openalex.org/W2969740599',
#   'https://openalex.org/W2971996420',
#   'https://openalex.org/W2972005891',
#   'https://openalex.org/W2972114612',
#   'https://openalex.org/W2972838397',
#   'https://openalex.org/W2973379954',
#   'https://openalex.org/W2974904219',
#   'https://openalex.org/W2981852735',
#   'https://openalex.org/W2998546572',
#   'https://openalex.org/W3005958085',
#   'https://openalex.org/W3015517925',
#   'https://openalex.org/W3020908159',
#   'https://openalex.org/W3021557422',
#   'https://openalex.org/W3022800647',
#   'https://openalex.org/W3030163527',
#   'https://openalex.org/W3036831227',
#   'https://openalex.org/W3047189408',
#   'https://openalex.org/W3082115681',
#   'https://openalex.org/W3100436891',
#   'https://openalex.org/W3101144749',
#   'https://openalex.org/W3104442086',
#   'https://openalex.org/W3105952014',
#   'https://openalex.org/W3106110407',
#   'https://openalex.org/W3111425437',
#   'https://openalex.org/W3116972344',
#   'https://openalex.org/W3163073193',
#   'https://openalex.org/W3163837402'],
#  'related_works': ['https://openalex.org/W1879936196',
#   'https://openalex.org/W2231123512',
#   'https://openalex.org/W2280475815',
#   'https://openalex.org/W2510759893',
#   'https://openalex.org/W2803946715',
#   'https://openalex.org/W2883616768',
#   'https://openalex.org/W2947053256',
#   'https://openalex.org/W2963721761',
#   'https://openalex.org/W2973374199',
#   'https://openalex.org/W2985050317',
#   'https://openalex.org/W2994088922',
#   'https://openalex.org/W3020535887',
#   'https://openalex.org/W3020873268',
#   'https://openalex.org/W3023420335',
#   'https://openalex.org/W3035043191',
#   'https://openalex.org/W3106234277',
#   'https://openalex.org/W3136182385',
#   'https://openalex.org/W3144879261',
#   'https://openalex.org/W3153480004',
#   'https://openalex.org/W3212747844'],
#  'ngrams_url': 'https://api.openalex.org/works/W3200980294/ngrams',
#  'abstract_inverted_index': {'A': [0, 176],
#   'major': [1],
#   'challenge': [2],
#   'for': [3, 19, 173, 191],
#   'scaling': [4],
#   'machine': [5],
#   'learning': [6, 42],
#   'is': [7],
#   'training': [8],
#   'models': [9, 52, 131],
#   'to': [10, 21, 60, 91, 113, 126],
#   'perform': [11],
#   'tasks': [12],
#   'that': [13],
#   'are': [14, 124],
#   'very': [15],
#   'difficult': [16],
#   'or': [17],
#   'time-consuming': [18],
#   'humans': [20, 62],
#   'evaluate.': [22],
#   'We': [23, 70, 164, 199],
#   'present': [24],
#   'progress': [25],
#   'on': [26, 29, 54, 66, 168, 186],
#   'this': [27],
#   'problem': [28],
#   'the': [30, 58, 67, 98, 105, 118, 130, 137, 152, 169, 187],
#   'task': [31, 48, 59],
#   'of': [32, 35, 57, 75, 104, 117, 147, 154, 162, 202],
#   'abstractive': [33],
#   'summarization': [34, 93],
#   'entire': [36, 119, 138, 148],
#   'fiction': [37],
#   'novels.': [38],
#   'Our': [39, 121, 141],
#   'method': [40],
#   'combines': [41],
#   'from': [43, 79, 204],
#   'human': [44, 80, 122],
#   'feedback': [45, 65],
#   'with': [46],
#   'recursive': [47],
#   'decomposition:': [49],
#   'we': [50],
#   'use': [51],
#   'trained': [53],
#   'smaller': [55],
#   'parts': [56],
#   'assist': [61],
#   'in': [63, 157],
#   'giving': [64],
#   'broader': [68],
#   'task.': [69],
#   'collect': [71],
#   'a': [72, 115, 158],
#   'large': [73],
#   'volume': [74],
#   'demonstrations': [76],
#   'and': [77, 82, 88, 107, 128, 196],
#   'comparisons': [78],
#   'labelers,': [81],
#   'fine-tune': [83],
#   'GPT-3': [84],
#   'using': [85, 180],
#   'behavioral': [86],
#   'cloning': [87],
#   'reward': [89],
#   'modeling': [90],
#   'do': [92],
#   'recursively.': [94],
#   'At': [95],
#   'inference': [96],
#   'time,': [97],
#   'model': [99, 143, 179],
#   'first': [100],
#   'summarizes': [101, 110],
#   'small': [102],
#   'sections': [103],
#   'book': [106],
#   'then': [108],
#   'recursively': [109],
#   'these': [111, 181],
#   'summaries': [112, 146, 156, 182],
#   'produce': [114],
#   'summary': [116],
#   'book.': [120],
#   'labelers': [123],
#   'able': [125],
#   'supervise': [127],
#   'evaluate': [129],
#   'quickly,': [132],
#   'despite': [133],
#   'not': [134],
#   'having': [135],
#   'read': [136],
#   'books': [139, 195],
#   'themselves.': [140],
#   'resulting': [142],
#   'generates': [144],
#   'sensible': [145],
#   'books,': [149],
#   'even': [150],
#   'matching': [151],
#   'quality': [153],
#   'human-written': [155],
#   'few': [159],
#   'cases': [160],
#   '($\\sim5\\%$': [161],
#   'books).': [163],
#   'achieve': [165],
#   'state-of-the-art': [166, 184],
#   'results': [167, 185],
#   'recent': [170],
#   'BookSum': [171],
#   'dataset': [172],
#   'book-length': [174],
#   'summarization.': [175],
#   'zero-shot': [177],
#   'question-answering': [178],
#   'achieves': [183],
#   'challenging': [188],
#   'NarrativeQA': [189],
#   'benchmark': [190],
#   'answering': [192],
#   'questions': [193],
#   'about': [194],
#   'movie': [197],
#   'scripts.': [198],
#   'release': [200],
#   'datasets': [201],
#   'samples': [203],
#   'our': [205],
#   'model.': [206]},
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W3200980294',
#  'counts_by_year': [{'year': 2022, 'cited_by_count': 1},
#   {'year': 2021, 'cited_by_count': 4}],
#  'updated_date': '2023-08-23T23:50:39.870035',
#  'created_date': '2021-09-27'}

# %%
excluded_works = [
    'https://openalex.org/W2618530766',  # 2017 AlexNet paper with incorrect affiliations
]

# %%
# If the work is already present, then replace it with the version from the extra OpenAI dataset
# Else, append it
openai_works_dict = {work["id"]:work for work in openai_research_works}
new_works = []
openai_works_replaced = set()
for work in works:
    if work["id"] in openai_works_dict.keys():
        openai_work = openai_works_dict[work["id"]]
        new_works.append(openai_work)
        openai_works_replaced.add(work["id"])
    else:
        # Exact case-sensitive title of Communications of The ACM paper
        if work['id'] in excluded_works:
            print(f"Skipping \"{work['display_name']}\"")
        else:
            new_works.append(work)

openai_works_added = set()
for work_id in openai_works_dict.keys():
    if work_id not in openai_works_replaced:
        new_works.append(openai_works_dict[work_id])
        openai_works_added.add(work_id)
# Out:
# Skipping "ImageNet classification with deep convolutional neural networks"

# %%
openai_works_replaced
# Out:
# {'https://openalex.org/W2560512785',
#  'https://openalex.org/W2762117857',
#  'https://openalex.org/W2762872434',
#  'https://openalex.org/W2898917980',
#  'https://openalex.org/W2950602864',
#  'https://openalex.org/W2963989027',
#  'https://openalex.org/W2964075320',
#  'https://openalex.org/W2964263543',
#  'https://openalex.org/W2973525135',
#  'https://openalex.org/W3030163527',
#  'https://openalex.org/W3082115681',
#  'https://openalex.org/W3093419064'}

# %%
openai_works_added
# Out:
# {'https://openalex.org/W2462906003',
#  'https://openalex.org/W2530944449',
#  'https://openalex.org/W2548137223',
#  'https://openalex.org/W2566467060',
#  'https://openalex.org/W2578206533',
#  'https://openalex.org/W2591957724',
#  'https://openalex.org/W2595180411',
#  'https://openalex.org/W2596367596',
#  'https://openalex.org/W2606347107',
#  'https://openalex.org/W2606433045',
#  'https://openalex.org/W2609650878',
#  'https://openalex.org/W2623491082',
#  'https://openalex.org/W2736601468',
#  'https://openalex.org/W2749928749',
#  'https://openalex.org/W2765602917',
#  'https://openalex.org/W2766774033',
#  'https://openalex.org/W2767313115',
#  'https://openalex.org/W2785397462',
#  'https://openalex.org/W2786303200',
#  'https://openalex.org/W2787887017',
#  'https://openalex.org/W2789008106',
#  'https://openalex.org/W2795900505',
#  'https://openalex.org/W2796979132',
#  'https://openalex.org/W2798877128',
#  'https://openalex.org/W2807324060',
#  'https://openalex.org/W2883433335',
#  'https://openalex.org/W2885550588',
#  'https://openalex.org/W2896930824',
#  'https://openalex.org/W2899205164',
#  'https://openalex.org/W2903181768',
#  'https://openalex.org/W2917705988',
#  'https://openalex.org/W2918965305',
#  'https://openalex.org/W2922772346',
#  'https://openalex.org/W2940744433',
#  'https://openalex.org/W2943657790',
#  'https://openalex.org/W2949103145',
#  'https://openalex.org/W2953116488',
#  'https://openalex.org/W2962528222',
#  'https://openalex.org/W2963094133',
#  'https://openalex.org/W2963139417',
#  'https://openalex.org/W2963231791',
#  'https://openalex.org/W2963407617',
#  'https://openalex.org/W2963533931',
#  'https://openalex.org/W2963557656',
#  'https://openalex.org/W2963627051',
#  'https://openalex.org/W2963641970',
#  'https://openalex.org/W2963685250',
#  'https://openalex.org/W2963828549',
#  'https://openalex.org/W2963881016',
#  'https://openalex.org/W2964001908',
#  'https://openalex.org/W2964122153',
#  'https://openalex.org/W2964198579',
#  'https://openalex.org/W2964227899',
#  'https://openalex.org/W2965341833',
#  'https://openalex.org/W2969454448',
#  'https://openalex.org/W2969958763',
#  'https://openalex.org/W2973379954',
#  'https://openalex.org/W2981030070',
#  'https://openalex.org/W2994073215',
#  'https://openalex.org/W2996037775',
#  'https://openalex.org/W2996603747',
#  'https://openalex.org/W3017343191',
#  'https://openalex.org/W3021164770',
#  'https://openalex.org/W3021954012',
#  'https://openalex.org/W3037207827',
#  'https://openalex.org/W3083835029',
#  'https://openalex.org/W3128912454',
#  'https://openalex.org/W3177813494',
#  'https://openalex.org/W3200980294',
#  'https://openalex.org/W3201174429',
#  'https://openalex.org/W4224035735',
#  'https://openalex.org/W4225576545',
#  'https://openalex.org/W4226278401',
#  'https://openalex.org/W4281748205',
#  'https://openalex.org/W4283460722',
#  'https://openalex.org/W4286892945',
#  'https://openalex.org/W4288804596',
#  'https://openalex.org/W4288805334',
#  'https://openalex.org/W4309088836',
#  'https://openalex.org/W4312045746',
#  'https://openalex.org/W4315881236',
#  'https://openalex.org/W4327810158',
#  'https://openalex.org/W4330336443'}

# %%
Works()[list(openai_works_added)[2]]
# Out:
# {'id': 'https://openalex.org/W2609650878',
#  'doi': None,
#  'title': 'Equivalence Between Policy Gradients and Soft Q-Learning',
#  'display_name': 'Equivalence Between Policy Gradients and Soft Q-Learning',
#  'publication_year': 2017,
#  'publication_date': '2017-04-21',
#  'ids': {'openalex': 'https://openalex.org/W2609650878', 'mag': '2609650878'},
#  'language': 'en',
#  'primary_location': {'is_oa': False,
#   'landing_page_url': 'https://arxiv.org/pdf/1704.06440.pdf',
#   'pdf_url': None,
#   'source': {'id': 'https://openalex.org/S4306400194',
#    'display_name': 'arXiv (Cornell University)',
#    'issn_l': None,
#    'issn': None,
#    'is_oa': True,
#    'is_in_doaj': False,
#    'host_organization': 'https://openalex.org/I205783295',
#    'host_organization_name': 'Cornell University',
#    'host_organization_lineage': ['https://openalex.org/I205783295'],
#    'host_organization_lineage_names': ['Cornell University'],
#    'type': 'repository'},
#   'license': None,
#   'version': 'submittedVersion',
#   'is_accepted': False,
#   'is_published': False},
#  'type': 'article',
#  'type_crossref': 'posted-content',
#  'open_access': {'is_oa': False,
#   'oa_status': 'closed',
#   'oa_url': None,
#   'any_repository_has_fulltext': False},
#  'authorships': [{'author_position': 'first',
#    'author': {'id': 'https://openalex.org/A5009037058',
#     'display_name': 'John Schulman',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'John Schulman',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'middle',
#    'author': {'id': 'https://openalex.org/A5008171524',
#     'display_name': 'Xi Chen',
#     'orcid': 'https://orcid.org/0000-0002-8523-3967'},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Xi Chen',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []},
#   {'author_position': 'last',
#    'author': {'id': 'https://openalex.org/A5049349154',
#     'display_name': 'Pieter Abbeel',
#     'orcid': None},
#    'institutions': [],
#    'countries': [],
#    'is_corresponding': False,
#    'raw_author_name': 'Pieter Abbeel',
#    'raw_affiliation_string': '',
#    'raw_affiliation_strings': []}],
#  'countries_distinct_count': 0,
#  'institutions_distinct_count': 0,
#  'corresponding_author_ids': [],
#  'corresponding_institution_ids': [],
#  'apc_list': None,
#  'apc_paid': None,
#  'has_fulltext': False,
#  'cited_by_count': 139,
#  'cited_by_percentile_year': {'min': 99.6, 'max': 99.6},
#  'biblio': {'volume': None,
#   'issue': None,
#   'first_page': None,
#   'last_page': None},
#  'is_retracted': False,
#  'is_paratext': False,
#  'keywords': [{'keyword': 'policy gradients', 'score': 0.648},
#   {'keyword': 'q-learning', 'score': 0.25}],
#  'concepts': [{'id': 'https://openalex.org/C97541855',
#    'wikidata': 'https://www.wikidata.org/wiki/Q830687',
#    'display_name': 'Reinforcement learning',
#    'level': 2,
#    'score': 0.7905744},
#   {'id': 'https://openalex.org/C188116033',
#    'wikidata': 'https://www.wikidata.org/wiki/Q2664563',
#    'display_name': 'Q-learning',
#    'level': 3,
#    'score': 0.68339634},
#   {'id': 'https://openalex.org/C2780069185',
#    'wikidata': 'https://www.wikidata.org/wiki/Q7977945',
#    'display_name': 'Equivalence (formal languages)',
#    'level': 2,
#    'score': 0.62448496},
#   {'id': 'https://openalex.org/C41008148',
#    'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#    'display_name': 'Computer science',
#    'level': 0,
#    'score': 0.54842293},
#   {'id': 'https://openalex.org/C106301342',
#    'wikidata': 'https://www.wikidata.org/wiki/Q4117933',
#    'display_name': 'Entropy (arrow of time)',
#    'level': 2,
#    'score': 0.46233934},
#   {'id': 'https://openalex.org/C185798385',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1161707',
#    'display_name': 'Benchmark (surveying)',
#    'level': 2,
#    'score': 0.41760683},
#   {'id': 'https://openalex.org/C154945302',
#    'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#    'display_name': 'Artificial intelligence',
#    'level': 1,
#    'score': 0.40908802},
#   {'id': 'https://openalex.org/C28826006',
#    'wikidata': 'https://www.wikidata.org/wiki/Q33521',
#    'display_name': 'Applied mathematics',
#    'level': 1,
#    'score': 0.3283134},
#   {'id': 'https://openalex.org/C33923547',
#    'wikidata': 'https://www.wikidata.org/wiki/Q395',
#    'display_name': 'Mathematics',
#    'level': 0,
#    'score': 0.32451966},
#   {'id': 'https://openalex.org/C126255220',
#    'wikidata': 'https://www.wikidata.org/wiki/Q141495',
#    'display_name': 'Mathematical optimization',
#    'level': 1,
#    'score': 0.32086974},
#   {'id': 'https://openalex.org/C121332964',
#    'wikidata': 'https://www.wikidata.org/wiki/Q413',
#    'display_name': 'Physics',
#    'level': 0,
#    'score': 0.15660596},
#   {'id': 'https://openalex.org/C118615104',
#    'wikidata': 'https://www.wikidata.org/wiki/Q121416',
#    'display_name': 'Discrete mathematics',
#    'level': 1,
#    'score': 0.13784352},
#   {'id': 'https://openalex.org/C13280743',
#    'wikidata': 'https://www.wikidata.org/wiki/Q131089',
#    'display_name': 'Geodesy',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C62520636',
#    'wikidata': 'https://www.wikidata.org/wiki/Q944',
#    'display_name': 'Quantum mechanics',
#    'level': 1,
#    'score': 0.0},
#   {'id': 'https://openalex.org/C205649164',
#    'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#    'display_name': 'Geography',
#    'level': 0,
#    'score': 0.0}],
#  'mesh': [],
#  'locations_count': 1,
#  'locations': [{'is_oa': False,
#    'landing_page_url': 'https://arxiv.org/pdf/1704.06440.pdf',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False}],
#  'best_oa_location': None,
#  'sustainable_development_goals': [{'id': 'https://metadata.un.org/sdg/16',
#    'display_name': 'Peace, Justice and strong institutions',
#    'score': 0.42},
#   {'id': 'https://metadata.un.org/sdg/17',
#    'display_name': 'Partnerships for the goals',
#    'score': 0.32}],
#  'grants': [],
#  'referenced_works_count': 11,
#  'referenced_works': ['https://openalex.org/W64088143',
#   'https://openalex.org/W1191599655',
#   'https://openalex.org/W2145339207',
#   'https://openalex.org/W2260756217',
#   'https://openalex.org/W2402108766',
#   'https://openalex.org/W2554120691',
#   'https://openalex.org/W2949561945',
#   'https://openalex.org/W2951143668',
#   'https://openalex.org/W2951507724',
#   'https://openalex.org/W2951799221',
#   'https://openalex.org/W2952726221'],
#  'related_works': ['https://openalex.org/W64088143',
#   'https://openalex.org/W2098774185',
#   'https://openalex.org/W2119567691',
#   'https://openalex.org/W2119717200',
#   'https://openalex.org/W2121863487',
#   'https://openalex.org/W2145339207',
#   'https://openalex.org/W2155027007',
#   'https://openalex.org/W2155968351',
#   'https://openalex.org/W2158782408',
#   'https://openalex.org/W2165150801',
#   'https://openalex.org/W2173248099',
#   'https://openalex.org/W2257979135',
#   'https://openalex.org/W2554120691',
#   'https://openalex.org/W2593044849',
#   'https://openalex.org/W2594103415',
#   'https://openalex.org/W2736601468',
#   'https://openalex.org/W2781726626',
#   'https://openalex.org/W2949608212',
#   'https://openalex.org/W2963267001',
#   'https://openalex.org/W2964043796'],
#  'ngrams_url': 'https://api.openalex.org/works/W2609650878/ngrams',
#  'abstract_inverted_index': {'Two': [0],
#   'of': [1, 74, 110, 156],
#   'the': [2, 36, 72, 107, 128, 132, 139, 153],
#   'leading': [3],
#   'approaches': [4],
#   'for': [5],
#   'model-free': [6],
#   'reinforcement': [7, 76],
#   'learning': [8, 154],
#   'are': [9, 40, 51],
#   'policy': [10, 54, 68, 87, 101, 113],
#   'gradient': [11, 55, 69, 88, 102],
#   'methods': [12, 17, 50, 70, 98],
#   'and': [13, 21, 67, 99, 112, 115],
#   '$Q$-learning': [14, 16, 49, 66, 81, 97, 111, 148],
#   'methods.': [15, 103],
#   'can': [18],
#   'be': [19, 47],
#   'effective': [20],
#   'sample-efficient': [22],
#   'when': [23],
#   'they': [24, 32, 38],
#   'work,': [25, 33],
#   'however,': [26],
#   'it': [27],
#   'is': [28, 61, 82],
#   'not': [29],
#   'well-understood': [30],
#   'why': [31],
#   'since': [34],
#   'empirically,': [35],
#   '$Q$-values': [37],
#   'estimate': [39],
#   'very': [41],
#   'inaccurate.': [42],
#   'A': [43],
#   'partial': [44],
#   'explanation': [45],
#   'may': [46],
#   'that': [48, 59, 78, 138, 150],
#   'secretly': [52],
#   'implementing': [53],
#   'updates:': [56],
#   'we': [57, 105, 116],
#   'show': [58, 137],
#   'there': [60],
#   'a': [62, 86, 94, 147, 160],
#   'precise': [63],
#   'equivalence': [64, 140],
#   'between': [65, 96],
#   'in': [71, 142],
#   'setting': [73],
#   'entropy-regularized': [75, 108],
#   'learning,': [77],
#   'soft': [79],
#   '(entropy-regularized)': [80],
#   'exactly': [83],
#   'equivalent': [84],
#   'to': [85, 119],
#   'method.': [89],
#   'We': [90, 135],
#   'also': [91, 136],
#   'point': [92],
#   'out': [93],
#   'connection': [95],
#   'natural': [100],
#   'Experimentally,': [104],
#   'explore': [106],
#   'versions': [109],
#   'gradients,': [114],
#   'find': [117],
#   'them': [118],
#   'perform': [120],
#   'as': [121, 123],
#   'well': [122],
#   '(or': [124],
#   'slightly': [125],
#   'better': [126],
#   'than)': [127],
#   'standard': [129],
#   'variants': [130],
#   'on': [131],
#   'Atari': [133],
#   'benchmark.': [134],
#   'holds': [141],
#   'practical': [143],
#   'settings': [144],
#   'by': [145],
#   'constructing': [146],
#   'method': [149],
#   'closely': [151],
#   'matches': [152],
#   'dynamics': [155],
#   'A3C': [157],
#   'without': [158],
#   'using': [159],
#   'target': [161],
#   'network': [162],
#   'or': [163],
#   '$\\epsilon$-greedy': [164],
#   'exploration': [165],
#   'schedule.': [166]},
#  'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2609650878',
#  'counts_by_year': [{'year': 2022, 'cited_by_count': 2},
#   {'year': 2021, 'cited_by_count': 23},
#   {'year': 2020, 'cited_by_count': 39},
#   {'year': 2019, 'cited_by_count': 31},
#   {'year': 2018, 'cited_by_count': 30},
#   {'year': 2017, 'cited_by_count': 13}],
#  'updated_date': '2023-10-29T01:21:01.862655',
#  'created_date': '2017-05-05'}

# %%
len(new_works) - len(works)
# Out:
# 82

# %%
works = new_works

# %%
len(works)
# Out:
# 66175

# %% [markdown]
# # Save

# %%
def write_jsonl(entries, filename, datatype=list):
    with open(filename, "w") as f:
        if datatype == dict:
            json.dump(entries, f)
        else:
            for entry in entries[:-1]:
                json.dump(entry, f)
                f.write("\n")
            json.dump(entries[-1], f)

# %%
timestamp = datetime.datetime.now()

works_fname = f"selected_institution_works_openalex_deduplicated_extra_openai_{timestamp.strftime('%Y-%m-%d_%H-%M-%S')}"
write_jsonl(works, data_file_location + works_fname + ".jsonl")

ids_fname = f"selected_institution_ids_{timestamp.strftime('%Y-%m-%d_%H-%M-%S')}"
write_jsonl(selected_institution_ids, data_file_location + ids_fname + ".jsonl")

aliases_fname = f"institution_aliases_{timestamp.strftime('%Y-%m-%d_%H-%M-%S')}"
write_jsonl(institution_aliases, data_file_location + aliases_fname + ".jsonl", datatype=dict)
