# %%
# %load_ext autoreload
# %autoreload 2

# %%
from collections import defaultdict
from datetime import datetime
import os
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import pyalex
from pyalex import Works

from researcher_impact.plotting import save_plot
from researcher_impact.utils import dict_to_dataarray

# %%
# The polite pool has much faster and more consistent response times. To get into the polite pool, you set your email:
pyalex.config.email = "ben@epochai.org"

# %%
pio.templates.default = "plotly_white"

# %%
result_file_location = 'results/'
os.makedirs(result_file_location, exist_ok=True)

# %%
# Download dataset
sheet_id = '1L_j7OaX19HXWWIx_apKvWo2OteY1XOB7FamaLEd_p0s'
tab_id = '578731623'
data_url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?gid={tab_id}&format=csv'
origins_df = pd.read_csv(data_url)

# %%
origins_df.head()
# Out:
#                       Algorithm  \
# 0                   Transformer
# 1    Kaplan et al. scaling laws
# 2  Hoffmann et al. scaling laws
# 3              Causal objective
# 4    Masked/denoising objective
#
#                                         Origin title  \
# 0                          Attention Is All You Need
# 1            Scaling Laws for Neural Language Models
# 2     Training Compute-Optimal Large Language Models
# 3  Improving Language Understanding by Generative...
# 4  BERT: Pre-training of Deep Bidirectional Trans...
#
#                                          Origin link Origin publication date  \
# 0                   https://arxiv.org/abs/1706.03762             2017-Jun-12
# 1                   https://arxiv.org/abs/2001.08361             2020-Jan-23
# 2                   https://arxiv.org/abs/2203.15556             2022-Mar-29
# 3  https://openai.com/research/language-unsupervised             2018-Jun-11
# 4                   https://arxiv.org/abs/1810.04805             2018-Oct-11
#
#                                  Origin affiliations  \
# 0  Google Brain; Google Research; University of T...
# 1                   Johns Hopkins University; OpenAI
# 2                                    Google DeepMind
# 3                                             OpenAI
# 4                                             Google
#
#                                       Origin authors
# 0  Ashish Vaswani, Noam Shazeer, Niki Parmar, Jak...
# 1  Jared Kaplan, Sam McCandlish, Tom Henighan, To...
# 2  Jordan Hoffmann, Sebastian Borgeaud, Arthur Me...
# 3  Alec Radford, Karthik Narasimhan, Tim Salimans...
# 4  Jacob Devlin, Ming-Wei Chang, Kenton Lee, Kris...

# %%
origins_df.dropna(subset=['Origin affiliations'], inplace=True)
origins_df.head()
# Out:
#                       Algorithm  \
# 0                   Transformer
# 1    Kaplan et al. scaling laws
# 2  Hoffmann et al. scaling laws
# 3              Causal objective
# 4    Masked/denoising objective
#
#                                         Origin title  \
# 0                          Attention Is All You Need
# 1            Scaling Laws for Neural Language Models
# 2     Training Compute-Optimal Large Language Models
# 3  Improving Language Understanding by Generative...
# 4  BERT: Pre-training of Deep Bidirectional Trans...
#
#                                          Origin link Origin publication date  \
# 0                   https://arxiv.org/abs/1706.03762             2017-Jun-12
# 1                   https://arxiv.org/abs/2001.08361             2020-Jan-23
# 2                   https://arxiv.org/abs/2203.15556             2022-Mar-29
# 3  https://openai.com/research/language-unsupervised             2018-Jun-11
# 4                   https://arxiv.org/abs/1810.04805             2018-Oct-11
#
#                                  Origin affiliations  \
# 0  Google Brain; Google Research; University of T...
# 1                   Johns Hopkins University; OpenAI
# 2                                    Google DeepMind
# 3                                             OpenAI
# 4                                             Google
#
#                                       Origin authors
# 0  Ashish Vaswani, Noam Shazeer, Niki Parmar, Jak...
# 1  Jared Kaplan, Sam McCandlish, Tom Henighan, To...
# 2  Jordan Hoffmann, Sebastian Borgeaud, Arthur Me...
# 3  Alec Radford, Karthik Narasimhan, Tim Salimans...
# 4  Jacob Devlin, Ming-Wei Chang, Kenton Lee, Kris...

# %% [markdown]
# Create institution => origins mapping

# %%
institution_aliases = {
    'Google': 'Google',
    'Google Brain': 'Google',
    'Google Research': 'Google',
    'DeepMind': 'DeepMind',
    'Google DeepMind': 'DeepMind',
    'OpenAI': 'OpenAI',
    'Baidu Research': 'Baidu',
    'NVIDIA': 'NVIDIA',
    'Facebook AI Research': 'Meta',
    'Zhuiyi Technology Co., Ltd.': 'Zhuiyi',
}

# %%
institution_key_algorithms = defaultdict(list)
for i, row in origins_df.iterrows():
    algorithm_name = row['Algorithm']
    affiliations = row['Origin affiliations']
    affiliations = [affiliation.strip() for affiliation in affiliations.split(';')]
    for affiliation in affiliations:
        if institution_aliases.get(affiliation) is not None:
            alias = institution_aliases[affiliation]
            institution_key_algorithms[alias].append(algorithm_name)
institution_key_algorithms
# Out:
# defaultdict(list,
#             {'Google': ['Transformer',
#               'Transformer',
#               'Masked/denoising objective',
#               'Chain-of-thought',
#               'Decoder-only architecture',
#               'LayerNorm',
#               'Sinusoidal position embeddings',
#               'Sinusoidal position embeddings',
#               'Relative position encodings',
#               'SwiGLU activation',
#               'Sparsely-Gated Mixture-of-Experts layer (MoE)',
#               'Multi-Query Attention',
#               'Grouped Query Attention',
#               'Dynamic batch size'],
#              'OpenAI': ['Kaplan et al. scaling laws',
#               'Causal objective',
#               'Instruction tuning',
#               'RLHF',
#               'PPO',
#               'Sparse Attention'],
#              'DeepMind': ['Hoffmann et al. scaling laws', 'RLHF'],
#              'Baidu': ['Mixed precision training'],
#              'NVIDIA': ['Mixed precision training'],
#              'Meta': ['Pre-normalization',
#               'Learnable position embeddings',
#               'ALiBi positional encodings'],
#              'Zhuiyi': ['Rotary position embeddings']})

# %%
institution_key_algorithms_count = dict_to_dataarray(institution_key_algorithms, dim='institution', val_fn=len)
institution_key_algorithms_count
# Out:
# <xarray.DataArray (institution: 7)>
# array([ 1.,  2., 14.,  3.,  1.,  6.,  1.])
# Coordinates:
#   * institution  (institution) <U8 'Baidu' 'DeepMind' ... 'OpenAI' 'Zhuiyi'

# %%
fig = go.Figure(data=[
    go.Bar(
        name='Key innovations',
        x=institution_key_algorithms_count.institution,
        y=institution_key_algorithms_count
    ),
])

## Plot layout
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.update_layout(
    # title='Initial ranking of companies leading in AI research',
    # xaxis_title='Company',
    yaxis_title='Number of innovations for LLMs',
)
fig.update_layout(
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="right",
        x=0.99,
    ),
)
fig.update_layout(
    autosize=False,
    width=400,
    height=300,
    title_x=0.5,
    font=dict(size=10),
    margin=dict(l=20, r=20, t=20, b=20),
)

## Save plot
save_plot(fig, result_file_location, 'num_key_innovations')

## Show plot
fig.show()

# %% [markdown]
# # Count occurrence of innovations directly

# %%
# Download dataset
sheet_id = '1L_j7OaX19HXWWIx_apKvWo2OteY1XOB7FamaLEd_p0s'
tab_id = '1765093800'
data_url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?gid={tab_id}&format=csv'
occurrences_df = pd.read_csv(data_url, index_col='Algorithm')

# %%
occurrences_df.head()
# Out:
#                               GPT-4  \
# Algorithm
# NaN                             NaN
# Transformer                     NaN
# Kaplan et al. scaling laws      NaN
# Hoffmann et al. scaling laws    NaN
# Causal objective                NaN
#
#                                                                          PaLM 2  \
# Algorithm
# NaN                           https://ai.google/static/documents/palm2techre...
# Transformer                                                                   1
# Kaplan et al. scaling laws                                                    0
# Hoffmann et al. scaling laws                                                  1
# Causal objective                                                              1
#
#                                                 Minerva (540B)  \
# Algorithm
# NaN                           https://arxiv.org/abs/2206.14858
# Transformer                                                  1
# Kaplan et al. scaling laws                                   1
# Hoffmann et al. scaling laws                                 0
# Causal objective                                             1
#
#                                                    PaLM (540B)  \
# Algorithm
# NaN                           https://arxiv.org/abs/2204.02311
# Transformer                                                  1
# Kaplan et al. scaling laws                                   1
# Hoffmann et al. scaling laws                                 0
# Causal objective                                             1
#
#                                     Megatron-Turing NLG (530B)  \
# Algorithm
# NaN                           https://arxiv.org/abs/2201.11990
# Transformer                                                  1
# Kaplan et al. scaling laws                                   1
# Hoffmann et al. scaling laws                                 0
# Causal objective                                             1
#
#                                                                   LLaMA 2 (70B)  \
# Algorithm
# NaN                           https://ai.meta.com/research/publications/llam...
# Transformer                                                                   1
# Kaplan et al. scaling laws                                                    0
# Hoffmann et al. scaling laws                                                  1
# Causal objective                                                              1
#
#                                                  Gopher (280B)  \
# Algorithm
# NaN                           https://arxiv.org/abs/2112.11446
# Transformer                                                  1
# Kaplan et al. scaling laws                                   1
# Hoffmann et al. scaling laws                                 0
# Causal objective                                             1
#
#                                               Chinchilla (70B)  \
# Algorithm
# NaN                           https://arxiv.org/abs/2203.15556
# Transformer                                                  1
# Kaplan et al. scaling laws                                   0
# Hoffmann et al. scaling laws                                 1
# Causal objective                                             1
#
#                                                    LLaMA (65B)  \
# Algorithm
# NaN                           https://arxiv.org/abs/2302.13971
# Transformer                                                  1
# Kaplan et al. scaling laws                                   0
# Hoffmann et al. scaling laws                                 1
# Causal objective                                             1
#
#                                                       OPT-175B  ...  \
# Algorithm                                                       ...
# NaN                           https://arxiv.org/abs/2205.01068  ...
# Transformer                                                  1  ...
# Kaplan et al. scaling laws                                   1  ...
# Hoffmann et al. scaling laws                                 0  ...
# Causal objective                                             1  ...
#
#                              Falcon-40B YaLM  ALIGN  \
# Algorithm
# NaN                                 NaN  NaN    NaN
# Transformer                         NaN  NaN    NaN
# Kaplan et al. scaling laws          NaN  NaN    NaN
# Hoffmann et al. scaling laws        NaN  NaN    NaN
# Causal objective                    NaN  NaN    NaN
#
#                                                    AlexaTM 20B  \
# Algorithm
# NaN                           https://arxiv.org/abs/2208.01448
# Transformer                                                  1
# Kaplan et al. scaling laws                                   0
# Hoffmann et al. scaling laws                                 1
# Causal objective                                             1
#
#                                                          BLOOM (176B)  \
# Algorithm
# NaN                           https://huggingface.co/bigscience/bloom
# Transformer                                                         1
# Kaplan et al. scaling laws                                          1
# Hoffmann et al. scaling laws                                        0
# Causal objective                                                    1
#
#                                                                            NLLB  \
# Algorithm
# NaN                           https://research.facebook.com/publications/no-...
# Transformer                                                                   1
# Kaplan et al. scaling laws                                                    0
# Hoffmann et al. scaling laws                                                  0
# Causal objective                                                              1
#
#                                                    Megatron-LM  \
# Algorithm
# NaN                           https://arxiv.org/abs/1909.08053
# Transformer                                                NaN
# Kaplan et al. scaling laws                                 NaN
# Hoffmann et al. scaling laws                               NaN
# Causal objective                                           NaN
#
#                                                                           GPT-2  \
# Algorithm
# NaN                           https://cdn.openai.com/better-language-models/...
# Transformer                                                                   1
# Kaplan et al. scaling laws                                                    0
# Hoffmann et al. scaling laws                                                  0
# Causal objective                                                              1
#
#                                                                             GPT  \
# Algorithm
# NaN                           https://cdn.openai.com/research-covers/languag...
# Transformer                                                                   1
# Kaplan et al. scaling laws                                                    0
# Hoffmann et al. scaling laws                                                  0
# Causal objective                                                              1
#
#                                                                     Transformer
# Algorithm
# NaN                           https://proceedings.neurips.cc/paper_files/pap...
# Transformer                                                                   1
# Kaplan et al. scaling laws                                                    0
# Hoffmann et al. scaling laws                                                  0
# Causal objective                                                              1
#
# [5 rows x 28 columns]

# %%
occurrences_df = occurrences_df[occurrences_df.index.notna()]
occurrences_df
# Out:
#                                                   GPT-4 PaLM 2 Minerva (540B)  \
# Algorithm
# Transformer                                         NaN      1              1
# Kaplan et al. scaling laws                          NaN      0              1
# Hoffmann et al. scaling laws                        NaN      1              0
# Causal objective                                    NaN      1              1
# Masked/denoising objective                          NaN      1              0
# FlashAttention                                      NaN      0              0
# Instruction tuning                                  NaN      1              0
# RLHF                                                NaN      0              0
# PPO                                                 NaN      0              0
# Chain-of-thought                                    NaN      1              1
# Mixed precision training                            NaN      ?              0
# Decoder-only architecture                           NaN      1              1
# RMSNorm                                             NaN      0              0
# LayerNorm                                           NaN      1              1
# Pre-normalization                                   NaN      ?              1
# Learnable position embeddings                       NaN    NaN              0
# Sinusoidal position embeddings                      NaN    NaN              0
# Relative position encodings                         NaN      0              0
# Rotary position embeddings                          NaN    NaN              1
# ALiBi positional encodings                          NaN    NaN              0
# ReLU activation                                     NaN      0              0
# GELU activation                                     NaN      0              0
# SwiGLU activation                                   NaN      1              1
# Sparsely-Gated Mixture-of-Experts layer (MoE)       NaN      0              0
# Sparse Attention                                    NaN    NaN              0
# Linear Attention                                    NaN    NaN              0
# Multi-Query Attention                               NaN    NaN              1
# Grouped Query Attention                             NaN    NaN              0
# Dynamic batch size                                  NaN    NaN              1
# Dropout                                             NaN    NaN              0
# Learning rate decay                                 NaN    NaN              1
# Learning rate warmup                                NaN    NaN              0
# Inverse square-root learning rate decay schedule    NaN    NaN              1
# Linear learning rate decay schedule                 NaN    NaN              0
# Cosine learning rate decay schedule                 NaN    NaN              0
# Adam optimizer                                      NaN    NaN              0
# AdamW optimizer                                     NaN    NaN              0
# Adafactor optimizer                                 NaN    NaN              1
# Weight decay                                        NaN    NaN              1
# Gradient clipping                                   NaN    NaN              1
# Restart to overcome training loss spike             NaN    NaN              1
#
#                                                  PaLM (540B)  \
# Algorithm
# Transformer                                                1
# Kaplan et al. scaling laws                                 1
# Hoffmann et al. scaling laws                               0
# Causal objective                                           1
# Masked/denoising objective                                 0
# FlashAttention                                             0
# Instruction tuning                                         0
# RLHF                                                       0
# PPO                                                        0
# Chain-of-thought                                           1
# Mixed precision training                                   0
# Decoder-only architecture                                  1
# RMSNorm                                                    0
# LayerNorm                                                  1
# Pre-normalization                                          1
# Learnable position embeddings                              0
# Sinusoidal position embeddings                             0
# Relative position encodings                                0
# Rotary position embeddings                                 1
# ALiBi positional encodings                                 0
# ReLU activation                                            0
# GELU activation                                            0
# SwiGLU activation                                          1
# Sparsely-Gated Mixture-of-Experts layer (MoE)              0
# Sparse Attention                                           0
# Linear Attention                                           0
# Multi-Query Attention                                      1
# Grouped Query Attention                                    0
# Dynamic batch size                                         1
# Dropout                                                    0
# Learning rate decay                                        1
# Learning rate warmup                                       0
# Inverse square-root learning rate decay schedule           1
# Linear learning rate decay schedule                        0
# Cosine learning rate decay schedule                        0
# Adam optimizer                                             0
# AdamW optimizer                                            0
# Adafactor optimizer                                        1
# Weight decay                                               1
# Gradient clipping                                          1
# Restart to overcome training loss spike                    1
#
#                                                  Megatron-Turing NLG (530B)  \
# Algorithm
# Transformer                                                               1
# Kaplan et al. scaling laws                                                1
# Hoffmann et al. scaling laws                                              0
# Causal objective                                                          1
# Masked/denoising objective                                                0
# FlashAttention                                                            0
# Instruction tuning                                                        0
# RLHF                                                                      0
# PPO                                                                       0
# Chain-of-thought                                                          0
# Mixed precision training                                                  1
# Decoder-only architecture                                                 1
# RMSNorm                                                                   0
# LayerNorm                                                                 1
# Pre-normalization                                                         1
# Learnable position embeddings                                             1
# Sinusoidal position embeddings                                            0
# Relative position encodings                                               0
# Rotary position embeddings                                                0
# ALiBi positional encodings                                                0
# ReLU activation                                                           0
# GELU activation                                                           1
# SwiGLU activation                                                         0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                             0
# Sparse Attention                                                          0
# Linear Attention                                                          0
# Multi-Query Attention                                                     0
# Grouped Query Attention                                                   0
# Dynamic batch size                                                        1
# Dropout                                                                   0
# Learning rate decay                                                       1
# Learning rate warmup                                                      1
# Inverse square-root learning rate decay schedule                          0
# Linear learning rate decay schedule                                       0
# Cosine learning rate decay schedule                                       1
# Adam optimizer                                                            1
# AdamW optimizer                                                           0
# Adafactor optimizer                                                       0
# Weight decay                                                              1
# Gradient clipping                                                         1
# Restart to overcome training loss spike                                   0
#
#                                                  LLaMA 2 (70B) Gopher (280B)  \
# Algorithm
# Transformer                                                  1             1
# Kaplan et al. scaling laws                                   0             1
# Hoffmann et al. scaling laws                                 1             0
# Causal objective                                             1             1
# Masked/denoising objective                                   0             0
# FlashAttention                                               1             0
# Instruction tuning                                           1             0
# RLHF                                                         1             0
# PPO                                                          1             0
# Chain-of-thought                                             0             0
# Mixed precision training                                     ?             0
# Decoder-only architecture                                    0             1
# RMSNorm                                                      1             1
# LayerNorm                                                    0             0
# Pre-normalization                                            1             1
# Learnable position embeddings                                0             0
# Sinusoidal position embeddings                               0             0
# Relative position encodings                                  0             1
# Rotary position embeddings                                   1             0
# ALiBi positional encodings                                   0             0
# ReLU activation                                              0             0
# GELU activation                                              0             1
# SwiGLU activation                                            1             0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                0             0
# Sparse Attention                                             0             0
# Linear Attention                                             0             0
# Multi-Query Attention                                        0             0
# Grouped Query Attention                                      1             0
# Dynamic batch size                                           0             1
# Dropout                                                      0             1
# Learning rate decay                                          1             1
# Learning rate warmup                                         1             1
# Inverse square-root learning rate decay schedule             0             0
# Linear learning rate decay schedule                          0             0
# Cosine learning rate decay schedule                          1             1
# Adam optimizer                                               0             1
# AdamW optimizer                                              1             0
# Adafactor optimizer                                          0             0
# Weight decay                                                 1             1
# Gradient clipping                                            1             1
# Restart to overcome training loss spike                      ?             ?
#
#                                                  Chinchilla (70B) LLaMA (65B)  \
# Algorithm
# Transformer                                                     1           1
# Kaplan et al. scaling laws                                      0           0
# Hoffmann et al. scaling laws                                    1           1
# Causal objective                                                1           1
# Masked/denoising objective                                      0           0
# FlashAttention                                                  0           1
# Instruction tuning                                              0           1
# RLHF                                                            0           0
# PPO                                                             0           0
# Chain-of-thought                                                0           0
# Mixed precision training                                        0           ?
# Decoder-only architecture                                       1           0
# RMSNorm                                                         1           1
# LayerNorm                                                       0           0
# Pre-normalization                                               1           1
# Learnable position embeddings                                   0           0
# Sinusoidal position embeddings                                  0           0
# Relative position encodings                                     1           0
# Rotary position embeddings                                      0           1
# ALiBi positional encodings                                      0           0
# ReLU activation                                                 0           0
# GELU activation                                                 1           0
# SwiGLU activation                                               0           1
# Sparsely-Gated Mixture-of-Experts layer (MoE)                   0           0
# Sparse Attention                                                0           0
# Linear Attention                                                0           0
# Multi-Query Attention                                           0           0
# Grouped Query Attention                                         0           0
# Dynamic batch size                                              1           0
# Dropout                                                         1           0
# Learning rate decay                                             1           1
# Learning rate warmup                                            1           1
# Inverse square-root learning rate decay schedule                0           0
# Linear learning rate decay schedule                             0           0
# Cosine learning rate decay schedule                             1           1
# Adam optimizer                                                  0           0
# AdamW optimizer                                                 1           1
# Adafactor optimizer                                             0           0
# Weight decay                                                    1           1
# Gradient clipping                                               1           1
# Restart to overcome training loss spike                         ?           ?
#
#                                                  OPT-175B  ... Falcon-40B  \
# Algorithm                                                  ...
# Transformer                                             1  ...        NaN
# Kaplan et al. scaling laws                              1  ...        NaN
# Hoffmann et al. scaling laws                            0  ...        NaN
# Causal objective                                        1  ...        NaN
# Masked/denoising objective                              0  ...        NaN
# FlashAttention                                          0  ...        NaN
# Instruction tuning                                      0  ...        NaN
# RLHF                                                    0  ...        NaN
# PPO                                                     0  ...        NaN
# Chain-of-thought                                        0  ...        NaN
# Mixed precision training                                1  ...        NaN
# Decoder-only architecture                               1  ...        NaN
# RMSNorm                                                 0  ...        NaN
# LayerNorm                                               1  ...        NaN
# Pre-normalization                                       1  ...        NaN
# Learnable position embeddings                           1  ...        NaN
# Sinusoidal position embeddings                          0  ...        NaN
# Relative position encodings                             0  ...        NaN
# Rotary position embeddings                              0  ...        NaN
# ALiBi positional encodings                              0  ...        NaN
# ReLU activation                                         1  ...        NaN
# GELU activation                                         0  ...        NaN
# SwiGLU activation                                       0  ...        NaN
# Sparsely-Gated Mixture-of-Experts layer (MoE)           0  ...        NaN
# Sparse Attention                                        1  ...        NaN
# Linear Attention                                        0  ...        NaN
# Multi-Query Attention                                   0  ...        NaN
# Grouped Query Attention                                 0  ...        NaN
# Dynamic batch size                                      0  ...        NaN
# Dropout                                                 1  ...        NaN
# Learning rate decay                                     1  ...        NaN
# Learning rate warmup                                    1  ...        NaN
# Inverse square-root learning rate decay schedule        0  ...        NaN
# Linear learning rate decay schedule                     1  ...        NaN
# Cosine learning rate decay schedule                     0  ...        NaN
# Adam optimizer                                          0  ...        NaN
# AdamW optimizer                                         1  ...        NaN
# Adafactor optimizer                                     0  ...        NaN
# Weight decay                                            1  ...        NaN
# Gradient clipping                                       1  ...        NaN
# Restart to overcome training loss spike                 1  ...        NaN
#
#                                                  YaLM  ALIGN  AlexaTM 20B  \
# Algorithm
# Transformer                                       NaN    NaN            1
# Kaplan et al. scaling laws                        NaN    NaN            0
# Hoffmann et al. scaling laws                      NaN    NaN            1
# Causal objective                                  NaN    NaN            1
# Masked/denoising objective                        NaN    NaN            1
# FlashAttention                                    NaN    NaN            0
# Instruction tuning                                NaN    NaN            0
# RLHF                                              NaN    NaN            0
# PPO                                               NaN    NaN            0
# Chain-of-thought                                  NaN    NaN            1
# Mixed precision training                          NaN    NaN            ?
# Decoder-only architecture                         NaN    NaN            0
# RMSNorm                                           NaN    NaN            0
# LayerNorm                                         NaN    NaN            1
# Pre-normalization                                 NaN    NaN            1
# Learnable position embeddings                     NaN    NaN            1
# Sinusoidal position embeddings                    NaN    NaN            0
# Relative position encodings                       NaN    NaN            0
# Rotary position embeddings                        NaN    NaN            0
# ALiBi positional encodings                        NaN    NaN            0
# ReLU activation                                   NaN    NaN            1
# GELU activation                                   NaN    NaN            0
# SwiGLU activation                                 NaN    NaN            0
# Sparsely-Gated Mixture-of-Experts layer (MoE)     NaN    NaN            0
# Sparse Attention                                  NaN    NaN            0
# Linear Attention                                  NaN    NaN            0
# Multi-Query Attention                             NaN    NaN          NaN
# Grouped Query Attention                           NaN    NaN          NaN
# Dynamic batch size                                NaN    NaN            0
# Dropout                                           NaN    NaN            0
# Learning rate decay                               NaN    NaN            1
# Learning rate warmup                              NaN    NaN          NaN
# Inverse square-root learning rate decay schedule  NaN    NaN          NaN
# Linear learning rate decay schedule               NaN    NaN            1
# Cosine learning rate decay schedule               NaN    NaN            0
# Adam optimizer                                    NaN    NaN            1
# AdamW optimizer                                   NaN    NaN            0
# Adafactor optimizer                               NaN    NaN          NaN
# Weight decay                                      NaN    NaN            1
# Gradient clipping                                 NaN    NaN            ?
# Restart to overcome training loss spike           NaN    NaN            ?
#
#                                                   BLOOM (176B)  NLLB  \
# Algorithm
# Transformer                                                  1     1
# Kaplan et al. scaling laws                                   1     0
# Hoffmann et al. scaling laws                                 0     0
# Causal objective                                             1     1
# Masked/denoising objective                                   0     1
# FlashAttention                                               0     0
# Instruction tuning                                           0     0
# RLHF                                                         0     0
# PPO                                                          0     0
# Chain-of-thought                                             0     0
# Mixed precision training                                     1     0
# Decoder-only architecture                                    1     0
# RMSNorm                                                      0     0
# LayerNorm                                                    1     1
# Pre-normalization                                            1     1
# Learnable position embeddings                                0     0
# Sinusoidal position embeddings                               0     1
# Relative position encodings                                  0     0
# Rotary position embeddings                                   0     0
# ALiBi positional encodings                                   1     0
# ReLU activation                                              0     1
# GELU activation                                              1     0
# SwiGLU activation                                            0     0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                0     1
# Sparse Attention                                             0     0
# Linear Attention                                             0     0
# Multi-Query Attention                                      NaN   NaN
# Grouped Query Attention                                    NaN   NaN
# Dynamic batch size                                           0     0
# Dropout                                                      0     1
# Learning rate decay                                          1     1
# Learning rate warmup                                       NaN     1
# Inverse square-root learning rate decay schedule           NaN     1
# Linear learning rate decay schedule                          0     0
# Cosine learning rate decay schedule                          1     0
# Adam optimizer                                               1     1
# AdamW optimizer                                              0     0
# Adafactor optimizer                                        NaN   NaN
# Weight decay                                                 1     ?
# Gradient clipping                                            1     ?
# Restart to overcome training loss spike                      ?     ?
#
#                                                  Megatron-LM  GPT-2  GPT  \
# Algorithm
# Transformer                                              NaN      1    1
# Kaplan et al. scaling laws                               NaN      0    0
# Hoffmann et al. scaling laws                             NaN      0    0
# Causal objective                                         NaN      1    1
# Masked/denoising objective                               NaN      0    0
# FlashAttention                                           NaN      0    0
# Instruction tuning                                       NaN      0    0
# RLHF                                                     NaN      0    0
# PPO                                                      NaN      0    0
# Chain-of-thought                                         NaN      0    0
# Mixed precision training                                   1      ?    ?
# Decoder-only architecture                                NaN      1    1
# RMSNorm                                                  NaN      0    0
# LayerNorm                                                NaN      1    1
# Pre-normalization                                        NaN      1    0
# Learnable position embeddings                            NaN      1    1
# Sinusoidal position embeddings                           NaN      0    0
# Relative position encodings                              NaN      0    0
# Rotary position embeddings                               NaN      0    0
# ALiBi positional encodings                               NaN      0    0
# ReLU activation                                          NaN      0    0
# GELU activation                                          NaN      1    1
# SwiGLU activation                                        NaN      0    0
# Sparsely-Gated Mixture-of-Experts layer (MoE)            NaN      0    0
# Sparse Attention                                         NaN      0    0
# Linear Attention                                         NaN      0    0
# Multi-Query Attention                                    NaN      0    0
# Grouped Query Attention                                  NaN      0    0
# Dynamic batch size                                       NaN      0    0
# Dropout                                                  NaN      1    1
# Learning rate decay                                      NaN      1    1
# Learning rate warmup                                     NaN      1    1
# Inverse square-root learning rate decay schedule         NaN      0    0
# Linear learning rate decay schedule                      NaN      1    1
# Cosine learning rate decay schedule                      NaN      1    1
# Adam optimizer                                           NaN      0    0
# AdamW optimizer                                          NaN      1    1
# Adafactor optimizer                                      NaN      0    0
# Weight decay                                             NaN      1    1
# Gradient clipping                                        NaN      ?    ?
# Restart to overcome training loss spike                  NaN      ?    ?
#
#                                                   Transformer
# Algorithm
# Transformer                                                 1
# Kaplan et al. scaling laws                                  0
# Hoffmann et al. scaling laws                                0
# Causal objective                                            1
# Masked/denoising objective                                  0
# FlashAttention                                              0
# Instruction tuning                                          0
# RLHF                                                        0
# PPO                                                         0
# Chain-of-thought                                            0
# Mixed precision training                                    0
# Decoder-only architecture                                   0
# RMSNorm                                                     0
# LayerNorm                                                   1
# Pre-normalization                                           0
# Learnable position embeddings                               0
# Sinusoidal position embeddings                              1
# Relative position encodings                                 0
# Rotary position embeddings                                  0
# ALiBi positional encodings                                  0
# ReLU activation                                             1
# GELU activation                                             0
# SwiGLU activation                                           0
# Sparsely-Gated Mixture-of-Experts layer (MoE)               0
# Sparse Attention                                            0
# Linear Attention                                            0
# Multi-Query Attention                                       0
# Grouped Query Attention                                     0
# Dynamic batch size                                          0
# Dropout                                                     1
# Learning rate decay                                         1
# Learning rate warmup                                        1
# Inverse square-root learning rate decay schedule            1
# Linear learning rate decay schedule                         0
# Cosine learning rate decay schedule                         0
# Adam optimizer                                              1
# AdamW optimizer                                             0
# Adafactor optimizer                                         0
# Weight decay                                                0
# Gradient clipping                                           0
# Restart to overcome training loss spike                     ?
#
# [41 rows x 28 columns]

# %%
# Replace '?' values with 0
occurrences_df = occurrences_df.replace('?', 0)
occurrences_df
# Out:
#                                                   GPT-4 PaLM 2 Minerva (540B)  \
# Algorithm
# Transformer                                         NaN      1              1
# Kaplan et al. scaling laws                          NaN      0              1
# Hoffmann et al. scaling laws                        NaN      1              0
# Causal objective                                    NaN      1              1
# Masked/denoising objective                          NaN      1              0
# FlashAttention                                      NaN      0              0
# Instruction tuning                                  NaN      1              0
# RLHF                                                NaN      0              0
# PPO                                                 NaN      0              0
# Chain-of-thought                                    NaN      1              1
# Mixed precision training                            NaN      0              0
# Decoder-only architecture                           NaN      1              1
# RMSNorm                                             NaN      0              0
# LayerNorm                                           NaN      1              1
# Pre-normalization                                   NaN      0              1
# Learnable position embeddings                       NaN    NaN              0
# Sinusoidal position embeddings                      NaN    NaN              0
# Relative position encodings                         NaN      0              0
# Rotary position embeddings                          NaN    NaN              1
# ALiBi positional encodings                          NaN    NaN              0
# ReLU activation                                     NaN      0              0
# GELU activation                                     NaN      0              0
# SwiGLU activation                                   NaN      1              1
# Sparsely-Gated Mixture-of-Experts layer (MoE)       NaN      0              0
# Sparse Attention                                    NaN    NaN              0
# Linear Attention                                    NaN    NaN              0
# Multi-Query Attention                               NaN    NaN              1
# Grouped Query Attention                             NaN    NaN              0
# Dynamic batch size                                  NaN    NaN              1
# Dropout                                             NaN    NaN              0
# Learning rate decay                                 NaN    NaN              1
# Learning rate warmup                                NaN    NaN              0
# Inverse square-root learning rate decay schedule    NaN    NaN              1
# Linear learning rate decay schedule                 NaN    NaN              0
# Cosine learning rate decay schedule                 NaN    NaN              0
# Adam optimizer                                      NaN    NaN              0
# AdamW optimizer                                     NaN    NaN              0
# Adafactor optimizer                                 NaN    NaN              1
# Weight decay                                        NaN    NaN              1
# Gradient clipping                                   NaN    NaN              1
# Restart to overcome training loss spike             NaN    NaN              1
#
#                                                  PaLM (540B)  \
# Algorithm
# Transformer                                                1
# Kaplan et al. scaling laws                                 1
# Hoffmann et al. scaling laws                               0
# Causal objective                                           1
# Masked/denoising objective                                 0
# FlashAttention                                             0
# Instruction tuning                                         0
# RLHF                                                       0
# PPO                                                        0
# Chain-of-thought                                           1
# Mixed precision training                                   0
# Decoder-only architecture                                  1
# RMSNorm                                                    0
# LayerNorm                                                  1
# Pre-normalization                                          1
# Learnable position embeddings                              0
# Sinusoidal position embeddings                             0
# Relative position encodings                                0
# Rotary position embeddings                                 1
# ALiBi positional encodings                                 0
# ReLU activation                                            0
# GELU activation                                            0
# SwiGLU activation                                          1
# Sparsely-Gated Mixture-of-Experts layer (MoE)              0
# Sparse Attention                                           0
# Linear Attention                                           0
# Multi-Query Attention                                      1
# Grouped Query Attention                                    0
# Dynamic batch size                                         1
# Dropout                                                    0
# Learning rate decay                                        1
# Learning rate warmup                                       0
# Inverse square-root learning rate decay schedule           1
# Linear learning rate decay schedule                        0
# Cosine learning rate decay schedule                        0
# Adam optimizer                                             0
# AdamW optimizer                                            0
# Adafactor optimizer                                        1
# Weight decay                                               1
# Gradient clipping                                          1
# Restart to overcome training loss spike                    1
#
#                                                  Megatron-Turing NLG (530B)  \
# Algorithm
# Transformer                                                               1
# Kaplan et al. scaling laws                                                1
# Hoffmann et al. scaling laws                                              0
# Causal objective                                                          1
# Masked/denoising objective                                                0
# FlashAttention                                                            0
# Instruction tuning                                                        0
# RLHF                                                                      0
# PPO                                                                       0
# Chain-of-thought                                                          0
# Mixed precision training                                                  1
# Decoder-only architecture                                                 1
# RMSNorm                                                                   0
# LayerNorm                                                                 1
# Pre-normalization                                                         1
# Learnable position embeddings                                             1
# Sinusoidal position embeddings                                            0
# Relative position encodings                                               0
# Rotary position embeddings                                                0
# ALiBi positional encodings                                                0
# ReLU activation                                                           0
# GELU activation                                                           1
# SwiGLU activation                                                         0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                             0
# Sparse Attention                                                          0
# Linear Attention                                                          0
# Multi-Query Attention                                                     0
# Grouped Query Attention                                                   0
# Dynamic batch size                                                        1
# Dropout                                                                   0
# Learning rate decay                                                       1
# Learning rate warmup                                                      1
# Inverse square-root learning rate decay schedule                          0
# Linear learning rate decay schedule                                       0
# Cosine learning rate decay schedule                                       1
# Adam optimizer                                                            1
# AdamW optimizer                                                           0
# Adafactor optimizer                                                       0
# Weight decay                                                              1
# Gradient clipping                                                         1
# Restart to overcome training loss spike                                   0
#
#                                                  LLaMA 2 (70B) Gopher (280B)  \
# Algorithm
# Transformer                                                  1             1
# Kaplan et al. scaling laws                                   0             1
# Hoffmann et al. scaling laws                                 1             0
# Causal objective                                             1             1
# Masked/denoising objective                                   0             0
# FlashAttention                                               1             0
# Instruction tuning                                           1             0
# RLHF                                                         1             0
# PPO                                                          1             0
# Chain-of-thought                                             0             0
# Mixed precision training                                     0             0
# Decoder-only architecture                                    0             1
# RMSNorm                                                      1             1
# LayerNorm                                                    0             0
# Pre-normalization                                            1             1
# Learnable position embeddings                                0             0
# Sinusoidal position embeddings                               0             0
# Relative position encodings                                  0             1
# Rotary position embeddings                                   1             0
# ALiBi positional encodings                                   0             0
# ReLU activation                                              0             0
# GELU activation                                              0             1
# SwiGLU activation                                            1             0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                0             0
# Sparse Attention                                             0             0
# Linear Attention                                             0             0
# Multi-Query Attention                                        0             0
# Grouped Query Attention                                      1             0
# Dynamic batch size                                           0             1
# Dropout                                                      0             1
# Learning rate decay                                          1             1
# Learning rate warmup                                         1             1
# Inverse square-root learning rate decay schedule             0             0
# Linear learning rate decay schedule                          0             0
# Cosine learning rate decay schedule                          1             1
# Adam optimizer                                               0             1
# AdamW optimizer                                              1             0
# Adafactor optimizer                                          0             0
# Weight decay                                                 1             1
# Gradient clipping                                            1             1
# Restart to overcome training loss spike                      0             0
#
#                                                  Chinchilla (70B) LLaMA (65B)  \
# Algorithm
# Transformer                                                     1           1
# Kaplan et al. scaling laws                                      0           0
# Hoffmann et al. scaling laws                                    1           1
# Causal objective                                                1           1
# Masked/denoising objective                                      0           0
# FlashAttention                                                  0           1
# Instruction tuning                                              0           1
# RLHF                                                            0           0
# PPO                                                             0           0
# Chain-of-thought                                                0           0
# Mixed precision training                                        0           0
# Decoder-only architecture                                       1           0
# RMSNorm                                                         1           1
# LayerNorm                                                       0           0
# Pre-normalization                                               1           1
# Learnable position embeddings                                   0           0
# Sinusoidal position embeddings                                  0           0
# Relative position encodings                                     1           0
# Rotary position embeddings                                      0           1
# ALiBi positional encodings                                      0           0
# ReLU activation                                                 0           0
# GELU activation                                                 1           0
# SwiGLU activation                                               0           1
# Sparsely-Gated Mixture-of-Experts layer (MoE)                   0           0
# Sparse Attention                                                0           0
# Linear Attention                                                0           0
# Multi-Query Attention                                           0           0
# Grouped Query Attention                                         0           0
# Dynamic batch size                                              1           0
# Dropout                                                         1           0
# Learning rate decay                                             1           1
# Learning rate warmup                                            1           1
# Inverse square-root learning rate decay schedule                0           0
# Linear learning rate decay schedule                             0           0
# Cosine learning rate decay schedule                             1           1
# Adam optimizer                                                  0           0
# AdamW optimizer                                                 1           1
# Adafactor optimizer                                             0           0
# Weight decay                                                    1           1
# Gradient clipping                                               1           1
# Restart to overcome training loss spike                         0           0
#
#                                                  OPT-175B  ... Falcon-40B  \
# Algorithm                                                  ...
# Transformer                                             1  ...        NaN
# Kaplan et al. scaling laws                              1  ...        NaN
# Hoffmann et al. scaling laws                            0  ...        NaN
# Causal objective                                        1  ...        NaN
# Masked/denoising objective                              0  ...        NaN
# FlashAttention                                          0  ...        NaN
# Instruction tuning                                      0  ...        NaN
# RLHF                                                    0  ...        NaN
# PPO                                                     0  ...        NaN
# Chain-of-thought                                        0  ...        NaN
# Mixed precision training                                1  ...        NaN
# Decoder-only architecture                               1  ...        NaN
# RMSNorm                                                 0  ...        NaN
# LayerNorm                                               1  ...        NaN
# Pre-normalization                                       1  ...        NaN
# Learnable position embeddings                           1  ...        NaN
# Sinusoidal position embeddings                          0  ...        NaN
# Relative position encodings                             0  ...        NaN
# Rotary position embeddings                              0  ...        NaN
# ALiBi positional encodings                              0  ...        NaN
# ReLU activation                                         1  ...        NaN
# GELU activation                                         0  ...        NaN
# SwiGLU activation                                       0  ...        NaN
# Sparsely-Gated Mixture-of-Experts layer (MoE)           0  ...        NaN
# Sparse Attention                                        1  ...        NaN
# Linear Attention                                        0  ...        NaN
# Multi-Query Attention                                   0  ...        NaN
# Grouped Query Attention                                 0  ...        NaN
# Dynamic batch size                                      0  ...        NaN
# Dropout                                                 1  ...        NaN
# Learning rate decay                                     1  ...        NaN
# Learning rate warmup                                    1  ...        NaN
# Inverse square-root learning rate decay schedule        0  ...        NaN
# Linear learning rate decay schedule                     1  ...        NaN
# Cosine learning rate decay schedule                     0  ...        NaN
# Adam optimizer                                          0  ...        NaN
# AdamW optimizer                                         1  ...        NaN
# Adafactor optimizer                                     0  ...        NaN
# Weight decay                                            1  ...        NaN
# Gradient clipping                                       1  ...        NaN
# Restart to overcome training loss spike                 1  ...        NaN
#
#                                                  YaLM  ALIGN  AlexaTM 20B  \
# Algorithm
# Transformer                                       NaN    NaN            1
# Kaplan et al. scaling laws                        NaN    NaN            0
# Hoffmann et al. scaling laws                      NaN    NaN            1
# Causal objective                                  NaN    NaN            1
# Masked/denoising objective                        NaN    NaN            1
# FlashAttention                                    NaN    NaN            0
# Instruction tuning                                NaN    NaN            0
# RLHF                                              NaN    NaN            0
# PPO                                               NaN    NaN            0
# Chain-of-thought                                  NaN    NaN            1
# Mixed precision training                          NaN    NaN            0
# Decoder-only architecture                         NaN    NaN            0
# RMSNorm                                           NaN    NaN            0
# LayerNorm                                         NaN    NaN            1
# Pre-normalization                                 NaN    NaN            1
# Learnable position embeddings                     NaN    NaN            1
# Sinusoidal position embeddings                    NaN    NaN            0
# Relative position encodings                       NaN    NaN            0
# Rotary position embeddings                        NaN    NaN            0
# ALiBi positional encodings                        NaN    NaN            0
# ReLU activation                                   NaN    NaN            1
# GELU activation                                   NaN    NaN            0
# SwiGLU activation                                 NaN    NaN            0
# Sparsely-Gated Mixture-of-Experts layer (MoE)     NaN    NaN            0
# Sparse Attention                                  NaN    NaN            0
# Linear Attention                                  NaN    NaN            0
# Multi-Query Attention                             NaN    NaN          NaN
# Grouped Query Attention                           NaN    NaN          NaN
# Dynamic batch size                                NaN    NaN            0
# Dropout                                           NaN    NaN            0
# Learning rate decay                               NaN    NaN            1
# Learning rate warmup                              NaN    NaN          NaN
# Inverse square-root learning rate decay schedule  NaN    NaN          NaN
# Linear learning rate decay schedule               NaN    NaN            1
# Cosine learning rate decay schedule               NaN    NaN            0
# Adam optimizer                                    NaN    NaN            1
# AdamW optimizer                                   NaN    NaN            0
# Adafactor optimizer                               NaN    NaN          NaN
# Weight decay                                      NaN    NaN            1
# Gradient clipping                                 NaN    NaN            0
# Restart to overcome training loss spike           NaN    NaN            0
#
#                                                   BLOOM (176B)  NLLB  \
# Algorithm
# Transformer                                                  1     1
# Kaplan et al. scaling laws                                   1     0
# Hoffmann et al. scaling laws                                 0     0
# Causal objective                                             1     1
# Masked/denoising objective                                   0     1
# FlashAttention                                               0     0
# Instruction tuning                                           0     0
# RLHF                                                         0     0
# PPO                                                          0     0
# Chain-of-thought                                             0     0
# Mixed precision training                                     1     0
# Decoder-only architecture                                    1     0
# RMSNorm                                                      0     0
# LayerNorm                                                    1     1
# Pre-normalization                                            1     1
# Learnable position embeddings                                0     0
# Sinusoidal position embeddings                               0     1
# Relative position encodings                                  0     0
# Rotary position embeddings                                   0     0
# ALiBi positional encodings                                   1     0
# ReLU activation                                              0     1
# GELU activation                                              1     0
# SwiGLU activation                                            0     0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                0     1
# Sparse Attention                                             0     0
# Linear Attention                                             0     0
# Multi-Query Attention                                      NaN   NaN
# Grouped Query Attention                                    NaN   NaN
# Dynamic batch size                                           0     0
# Dropout                                                      0     1
# Learning rate decay                                          1     1
# Learning rate warmup                                       NaN     1
# Inverse square-root learning rate decay schedule           NaN     1
# Linear learning rate decay schedule                          0     0
# Cosine learning rate decay schedule                          1     0
# Adam optimizer                                               1     1
# AdamW optimizer                                              0     0
# Adafactor optimizer                                        NaN   NaN
# Weight decay                                                 1     0
# Gradient clipping                                            1     0
# Restart to overcome training loss spike                      0     0
#
#                                                  Megatron-LM  GPT-2  GPT  \
# Algorithm
# Transformer                                              NaN      1    1
# Kaplan et al. scaling laws                               NaN      0    0
# Hoffmann et al. scaling laws                             NaN      0    0
# Causal objective                                         NaN      1    1
# Masked/denoising objective                               NaN      0    0
# FlashAttention                                           NaN      0    0
# Instruction tuning                                       NaN      0    0
# RLHF                                                     NaN      0    0
# PPO                                                      NaN      0    0
# Chain-of-thought                                         NaN      0    0
# Mixed precision training                                   1      0    0
# Decoder-only architecture                                NaN      1    1
# RMSNorm                                                  NaN      0    0
# LayerNorm                                                NaN      1    1
# Pre-normalization                                        NaN      1    0
# Learnable position embeddings                            NaN      1    1
# Sinusoidal position embeddings                           NaN      0    0
# Relative position encodings                              NaN      0    0
# Rotary position embeddings                               NaN      0    0
# ALiBi positional encodings                               NaN      0    0
# ReLU activation                                          NaN      0    0
# GELU activation                                          NaN      1    1
# SwiGLU activation                                        NaN      0    0
# Sparsely-Gated Mixture-of-Experts layer (MoE)            NaN      0    0
# Sparse Attention                                         NaN      0    0
# Linear Attention                                         NaN      0    0
# Multi-Query Attention                                    NaN      0    0
# Grouped Query Attention                                  NaN      0    0
# Dynamic batch size                                       NaN      0    0
# Dropout                                                  NaN      1    1
# Learning rate decay                                      NaN      1    1
# Learning rate warmup                                     NaN      1    1
# Inverse square-root learning rate decay schedule         NaN      0    0
# Linear learning rate decay schedule                      NaN      1    1
# Cosine learning rate decay schedule                      NaN      1    1
# Adam optimizer                                           NaN      0    0
# AdamW optimizer                                          NaN      1    1
# Adafactor optimizer                                      NaN      0    0
# Weight decay                                             NaN      1    1
# Gradient clipping                                        NaN      0    0
# Restart to overcome training loss spike                  NaN      0    0
#
#                                                   Transformer
# Algorithm
# Transformer                                                 1
# Kaplan et al. scaling laws                                  0
# Hoffmann et al. scaling laws                                0
# Causal objective                                            1
# Masked/denoising objective                                  0
# FlashAttention                                              0
# Instruction tuning                                          0
# RLHF                                                        0
# PPO                                                         0
# Chain-of-thought                                            0
# Mixed precision training                                    0
# Decoder-only architecture                                   0
# RMSNorm                                                     0
# LayerNorm                                                   1
# Pre-normalization                                           0
# Learnable position embeddings                               0
# Sinusoidal position embeddings                              1
# Relative position encodings                                 0
# Rotary position embeddings                                  0
# ALiBi positional encodings                                  0
# ReLU activation                                             1
# GELU activation                                             0
# SwiGLU activation                                           0
# Sparsely-Gated Mixture-of-Experts layer (MoE)               0
# Sparse Attention                                            0
# Linear Attention                                            0
# Multi-Query Attention                                       0
# Grouped Query Attention                                     0
# Dynamic batch size                                          0
# Dropout                                                     1
# Learning rate decay                                         1
# Learning rate warmup                                        1
# Inverse square-root learning rate decay schedule            1
# Linear learning rate decay schedule                         0
# Cosine learning rate decay schedule                         0
# Adam optimizer                                              1
# AdamW optimizer                                             0
# Adafactor optimizer                                         0
# Weight decay                                                0
# Gradient clipping                                           0
# Restart to overcome training loss spike                     0
#
# [41 rows x 28 columns]

# %%
# Filter columns
keep_systems = ['Algorithm', 'PaLM (540B)', 'Megatron-Turing NLG (530B)', 'LLaMA 2 (70B)', 'Gopher (280B)', 'Chinchilla (70B)', 'LLaMA (65B)', 'OPT-175B', 'Yuan 1.0', 'AlphaCode', 'GPT-3 (175B)']
selected_systems_occurrences_df = occurrences_df.filter(keep_systems)
selected_systems_occurrences_df
# Out:
#                                                  PaLM (540B)  \
# Algorithm
# Transformer                                                1
# Kaplan et al. scaling laws                                 1
# Hoffmann et al. scaling laws                               0
# Causal objective                                           1
# Masked/denoising objective                                 0
# FlashAttention                                             0
# Instruction tuning                                         0
# RLHF                                                       0
# PPO                                                        0
# Chain-of-thought                                           1
# Mixed precision training                                   0
# Decoder-only architecture                                  1
# RMSNorm                                                    0
# LayerNorm                                                  1
# Pre-normalization                                          1
# Learnable position embeddings                              0
# Sinusoidal position embeddings                             0
# Relative position encodings                                0
# Rotary position embeddings                                 1
# ALiBi positional encodings                                 0
# ReLU activation                                            0
# GELU activation                                            0
# SwiGLU activation                                          1
# Sparsely-Gated Mixture-of-Experts layer (MoE)              0
# Sparse Attention                                           0
# Linear Attention                                           0
# Multi-Query Attention                                      1
# Grouped Query Attention                                    0
# Dynamic batch size                                         1
# Dropout                                                    0
# Learning rate decay                                        1
# Learning rate warmup                                       0
# Inverse square-root learning rate decay schedule           1
# Linear learning rate decay schedule                        0
# Cosine learning rate decay schedule                        0
# Adam optimizer                                             0
# AdamW optimizer                                            0
# Adafactor optimizer                                        1
# Weight decay                                               1
# Gradient clipping                                          1
# Restart to overcome training loss spike                    1
#
#                                                  Megatron-Turing NLG (530B)  \
# Algorithm
# Transformer                                                               1
# Kaplan et al. scaling laws                                                1
# Hoffmann et al. scaling laws                                              0
# Causal objective                                                          1
# Masked/denoising objective                                                0
# FlashAttention                                                            0
# Instruction tuning                                                        0
# RLHF                                                                      0
# PPO                                                                       0
# Chain-of-thought                                                          0
# Mixed precision training                                                  1
# Decoder-only architecture                                                 1
# RMSNorm                                                                   0
# LayerNorm                                                                 1
# Pre-normalization                                                         1
# Learnable position embeddings                                             1
# Sinusoidal position embeddings                                            0
# Relative position encodings                                               0
# Rotary position embeddings                                                0
# ALiBi positional encodings                                                0
# ReLU activation                                                           0
# GELU activation                                                           1
# SwiGLU activation                                                         0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                             0
# Sparse Attention                                                          0
# Linear Attention                                                          0
# Multi-Query Attention                                                     0
# Grouped Query Attention                                                   0
# Dynamic batch size                                                        1
# Dropout                                                                   0
# Learning rate decay                                                       1
# Learning rate warmup                                                      1
# Inverse square-root learning rate decay schedule                          0
# Linear learning rate decay schedule                                       0
# Cosine learning rate decay schedule                                       1
# Adam optimizer                                                            1
# AdamW optimizer                                                           0
# Adafactor optimizer                                                       0
# Weight decay                                                              1
# Gradient clipping                                                         1
# Restart to overcome training loss spike                                   0
#
#                                                  LLaMA 2 (70B) Gopher (280B)  \
# Algorithm
# Transformer                                                  1             1
# Kaplan et al. scaling laws                                   0             1
# Hoffmann et al. scaling laws                                 1             0
# Causal objective                                             1             1
# Masked/denoising objective                                   0             0
# FlashAttention                                               1             0
# Instruction tuning                                           1             0
# RLHF                                                         1             0
# PPO                                                          1             0
# Chain-of-thought                                             0             0
# Mixed precision training                                     0             0
# Decoder-only architecture                                    0             1
# RMSNorm                                                      1             1
# LayerNorm                                                    0             0
# Pre-normalization                                            1             1
# Learnable position embeddings                                0             0
# Sinusoidal position embeddings                               0             0
# Relative position encodings                                  0             1
# Rotary position embeddings                                   1             0
# ALiBi positional encodings                                   0             0
# ReLU activation                                              0             0
# GELU activation                                              0             1
# SwiGLU activation                                            1             0
# Sparsely-Gated Mixture-of-Experts layer (MoE)                0             0
# Sparse Attention                                             0             0
# Linear Attention                                             0             0
# Multi-Query Attention                                        0             0
# Grouped Query Attention                                      1             0
# Dynamic batch size                                           0             1
# Dropout                                                      0             1
# Learning rate decay                                          1             1
# Learning rate warmup                                         1             1
# Inverse square-root learning rate decay schedule             0             0
# Linear learning rate decay schedule                          0             0
# Cosine learning rate decay schedule                          1             1
# Adam optimizer                                               0             1
# AdamW optimizer                                              1             0
# Adafactor optimizer                                          0             0
# Weight decay                                                 1             1
# Gradient clipping                                            1             1
# Restart to overcome training loss spike                      0             0
#
#                                                  Chinchilla (70B) LLaMA (65B)  \
# Algorithm
# Transformer                                                     1           1
# Kaplan et al. scaling laws                                      0           0
# Hoffmann et al. scaling laws                                    1           1
# Causal objective                                                1           1
# Masked/denoising objective                                      0           0
# FlashAttention                                                  0           1
# Instruction tuning                                              0           1
# RLHF                                                            0           0
# PPO                                                             0           0
# Chain-of-thought                                                0           0
# Mixed precision training                                        0           0
# Decoder-only architecture                                       1           0
# RMSNorm                                                         1           1
# LayerNorm                                                       0           0
# Pre-normalization                                               1           1
# Learnable position embeddings                                   0           0
# Sinusoidal position embeddings                                  0           0
# Relative position encodings                                     1           0
# Rotary position embeddings                                      0           1
# ALiBi positional encodings                                      0           0
# ReLU activation                                                 0           0
# GELU activation                                                 1           0
# SwiGLU activation                                               0           1
# Sparsely-Gated Mixture-of-Experts layer (MoE)                   0           0
# Sparse Attention                                                0           0
# Linear Attention                                                0           0
# Multi-Query Attention                                           0           0
# Grouped Query Attention                                         0           0
# Dynamic batch size                                              1           0
# Dropout                                                         1           0
# Learning rate decay                                             1           1
# Learning rate warmup                                            1           1
# Inverse square-root learning rate decay schedule                0           0
# Linear learning rate decay schedule                             0           0
# Cosine learning rate decay schedule                             1           1
# Adam optimizer                                                  0           0
# AdamW optimizer                                                 1           1
# Adafactor optimizer                                             0           0
# Weight decay                                                    1           1
# Gradient clipping                                               1           1
# Restart to overcome training loss spike                         0           0
#
#                                                  OPT-175B Yuan 1.0 AlphaCode  \
# Algorithm
# Transformer                                             1        1         1
# Kaplan et al. scaling laws                              1        0         0
# Hoffmann et al. scaling laws                            0        0         0
# Causal objective                                        1        1         1
# Masked/denoising objective                              0        0         1
# FlashAttention                                          0        0         0
# Instruction tuning                                      0        0         0
# RLHF                                                    0        0         0
# PPO                                                     0        0         0
# Chain-of-thought                                        0        0         0
# Mixed precision training                                1        0         0
# Decoder-only architecture                               1        1         0
# RMSNorm                                                 0        0         0
# LayerNorm                                               1        1         1
# Pre-normalization                                       1        1         0
# Learnable position embeddings                           1        1         0
# Sinusoidal position embeddings                          0        0         1
# Relative position encodings                             0        0         0
# Rotary position embeddings                              0        0         0
# ALiBi positional encodings                              0        0         0
# ReLU activation                                         1        0         1
# GELU activation                                         0        1         0
# SwiGLU activation                                       0        0         0
# Sparsely-Gated Mixture-of-Experts layer (MoE)           0        0         0
# Sparse Attention                                        1        0         0
# Linear Attention                                        0        0         0
# Multi-Query Attention                                   0        0         1
# Grouped Query Attention                                 0        0         0
# Dynamic batch size                                      0        1         0
# Dropout                                                 1        1         0
# Learning rate decay                                     1        1         1
# Learning rate warmup                                    1        1         1
# Inverse square-root learning rate decay schedule        0        0         0
# Linear learning rate decay schedule                     1        0         0
# Cosine learning rate decay schedule                     0        1         1
# Adam optimizer                                          0        1         0
# AdamW optimizer                                         1        0         1
# Adafactor optimizer                                     0        0         0
# Weight decay                                            1        1         1
# Gradient clipping                                       1        1         1
# Restart to overcome training loss spike                 1        0         0
#
#                                                  GPT-3 (175B)
# Algorithm
# Transformer                                                 1
# Kaplan et al. scaling laws                                  1
# Hoffmann et al. scaling laws                                0
# Causal objective                                            1
# Masked/denoising objective                                  0
# FlashAttention                                              0
# Instruction tuning                                          0
# RLHF                                                        0
# PPO                                                         0
# Chain-of-thought                                            0
# Mixed precision training                                    0
# Decoder-only architecture                                   1
# RMSNorm                                                     0
# LayerNorm                                                   1
# Pre-normalization                                           1
# Learnable position embeddings                               1
# Sinusoidal position embeddings                              0
# Relative position encodings                                 0
# Rotary position embeddings                                  0
# ALiBi positional encodings                                  0
# ReLU activation                                             0
# GELU activation                                             1
# SwiGLU activation                                           0
# Sparsely-Gated Mixture-of-Experts layer (MoE)               0
# Sparse Attention                                            1
# Linear Attention                                            0
# Multi-Query Attention                                       0
# Grouped Query Attention                                     0
# Dynamic batch size                                          1
# Dropout                                                     1
# Learning rate decay                                         1
# Learning rate warmup                                        1
# Inverse square-root learning rate decay schedule            0
# Linear learning rate decay schedule                         0
# Cosine learning rate decay schedule                         1
# Adam optimizer                                              0
# AdamW optimizer                                             1
# Adafactor optimizer                                         0
# Weight decay                                                1
# Gradient clipping                                           1
# Restart to overcome training loss spike                     0

# %%
# Make values integers
selected_systems_occurrences_df = selected_systems_occurrences_df.astype(int)

# %%
# Sum each row
total_occurrences_by_innovation = selected_systems_occurrences_df.sum(axis=1)
total_occurrences_by_innovation
# Out:
# Algorithm
# Transformer                                         10
# Kaplan et al. scaling laws                           5
# Hoffmann et al. scaling laws                         3
# Causal objective                                    10
# Masked/denoising objective                           1
# FlashAttention                                       2
# Instruction tuning                                   2
# RLHF                                                 1
# PPO                                                  1
# Chain-of-thought                                     1
# Mixed precision training                             2
# Decoder-only architecture                            7
# RMSNorm                                              4
# LayerNorm                                            6
# Pre-normalization                                    9
# Learnable position embeddings                        4
# Sinusoidal position embeddings                       1
# Relative position encodings                          2
# Rotary position embeddings                           3
# ALiBi positional encodings                           0
# ReLU activation                                      2
# GELU activation                                      5
# SwiGLU activation                                    3
# Sparsely-Gated Mixture-of-Experts layer (MoE)        0
# Sparse Attention                                     2
# Linear Attention                                     0
# Multi-Query Attention                                2
# Grouped Query Attention                              1
# Dynamic batch size                                   6
# Dropout                                              5
# Learning rate decay                                 10
# Learning rate warmup                                 9
# Inverse square-root learning rate decay schedule     1
# Linear learning rate decay schedule                  1
# Cosine learning rate decay schedule                  8
# Adam optimizer                                       3
# AdamW optimizer                                      6
# Adafactor optimizer                                  1
# Weight decay                                        10
# Gradient clipping                                   10
# Restart to overcome training loss spike              2
# dtype: int64

# %%
len(origins_df[origins_df['Algorithm'] == 'GELU'])
# Out:
# 0

# %%
institution_key_algorithm_occurrences = defaultdict(dict)
for innovation, occurrence_count in total_occurrences_by_innovation.items():
    if occurrence_count == 0:
        continue
    print(innovation)
    matching_origin = origins_df[origins_df['Algorithm'] == innovation]
    if len(matching_origin) == 0:
        continue
    origin_row_number = matching_origin.index[0]
    origin_affiliations = origins_df.loc[origin_row_number]['Origin affiliations']
    origin_affiliations = [affiliation.strip() for affiliation in origin_affiliations.split(';')]
    print(origin_affiliations)
    for affiliation in origin_affiliations:
        alias = institution_aliases.get(affiliation)
        print(alias)
        if alias is not None:
            institution_key_algorithm_occurrences[innovation][alias] = occurrence_count
        else:
            print(f'No alias for {affiliation}')
    print(institution_key_algorithm_occurrences)
    print()

institution_key_algorithm_occurrences
# Out:
# Transformer
# ['Google Brain', 'Google Research', 'University of Toronto']
# Google
# Google
# None
# No alias for University of Toronto
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}})
#
# Kaplan et al. scaling laws
# ['Johns Hopkins University', 'OpenAI']
# None
# No alias for Johns Hopkins University
# OpenAI
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}})
#
# Hoffmann et al. scaling laws
# ['Google DeepMind']
# DeepMind
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}})
#
# Causal objective
# ['OpenAI']
# OpenAI
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}})
#
# Masked/denoising objective
# ['Google']
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}})
#
# FlashAttention
# ['Stanford University', 'University at Buffalo, SUNY']
# None
# No alias for Stanford University
# None
# No alias for University at Buffalo, SUNY
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}})
#
# Instruction tuning
# ['OpenAI']
# OpenAI
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}})
#
# RLHF
# ['OpenAI', 'DeepMind']
# OpenAI
# DeepMind
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}})
#
# PPO
# ['OpenAI']
# OpenAI
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}})
#
# Chain-of-thought
# ['Google Brain']
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}})
#
# Mixed precision training
# ['Baidu Research', 'NVIDIA']
# Baidu
# NVIDIA
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}})
#
# Decoder-only architecture
# ['Google Brain']
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}})
#
# RMSNorm
# ['University of Edinburgh', 'University of Zurich']
# None
# No alias for University of Edinburgh
# None
# No alias for University of Zurich
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}})
#
# LayerNorm
# ['University of Toronto', 'Google']
# None
# No alias for University of Toronto
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}})
#
# Pre-normalization
# ['Facebook AI Research']
# Meta
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}})
#
# Learnable position embeddings
# ['Facebook AI Research']
# Meta
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}})
#
# Sinusoidal position embeddings
# ['Google Brain', 'Google Research', 'University of Toronto']
# Google
# Google
# None
# No alias for University of Toronto
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}})
#
# Relative position encodings
# ['Carnegie Mellon University', 'Google Brain']
# None
# No alias for Carnegie Mellon University
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}})
#
# Rotary position embeddings
# ['Zhuiyi Technology Co., Ltd.']
# Zhuiyi
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}})
#
# ReLU activation
# ['University of Toronto']
# None
# No alias for University of Toronto
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}})
#
# GELU activation
# ['University of Chicago', 'Toyota Technological Institute at Chicago']
# None
# No alias for University of Chicago
# None
# No alias for Toyota Technological Institute at Chicago
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}})
#
# SwiGLU activation
# ['Google']
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}})
#
# Sparse Attention
# ['OpenAI']
# OpenAI
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}, 'Sparse Attention': {'OpenAI': 2}})
#
# Multi-Query Attention
# ['Google']
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}, 'Sparse Attention': {'OpenAI': 2}, 'Multi-Query Attention': {'Google': 2}})
#
# Grouped Query Attention
# ['Google Research']
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}, 'Sparse Attention': {'OpenAI': 2}, 'Multi-Query Attention': {'Google': 2}, 'Grouped Query Attention': {'Google': 1}})
#
# Dynamic batch size
# ['Google Brain']
# Google
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}, 'Sparse Attention': {'OpenAI': 2}, 'Multi-Query Attention': {'Google': 2}, 'Grouped Query Attention': {'Google': 1}, 'Dynamic batch size': {'Google': 6}})
#
# Dropout
# Learning rate decay
# Learning rate warmup
# Inverse square-root learning rate decay schedule
# Linear learning rate decay schedule
# Cosine learning rate decay schedule
# Adam optimizer
# ['University of Amsterdam', 'University of Toronto']
# None
# No alias for University of Amsterdam
# None
# No alias for University of Toronto
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}, 'Sparse Attention': {'OpenAI': 2}, 'Multi-Query Attention': {'Google': 2}, 'Grouped Query Attention': {'Google': 1}, 'Dynamic batch size': {'Google': 6}})
#
# AdamW optimizer
# ['University of Freiburg']
# None
# No alias for University of Freiburg
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}, 'Sparse Attention': {'OpenAI': 2}, 'Multi-Query Attention': {'Google': 2}, 'Grouped Query Attention': {'Google': 1}, 'Dynamic batch size': {'Google': 6}})
#
# Adafactor optimizer
# Weight decay
# Gradient clipping
# ['University of Montreal', 'Brno University']
# None
# No alias for University of Montreal
# None
# No alias for Brno University
# defaultdict(<class 'dict'>, {'Transformer': {'Google': 10}, 'Kaplan et al. scaling laws': {'OpenAI': 5}, 'Hoffmann et al. scaling laws': {'DeepMind': 3}, 'Causal objective': {'OpenAI': 10}, 'Masked/denoising objective': {'Google': 1}, 'Instruction tuning': {'OpenAI': 2}, 'RLHF': {'OpenAI': 1, 'DeepMind': 1}, 'PPO': {'OpenAI': 1}, 'Chain-of-thought': {'Google': 1}, 'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2}, 'Decoder-only architecture': {'Google': 7}, 'LayerNorm': {'Google': 6}, 'Pre-normalization': {'Meta': 9}, 'Learnable position embeddings': {'Meta': 4}, 'Sinusoidal position embeddings': {'Google': 1}, 'Relative position encodings': {'Google': 2}, 'Rotary position embeddings': {'Zhuiyi': 3}, 'SwiGLU activation': {'Google': 3}, 'Sparse Attention': {'OpenAI': 2}, 'Multi-Query Attention': {'Google': 2}, 'Grouped Query Attention': {'Google': 1}, 'Dynamic batch size': {'Google': 6}})
#
# Restart to overcome training loss spike
# defaultdict(dict,
#             {'Transformer': {'Google': 10},
#              'Kaplan et al. scaling laws': {'OpenAI': 5},
#              'Hoffmann et al. scaling laws': {'DeepMind': 3},
#              'Causal objective': {'OpenAI': 10},
#              'Masked/denoising objective': {'Google': 1},
#              'Instruction tuning': {'OpenAI': 2},
#              'RLHF': {'OpenAI': 1, 'DeepMind': 1},
#              'PPO': {'OpenAI': 1},
#              'Chain-of-thought': {'Google': 1},
#              'Mixed precision training': {'Baidu': 2, 'NVIDIA': 2},
#              'Decoder-only architecture': {'Google': 7},
#              'LayerNorm': {'Google': 6},
#              'Pre-normalization': {'Meta': 9},
#              'Learnable position embeddings': {'Meta': 4},
#              'Sinusoidal position embeddings': {'Google': 1},
#              'Relative position encodings': {'Google': 2},
#              'Rotary position embeddings': {'Zhuiyi': 3},
#              'SwiGLU activation': {'Google': 3},
#              'Sparse Attention': {'OpenAI': 2},
#              'Multi-Query Attention': {'Google': 2},
#              'Grouped Query Attention': {'Google': 1},
#              'Dynamic batch size': {'Google': 6}})

# %%
# Generate the stacked bar chart
fig = go.Figure()

annotations = []
company_count_stack = defaultdict(int)

# Add bar traces
for innovation, company_counts in sorted(institution_key_algorithm_occurrences.items(), key=lambda x: min(x[1].values()), reverse=True):
    y_values = list(company_counts.values())
    x_values = list(company_counts.keys())
    fig.add_trace(go.Bar(name=innovation, x=x_values, y=y_values, marker=dict(color='blue', opacity=0.6)))

    for x, y in zip(x_values, y_values):
        # if innovation in ['Transformer']:
        start_y = company_count_stack[x]
        end_y = start_y + y
        middle_y = (start_y + end_y) / 2
        if y > 5:  # Choose a threshold to decide if the segment is too short for text
            annotations.append(dict(x=x, y=middle_y, text=innovation, showarrow=False, font=dict(size=6)))
        company_count_stack[x] += y

## Plot layout
fig.update_layout(
    barmode='stack',
    xaxis={'categoryorder':'total descending'},
    title='Occurrence of innovations in the top 10 largest LMs',
    xaxis_title='Company responsible for innovation',
    yaxis_title='Number of occurrences',
    showlegend=False,
    # annotations=annotations,
    autosize=False,
    width=400,
    height=300,
    title_x=0.5,
    font=dict(size=10),
    margin=dict(l=20, r=20, t=30, b=20),
)

## Save plot
save_plot(fig, result_file_location, 'key_innovations_occurrence')

# Show the figure
fig.show()

# %% [markdown]
# # Count occurrence of innovations by citations

# %% [markdown]
# Create ID => affiliations mapping

# %%
origin_affiliation = {}
for i, row in origins_df.iterrows():
    title = row['Origin title']
    search_title = title.replace(',', '')
    affiliations = row['Origin affiliations']
    affiliations = [affiliation.strip() for affiliation in affiliations.split(';')]
    print(title)

    search_results = Works().search_filter(title=search_title).get()
    if len(search_results) > 0:
        for result in search_results:
            if result['title'].lower() == title.lower():
                print("Matched title: ", result['title'])
                origin_affiliation[result['id']] = affiliations

        # top_result = search_results[0]
        # print("Top result: ", top_result['title'])
        # # Check relevance of result is high enough
        # if len(search_results) > 1:
        #     print("Relevance score: ", top_result['relevance_score'])
        #     # Factor out the number of citations - we want to match on the title
        #     match_score = top_result['relevance_score'] / top_result['cited_by_count']**0.5
        #     print("Match score: ", match_score)
        #     if match_score >= 50:
        #         origin_affiliation[top_result['id']] = affiliations
        # else:
        #     origin_affiliation[top_result['id']] = affiliations
    print()
# Out:
# Attention Is All You Need
# Matched title:  Attention is All you Need
# Matched title:  Attention Is All You Need
# Matched title:  Attention Is All You Need
#
# Scaling Laws for Neural Language Models
# Matched title:  Scaling Laws for Neural Language Models
#
# Training Compute-Optimal Large Language Models
# Matched title:  Training Compute-Optimal Large Language Models
#
# Improving Language Understanding by Generative Pre-Training
#
# BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# Matched title:  BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
#
# Neural Machine Translation by Jointly Learning to Align and Translate
# Matched title:  Neural Machine Translation by Jointly Learning to Align and Translate
# Matched title:  Neural Machine Translation by Jointly Learning to Align and Translate
# Matched title:  Neural Machine Translation by Jointly Learning to Align and Translate
#
# FlashAttention: Fast and Memory-Efficient Exact Attention with IO-Awareness
#
# Training language models to follow instructions with human feedback
# Matched title:  Training language models to follow instructions with human feedback
#
# Deep Reinforcement Learning from Human Preferences
# Matched title:  Deep Reinforcement Learning from Human Preferences
# Matched title:  Deep reinforcement learning from human preferences
# Matched title:  Deep reinforcement learning from human preferences
#
# Proximal Policy Optimization Algorithms
# Matched title:  Proximal Policy Optimization Algorithms
#
# Chain-of-Thought Prompting Elicits Reasoning in Large Language Models
# Matched title:  Chain-of-Thought Prompting Elicits Reasoning in Large Language Models
#
# Mixed Precision Training
# Matched title:  Mixed Precision Training
# Matched title:  Mixed Precision Training
#
# Generating Wikipedia by Summarizing Long Sequences
# Matched title:  Generating Wikipedia by Summarizing Long Sequences
# Matched title:  Generating Wikipedia by Summarizing Long Sequences
#
# Root Mean Square Layer Normalization
# Matched title:  Root Mean Square Layer Normalization
#
# Layer Normalization
# Matched title:  Layer Normalization
#
# Adaptive Input Representations for Neural Language Modeling
# Matched title:  Adaptive Input Representations for Neural Language Modeling
# Matched title:  Adaptive Input Representations for Neural Language Modeling
#
# Convolutional Sequence to Sequence Learning
# Matched title:  Convolutional Sequence to Sequence Learning
# Matched title:  Convolutional Sequence to Sequence Learning
#
# Attention Is All You Need
# Matched title:  Attention is All you Need
# Matched title:  Attention Is All You Need
# Matched title:  Attention Is All You Need
#
# RoFormer: Enhanced Transformer with Rotary Position Embedding
# Matched title:  RoFormer: Enhanced Transformer with Rotary Position Embedding
#
# Train Short, Test Long: Attention with Linear Biases Enables Input Length Extrapolation
# Matched title:  Train Short, Test Long: Attention with Linear Biases Enables Input Length Extrapolation
#
# Rectified Linear Units Improve Restricted Boltzmann Machines
# Matched title:  Rectified Linear Units Improve Restricted Boltzmann Machines
#
# Bridging Nonlinearities and Stochastic Regularizers with Gaussian Error Linear Units
# Matched title:  Bridging Nonlinearities and Stochastic Regularizers with Gaussian Error Linear Units
#
# GLU Variants Improve Transformer
# Matched title:  GLU Variants Improve Transformer
#
# Outrageously Large Neural Networks: The Sparsely-Gated Mixture-of-Experts Layer
# Matched title:  Outrageously Large Neural Networks: The Sparsely-Gated Mixture-of-Experts Layer
# Matched title:  Outrageously Large Neural Networks: The Sparsely-Gated Mixture-of-Experts Layer
#
# Generating Long Sequences with Sparse Transformers
# Matched title:  Generating Long Sequences with Sparse Transformers
#
# Don't Decay the Learning Rate, Increase the Batch Size
# Matched title:  Don't decay the learning rate, increase the batch size
# Matched title:  Don't Decay the Learning Rate, Increase the Batch Size
#
# SGDR: Stochastic Gradient Descent with Warm Restarts
# Matched title:  SGDR: Stochastic Gradient Descent with Warm Restarts
# Matched title:  SGDR: Stochastic Gradient Descent with Warm Restarts
#
# Adam: A Method for Stochastic Optimization
# Matched title:  Adam: A Method for Stochastic Optimization
# Matched title:  Adam: A Method for Stochastic Optimization
#
# Decoupled Weight Decay Regularization
# Matched title:  Decoupled Weight Decay Regularization
#
# On the difficulty of training Recurrent Neural Networks
# Matched title:  On the difficulty of training recurrent neural networks
# Matched title:  On the difficulty of training Recurrent Neural Networks
#
# PaLM: Scaling Language Modeling with Pathways
# Matched title:  PaLM: Scaling Language Modeling with Pathways

# %%
origin_affiliation
# Out:
# {'https://openalex.org/W2963403868': ['Google Brain',
#   'Google Research',
#   'University of Toronto'],
#  'https://openalex.org/W2626778328': ['Google Brain',
#   'Google Research',
#   'University of Toronto'],
#  'https://openalex.org/W4385245566': ['Google Brain',
#   'Google Research',
#   'University of Toronto'],
#  'https://openalex.org/W3001279689': ['Johns Hopkins University', 'OpenAI'],
#  'https://openalex.org/W4225591000': ['Google DeepMind'],
#  'https://openalex.org/W2896457183': ['Google'],
#  'https://openalex.org/W2964308564': ['Jacobs University Bremen, Germany',
#   'University of Montreal'],
#  'https://openalex.org/W2133564696': ['Jacobs University Bremen, Germany',
#   'University of Montreal'],
#  'https://openalex.org/W4297734170': ['Jacobs University Bremen, Germany',
#   'University of Montreal'],
#  'https://openalex.org/W4226278401': ['OpenAI'],
#  'https://openalex.org/W2964263543': ['OpenAI', 'DeepMind'],
#  'https://openalex.org/W2626804490': ['OpenAI', 'DeepMind'],
#  'https://openalex.org/W4321392130': ['OpenAI', 'DeepMind'],
#  'https://openalex.org/W2736601468': ['OpenAI'],
#  'https://openalex.org/W4221143046': ['Google Brain'],
#  'https://openalex.org/W2763421725': ['Baidu Research', 'NVIDIA'],
#  'https://openalex.org/W2963112338': ['Baidu Research', 'NVIDIA'],
#  'https://openalex.org/W2963045354': ['Google Brain'],
#  'https://openalex.org/W2787214294': ['Google Brain'],
#  'https://openalex.org/W2970903692': ['University of Edinburgh',
#   'University of Zurich'],
#  'https://openalex.org/W3037932933': ['University of Toronto', 'Google'],
#  'https://openalex.org/W2963631907': ['Facebook AI Research'],
#  'https://openalex.org/W2894175714': ['Facebook AI Research'],
#  'https://openalex.org/W2964265128': ['Facebook AI Research'],
#  'https://openalex.org/W2613904329': ['Facebook AI Research'],
#  'https://openalex.org/W3155806510': ['Zhuiyi Technology Co., Ltd.'],
#  'https://openalex.org/W3196318247': ['University of Washington',
#   'Facebook AI Research',
#   'Allen Institute for AI'],
#  'https://openalex.org/W1665214252': ['University of Toronto'],
#  'https://openalex.org/W2462831000': ['University of Chicago',
#   'Toyota Technological Institute at Chicago'],
#  'https://openalex.org/W4301581299': ['Google'],
#  'https://openalex.org/W2952339051': ['Google Brain',
#   'Jagiellonian University'],
#  'https://openalex.org/W2581624817': ['Google Brain',
#   'Jagiellonian University'],
#  'https://openalex.org/W4323654151': ['OpenAI'],
#  'https://openalex.org/W2963702144': ['Google Brain'],
#  'https://openalex.org/W2766164908': ['Google Brain'],
#  'https://openalex.org/W2518108298': ['University of Freiburg'],
#  'https://openalex.org/W2963263347': ['University of Freiburg'],
#  'https://openalex.org/W2964121744': ['University of Amsterdam',
#   'University of Toronto'],
#  'https://openalex.org/W1522301498': ['University of Amsterdam',
#   'University of Toronto'],
#  'https://openalex.org/W2950541952': ['University of Freiburg'],
#  'https://openalex.org/W1815076433': ['University of Montreal',
#   'Brno University'],
#  'https://openalex.org/W2949190276': ['University of Montreal',
#   'Brno University'],
#  'https://openalex.org/W4224308101': ['Google Research']}

# %% [markdown]
# Now get a list of notable ML system papers

# %%
# Download dataset from the Parameters, Compute and Data Trends in ML sheet
sheet_id = '1AAIebjNsnJj_uKALHbXNfn3_YsT6sHXtCU0q7OIPuc4'
data_url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet='
notable_df = pd.read_csv(data_url + 'NOTABLE%20ML%20SYSTEMS')

# %%
notable_df.head()
# Out:
#          System         Domain                Task               Organization  \
# 0         Gen-2  Text-to-Video    Video generation                     Runway
# 1      InternLM       Language  Language modelling  Shanghai AI Lab,SenseTime
# 2     ERNIE 3.5       Language  Language modelling                      Baidu
# 3  Inflection-1       Language  Language modelling              Inflection AI
# 4       RoboCat       Robotics                 NaN     Google DeepMind,Google
#
#   Organization Categorization  \
# 0                    Industry
# 1                    Academia
# 2                    Industry
# 3                    Industry
# 4                    Industry
#
#                                              Authors Publication date  \
# 0                                                NaN       2023-12-31
# 1                                                NaN       2023-07-06
# 2                                                NaN       2023-06-27
# 3                                                NaN       2023-06-23
# 4  Konstantinos Bousmalis, Giulia Vezzani, Dushya...       2023-06-20
#
#                                            Reference  \
# 0                                                NaN
# 1                                                NaN
# 2  Introducing ERNIE 3.5: Baidu’s Knowledge-Enhan...
# 3                        Inflection-1 technical memo
# 4  RoboCat: A Self-Improving Foundation Agent for...
#
#                                                Link  Citations  ...  \
# 0                https://research.runwayml.com/gen2        0.0  ...
# 1                             https://internlm.org/        NaN  ...
# 2  http://research.baidu.com/Blog/index-view?id=185        NaN  ...
# 3     https://inflection.ai/assets/Inflection-1.pdf        NaN  ...
# 4                  https://arxiv.org/abs/2306.11706        NaN  ...
#
#                                  Training time notes       Training hardware  \
# 0                                                NaN                     NaN
# 1  Training performance for the open-source Inter...  NVIDIA A100 SXM4 80 GB
# 2                                                NaN                     NaN
# 3                                                NaN        NVIDIA H100 SXM5
# 4                                                NaN                     NaN
#
#    Approach Training compute cost (2020 USD)  Compute cost notes  \
# 0       NaN                              NaN                 NaN
# 1       NaN                              NaN                 NaN
# 2       NaN                              NaN                 NaN
# 3       NaN                              NaN                 NaN
# 4       NaN                              NaN                 NaN
#
#   Self-supervised training Compute Sponsor Categorization Epistemic status  \
# 0                      NaN                            NaN       Unverified
# 1                      NaN                            NaN      Speculative
# 2                      NaN                            NaN       Unverified
# 3                      NaN                       Industry      Speculative
# 4                      NaN                       Industry      Speculative
#
#                                             Abstract        Last Modified
# 0                                                NaN  2023-08-15 20:28:23
# 1  Pre-training a bilingual 100B Foundation model...  2023-08-15 20:04:54
# 2                                                NaN  2023-07-05 16:08:00
# 3  Large language models (LLMs) based on the Tran...  2023-06-27 15:14:23
# 4  The ability to leverage heterogeneous robotic ...  2023-08-10 15:22:11
#
# [5 rows x 33 columns]

# %%
# Ensure date column is in datetime format
notable_df['Publication date'] = pd.to_datetime(notable_df['Publication date'])

# %%
# Filter by Language domain since 2021
notable_language_df = notable_df[notable_df['Domain'] == 'Language']
notable_recent_language_df = notable_language_df[notable_df['Publication date'] >= pd.to_datetime('2021-01-01')]
notable_recent_language_df
# Out:
# /var/folders/s2/stl5t_bn7xg9vdfxxr71rzrc0000gn/T/ipykernel_20814/2291865180.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#                       System    Domain                             Task  \
# 1                   InternLM  Language               Language modelling
# 2                  ERNIE 3.5  Language               Language modelling
# 3               Inflection-1  Language               Language modelling
# 5                     PaLM 2  Language               Language modelling
# 7                LLaMA (65B)  Language               Language modelling
# 9                    ALM 1.0  Language               Language modelling
# 10                     BLOOM  Language                   Language model
# 14               AlexaTM 20B  Language               Language modelling
# 15                      NLLB  Language                      Translation
# 16            Minerva (540B)  Language  Quantitative Reasoning Problems
# 21                       UL2  Language                              NaN
# 23            Sparse all-MLP  Language                              NaN
# 26               PaLM (540B)  Language               Language modelling
# 27                Chinchilla  Language               Language modelling
# 28                     LaMDA  Language               Language modelling
# 29              GPT-NeoX-20B  Language                              NaN
# 30                 AlphaCode  Language                  Code generation
# 31               InstructGPT  Language                              NaN
# 32       data2vec (language)  Language                              NaN
# 35                      XGLM  Language                              NaN
# 38  Megatron-Turing NLG 530B  Language                              NaN
# 39                  PLATO-XL  Language               Language modelling
# 41                      FLAN  Language               Language modelling
# 42                  XLMR-XXL  Language                              NaN
# 44                    HuBERT  Language                              NaN
# 45                     Codex  Language              Code autocompletion
# 49                   ConSERT  Language               Language modelling
# 50                      PLUG  Language                              NaN
# 51          Megatron-LM (1T)  Language              Text autocompletion
# 52            Generative BST  Language                              NaN
#
#                           Organization  \
# 1            Shanghai AI Lab,SenseTime
# 2                                Baidu
# 3                        Inflection AI
# 5                               Google
# 7                              Meta AI
# 9                                 BAAI
# 10             Hugging Face,BigScience
# 14                              Amazon
# 15                             Meta AI
# 16                              Google
# 21        Google Research,Google Brain
# 23                              MetaAI
# 26                     Google Research
# 27                            DeepMind
# 28                              Google
# 29                          EleutherAI
# 30                            DeepMind
# 31                              OpenAI
# 32                              MetaAI
# 35                             Meta AI
# 38                    Microsoft,NVIDIA
# 39                               Baidu
# 41                     Google Research
# 42                Facebook AI Research
# 44                Facebook AI Research
# 45                             Open AI
# 49                                 NaN
# 50                       Alibaba Group
# 51  Stanford,Microsoft Research,NVIDIA
# 52                Facebook AI Research
#
#                           Organization Categorization  \
# 1                                            Academia
# 2                                            Industry
# 3                                            Industry
# 5                                            Industry
# 7                                            Industry
# 9                                            Academia
# 10                                Research Collective
# 14                                           Industry
# 15                                           Industry
# 16                                           Industry
# 21                                           Industry
# 23  Industry - Academia Collaboration (Industry le...
# 26                                           Industry
# 27                                           Industry
# 28                                           Industry
# 29                                Research Collective
# 30                                           Industry
# 31                                           Industry
# 32                                           Industry
# 35                                           Industry
# 38                                           Industry
# 39                                           Industry
# 41                                           Industry
# 42                                           Industry
# 44                                           Industry
# 45                                           Industry
# 49                                           Academia
# 50                                           Industry
# 51  Industry - Academia Collaboration (Industry le...
# 52                                           Industry
#
#                                               Authors Publication date  \
# 1                                                 NaN       2023-07-06
# 2                                                 NaN       2023-06-27
# 3                                                 NaN       2023-06-23
# 5   Andrew M. Dai, David R. So, Dmitry Lepikhin, J...       2023-05-10
# 7   Hugo Touvron, Thibaut Lavril, Gautier Izacard,...       2023-02-24
# 9                                                 NaN       2022-11-28
# 10  Margaret Mitchell, Giada Pistilli, Yacine Jern...       2022-11-08
# 14  Saleh Soltan, Shankar Ananthakrishnan, Jack Fi...       2022-08-02
# 15  Marta R. Costa-jussà, James Cross, Onur Çelebi...       2022-07-06
# 16  Aitor Lewkowycz, Anders Andreassen, David Doha...       2022-06-29
# 21  Yi Tay, Mostafa Dehghani, Vinh Q. Tran, Xavier...       2022-05-10
# 23  Ping Yu, Mikel Artexte, Myle Ott, Sam Shleifer...       2022-04-14
# 26  Aakanksha Chowdhery, Sharan Narang, Jacob Devl...       2022-04-04
# 27  Jordan Hoffmann, Sebastian Borgeaud, Arthur Me...       2022-03-29
# 28  Romal Thoppilan, Daniel De Freitas, Jamie Hall...       2022-02-10
# 29  Sid Black, Stella Biderman, Eric Hallahan, Que...       2022-02-09
# 30                                The Alpha Code team       2022-02-02
# 31  Long Ouyang, Pamela Mishkin, Jeff Wu, Xu Jiang...       2022-01-27
# 32  Alexei Baevski,  Wei-Ning Hsu,  Qiantong Xu , ...       2022-01-20
# 35  Xi Victoria Lin, Todor Mihaylov, Mikel Artetxe...       2021-12-20
# 38                            Ali Alvi, Paresh Kharya       2021-10-11
# 39  Siqi Bao, Huang He, Fan Wang, Hua Wu, Haifeng ...       2021-09-20
# 41  Jason Wei, Maarten Bosma, Vincent Y. Zhao, Kel...       2021-09-03
# 42  Naman Goyal, Jingfei Du, Myle Ott, Giri Ananth...       2021-08-17
# 44  Wei-Ning Hsu, Benjamin Bolte, Yao-Hung Hubert ...       2021-07-27
# 45  Mark Chen , Jerry Tworek, Heewoo Jun, Qiming Y...       2021-07-07
# 49  Yuanmeng Yan, Rumei Li, Sirui Wang, Fuzheng Zh...       2021-05-25
# 50                                                NaN       2021-04-19
# 51  Deepak Narayanan, Mohammad Shoeybi, Jared Casp...       2021-04-09
# 52  Stephen Roller, Emily Dinan, Naman Goyal, Da J...       2021-03-05
#
#                                             Reference  \
# 1                                                 NaN
# 2   Introducing ERNIE 3.5: Baidu’s Knowledge-Enhan...
# 3                         Inflection-1 technical memo
# 5                             PaLM 2 Technical Report
# 7   LLaMA: Open and Efficient Foundation Language ...
# 9                                             ALM 1.0
# 10  BigScience Large Open-science Open-access Mult...
# 14  AlexaTM 20B: Few-Shot Learning Using a Large-S...
# 15  No Language Left Behind: Scaling Human-Centere...
# 16  Solving Quantitative Reasoning Problems with L...
# 21               Unifying Language Learning Paradigms
# 23    Efficient Language Modeling with Sparse all-MLP
# 26      PaLM: Scaling Language Modeling with Pathways
# 27     Training Compute-Optimal Large Language Models
# 28     LaMDA: Language Models for Dialog Applications
# 29                          Announcing GPT- NeoX- 20B
# 30   Competition-Level Code Generation with AlphaCode
# 31  Training language models to follow instruction...
# 32  Data2vec: A General Framework for Self-supervi...
# 35  Few-shot Learning with Multilingual Language M...
# 38  Using DeepSpeed and Megatron to Train Megatron...
# 39  PLATO-XL: Exploring the Large-scale Pre-traini...
# 41   FINETUNED LANGUAGE MODELS ARE ZERO-SHOT LEARNERS
# 42  Larger-Scale Transformers for Multilingual Mas...
# 44  HuBERT: Self-Supervised Speech Representation ...
# 45   Evaluating Large Language Models Trained on Code
# 49  ConSERT: A contrastive framework for self-supe...
# 50                                                NaN
# 51  Efficient Large-Scale Language Model Training ...
# 52        Recipes for building an open-domain chatbot
#
#                                                  Link  Citations  ...  \
# 1                               https://internlm.org/        NaN  ...
# 2    http://research.baidu.com/Blog/index-view?id=185        NaN  ...
# 3       https://inflection.ai/assets/Inflection-1.pdf        NaN  ...
# 5   https://ai.google/static/documents/palm2techre...        NaN  ...
# 7                    https://arxiv.org/abs/2302.13971      702.0  ...
# 9   https://github.com/FlagAI-Open/FlagAI/blob/mas...        NaN  ...
# 10            https://huggingface.co/bigscience/bloom        NaN  ...
# 14                   https://arxiv.org/abs/2208.01448        NaN  ...
# 15  https://research.facebook.com/publications/no-...       19.0  ...
# 16                   https://arxiv.org/abs/2206.14858        NaN  ...
# 21                 https://arxiv.org/abs/2205.05131v1       19.0  ...
# 23                   https://arxiv.org/abs/2203.06850        0.0  ...
# 26                   https://arxiv.org/abs/2204.02311      228.0  ...
# 27                   https://arxiv.org/abs/2203.15556        NaN  ...
# 28                   https://arxiv.org/abs/2201.08239        NaN  ...
# 29           https://blog.eleuther.ai/announcing-20b/       45.0  ...
# 30               https://arxiv.org/pdf/2203.07814.pdf       75.0  ...
# 31  https://cdn.openai.com/papers/Training_languag...      149.0  ...
# 32  https://ai.facebook.com/research/data2vec-a-ge...      180.0  ...
# 35               https://arxiv.org/pdf/2112.10668.pdf       12.0  ...
# 38  https://www.microsoft.com/en-us/research/blog/...      281.0  ...
# 39                   https://arxiv.org/abs/2109.09519        NaN  ...
# 41               https://arxiv.org/pdf/2109.01652.pdf      240.0  ...
# 42                   https://arxiv.org/abs/2105.00572       18.0  ...
# 44                   https://arxiv.org/abs/2106.07447      458.0  ...
# 45              https://openai.com/blog/openai-codex/      301.0  ...
# 49                   https://arxiv.org/abs/2105.11741        NaN  ...
# 50  https://mp.weixin.qq.com/s/DAQomIkDa52Sef-ruyH5qg        NaN  ...
# 51                   https://arxiv.org/abs/2104.04473      217.0  ...
# 52                   https://arxiv.org/abs/2004.13637      503.0  ...
#
#                                   Training time notes  \
# 1   Training performance for the open-source Inter...
# 2                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 7   "When training a 65B-parameter model, our code...
# 9                                                 NaN
# 10                                                NaN
# 14  See p.5 of the paper: "We trained AlexaTM 20B ...
# 15                                                NaN
# 16                                                NaN
# 21                                                NaN
# 23                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 35                                                NaN
# 38                                                NaN
# 39                                                NaN
# 41                                                NaN
# 42                                                NaN
# 44                                                NaN
# 45                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                            84 days
# 52                                                NaN
#
#                 Training hardware                  Approach  \
# 1          NVIDIA A100 SXM4 80 GB                       NaN
# 2                             NaN                       NaN
# 3                NVIDIA H100 SXM5                       NaN
# 5                             NaN                       NaN
# 7                     NVIDIA A100                Supervised
# 9                             NaN                       NaN
# 10                            NaN  Self-supervised learning
# 14                            NaN                       NaN
# 15                            NaN                       NaN
# 16                            NaN  Self-supervised learning
# 21                            NaN                       NaN
# 23                            NaN  Self-supervised learning
# 26                            NaN  Self-supervised learning
# 27                            NaN                       NaN
# 28                            NaN                       NaN
# 29                            NaN                       NaN
# 30                            NaN                       NaN
# 31                            NaN                       NaN
# 32                            NaN                       NaN
# 35                            NaN                       NaN
# 38                            NaN  Self-supervised learning
# 39   NVIDIA Tesla V100 DGXS 32 GB                       NaN
# 41                            NaN  Self-supervised learning
# 42                            NaN                       NaN
# 44                            NaN                       NaN
# 45                            NaN                       NaN
# 49  NVIDIA Tesla V100S PCIe 32 GB                       NaN
# 50                            NaN                       NaN
# 51                    NVIDIA A100  Self-supervised learning
# 52                            NaN                       NaN
#
#    Training compute cost (2020 USD)  \
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 5                               NaN
# 7                        1179384.75
# 9                               NaN
# 10                              NaN
# 14                              NaN
# 15                         39175.64
# 16                       3267257.75
# 21                              NaN
# 23                           320.00
# 26                       3232806.53
# 27                        753491.58
# 28                        484957.20
# 29                        202407.46
# 30                              NaN
# 31                              NaN
# 32                              NaN
# 35                              NaN
# 38                       3046994.09
# 39                              NaN
# 41                              NaN
# 42                              NaN
# 44                          8632.11
# 45                              NaN
# 49                              NaN
# 50                              NaN
# 51                              NaN
# 52                              NaN
#
#                                    Compute cost notes  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 5   PaLM 2 was trained on TPU v4 according to the ...
# 7   1023384 processor-hours on A100 GPUs. May 2023...
# 9                                                 NaN
# 10                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 21                                                NaN
# 23                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 35                                                NaN
# 38                                                NaN
# 39                                                NaN
# 41                                                NaN
# 42                                                NaN
# 44                                                NaN
# 45                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
#
#    Self-supervised training Compute Sponsor Categorization Epistemic status  \
# 1                       NaN                            NaN      Speculative
# 2                       NaN                            NaN       Unverified
# 3                       NaN                       Industry      Speculative
# 5                       NaN                       Industry              NaN
# 7                       NaN                       Industry           Likely
# 9                       NaN                            NaN      Speculative
# 10                      Yes                            NaN              NaN
# 14                      NaN                       Industry              NaN
# 15                      Yes                       Industry              NaN
# 16                      Yes                       Industry              NaN
# 21                      NaN                       Industry              NaN
# 23                      Yes                       Industry              NaN
# 26                      Yes                       Industry              NaN
# 27                      Yes                       Industry              NaN
# 28                      Yes                       Industry              NaN
# 29                      Yes                       Industry              NaN
# 30                      Yes                       Industry              NaN
# 31                      Yes                       Industry              NaN
# 32                      Yes                       Industry              NaN
# 35                      Yes                       Industry              NaN
# 38                      Yes                       Industry              NaN
# 39                      NaN                       Industry           Likely
# 41                      NaN                       Industry              NaN
# 42                      NaN                       Industry              NaN
# 44                      Yes                       Industry              NaN
# 45                      Yes                       Industry              NaN
# 49                      NaN                            NaN           Likely
# 50                      NaN                            NaN              NaN
# 51                      Yes                       Industry           Likely
# 52                      NaN                       Industry              NaN
#
#                                              Abstract        Last Modified
# 1   Pre-training a bilingual 100B Foundation model...  2023-08-15 20:04:54
# 2                                                 NaN  2023-07-05 16:08:00
# 3   Large language models (LLMs) based on the Tran...  2023-06-27 15:14:23
# 5   We introduce PaLM 2, a new state-of-the-art la...  2023-08-10 15:21:27
# 7   We introduce LLaMA, a collection of foundation...  2023-07-28 16:26:34
# 9                                                 NaN  2023-08-15 17:42:35
# 10                                                NaN  2023-08-04 13:13:07
# 14  In this work, we demonstrate that multilingual...  2023-06-08 00:39:43
# 15  Driven by the goal of eradicating language bar...  2023-05-29 20:51:04
# 16  Language models have achieved remarkable perfo...  2023-08-10 15:22:32
# 21                                                NaN  2023-08-11 19:08:43
# 23  All-MLP architectures have attracted increasin...  2023-08-01 10:07:00
# 26  Large language models have been shown to achie...  2023-08-11 19:08:06
# 27  We investigate the optimal model size and numb...  2023-05-29 20:51:04
# 28  We present LaMDA: Language Models for Dialog A...  2023-05-30 18:54:45
# 29                                                NaN  2023-05-29 20:51:04
# 30                                                NaN  2023-05-29 20:51:04
# 31                                                NaN  2023-05-29 20:51:04
# 32                                                NaN  2023-05-29 20:51:04
# 35                                                NaN  2023-05-29 20:51:04
# 38  Pretrained general-purpose language models can...  2023-08-15 14:40:57
# 39  To explore the limit of dialogue generation pr...  2023-06-09 15:44:34
# 41  This paper explores a simple method for improv...  2023-08-11 19:07:14
# 42                                                NaN  2023-06-08 00:39:43
# 44  Self-supervised approaches for speech represen...  2023-05-29 20:51:04
# 45                                                NaN  2023-05-29 20:51:04
# 49  Learning high-quality sentence representations...  2023-06-21 19:04:47
# 50                                                NaN  2023-06-08 00:39:43
# 51  Large language models have led to state-of-the...  2023-08-15 17:12:01
# 52                                                NaN  2023-06-08 00:39:43
#
# [30 rows x 33 columns]

# %%
for i, row in notable_recent_language_df.iterrows():
    print(row['System'], row['Link'])
# Out:
# InternLM https://internlm.org/
# ERNIE 3.5 http://research.baidu.com/Blog/index-view?id=185
# Inflection-1 https://inflection.ai/assets/Inflection-1.pdf
# PaLM 2 https://ai.google/static/documents/palm2techreport.pdf
# LLaMA (65B) https://arxiv.org/abs/2302.13971
# ALM 1.0 https://github.com/FlagAI-Open/FlagAI/blob/master/examples/ALM/README.md
# BLOOM https://huggingface.co/bigscience/bloom
# AlexaTM 20B https://arxiv.org/abs/2208.01448
# NLLB https://research.facebook.com/publications/no-language-left-behind/?utm_source=twitter&utm_medium=organic_social&utm_campaign=nllb&utm_content=os-artifacts
# Minerva (540B) https://arxiv.org/abs/2206.14858
# UL2 https://arxiv.org/abs/2205.05131v1
# Sparse all-MLP https://arxiv.org/abs/2203.06850
# PaLM (540B) https://arxiv.org/abs/2204.02311
# Chinchilla https://arxiv.org/abs/2203.15556
# LaMDA https://arxiv.org/abs/2201.08239
# GPT-NeoX-20B https://blog.eleuther.ai/announcing-20b/
# AlphaCode https://arxiv.org/pdf/2203.07814.pdf
# InstructGPT https://cdn.openai.com/papers/Training_language_models_to_follow_instructions_with_human_feedback.pdf
# data2vec (language) https://ai.facebook.com/research/data2vec-a-general-framework-for-self-supervised-learning-in-speech-vision-and-language/
# XGLM https://arxiv.org/pdf/2112.10668.pdf
# Megatron-Turing NLG 530B https://www.microsoft.com/en-us/research/blog/using-deepspeed-and-megatron-to-train-megatron-turing-nlg-530b-the-worlds-largest-and-most-powerful-generative-language-model/
# PLATO-XL https://arxiv.org/abs/2109.09519
# FLAN https://arxiv.org/pdf/2109.01652.pdf
# XLMR-XXL https://arxiv.org/abs/2105.00572
# HuBERT https://arxiv.org/abs/2106.07447
# Codex https://openai.com/blog/openai-codex/
# ConSERT https://arxiv.org/abs/2105.11741
# PLUG https://mp.weixin.qq.com/s/DAQomIkDa52Sef-ruyH5qg
# Megatron-LM (1T) https://arxiv.org/abs/2104.04473
# Generative BST https://arxiv.org/abs/2004.13637

# %%
notable_recent_language_df = notable_recent_language_df.dropna(subset=['Reference'])

# %%
notable_recent_language_df
# Out:
#                       System    Domain                             Task  \
# 2                  ERNIE 3.5  Language               Language modelling
# 3               Inflection-1  Language               Language modelling
# 5                     PaLM 2  Language               Language modelling
# 7                LLaMA (65B)  Language               Language modelling
# 9                    ALM 1.0  Language               Language modelling
# 10                     BLOOM  Language                   Language model
# 14               AlexaTM 20B  Language               Language modelling
# 15                      NLLB  Language                      Translation
# 16            Minerva (540B)  Language  Quantitative Reasoning Problems
# 21                       UL2  Language                              NaN
# 23            Sparse all-MLP  Language                              NaN
# 26               PaLM (540B)  Language               Language modelling
# 27                Chinchilla  Language               Language modelling
# 28                     LaMDA  Language               Language modelling
# 29              GPT-NeoX-20B  Language                              NaN
# 30                 AlphaCode  Language                  Code generation
# 31               InstructGPT  Language                              NaN
# 32       data2vec (language)  Language                              NaN
# 35                      XGLM  Language                              NaN
# 38  Megatron-Turing NLG 530B  Language                              NaN
# 39                  PLATO-XL  Language               Language modelling
# 41                      FLAN  Language               Language modelling
# 42                  XLMR-XXL  Language                              NaN
# 44                    HuBERT  Language                              NaN
# 45                     Codex  Language              Code autocompletion
# 49                   ConSERT  Language               Language modelling
# 51          Megatron-LM (1T)  Language              Text autocompletion
# 52            Generative BST  Language                              NaN
#
#                           Organization  \
# 2                                Baidu
# 3                        Inflection AI
# 5                               Google
# 7                              Meta AI
# 9                                 BAAI
# 10             Hugging Face,BigScience
# 14                              Amazon
# 15                             Meta AI
# 16                              Google
# 21        Google Research,Google Brain
# 23                              MetaAI
# 26                     Google Research
# 27                            DeepMind
# 28                              Google
# 29                          EleutherAI
# 30                            DeepMind
# 31                              OpenAI
# 32                              MetaAI
# 35                             Meta AI
# 38                    Microsoft,NVIDIA
# 39                               Baidu
# 41                     Google Research
# 42                Facebook AI Research
# 44                Facebook AI Research
# 45                             Open AI
# 49                                 NaN
# 51  Stanford,Microsoft Research,NVIDIA
# 52                Facebook AI Research
#
#                           Organization Categorization  \
# 2                                            Industry
# 3                                            Industry
# 5                                            Industry
# 7                                            Industry
# 9                                            Academia
# 10                                Research Collective
# 14                                           Industry
# 15                                           Industry
# 16                                           Industry
# 21                                           Industry
# 23  Industry - Academia Collaboration (Industry le...
# 26                                           Industry
# 27                                           Industry
# 28                                           Industry
# 29                                Research Collective
# 30                                           Industry
# 31                                           Industry
# 32                                           Industry
# 35                                           Industry
# 38                                           Industry
# 39                                           Industry
# 41                                           Industry
# 42                                           Industry
# 44                                           Industry
# 45                                           Industry
# 49                                           Academia
# 51  Industry - Academia Collaboration (Industry le...
# 52                                           Industry
#
#                                               Authors Publication date  \
# 2                                                 NaN       2023-06-27
# 3                                                 NaN       2023-06-23
# 5   Andrew M. Dai, David R. So, Dmitry Lepikhin, J...       2023-05-10
# 7   Hugo Touvron, Thibaut Lavril, Gautier Izacard,...       2023-02-24
# 9                                                 NaN       2022-11-28
# 10  Margaret Mitchell, Giada Pistilli, Yacine Jern...       2022-11-08
# 14  Saleh Soltan, Shankar Ananthakrishnan, Jack Fi...       2022-08-02
# 15  Marta R. Costa-jussà, James Cross, Onur Çelebi...       2022-07-06
# 16  Aitor Lewkowycz, Anders Andreassen, David Doha...       2022-06-29
# 21  Yi Tay, Mostafa Dehghani, Vinh Q. Tran, Xavier...       2022-05-10
# 23  Ping Yu, Mikel Artexte, Myle Ott, Sam Shleifer...       2022-04-14
# 26  Aakanksha Chowdhery, Sharan Narang, Jacob Devl...       2022-04-04
# 27  Jordan Hoffmann, Sebastian Borgeaud, Arthur Me...       2022-03-29
# 28  Romal Thoppilan, Daniel De Freitas, Jamie Hall...       2022-02-10
# 29  Sid Black, Stella Biderman, Eric Hallahan, Que...       2022-02-09
# 30                                The Alpha Code team       2022-02-02
# 31  Long Ouyang, Pamela Mishkin, Jeff Wu, Xu Jiang...       2022-01-27
# 32  Alexei Baevski,  Wei-Ning Hsu,  Qiantong Xu , ...       2022-01-20
# 35  Xi Victoria Lin, Todor Mihaylov, Mikel Artetxe...       2021-12-20
# 38                            Ali Alvi, Paresh Kharya       2021-10-11
# 39  Siqi Bao, Huang He, Fan Wang, Hua Wu, Haifeng ...       2021-09-20
# 41  Jason Wei, Maarten Bosma, Vincent Y. Zhao, Kel...       2021-09-03
# 42  Naman Goyal, Jingfei Du, Myle Ott, Giri Ananth...       2021-08-17
# 44  Wei-Ning Hsu, Benjamin Bolte, Yao-Hung Hubert ...       2021-07-27
# 45  Mark Chen , Jerry Tworek, Heewoo Jun, Qiming Y...       2021-07-07
# 49  Yuanmeng Yan, Rumei Li, Sirui Wang, Fuzheng Zh...       2021-05-25
# 51  Deepak Narayanan, Mohammad Shoeybi, Jared Casp...       2021-04-09
# 52  Stephen Roller, Emily Dinan, Naman Goyal, Da J...       2021-03-05
#
#                                             Reference  \
# 2   Introducing ERNIE 3.5: Baidu’s Knowledge-Enhan...
# 3                         Inflection-1 technical memo
# 5                             PaLM 2 Technical Report
# 7   LLaMA: Open and Efficient Foundation Language ...
# 9                                             ALM 1.0
# 10  BigScience Large Open-science Open-access Mult...
# 14  AlexaTM 20B: Few-Shot Learning Using a Large-S...
# 15  No Language Left Behind: Scaling Human-Centere...
# 16  Solving Quantitative Reasoning Problems with L...
# 21               Unifying Language Learning Paradigms
# 23    Efficient Language Modeling with Sparse all-MLP
# 26      PaLM: Scaling Language Modeling with Pathways
# 27     Training Compute-Optimal Large Language Models
# 28     LaMDA: Language Models for Dialog Applications
# 29                          Announcing GPT- NeoX- 20B
# 30   Competition-Level Code Generation with AlphaCode
# 31  Training language models to follow instruction...
# 32  Data2vec: A General Framework for Self-supervi...
# 35  Few-shot Learning with Multilingual Language M...
# 38  Using DeepSpeed and Megatron to Train Megatron...
# 39  PLATO-XL: Exploring the Large-scale Pre-traini...
# 41   FINETUNED LANGUAGE MODELS ARE ZERO-SHOT LEARNERS
# 42  Larger-Scale Transformers for Multilingual Mas...
# 44  HuBERT: Self-Supervised Speech Representation ...
# 45   Evaluating Large Language Models Trained on Code
# 49  ConSERT: A contrastive framework for self-supe...
# 51  Efficient Large-Scale Language Model Training ...
# 52        Recipes for building an open-domain chatbot
#
#                                                  Link  Citations  ...  \
# 2    http://research.baidu.com/Blog/index-view?id=185        NaN  ...
# 3       https://inflection.ai/assets/Inflection-1.pdf        NaN  ...
# 5   https://ai.google/static/documents/palm2techre...        NaN  ...
# 7                    https://arxiv.org/abs/2302.13971      702.0  ...
# 9   https://github.com/FlagAI-Open/FlagAI/blob/mas...        NaN  ...
# 10            https://huggingface.co/bigscience/bloom        NaN  ...
# 14                   https://arxiv.org/abs/2208.01448        NaN  ...
# 15  https://research.facebook.com/publications/no-...       19.0  ...
# 16                   https://arxiv.org/abs/2206.14858        NaN  ...
# 21                 https://arxiv.org/abs/2205.05131v1       19.0  ...
# 23                   https://arxiv.org/abs/2203.06850        0.0  ...
# 26                   https://arxiv.org/abs/2204.02311      228.0  ...
# 27                   https://arxiv.org/abs/2203.15556        NaN  ...
# 28                   https://arxiv.org/abs/2201.08239        NaN  ...
# 29           https://blog.eleuther.ai/announcing-20b/       45.0  ...
# 30               https://arxiv.org/pdf/2203.07814.pdf       75.0  ...
# 31  https://cdn.openai.com/papers/Training_languag...      149.0  ...
# 32  https://ai.facebook.com/research/data2vec-a-ge...      180.0  ...
# 35               https://arxiv.org/pdf/2112.10668.pdf       12.0  ...
# 38  https://www.microsoft.com/en-us/research/blog/...      281.0  ...
# 39                   https://arxiv.org/abs/2109.09519        NaN  ...
# 41               https://arxiv.org/pdf/2109.01652.pdf      240.0  ...
# 42                   https://arxiv.org/abs/2105.00572       18.0  ...
# 44                   https://arxiv.org/abs/2106.07447      458.0  ...
# 45              https://openai.com/blog/openai-codex/      301.0  ...
# 49                   https://arxiv.org/abs/2105.11741        NaN  ...
# 51                   https://arxiv.org/abs/2104.04473      217.0  ...
# 52                   https://arxiv.org/abs/2004.13637      503.0  ...
#
#                                   Training time notes  \
# 2                                                 NaN
# 3                                                 NaN
# 5                                                 NaN
# 7   "When training a 65B-parameter model, our code...
# 9                                                 NaN
# 10                                                NaN
# 14  See p.5 of the paper: "We trained AlexaTM 20B ...
# 15                                                NaN
# 16                                                NaN
# 21                                                NaN
# 23                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 35                                                NaN
# 38                                                NaN
# 39                                                NaN
# 41                                                NaN
# 42                                                NaN
# 44                                                NaN
# 45                                                NaN
# 49                                                NaN
# 51                                            84 days
# 52                                                NaN
#
#                 Training hardware                  Approach  \
# 2                             NaN                       NaN
# 3                NVIDIA H100 SXM5                       NaN
# 5                             NaN                       NaN
# 7                     NVIDIA A100                Supervised
# 9                             NaN                       NaN
# 10                            NaN  Self-supervised learning
# 14                            NaN                       NaN
# 15                            NaN                       NaN
# 16                            NaN  Self-supervised learning
# 21                            NaN                       NaN
# 23                            NaN  Self-supervised learning
# 26                            NaN  Self-supervised learning
# 27                            NaN                       NaN
# 28                            NaN                       NaN
# 29                            NaN                       NaN
# 30                            NaN                       NaN
# 31                            NaN                       NaN
# 32                            NaN                       NaN
# 35                            NaN                       NaN
# 38                            NaN  Self-supervised learning
# 39   NVIDIA Tesla V100 DGXS 32 GB                       NaN
# 41                            NaN  Self-supervised learning
# 42                            NaN                       NaN
# 44                            NaN                       NaN
# 45                            NaN                       NaN
# 49  NVIDIA Tesla V100S PCIe 32 GB                       NaN
# 51                    NVIDIA A100  Self-supervised learning
# 52                            NaN                       NaN
#
#    Training compute cost (2020 USD)  \
# 2                               NaN
# 3                               NaN
# 5                               NaN
# 7                        1179384.75
# 9                               NaN
# 10                              NaN
# 14                              NaN
# 15                         39175.64
# 16                       3267257.75
# 21                              NaN
# 23                           320.00
# 26                       3232806.53
# 27                        753491.58
# 28                        484957.20
# 29                        202407.46
# 30                              NaN
# 31                              NaN
# 32                              NaN
# 35                              NaN
# 38                       3046994.09
# 39                              NaN
# 41                              NaN
# 42                              NaN
# 44                          8632.11
# 45                              NaN
# 49                              NaN
# 51                              NaN
# 52                              NaN
#
#                                    Compute cost notes  \
# 2                                                 NaN
# 3                                                 NaN
# 5   PaLM 2 was trained on TPU v4 according to the ...
# 7   1023384 processor-hours on A100 GPUs. May 2023...
# 9                                                 NaN
# 10                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 21                                                NaN
# 23                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 35                                                NaN
# 38                                                NaN
# 39                                                NaN
# 41                                                NaN
# 42                                                NaN
# 44                                                NaN
# 45                                                NaN
# 49                                                NaN
# 51                                                NaN
# 52                                                NaN
#
#    Self-supervised training Compute Sponsor Categorization Epistemic status  \
# 2                       NaN                            NaN       Unverified
# 3                       NaN                       Industry      Speculative
# 5                       NaN                       Industry              NaN
# 7                       NaN                       Industry           Likely
# 9                       NaN                            NaN      Speculative
# 10                      Yes                            NaN              NaN
# 14                      NaN                       Industry              NaN
# 15                      Yes                       Industry              NaN
# 16                      Yes                       Industry              NaN
# 21                      NaN                       Industry              NaN
# 23                      Yes                       Industry              NaN
# 26                      Yes                       Industry              NaN
# 27                      Yes                       Industry              NaN
# 28                      Yes                       Industry              NaN
# 29                      Yes                       Industry              NaN
# 30                      Yes                       Industry              NaN
# 31                      Yes                       Industry              NaN
# 32                      Yes                       Industry              NaN
# 35                      Yes                       Industry              NaN
# 38                      Yes                       Industry              NaN
# 39                      NaN                       Industry           Likely
# 41                      NaN                       Industry              NaN
# 42                      NaN                       Industry              NaN
# 44                      Yes                       Industry              NaN
# 45                      Yes                       Industry              NaN
# 49                      NaN                            NaN           Likely
# 51                      Yes                       Industry           Likely
# 52                      NaN                       Industry              NaN
#
#                                              Abstract        Last Modified
# 2                                                 NaN  2023-07-05 16:08:00
# 3   Large language models (LLMs) based on the Tran...  2023-06-27 15:14:23
# 5   We introduce PaLM 2, a new state-of-the-art la...  2023-08-10 15:21:27
# 7   We introduce LLaMA, a collection of foundation...  2023-07-28 16:26:34
# 9                                                 NaN  2023-08-15 17:42:35
# 10                                                NaN  2023-08-04 13:13:07
# 14  In this work, we demonstrate that multilingual...  2023-06-08 00:39:43
# 15  Driven by the goal of eradicating language bar...  2023-05-29 20:51:04
# 16  Language models have achieved remarkable perfo...  2023-08-10 15:22:32
# 21                                                NaN  2023-08-11 19:08:43
# 23  All-MLP architectures have attracted increasin...  2023-08-01 10:07:00
# 26  Large language models have been shown to achie...  2023-08-11 19:08:06
# 27  We investigate the optimal model size and numb...  2023-05-29 20:51:04
# 28  We present LaMDA: Language Models for Dialog A...  2023-05-30 18:54:45
# 29                                                NaN  2023-05-29 20:51:04
# 30                                                NaN  2023-05-29 20:51:04
# 31                                                NaN  2023-05-29 20:51:04
# 32                                                NaN  2023-05-29 20:51:04
# 35                                                NaN  2023-05-29 20:51:04
# 38  Pretrained general-purpose language models can...  2023-08-15 14:40:57
# 39  To explore the limit of dialogue generation pr...  2023-06-09 15:44:34
# 41  This paper explores a simple method for improv...  2023-08-11 19:07:14
# 42                                                NaN  2023-06-08 00:39:43
# 44  Self-supervised approaches for speech represen...  2023-05-29 20:51:04
# 45                                                NaN  2023-05-29 20:51:04
# 49  Learning high-quality sentence representations...  2023-06-21 19:04:47
# 51  Large language models have led to state-of-the...  2023-08-15 17:12:01
# 52                                                NaN  2023-06-08 00:39:43
#
# [28 rows x 33 columns]

# %%
notable_recent_language_works = []
for i, row in notable_recent_language_df.iterrows():
    title = row['Reference']
    print('Reference:', title)
    # Remove commas to avoid issues with query parsing
    search_title = title.replace(',', '')
    search_results = Works().search_filter(title=search_title).get()
    if len(search_results) > 0:
        for result in search_results:
            if result['title'].lower() == title.lower():
                print("Matched title: ", result['title'])
                notable_recent_language_works.append(result)

        # top_result = search_results[0]
        # print("Top result: ", top_result['title'])
        # # Check relevance of result is high enough
        # if len(search_results) > 1 and top_result.get('relevance_score') is not None:
        #     print("Relevance score: ", top_result['relevance_score'])
        #     # Factor out the number of citations - we want to match on the title
        #     match_score = top_result['relevance_score'] / top_result['cited_by_count']**0.5
        #     print("Match score: ", match_score)
        #     if match_score >= 50:
        #         notable_recent_language_works.append(top_result)
        # else:
        #     notable_recent_language_works.append(top_result)
    print()
# Out:
# Reference: Introducing ERNIE 3.5: Baidu’s Knowledge-Enhanced Foundation Model Takes a Giant Leap Forward
#
# Reference: Inflection-1 technical memo
#
# Reference: PaLM 2 Technical Report
# Matched title:  PaLM 2 Technical Report
#
# Reference: LLaMA: Open and Efficient Foundation Language Models
# Matched title:  LLaMA: Open and Efficient Foundation Language Models
#
# Reference: ALM 1.0
#
# Reference: BigScience Large Open-science Open-access Multilingual Language Model
#
# Reference: AlexaTM 20B: Few-Shot Learning Using a Large-Scale Multilingual Seq2Seq Model
#
# Reference: No Language Left Behind: Scaling Human-Centered Machine Translation
# Matched title:  No Language Left Behind: Scaling Human-Centered Machine Translation
#
# Reference: Solving Quantitative Reasoning Problems with Language Models
# Matched title:  Solving Quantitative Reasoning Problems with Language Models
#
# Reference: Unifying Language Learning Paradigms
#
# Reference: Efficient Language Modeling with Sparse all-MLP
# Matched title:  Efficient Language Modeling with Sparse all-MLP
#
# Reference: PaLM: Scaling Language Modeling with Pathways
# Matched title:  PaLM: Scaling Language Modeling with Pathways
#
# Reference: Training Compute-Optimal Large Language Models
# Matched title:  Training Compute-Optimal Large Language Models
#
# Reference: LaMDA: Language Models for Dialog Applications
# Matched title:  LaMDA: Language Models for Dialog Applications
#
# Reference: Announcing GPT- NeoX- 20B
#
# Reference: Competition-Level Code Generation with AlphaCode
# Matched title:  Competition-Level Code Generation with AlphaCode
#
# Reference: Training language models to follow instructions with human feedback
# Matched title:  Training language models to follow instructions with human feedback
#
# Reference: Data2vec: A General Framework for Self-supervised Learning in Speech, Vision and Language
#
# Reference: Few-shot Learning with Multilingual Language Models
# Matched title:  Few-shot Learning with Multilingual Language Models
#
# Reference: Using DeepSpeed and Megatron to Train Megatron-Turing NLG 530B, the World’s Largest and Most Powerful Generative Language Model
#
# Reference: PLATO-XL: Exploring the Large-scale Pre-training of Dialogue Generation
# Matched title:  PLATO-XL: Exploring the Large-scale Pre-training of Dialogue Generation
#
# Reference: FINETUNED LANGUAGE MODELS ARE ZERO-SHOT LEARNERS
# Matched title:  Finetuned Language Models Are Zero-Shot Learners
# Matched title:  Finetuned Language Models Are Zero-Shot Learners
#
# Reference: Larger-Scale Transformers for Multilingual Masked Language Modeling
# Matched title:  Larger-Scale Transformers for Multilingual Masked Language Modeling
# Matched title:  Larger-Scale Transformers for Multilingual Masked Language Modeling
# Matched title:  Larger-Scale Transformers for Multilingual Masked Language Modeling
#
# Reference: HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units
# Matched title:  HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units
# Matched title:  HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units
#
# Reference: Evaluating Large Language Models Trained on Code
# Matched title:  Evaluating Large Language Models Trained on Code
#
# Reference: ConSERT: A contrastive framework for self-supervised sentence representation transfer
# Matched title:  ConSERT: A Contrastive Framework for Self-Supervised Sentence Representation Transfer
#
# Reference: Efficient Large-Scale Language Model Training on GPU Clusters
# Matched title:  Efficient Large-Scale Language Model Training on GPU Clusters
#
# Reference: Recipes for building an open-domain chatbot
# Matched title:  Recipes for building an open-domain chatbot
# Matched title:  Recipes for Building an Open-Domain Chatbot
# Matched title:  Recipes for building an open-domain chatbot

# %%
print(len(notable_recent_language_works), 'works')
for work in notable_recent_language_works:
    print(work['display_name'])
# Out:
# 25 works
# PaLM 2 Technical Report
# LLaMA: Open and Efficient Foundation Language Models
# No Language Left Behind: Scaling Human-Centered Machine Translation
# Solving Quantitative Reasoning Problems with Language Models
# Efficient Language Modeling with Sparse all-MLP
# PaLM: Scaling Language Modeling with Pathways
# Training Compute-Optimal Large Language Models
# LaMDA: Language Models for Dialog Applications
# Competition-Level Code Generation with AlphaCode
# Training language models to follow instructions with human feedback
# Few-shot Learning with Multilingual Language Models
# PLATO-XL: Exploring the Large-scale Pre-training of Dialogue Generation
# Finetuned Language Models Are Zero-Shot Learners
# Finetuned Language Models Are Zero-Shot Learners
# Larger-Scale Transformers for Multilingual Masked Language Modeling
# Larger-Scale Transformers for Multilingual Masked Language Modeling
# Larger-Scale Transformers for Multilingual Masked Language Modeling
# HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units
# HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units
# Evaluating Large Language Models Trained on Code
# ConSERT: A Contrastive Framework for Self-Supervised Sentence Representation Transfer
# Efficient Large-Scale Language Model Training on GPU Clusters
# Recipes for building an open-domain chatbot
# Recipes for Building an Open-Domain Chatbot
# Recipes for building an open-domain chatbot

# %%
algorithm_occurences = defaultdict(list)

# %% [markdown]
# - For each work in `notable_works`
#   - Fetch the list of references
#   - For each reference
#     - If its ID is in `algorithm_origin_works`
#     - Append the ID of the work to the occurrence dict

# %%
for work in notable_recent_language_works:
    print(work['display_name'])
    # Fetch the list of references
    references = work['referenced_works']
    if len(references) == 0:
        print('No references found')
        continue
    for reference_work_id in references:
        if reference_work_id in origin_affiliation.keys():
            algorithm_occurences[reference_work_id].append(work['id'])
# Out:
# PaLM 2 Technical Report
# No references found
# LLaMA: Open and Efficient Foundation Language Models
# No references found
# No Language Left Behind: Scaling Human-Centered Machine Translation
# No references found
# Solving Quantitative Reasoning Problems with Language Models
# No references found
# Efficient Language Modeling with Sparse all-MLP
# No references found
# PaLM: Scaling Language Modeling with Pathways
# No references found
# Training Compute-Optimal Large Language Models
# No references found
# LaMDA: Language Models for Dialog Applications
# No references found
# Competition-Level Code Generation with AlphaCode
# No references found
# Training language models to follow instructions with human feedback
# No references found
# Few-shot Learning with Multilingual Language Models
# No references found
# PLATO-XL: Exploring the Large-scale Pre-training of Dialogue Generation
# Finetuned Language Models Are Zero-Shot Learners
# Finetuned Language Models Are Zero-Shot Learners
# No references found
# Larger-Scale Transformers for Multilingual Masked Language Modeling
# Larger-Scale Transformers for Multilingual Masked Language Modeling
# Larger-Scale Transformers for Multilingual Masked Language Modeling
# No references found
# HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units
# HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units
# Evaluating Large Language Models Trained on Code
# ConSERT: A Contrastive Framework for Self-Supervised Sentence Representation Transfer
# Efficient Large-Scale Language Model Training on GPU Clusters
# Recipes for building an open-domain chatbot
# Recipes for Building an Open-Domain Chatbot
# Recipes for building an open-domain chatbot
# No references found

# %%
algorithm_occurences
# Out:
# defaultdict(list,
#             {'https://openalex.org/W2896457183': ['https://openalex.org/W3200128700'],
#              'https://openalex.org/W2964121744': ['https://openalex.org/W3200128700',
#               'https://openalex.org/W3155584966'],
#              'https://openalex.org/W3001279689': ['https://openalex.org/W3200128700',
#               'https://openalex.org/W3177813494',
#               'https://openalex.org/W3023786569',
#               'https://openalex.org/W3155584966'],
#              'https://openalex.org/W2963403868': ['https://openalex.org/W3185293939',
#               'https://openalex.org/W3159134453',
#               'https://openalex.org/W3023786569',
#               'https://openalex.org/W3155584966'],
#              'https://openalex.org/W1522301498': ['https://openalex.org/W3169320628',
#               'https://openalex.org/W3023786569'],
#              'https://openalex.org/W2626778328': ['https://openalex.org/W3177813494',
#               'https://openalex.org/W3153553004'],
#              'https://openalex.org/W2763421725': ['https://openalex.org/W3023786569']})

# %%
for algorithm_id, occurrence_ids in algorithm_occurences.items():
    print(Works()[algorithm_id]['display_name'])
    print([Works()[occurrence_id]['display_name'] for occurrence_id in occurrence_ids])
    print()
# Out:
# BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# ['PLATO-XL: Exploring the Large-scale Pre-training of Dialogue Generation']
#
# Adam: A Method for Stochastic Optimization
# ['PLATO-XL: Exploring the Large-scale Pre-training of Dialogue Generation', 'Recipes for Building an Open-Domain Chatbot']
#
# Scaling Laws for Neural Language Models
# ['PLATO-XL: Exploring the Large-scale Pre-training of Dialogue Generation', 'Evaluating Large Language Models Trained on Code', 'Recipes for building an open-domain chatbot', 'Recipes for Building an Open-Domain Chatbot']
#
# Attention is All you Need
# ['Larger-Scale Transformers for Multilingual Masked Language Modeling', 'Larger-Scale Transformers for Multilingual Masked Language Modeling', 'Recipes for building an open-domain chatbot', 'Recipes for Building an Open-Domain Chatbot']
#
# Adam: A Method for Stochastic Optimization
# ['HuBERT: Self-Supervised Speech Representation Learning by Masked Prediction of Hidden Units', 'Recipes for building an open-domain chatbot']
#
# Attention Is All You Need
# ['Evaluating Large Language Models Trained on Code', 'Efficient Large-Scale Language Model Training on GPU Clusters']
#
# Mixed Precision Training
# ['Recipes for building an open-domain chatbot']

# %%
w = Works().search_filter(title="Attention is all you need")
tmp = w.get()
tmp
# Out:
# [{'id': 'https://openalex.org/W2963403868',
#   'doi': None,
#   'title': 'Attention is All you Need',
#   'display_name': 'Attention is All you Need',
#   'relevance_score': 13292.191,
#   'publication_year': 2017,
#   'publication_date': '2017-06-12',
#   'ids': {'openalex': 'https://openalex.org/W2963403868', 'mag': '2963403868'},
#   'language': 'en',
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'https://arxiv.org/pdf/1706.03762v5',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': None,
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'proceedings-article',
#   'open_access': {'is_oa': False,
#    'oa_status': 'closed',
#    'oa_url': None,
#    'any_repository_has_fulltext': False},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5050626617',
#      'display_name': 'Ashish Vaswani',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5021878400',
#      'display_name': 'Noam Shazeer',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5005777963',
#      'display_name': 'Niki Parmar',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1174212',
#       'display_name': 'University of Southern California',
#       'ror': 'https://ror.org/03taz7m60',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5022416424',
#      'display_name': 'Jakob Uszkoreit',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5023448834',
#      'display_name': 'Llion Jones',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5079288315',
#      'display_name': 'Aidan N. Gomez',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5031789995',
#      'display_name': 'Lukasz Kaiser',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5045719436',
#      'display_name': 'Illia Polosukhin',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'institutions_distinct_count': 2,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 15587,
#   'biblio': {'volume': '30',
#    'issue': None,
#    'first_page': '5998',
#    'last_page': '6008'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C203005215',
#     'wikidata': 'https://www.wikidata.org/wiki/Q79798',
#     'display_name': 'Machine translation',
#     'level': 2,
#     'score': 0.86135995},
#    {'id': 'https://openalex.org/C622187',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3500773',
#     'display_name': 'BLEU',
#     'level': 3,
#     'score': 0.8548184},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.8509927},
#    {'id': 'https://openalex.org/C118505674',
#     'wikidata': 'https://www.wikidata.org/wiki/Q42586063',
#     'display_name': 'Encoder',
#     'level': 2,
#     'score': 0.7163659},
#    {'id': 'https://openalex.org/C148047603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1014612',
#     'display_name': 'Parallelizable manifold',
#     'level': 2,
#     'score': 0.6531005},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.6072661},
#    {'id': 'https://openalex.org/C149364088',
#     'wikidata': 'https://www.wikidata.org/wiki/Q185917',
#     'display_name': 'Translation (biology)',
#     'level': 4,
#     'score': 0.5975386},
#    {'id': 'https://openalex.org/C204321447',
#     'wikidata': 'https://www.wikidata.org/wiki/Q30642',
#     'display_name': 'Natural language processing',
#     'level': 1,
#     'score': 0.48719376},
#    {'id': 'https://openalex.org/C2778112365',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3511065',
#     'display_name': 'Sequence (biology)',
#     'level': 2,
#     'score': 0.4693989},
#    {'id': 'https://openalex.org/C28490314',
#     'wikidata': 'https://www.wikidata.org/wiki/Q189436',
#     'display_name': 'Speech recognition',
#     'level': 1,
#     'score': 0.45668876},
#    {'id': 'https://openalex.org/C57273362',
#     'wikidata': 'https://www.wikidata.org/wiki/Q576722',
#     'display_name': 'Decoding methods',
#     'level': 2,
#     'score': 0.4194127},
#    {'id': 'https://openalex.org/C11413529',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8366',
#     'display_name': 'Algorithm',
#     'level': 1,
#     'score': 0.21066764},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C105580179',
#     'wikidata': 'https://www.wikidata.org/wiki/Q188928',
#     'display_name': 'Messenger RNA',
#     'level': 3,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C104317684',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7187',
#     'display_name': 'Gene',
#     'level': 2,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': 0.0}],
#   'mesh': [],
#   'locations_count': 1,
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'https://arxiv.org/pdf/1706.03762v5',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': None,
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': None,
#   'sustainable_development_goals': [],
#   'grants': [],
#   'referenced_works_count': 0,
#   'referenced_works': [],
#   'related_works': ['https://openalex.org/W1902237438',
#    'https://openalex.org/W2064675550',
#    'https://openalex.org/W2095705004',
#    'https://openalex.org/W2101105183',
#    'https://openalex.org/W2108598243',
#    'https://openalex.org/W2130942839',
#    'https://openalex.org/W2153579005',
#    'https://openalex.org/W2154652894',
#    'https://openalex.org/W2157331557',
#    'https://openalex.org/W2163605009',
#    'https://openalex.org/W2194775991',
#    'https://openalex.org/W2250539671',
#    'https://openalex.org/W2525778437',
#    'https://openalex.org/W2962739339',
#    'https://openalex.org/W2962784628',
#    'https://openalex.org/W2963341956',
#    'https://openalex.org/W2964121744',
#    'https://openalex.org/W2964308564',
#    'https://openalex.org/W2965373594',
#    'https://openalex.org/W2970597249'],
#   'ngrams_url': 'https://api.openalex.org/works/W2963403868/ngrams',
#   'abstract_inverted_index': {'The': [0, 19],
#    'dominant': [1],
#    'sequence': [2],
#    'transduction': [3],
#    'models': [4, 23, 59],
#    'are': [5],
#    'based': [6, 41],
#    'on': [7, 52],
#    'complex': [8],
#    'recurrent': [9],
#    'orconvolutional': [10],
#    'neural': [11],
#    'networks': [12],
#    'in': [13],
#    'an': [14, 31],
#    'encoder': [15, 27],
#    'and': [16, 28, 49, 68],
#    'decoder': [17, 29],
#    'configuration.': [18],
#    'best': [20, 90],
#    'performing': [21],
#    'such': [22],
#    'also': [24],
#    'connect': [25],
#    'the': [26, 88, 102],
#    'through': [30],
#    'attentionm': [32],
#    'echanisms.': [33],
#    'We': [34],
#    'propose': [35],
#    'a': [36, 111],
#    'novel,': [37],
#    'simple': [38],
#    'network': [39],
#    'architecture': [40],
#    'solely': [42],
#    'onan': [43],
#    'attention': [44],
#    'mechanism,': [45],
#    'dispensing': [46],
#    'with': [47, 77, 105],
#    'recurrence': [48],
#    'convolutions': [50],
#    'entirely.Experiments': [51],
#    'two': [53],
#    'machine': [54],
#    'translation': [55],
#    'tasks': [56],
#    'show': [57],
#    'these': [58],
#    'to': [60],
#    'be': [61],
#    'superiorin': [62],
#    'quality': [63],
#    'while': [64],
#    'being': [65],
#    'more': [66],
#    'parallelizable': [67],
#    'requiring': [69],
#    'significantly': [70],
#    'less': [71],
#    'timeto': [72],
#    'train.': [73],
#    'Our': [74],
#    'single': [75],
#    'model': [76, 106],
#    '165': [78],
#    'million': [79],
#    'parameters,': [80],
#    'achieves': [81],
#    '27.5': [82],
#    'BLEU': [83, 112],
#    'onEnglish-to-German': [84],
#    'translation,': [85, 99],
#    'improving': [86],
#    'over': [87, 94],
#    'existing': [89],
#    'ensemble': [91],
#    'result': [92],
#    'by': [93, 107],
#    '1': [95],
#    'BLEU.': [96],
#    'On': [97],
#    'English-to-French': [98],
#    'we': [100],
#    'outperform': [101],
#    'previoussingle': [103],
#    'state-of-the-art': [104],
#    '0.7': [108],
#    'BLEU,': [109],
#    'achieving': [110],
#    'score': [113],
#    'of': [114],
#    '41.1.': [115]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2963403868',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 13},
#    {'year': 2022, 'cited_by_count': 205},
#    {'year': 2021, 'cited_by_count': 6273},
#    {'year': 2020, 'cited_by_count': 5523},
#    {'year': 2019, 'cited_by_count': 2975},
#    {'year': 2018, 'cited_by_count': 592},
#    {'year': 2017, 'cited_by_count': 19}],
#   'updated_date': '2023-08-13T00:52:25.323597',
#   'created_date': '2019-07-30'},
#  {'id': 'https://openalex.org/W2626778328',
#   'doi': None,
#   'title': 'Attention Is All You Need',
#   'display_name': 'Attention Is All You Need',
#   'relevance_score': 5878.7905,
#   'publication_year': 2017,
#   'publication_date': '2017-06-12',
#   'ids': {'openalex': 'https://openalex.org/W2626778328', 'mag': '2626778328'},
#   'language': 'en',
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'https://arxiv.org/pdf/1706.03762v5',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'posted-content',
#   'open_access': {'is_oa': False,
#    'oa_status': 'closed',
#    'oa_url': None,
#    'any_repository_has_fulltext': False},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5050626617',
#      'display_name': 'Ashish Vaswani',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5021878400',
#      'display_name': 'Noam Shazeer',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5005777963',
#      'display_name': 'Niki Parmar',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1174212',
#       'display_name': 'University of Southern California',
#       'ror': 'https://ror.org/03taz7m60',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5022416424',
#      'display_name': 'Jakob Uszkoreit',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5023448834',
#      'display_name': 'Llion Jones',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5079288315',
#      'display_name': 'Aidan N. Gomez',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5031789995',
#      'display_name': 'Lukasz Kaiser',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5045719436',
#      'display_name': 'Illia Polosukhin',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I1291425158',
#       'display_name': 'Google (United States)',
#       'ror': 'https://ror.org/00njsd438',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'institutions_distinct_count': 2,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 3053,
#   'biblio': {'volume': None,
#    'issue': None,
#    'first_page': None,
#    'last_page': None},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.85672426},
#    {'id': 'https://openalex.org/C203005215',
#     'wikidata': 'https://www.wikidata.org/wiki/Q79798',
#     'display_name': 'Machine translation',
#     'level': 2,
#     'score': 0.83671224},
#    {'id': 'https://openalex.org/C66322947',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11658',
#     'display_name': 'Transformer',
#     'level': 3,
#     'score': 0.77073336},
#    {'id': 'https://openalex.org/C622187',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3500773',
#     'display_name': 'BLEU',
#     'level': 3,
#     'score': 0.7233442},
#    {'id': 'https://openalex.org/C118505674',
#     'wikidata': 'https://www.wikidata.org/wiki/Q42586063',
#     'display_name': 'Encoder',
#     'level': 2,
#     'score': 0.64366007},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.61310196},
#    {'id': 'https://openalex.org/C148047603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1014612',
#     'display_name': 'Parallelizable manifold',
#     'level': 2,
#     'score': 0.52845216},
#    {'id': 'https://openalex.org/C186644900',
#     'wikidata': 'https://www.wikidata.org/wiki/Q194152',
#     'display_name': 'Parsing',
#     'level': 2,
#     'score': 0.5106223},
#    {'id': 'https://openalex.org/C137293760',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3621696',
#     'display_name': 'Language model',
#     'level': 2,
#     'score': 0.49619204},
#    {'id': 'https://openalex.org/C204321447',
#     'wikidata': 'https://www.wikidata.org/wiki/Q30642',
#     'display_name': 'Natural language processing',
#     'level': 1,
#     'score': 0.49199364},
#    {'id': 'https://openalex.org/C57273362',
#     'wikidata': 'https://www.wikidata.org/wiki/Q576722',
#     'display_name': 'Decoding methods',
#     'level': 2,
#     'score': 0.48863536},
#    {'id': 'https://openalex.org/C2780451532',
#     'wikidata': 'https://www.wikidata.org/wiki/Q759676',
#     'display_name': 'Task (project management)',
#     'level': 2,
#     'score': 0.4849508},
#    {'id': 'https://openalex.org/C81363708',
#     'wikidata': 'https://www.wikidata.org/wiki/Q17084460',
#     'display_name': 'Convolutional neural network',
#     'level': 2,
#     'score': 0.4228912},
#    {'id': 'https://openalex.org/C28490314',
#     'wikidata': 'https://www.wikidata.org/wiki/Q189436',
#     'display_name': 'Speech recognition',
#     'level': 1,
#     'score': 0.39373556},
#    {'id': 'https://openalex.org/C119857082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#     'display_name': 'Machine learning',
#     'level': 1,
#     'score': 0.36078966},
#    {'id': 'https://openalex.org/C11413529',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8366',
#     'display_name': 'Algorithm',
#     'level': 1,
#     'score': 0.1444417},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C187736073',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2920921',
#     'display_name': 'Management',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C165801399',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25428',
#     'display_name': 'Voltage',
#     'level': 2,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C162324750',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#     'display_name': 'Economics',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': 0.0}],
#   'mesh': [],
#   'locations_count': 1,
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'https://arxiv.org/pdf/1706.03762v5',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': 'submittedVersion',
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': None,
#   'sustainable_development_goals': [],
#   'grants': [],
#   'referenced_works_count': 28,
#   'referenced_works': ['https://openalex.org/W1632114991',
#    'https://openalex.org/W1810943226',
#    'https://openalex.org/W1902237438',
#    'https://openalex.org/W2113691817',
#    'https://openalex.org/W2126433015',
#    'https://openalex.org/W2139621418',
#    'https://openalex.org/W2163568299',
#    'https://openalex.org/W2194775991',
#    'https://openalex.org/W2259472270',
#    'https://openalex.org/W2289899728',
#    'https://openalex.org/W2514713644',
#    'https://openalex.org/W2525778437',
#    'https://openalex.org/W2545625743',
#    'https://openalex.org/W2594990650',
#    'https://openalex.org/W2605203995',
#    'https://openalex.org/W2612675303',
#    'https://openalex.org/W2613904329',
#    'https://openalex.org/W2949847915',
#    'https://openalex.org/W2951008357',
#    'https://openalex.org/W2951583185',
#    'https://openalex.org/W2952191002',
#    'https://openalex.org/W2952339051',
#    'https://openalex.org/W2962784628',
#    'https://openalex.org/W2963069010',
#    'https://openalex.org/W2963187627',
#    'https://openalex.org/W2963991316',
#    'https://openalex.org/W2964121744',
#    'https://openalex.org/W2964308564'],
#   'related_works': ['https://openalex.org/W1902237438',
#    'https://openalex.org/W2064675550',
#    'https://openalex.org/W2095705004',
#    'https://openalex.org/W2101105183',
#    'https://openalex.org/W2108598243',
#    'https://openalex.org/W2157331557',
#    'https://openalex.org/W2163605009',
#    'https://openalex.org/W2194775991',
#    'https://openalex.org/W2250539671',
#    'https://openalex.org/W2525778437',
#    'https://openalex.org/W2787560479',
#    'https://openalex.org/W2949888546',
#    'https://openalex.org/W2950133940',
#    'https://openalex.org/W2950577311',
#    'https://openalex.org/W2962784628',
#    'https://openalex.org/W2963091558',
#    'https://openalex.org/W2963341956',
#    'https://openalex.org/W2964121744',
#    'https://openalex.org/W2964308564',
#    'https://openalex.org/W2965373594'],
#   'ngrams_url': 'https://api.openalex.org/works/W2626778328/ngrams',
#   'abstract_inverted_index': {'The': [0, 18],
#    'dominant': [1],
#    'sequence': [2],
#    'transduction': [3],
#    'models': [4, 21, 60, 137],
#    'are': [5],
#    'based': [6, 41],
#    'on': [7, 43, 53, 82, 124],
#    'complex': [8],
#    'recurrent': [9],
#    'or': [10],
#    'convolutional': [11],
#    'neural': [12],
#    'networks': [13],
#    'in': [14, 64],
#    'an': [15, 29],
#    'encoder-decoder': [16],
#    'configuration.': [17],
#    'best': [19, 93, 136],
#    'performing': [20],
#    'also': [22],
#    'connect': [23],
#    'the': [24, 39, 83, 91, 102, 131, 135, 139, 144],
#    'encoder': [25],
#    'and': [26, 49, 70, 162],
#    'decoder': [27],
#    'through': [28],
#    'attention': [30, 44],
#    'mechanism.': [31],
#    'We': [32, 141],
#    'propose': [33],
#    'a': [34, 111, 127],
#    'new': [35, 112],
#    'simple': [36],
#    'network': [37],
#    'architecture,': [38],
#    'Transformer,': [40],
#    'solely': [42],
#    'mechanisms,': [45],
#    'dispensing': [46],
#    'with': [47, 160],
#    'recurrence': [48],
#    'convolutions': [50],
#    'entirely.': [51],
#    'Experiments': [52],
#    'two': [54],
#    'machine': [55],
#    'translation': [56, 87, 106],
#    'tasks': [57, 150],
#    'show': [58, 142],
#    'these': [59],
#    'to': [61, 75, 148, 155],
#    'be': [62],
#    'superior': [63],
#    'quality': [65],
#    'while': [66],
#    'being': [67],
#    'more': [68],
#    'parallelizable': [69],
#    'requiring': [71],
#    'significantly': [72],
#    'less': [73],
#    'time': [74],
#    'train.': [76],
#    'Our': [77],
#    'model': [78, 109],
#    'achieves': [79],
#    '28.4': [80],
#    'BLEU': [81, 115],
#    'WMT': [84, 103],
#    '2014': [85, 104],
#    'English-to-German': [86],
#    'task,': [88, 107],
#    'improving': [89],
#    'over': [90, 98],
#    'existing': [92],
#    'results,': [94],
#    'including': [95],
#    'ensembles': [96],
#    'by': [97, 151],
#    '2': [99],
#    'BLEU.': [100],
#    'On': [101],
#    'English-to-French': [105],
#    'our': [108],
#    'establishes': [110],
#    'single-model': [113],
#    'state-of-the-art': [114],
#    'score': [116],
#    'of': [117, 130, 134],
#    '41.8': [118],
#    'after': [119],
#    'training': [120, 132, 164],
#    'for': [121],
#    '3.5': [122],
#    'days': [123],
#    'eight': [125],
#    'GPUs,': [126],
#    'small': [128],
#    'fraction': [129],
#    'costs': [133],
#    'from': [138],
#    'literature.': [140],
#    'that': [143],
#    'Transformer': [145],
#    'generalizes': [146],
#    'well': [147],
#    'other': [149],
#    'applying': [152],
#    'it': [153],
#    'successfully': [154],
#    'English': [156],
#    'constituency': [157],
#    'parsing': [158],
#    'both': [159],
#    'large': [161],
#    'limited': [163],
#    'data.': [165]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2626778328',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 3},
#    {'year': 2022, 'cited_by_count': 42},
#    {'year': 2021, 'cited_by_count': 1253},
#    {'year': 2020, 'cited_by_count': 821},
#    {'year': 2019, 'cited_by_count': 505},
#    {'year': 2018, 'cited_by_count': 381},
#    {'year': 2017, 'cited_by_count': 52}],
#   'updated_date': '2023-08-16T14:03:34.384109',
#   'created_date': '2017-06-23'},
#  {'id': 'https://openalex.org/W3163652268',
#   'doi': 'https://doi.org/10.1109/icassp39728.2021.9413901',
#   'title': 'Attention Is All You Need In Speech Separation',
#   'display_name': 'Attention Is All You Need In Speech Separation',
#   'relevance_score': 1082.3658,
#   'publication_year': 2021,
#   'publication_date': '2021-06-06',
#   'ids': {'openalex': 'https://openalex.org/W3163652268',
#    'doi': 'https://doi.org/10.1109/icassp39728.2021.9413901',
#    'mag': '3163652268'},
#   'language': 'en',
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'https://doi.org/10.1109/icassp39728.2021.9413901',
#    'pdf_url': None,
#    'source': None,
#    'license': None,
#    'version': None,
#    'is_accepted': False,
#    'is_published': False},
#   'type': 'article',
#   'type_crossref': 'proceedings-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'green',
#    'oa_url': 'http://arxiv.org/pdf/2010.13154',
#    'any_repository_has_fulltext': True},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5023830739',
#      'display_name': 'Cem Subakan',
#      'orcid': 'https://orcid.org/0000-0002-7593-6589'},
#     'institutions': [{'id': 'https://openalex.org/I4210164802',
#       'display_name': 'Mila - Quebec Artificial Intelligence Institute',
#       'ror': 'https://ror.org/05c22rx21',
#       'country_code': 'CA',
#       'type': 'facility'}],
#     'countries': ['CA'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Mila-Quebec AI Institute,Canada',
#     'raw_affiliation_strings': ['Mila-Quebec AI Institute,Canada']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5040811098',
#      'display_name': 'Mirco Ravanelli',
#      'orcid': 'https://orcid.org/0000-0001-8479-3121'},
#     'institutions': [{'id': 'https://openalex.org/I4210164802',
#       'display_name': 'Mila - Quebec Artificial Intelligence Institute',
#       'ror': 'https://ror.org/05c22rx21',
#       'country_code': 'CA',
#       'type': 'facility'}],
#     'countries': ['CA'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Mila-Quebec AI Institute,Canada',
#     'raw_affiliation_strings': ['Mila-Quebec AI Institute,Canada']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5047682990',
#      'display_name': 'Samuele Cornell',
#      'orcid': 'https://orcid.org/0000-0002-5358-1844'},
#     'institutions': [{'id': 'https://openalex.org/I122534668',
#       'display_name': 'Marche Polytechnic University',
#       'ror': 'https://ror.org/00x69rs40',
#       'country_code': 'IT',
#       'type': 'education'}],
#     'countries': ['IT'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Università Politecnica delle Marche (Italy)',
#     'raw_affiliation_strings': ['Università Politecnica delle Marche (Italy)']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5028787566',
#      'display_name': 'Mirko Bronzi',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210164802',
#       'display_name': 'Mila - Quebec Artificial Intelligence Institute',
#       'ror': 'https://ror.org/05c22rx21',
#       'country_code': 'CA',
#       'type': 'facility'}],
#     'countries': ['CA'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Mila-Quebec AI Institute,Canada',
#     'raw_affiliation_strings': ['Mila-Quebec AI Institute,Canada']},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5063943539',
#      'display_name': 'Jianyuan Zhong',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I5388228',
#       'display_name': 'University of Rochester',
#       'ror': 'https://ror.org/022kthw22',
#       'country_code': 'US',
#       'type': 'education'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'University of Rochester  USA',
#     'raw_affiliation_strings': ['University of Rochester  USA']}],
#   'institutions_distinct_count': 3,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 136,
#   'biblio': {'volume': None,
#    'issue': None,
#    'first_page': None,
#    'last_page': None},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.8041918},
#    {'id': 'https://openalex.org/C147168706',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1457734',
#     'display_name': 'Recurrent neural network',
#     'level': 3,
#     'score': 0.7707248},
#    {'id': 'https://openalex.org/C66322947',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11658',
#     'display_name': 'Transformer',
#     'level': 3,
#     'score': 0.7162198},
#    {'id': 'https://openalex.org/C45374587',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12525525',
#     'display_name': 'Computation',
#     'level': 2,
#     'score': 0.63549817},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.4803756},
#    {'id': 'https://openalex.org/C110384440',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1143270',
#     'display_name': 'Upsampling',
#     'level': 3,
#     'score': 0.4537412},
#    {'id': 'https://openalex.org/C28490314',
#     'wikidata': 'https://www.wikidata.org/wiki/Q189436',
#     'display_name': 'Speech recognition',
#     'level': 1,
#     'score': 0.3888494},
#    {'id': 'https://openalex.org/C50644808',
#     'wikidata': 'https://www.wikidata.org/wiki/Q192776',
#     'display_name': 'Artificial neural network',
#     'level': 2,
#     'score': 0.3788163},
#    {'id': 'https://openalex.org/C11413529',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8366',
#     'display_name': 'Algorithm',
#     'level': 1,
#     'score': 0.20329899},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 0.08644009},
#    {'id': 'https://openalex.org/C165801399',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25428',
#     'display_name': 'Voltage',
#     'level': 2,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C119599485',
#     'wikidata': 'https://www.wikidata.org/wiki/Q43035',
#     'display_name': 'Electrical engineering',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C115961682',
#     'wikidata': 'https://www.wikidata.org/wiki/Q860623',
#     'display_name': 'Image (mathematics)',
#     'level': 2,
#     'score': 0.0}],
#   'mesh': [],
#   'locations_count': 2,
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'https://doi.org/10.1109/icassp39728.2021.9413901',
#     'pdf_url': None,
#     'source': None,
#     'license': None,
#     'version': None,
#     'is_accepted': False,
#     'is_published': False},
#    {'is_oa': True,
#     'landing_page_url': 'http://arxiv.org/abs/2010.13154',
#     'pdf_url': 'http://arxiv.org/pdf/2010.13154',
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': 'submittedVersion',
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': {'is_oa': True,
#    'landing_page_url': 'http://arxiv.org/abs/2010.13154',
#    'pdf_url': 'http://arxiv.org/pdf/2010.13154',
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'host_organization_lineage': ['https://openalex.org/I205783295'],
#     'host_organization_lineage_names': ['Cornell University'],
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion',
#    'is_accepted': False,
#    'is_published': False},
#   'sustainable_development_goals': [],
#   'grants': [],
#   'referenced_works_count': 19,
#   'referenced_works': ['https://openalex.org/W2064675550',
#    'https://openalex.org/W2127851351',
#    'https://openalex.org/W2221409856',
#    'https://openalex.org/W2460742184',
#    'https://openalex.org/W2734774145',
#    'https://openalex.org/W2794209590',
#    'https://openalex.org/W2903739847',
#    'https://openalex.org/W2952218014',
#    'https://openalex.org/W2963317762',
#    'https://openalex.org/W2963443859',
#    'https://openalex.org/W2964199361',
#    'https://openalex.org/W2972460025',
#    'https://openalex.org/W2972818416',
#    'https://openalex.org/W2981436548',
#    'https://openalex.org/W3015834770',
#    'https://openalex.org/W3016129867',
#    'https://openalex.org/W3094607766',
#    'https://openalex.org/W3095717210',
#    'https://openalex.org/W3096893582'],
#   'related_works': ['https://openalex.org/W2279739',
#    'https://openalex.org/W3011399',
#    'https://openalex.org/W4354089',
#    'https://openalex.org/W5683847',
#    'https://openalex.org/W6452702',
#    'https://openalex.org/W6882942',
#    'https://openalex.org/W7958345',
#    'https://openalex.org/W8459508',
#    'https://openalex.org/W13529535',
#    'https://openalex.org/W14899464'],
#   'ngrams_url': 'https://api.openalex.org/works/W3163652268/ngrams',
#   'abstract_inverted_index': {'Recurrent': [0],
#    'Neural': [1],
#    'Networks': [2],
#    '(RNNs)': [3],
#    'have': [4],
#    'long': [5],
#    'been': [6],
#    'the': [7, 49, 82, 106, 119, 138],
#    'dominant': [8],
#    'architecture': [9],
#    'in': [10],
#    'sequence-to-sequence': [11],
#    'learning.': [12],
#    'RNNs,': [13, 36],
#    'however,': [14],
#    'are': [15, 28],
#    'inherently': [16],
#    'sequential': [17],
#    'models': [18],
#    'that': [19, 71],
#    'do': [20],
#    'not': [21],
#    'allow': [22],
#    'parallelization': [23, 107],
#    'of': [24, 90, 98, 109, 125],
#    'their': [25],
#    'computations.': [26],
#    'Transformers': [27, 110],
#    'emerging': [29],
#    'as': [30],
#    'a': [31, 41, 51, 68, 113, 123],
#    'natural': [32],
#    'alternative': [33],
#    'to': [34],
#    'standard': [35, 83],
#    'replacing': [37],
#    'recurrent': [38],
#    'computations': [39],
#    'with': [40, 67, 143],
#    'multi-head': [42],
#    'attention': [43],
#    'mechanism.In': [44],
#    'this': [45],
#    'paper,': [46],
#    'we': [47],
#    'propose': [48],
#    'SepFormer,': [50],
#    'novel': [52],
#    'RNN-free': [53],
#    'Transformer-based': [54],
#    'neural': [55],
#    'network': [56],
#    'for': [57],
#    'speech': [58, 140],
#    'separation.': [59],
#    'The': [60, 74, 103],
#    'Sep-Former': [61],
#    'learns': [62],
#    'short': [63],
#    'and': [64, 95, 111, 132],
#    'long-term': [65],
#    'dependencies': [66],
#    'multi-scale': [69],
#    'approach': [70],
#    'employs': [72],
#    'transformers.': [73],
#    'proposed': [75],
#    'model': [76],
#    'achieves': [77, 112],
#    'state-of-the-art': [78],
#    '(SOTA)': [79],
#    'performance': [80, 115],
#    'on': [81, 93, 101],
#    'WSJ0-2/3mix': [84],
#    'datasets.': [85],
#    'It': [86, 127],
#    'reaches': [87],
#    'an': [88, 96],
#    'SI-SNRi': [89, 97],
#    '22.3': [91],
#    'dB': [92, 100],
#    'WSJ0-2mix': [94],
#    '19.5': [99],
#    'WSJ0-3mix.': [102],
#    'SepFormer': [104],
#    'inherits': [105],
#    'advantages': [108],
#    'competitive': [114],
#    'even': [116],
#    'when': [117],
#    'downsampling': [118],
#    'encoded': [120],
#    'representation': [121],
#    'by': [122],
#    'factor': [124],
#    '8.': [126],
#    'is': [128, 134],
#    'thus': [129],
#    'significantly': [130],
#    'faster': [131],
#    'it': [133],
#    'less': [135],
#    'memory-demanding': [136],
#    'than': [137],
#    'latest': [139],
#    'separation': [141],
#    'systems': [142],
#    'comparable': [144],
#    'performance.': [145]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W3163652268',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 57},
#    {'year': 2022, 'cited_by_count': 58},
#    {'year': 2021, 'cited_by_count': 19}],
#   'updated_date': '2023-08-13T08:45:46.875660',
#   'created_date': '2021-05-24'},
#  {'id': 'https://openalex.org/W2997150500',
#   'doi': 'https://doi.org/10.1609/aaai.v34i07.6693',
#   'title': 'Channel Attention Is All You Need for Video Frame Interpolation',
#   'display_name': 'Channel Attention Is All You Need for Video Frame Interpolation',
#   'relevance_score': 945.84607,
#   'publication_year': 2020,
#   'publication_date': '2020-04-03',
#   'ids': {'openalex': 'https://openalex.org/W2997150500',
#    'doi': 'https://doi.org/10.1609/aaai.v34i07.6693',
#    'mag': '2997150500'},
#   'language': 'en',
#   'primary_location': {'is_oa': True,
#    'landing_page_url': 'https://doi.org/10.1609/aaai.v34i07.6693',
#    'pdf_url': 'https://ojs.aaai.org/index.php/AAAI/article/download/6693/6547',
#    'source': {'id': 'https://openalex.org/S4210191458',
#     'display_name': 'Proceedings of the ... AAAI Conference on Artificial Intelligence',
#     'issn_l': '2159-5399',
#     'issn': ['2159-5399', '2374-3468'],
#     'is_oa': True,
#     'is_in_doaj': False,
#     'host_organization': None,
#     'host_organization_name': None,
#     'host_organization_lineage': [],
#     'host_organization_lineage_names': [],
#     'type': 'conference'},
#    'license': None,
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   'type': 'article',
#   'type_crossref': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'gold',
#    'oa_url': 'https://ojs.aaai.org/index.php/AAAI/article/download/6693/6547',
#    'any_repository_has_fulltext': False},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5031461471',
#      'display_name': 'Myungsub Choi',
#      'orcid': 'https://orcid.org/0000-0003-4731-3074'},
#     'institutions': [{'id': 'https://openalex.org/I139264467',
#       'display_name': 'Seoul National University',
#       'ror': 'https://ror.org/04h9pn542',
#       'country_code': 'KR',
#       'type': 'education'}],
#     'countries': ['KR'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Seoul National Univ.#TAB#',
#     'raw_affiliation_strings': ['Seoul National Univ.#TAB#']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5003678844',
#      'display_name': 'Heewon Kim',
#      'orcid': 'https://orcid.org/0000-0002-1341-8962'},
#     'institutions': [{'id': 'https://openalex.org/I139264467',
#       'display_name': 'Seoul National University',
#       'ror': 'https://ror.org/04h9pn542',
#       'country_code': 'KR',
#       'type': 'education'}],
#     'countries': ['KR'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Seoul National Univ.#TAB#',
#     'raw_affiliation_strings': ['Seoul National Univ.#TAB#']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5006594639',
#      'display_name': 'Bohyung Han',
#      'orcid': 'https://orcid.org/0000-0003-3099-3616'},
#     'institutions': [{'id': 'https://openalex.org/I139264467',
#       'display_name': 'Seoul National University',
#       'ror': 'https://ror.org/04h9pn542',
#       'country_code': 'KR',
#       'type': 'education'}],
#     'countries': ['KR'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Seoul National Univ.#TAB#',
#     'raw_affiliation_strings': ['Seoul National Univ.#TAB#']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5040143669',
#      'display_name': 'Ning Xu',
#      'orcid': 'https://orcid.org/0000-0001-8336-5926'},
#     'institutions': [{'id': 'https://openalex.org/I1311688040',
#       'display_name': 'Amazon (United States)',
#       'ror': 'https://ror.org/04mv4n011',
#       'country_code': 'US',
#       'type': 'company'}],
#     'countries': ['US'],
#     'is_corresponding': False,
#     'raw_affiliation_string': '[Amazon Go]',
#     'raw_affiliation_strings': ['[Amazon Go]']},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5046504049',
#      'display_name': 'Kyoung Mu Lee',
#      'orcid': 'https://orcid.org/0000-0001-7210-1036'},
#     'institutions': [{'id': 'https://openalex.org/I139264467',
#       'display_name': 'Seoul National University',
#       'ror': 'https://ror.org/04h9pn542',
#       'country_code': 'KR',
#       'type': 'education'}],
#     'countries': ['KR'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Seoul National Univ.#TAB#',
#     'raw_affiliation_strings': ['Seoul National Univ.#TAB#']}],
#   'institutions_distinct_count': 2,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': None,
#   'apc_paid': None,
#   'cited_by_count': 121,
#   'biblio': {'volume': '34',
#    'issue': '07',
#    'first_page': '10663',
#    'last_page': '10671'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.7710172},
#    {'id': 'https://openalex.org/C155542232',
#     'wikidata': 'https://www.wikidata.org/wiki/Q736111',
#     'display_name': 'Optical flow',
#     'level': 3,
#     'score': 0.7542856},
#    {'id': 'https://openalex.org/C137800194',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11713455',
#     'display_name': 'Interpolation (computer graphics)',
#     'level': 3,
#     'score': 0.70001215},
#    {'id': 'https://openalex.org/C127162648',
#     'wikidata': 'https://www.wikidata.org/wiki/Q16858953',
#     'display_name': 'Channel (broadcasting)',
#     'level': 2,
#     'score': 0.69493765},
#    {'id': 'https://openalex.org/C72560505',
#     'wikidata': 'https://www.wikidata.org/wiki/Q204510',
#     'display_name': 'Motion interpolation',
#     'level': 5,
#     'score': 0.6943482},
#    {'id': 'https://openalex.org/C126042441',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1324888',
#     'display_name': 'Frame (networking)',
#     'level': 2,
#     'score': 0.6751437},
#    {'id': 'https://openalex.org/C2776401178',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12050496',
#     'display_name': 'Feature (linguistics)',
#     'level': 2,
#     'score': 0.5814621},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.5811527},
#    {'id': 'https://openalex.org/C185798385',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1161707',
#     'display_name': 'Benchmark (surveying)',
#     'level': 2,
#     'score': 0.5786351},
#    {'id': 'https://openalex.org/C31972630',
#     'wikidata': 'https://www.wikidata.org/wiki/Q844240',
#     'display_name': 'Computer vision',
#     'level': 1,
#     'score': 0.5598151},
#    {'id': 'https://openalex.org/C168167062',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1117970',
#     'display_name': 'Component (thermodynamics)',
#     'level': 2,
#     'score': 0.55353236},
#    {'id': 'https://openalex.org/C10161872',
#     'wikidata': 'https://www.wikidata.org/wiki/Q557891',
#     'display_name': 'Motion estimation',
#     'level': 2,
#     'score': 0.54152817},
#    {'id': 'https://openalex.org/C45374587',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12525525',
#     'display_name': 'Computation',
#     'level': 2,
#     'score': 0.5403623},
#    {'id': 'https://openalex.org/C104114177',
#     'wikidata': 'https://www.wikidata.org/wiki/Q79782',
#     'display_name': 'Motion (physics)',
#     'level': 2,
#     'score': 0.51025224},
#    {'id': 'https://openalex.org/C167510206',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2835824',
# ...
#    'quickly': [247],
#    'degenerates': [248],
#    'rank-1': [251],
#    'matrix,': [252],
#    'may': [256],
#    'another': [258],
#    'cure': [259],
#    'trend.': [262]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4206455206',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 2},
#    {'year': 2022, 'cited_by_count': 6}],
#   'updated_date': '2023-08-18T02:11:19.134596',
#   'created_date': '2022-01-25'},
#  {'id': 'https://openalex.org/W4295846679',
#   'doi': 'https://doi.org/10.3390/info13090426',
#   'title': 'Fake News Spreaders Detection: Sometimes Attention Is Not All You Need',
#   'display_name': 'Fake News Spreaders Detection: Sometimes Attention Is Not All You Need',
#   'relevance_score': 63.97444,
#   'publication_year': 2022,
#   'publication_date': '2022-09-09',
#   'ids': {'openalex': 'https://openalex.org/W4295846679',
#    'doi': 'https://doi.org/10.3390/info13090426'},
#   'language': 'en',
#   'primary_location': {'is_oa': True,
#    'landing_page_url': 'https://doi.org/10.3390/info13090426',
#    'pdf_url': 'https://www.mdpi.com/2078-2489/13/9/426/pdf?version=1662718934',
#    'source': {'id': 'https://openalex.org/S4210219776',
#     'display_name': 'Information',
#     'issn_l': '2078-2489',
#     'issn': ['2078-2489'],
#     'is_oa': True,
#     'is_in_doaj': True,
#     'host_organization': 'https://openalex.org/P4310310987',
#     'host_organization_name': 'Multidisciplinary Digital Publishing Institute',
#     'host_organization_lineage': ['https://openalex.org/P4310310987'],
#     'host_organization_lineage_names': ['Multidisciplinary Digital Publishing Institute'],
#     'type': 'journal'},
#    'license': 'cc-by',
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   'type': 'article',
#   'type_crossref': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'gold',
#    'oa_url': 'https://www.mdpi.com/2078-2489/13/9/426/pdf?version=1662718934',
#    'any_repository_has_fulltext': True},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5016005510',
#      'display_name': 'Marco Siino',
#      'orcid': 'https://orcid.org/0000-0002-4453-5352'},
#     'institutions': [{'id': 'https://openalex.org/I900890020',
#       'display_name': 'University of Palermo',
#       'ror': 'https://ror.org/044k9ta02',
#       'country_code': 'IT',
#       'type': 'education'}],
#     'countries': ['IT'],
#     'is_corresponding': True,
#     'raw_affiliation_string': 'Department of Engineering, University of Palermo, 90128 Palermo, PA, Italy',
#     'raw_affiliation_strings': ['Department of Engineering, University of Palermo, 90128 Palermo, PA, Italy']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5011152166',
#      'display_name': 'Elisa Di Nuovo',
#      'orcid': 'https://orcid.org/0000-0002-4814-982X'},
#     'institutions': [{'id': 'https://openalex.org/I55143463',
#       'display_name': 'University of Turin',
#       'ror': 'https://ror.org/048tbm396',
#       'country_code': 'IT',
#       'type': 'education'}],
#     'countries': ['IT'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Dipartimento di Lingue e Letterature Straniere e Culture Moderne, University of Turin, 10124 Torino, TO, Italy',
#     'raw_affiliation_strings': ['Dipartimento di Lingue e Letterature Straniere e Culture Moderne, University of Turin, 10124 Torino, TO, Italy']},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5090983431',
#      'display_name': 'Ilenia Tinnirello',
#      'orcid': 'https://orcid.org/0000-0002-1305-0248'},
#     'institutions': [{'id': 'https://openalex.org/I900890020',
#       'display_name': 'University of Palermo',
#       'ror': 'https://ror.org/044k9ta02',
#       'country_code': 'IT',
#       'type': 'education'}],
#     'countries': ['IT'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Department of Engineering, University of Palermo, 90128 Palermo, PA, Italy',
#     'raw_affiliation_strings': ['Department of Engineering, University of Palermo, 90128 Palermo, PA, Italy']},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5001373862',
#      'display_name': 'Marco La Cascia',
#      'orcid': 'https://orcid.org/0000-0002-8766-6395'},
#     'institutions': [{'id': 'https://openalex.org/I900890020',
#       'display_name': 'University of Palermo',
#       'ror': 'https://ror.org/044k9ta02',
#       'country_code': 'IT',
#       'type': 'education'}],
#     'countries': ['IT'],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Department of Engineering, University of Palermo, 90128 Palermo, PA, Italy',
#     'raw_affiliation_strings': ['Department of Engineering, University of Palermo, 90128 Palermo, PA, Italy']}],
#   'institutions_distinct_count': 2,
#   'corresponding_author_ids': ['https://openalex.org/A5016005510'],
#   'corresponding_institution_ids': ['https://openalex.org/I900890020'],
#   'apc_list': {'value': 1400,
#    'currency': 'CHF',
#    'value_usd': 1515,
#    'provenance': 'doaj'},
#   'apc_paid': {'value': 1400,
#    'currency': 'CHF',
#    'value_usd': 1515,
#    'provenance': 'doaj'},
#   'cited_by_count': 6,
#   'biblio': {'volume': '13',
#    'issue': '9',
#    'first_page': '426',
#    'last_page': '426'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.83510435},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 0.6939965},
#    {'id': 'https://openalex.org/C204321447',
#     'wikidata': 'https://www.wikidata.org/wiki/Q30642',
#     'display_name': 'Natural language processing',
#     'level': 1,
#     'score': 0.6317978},
#    {'id': 'https://openalex.org/C66322947',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11658',
#     'display_name': 'Transformer',
#     'level': 3,
#     'score': 0.58171713},
#    {'id': 'https://openalex.org/C2779231336',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7534724',
#     'display_name': 'Sketch',
#     'level': 2,
#     'score': 0.49518672},
#    {'id': 'https://openalex.org/C108583219',
#     'wikidata': 'https://www.wikidata.org/wiki/Q197536',
#     'display_name': 'Deep learning',
#     'level': 2,
#     'score': 0.48250484},
#    {'id': 'https://openalex.org/C95623464',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1096149',
#     'display_name': 'Classifier (UML)',
#     'level': 2,
#     'score': 0.4486204},
#    {'id': 'https://openalex.org/C119857082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#     'display_name': 'Machine learning',
#     'level': 1,
#     'score': 0.44455773},
#    {'id': 'https://openalex.org/C12267149',
#     'wikidata': 'https://www.wikidata.org/wiki/Q282453',
#     'display_name': 'Support vector machine',
#     'level': 2,
#     'score': 0.4295072},
#    {'id': 'https://openalex.org/C137293760',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3621696',
#     'display_name': 'Language model',
#     'level': 2,
#     'score': 0.41723648},
#    {'id': 'https://openalex.org/C43126263',
#     'wikidata': 'https://www.wikidata.org/wiki/Q128751',
#     'display_name': 'Source code',
#     'level': 2,
#     'score': 0.4104784},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C11413529',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8366',
#     'display_name': 'Algorithm',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C165801399',
#     'wikidata': 'https://www.wikidata.org/wiki/Q25428',
#     'display_name': 'Voltage',
#     'level': 2,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': 0.0}],
#   'mesh': [],
#   'locations_count': 2,
#   'locations': [{'is_oa': True,
#     'landing_page_url': 'https://doi.org/10.3390/info13090426',
#     'pdf_url': 'https://www.mdpi.com/2078-2489/13/9/426/pdf?version=1662718934',
#     'source': {'id': 'https://openalex.org/S4210219776',
#      'display_name': 'Information',
#      'issn_l': '2078-2489',
#      'issn': ['2078-2489'],
#      'is_oa': True,
#      'is_in_doaj': True,
#      'host_organization': 'https://openalex.org/P4310310987',
#      'host_organization_name': 'Multidisciplinary Digital Publishing Institute',
#      'host_organization_lineage': ['https://openalex.org/P4310310987'],
#      'host_organization_lineage_names': ['Multidisciplinary Digital Publishing Institute'],
#      'type': 'journal'},
#     'license': 'cc-by',
#     'version': 'publishedVersion',
#     'is_accepted': True,
#     'is_published': True},
#    {'is_oa': True,
#     'landing_page_url': 'http://hdl.handle.net/10447/568262',
#     'pdf_url': 'https://iris.unipa.it/bitstream/10447/568262/2/information-13-00426.pdf',
#     'source': {'id': 'https://openalex.org/S4306401065',
#      'display_name': 'Nova Science Publishers (Nova Science Publishers, Inc.)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': None,
#      'host_organization_name': None,
#      'host_organization_lineage': [],
#      'host_organization_lineage_names': [],
#      'type': 'repository'},
#     'license': 'cc-by',
#     'version': 'publishedVersion',
#     'is_accepted': True,
#     'is_published': True}],
#   'best_oa_location': {'is_oa': True,
#    'landing_page_url': 'https://doi.org/10.3390/info13090426',
#    'pdf_url': 'https://www.mdpi.com/2078-2489/13/9/426/pdf?version=1662718934',
#    'source': {'id': 'https://openalex.org/S4210219776',
#     'display_name': 'Information',
#     'issn_l': '2078-2489',
#     'issn': ['2078-2489'],
#     'is_oa': True,
#     'is_in_doaj': True,
#     'host_organization': 'https://openalex.org/P4310310987',
#     'host_organization_name': 'Multidisciplinary Digital Publishing Institute',
#     'host_organization_lineage': ['https://openalex.org/P4310310987'],
#     'host_organization_lineage_names': ['Multidisciplinary Digital Publishing Institute'],
#     'type': 'journal'},
#    'license': 'cc-by',
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   'sustainable_development_goals': [],
#   'grants': [],
#   'referenced_works_count': 32,
#   'referenced_works': ['https://openalex.org/W2070205520',
#    'https://openalex.org/W2149167588',
#    'https://openalex.org/W2153635508',
#    'https://openalex.org/W2158947497',
#    'https://openalex.org/W2742330194',
#    'https://openalex.org/W2775711157',
#    'https://openalex.org/W2785537800',
#    'https://openalex.org/W2788235048',
#    'https://openalex.org/W2790166049',
#    'https://openalex.org/W2791544114',
#    'https://openalex.org/W2911715381',
#    'https://openalex.org/W2925285378',
#    'https://openalex.org/W2952861497',
#    'https://openalex.org/W2954444514',
#    'https://openalex.org/W2981194182',
#    'https://openalex.org/W3023367181',
#    'https://openalex.org/W3034723486',
#    'https://openalex.org/W3121385255',
#    'https://openalex.org/W3121787084',
#    'https://openalex.org/W3125182500',
#    'https://openalex.org/W3130867177',
#    'https://openalex.org/W3154741768',
#    'https://openalex.org/W3169337282',
#    'https://openalex.org/W3189595867',
#    'https://openalex.org/W3196268181',
#    'https://openalex.org/W3201829457',
#    'https://openalex.org/W4200022165',
#    'https://openalex.org/W4200503161',
#    'https://openalex.org/W4211148787',
#    'https://openalex.org/W4286206444',
#    'https://openalex.org/W4287854647',
#    'https://openalex.org/W4288079542'],
#   'related_works': ['https://openalex.org/W2520775273',
#    'https://openalex.org/W2803710604',
#    'https://openalex.org/W3158264953',
#    'https://openalex.org/W4223943233',
#    'https://openalex.org/W4285106639',
#    'https://openalex.org/W4310989423',
#    'https://openalex.org/W4311106074',
#    'https://openalex.org/W4312200629',
#    'https://openalex.org/W4360585206',
#    'https://openalex.org/W4364306694'],
#   'ngrams_url': 'https://api.openalex.org/works/W4295846679/ngrams',
#   'abstract_inverted_index': {'Guided': [0],
#    'by': [1],
#    'a': [2, 11, 19, 76, 132, 156, 194],
#    'corpus': [3, 51, 173],
#    'linguistics': [4, 52, 174],
#    'approach,': [5],
#    'in': [6, 202],
#    'this': [7, 128, 203],
#    'article': [8],
#    'we': [9, 40, 63, 74, 130, 168],
#    'present': [10],
#    'comparative': [12, 77],
#    'evaluation': [13, 78],
#    'of': [14, 28, 114, 142, 154, 172],
#    'State-of-the-Art': [15],
#    '(SotA)': [16],
#    'models,': [17],
#    'with': [18],
#    'special': [20],
#    'focus': [21],
#    'on': [22, 66, 120, 216],
#    'Transformers,': [23],
#    'to': [24, 111, 125, 138, 209],
#    'address': [25],
#    'the': [26,
#     42,
#     47,
#     80,
#     107,
#     112,
#     121,
#     140,
#     143,
#     152,
#     160,
#     170,
#     189,
#     199,
#     206],
#    'task': [27, 197],
#    'Fake': [29, 36],
#    'News': [30],
#    'Spreaders': [31],
#    '(i.e.,': [32],
#    'users': [33],
#    'that': [34, 179],
#    'share': [35],
#    'News)': [37],
#    'detection.': [38],
#    'First,': [39],
#    'explore': [41],
#    'reference': [43],
#    'multilingual': [44],
#    'dataset': [45],
#    'for': [46, 69],
#    'considered': [48],
#    'task,': [49],
#    'exploiting': [50],
#    'techniques,': [53],
#    'such': [54],
#    'as': [55, 135, 198],
#    'chi-square': [56],
#    'test,': [57],
#    'keywords': [58],
#    'and': [59, 91, 94],
#    'Word': [60],
#    'Sketch.': [61],
#    'Second,': [62],
#    'perform': [64, 75],
#    'experiments': [65],
#    'several': [67],
#    'models': [68, 84, 97, 108, 183],
#    'Natural': [70],
#    'Language': [71],
#    'Processing.': [72],
#    'Third,': [73],
#    'using': [79],
#    'most': [81],
#    'recent': [82],
#    'Transformer-based': [83],
#    '(RoBERTa,': [85],
#    'DistilBERT,': [86],
#    'BERT,': [87],
#    'XLNet,': [88],
#    'ELECTRA,': [89],
#    'Longformer)': [90],
#    'other': [92],
#    'deep': [93, 182],
#    'non-deep': [95],
#    'SotA': [96],
#    '(CNN,': [98],
#    'MultiCNN,': [99],
#    'Bayes,': [100],
#    'SVM).': [101],
#    'The': [102],
#    'CNN': [103],
#    'tested': [104, 109],
#    'outperforms': [105],
#    'all': [106],
#    'and,': [110],
#    'best': [113, 145],
#    'our': [115, 211],
#    'knowledge,': [116],
#    'any': [117],
#    'existing': [118],
#    'approach': [119],
#    'same': [122],
#    'dataset.': [123],
#    'Fourth,': [124],
#    'better': [126],
#    'understand': [127],
#    'result,': [129],
#    'conduct': [131],
#    'post-hoc': [133],
#    'analysis': [134],
#    'an': [136, 165],
#    'attempt': [137],
#    'investigate': [139],
#    'behaviour': [141],
#    'presented': [144, 201],
#    'performing': [146],
#    'black-box': [147],
#    'model.': [148],
#    'This': [149],
#    'study': [150],
#    'highlights': [151],
#    'importance': [153],
#    'choosing': [155],
#    'suitable': [157],
#    'classifier': [158],
#    'given': [159],
#    'specific': [161],
#    'task.': [162],
#    'To': [163],
#    'make': [164],
#    'educated': [166],
#    'decision,': [167],
#    'propose': [169],
#    'use': [171],
#    'techniques.': [175],
#    'Our': [176],
#    'results': [177],
#    'suggest': [178],
#    'large': [180],
#    'pre-trained': [181],
#    'like': [184],
#    'Transformers': [185],
#    'are': [186],
#    'not': [187],
#    'necessarily': [188],
#    'first': [190],
#    'choice': [191],
#    'when': [192],
#    'addressing': [193],
#    'text': [195],
#    'classification': [196],
#    'one': [200],
#    'article.': [204],
#    'All': [205],
#    'code': [207],
#    'developed': [208],
#    'run': [210],
#    'tests': [212],
#    'is': [213],
#    'publicly': [214],
#    'available': [215],
#    'GitHub.': [217]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4295846679',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 6}],
#   'updated_date': '2023-08-12T02:00:05.668787',
#   'created_date': '2022-09-15'}]
